# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model 
from tensorflow.keras.layers import Dense, Flatten, Input, concatenate, Conv2D, MaxPool2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pyperclip
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import time

driver = webdriver.Chrome("chromedriver")
# 인스타그램 접속하기
driver.get("http://www.instargram.com")

#로딩하는데 시간이 걸릴 수 있으므로 3초간 대기
time.sleep(3)

# %%
# 인스타계정으로 로그인

# id, pass 입력
driver.find_element(By.NAME, "username").send_keys("bonobono3418@gmail.com")
driver.find_element(By.NAME, "password").send_keys("audgns12!@")

driver.find_element(By.XPATH, "//*[@id='loginForm']/div/div[3]/button/div").click()

# %%
driver.find_element(By.CLASS_NAME, "_ac8f").click()

# %%
driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [232], in <cell line: 1>()
# ----> 1 driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]").click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]"}
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00C7F243]
# 	(No symbol) [0x00C07FD1]
# 	(No symbol) [0x00AFD04D]
# 	(No symbol) [0x00B2C0B0]
# 	(No symbol) [0x00B2C22B]
# 	(No symbol) [0x00B5E612]
# 	(No symbol) [0x00B485D4]
# 	(No symbol) [0x00B5C9EB]
# 	(No symbol) [0x00B48386]
# 	(No symbol) [0x00B2163C]
# 	(No symbol) [0x00B2269D]
# 	GetHandleVerifier [0x00F19A22+2655074]
# 	GetHandleVerifier [0x00F0CA24+2601828]
# 	GetHandleVerifier [0x00D28C0A+619850]
# 	GetHandleVerifier [0x00D27830+614768]
# 	(No symbol) [0x00C105FC]
# 	(No symbol) [0x00C15968]
# 	(No symbol) [0x00C15A55]
# 	(No symbol) [0x00C2051B]
# 	BaseThreadInitThunk [0x75AF00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77C77BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77C77B8E+238]

# %%
def searching(word):
    url = 'https://www.instagram.com/explore/tags/'+word
    return url

# %%
word = '돈까스'
url = searching(word)
driver.get(url)

# %%
def click_first(driver):
    first = driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div/div[1]/div/div/div/div[1]/div[1]/div[2]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div[1]/div[2]").click()
    time.sleep(3)
click_first(driver)

# %%
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

like = soup.select('section._ae5m > div')[0].text[4:-1]
print(like)
# Out:
# 2483

# %%
import re
from bs4 import BeautifulSoup

def get_content(driver):

    # 1. 현재 게시글 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 2. 본문 내용 가져오기
    # 본문 내용이 없을 수 있으므로 예외 처리구문을 이용
    try:
        content = soup.select('div._a9zs > span')[0].text
    except:
        content = ' '

    # 3. 작성 일시, 좋아요 수 , 위치 정보 가져오기
    # 해쉬 태그는 정규 표현식을 이용해 가져온다.
    tags = re.findall(r'#[^\s#,\\]+', content)  

    #  좋아요 수 가져오기
    # 예외처리구문.
    try:
        like = soup.select('section._ae5m > div')[0].text[4:-1]
#         likes = soup.select('div._ae2s._ae3v._ae3w')[0].text[4:-1]
#         like = re.findall("^[0-9]+", likes)   
    except:
        like = 0
    # 계정 정보
    ID = soup.select('div._aaqt > div > div')[0].text
    # 4. 저장하기
    data = [content, like, ID, tags]
    return data

get_content(driver)
# Out:
# ['할아버지 할머니도 춤을 추게 만드는 곳이 있습니다.서울 강남구 대치동 은마상가에 위치한 돈가스 전문점에 방문했습니다.바로 오늘의 맛집 #할아버지돈까스할아버지돈까스는 최고령 셰프의 특제 소스가 뿌려진 돈가스 맛집으로 유명한 곳인데요.최현석 셰프도 방문한 이제는 따님이 물려받은 할아버지의 손맛이 궁금해서 방문하게 되었습니다.#돈가스추억의 돈까스로 불릴만한 리얼 경양식 돈가스입니다.대한민국 최고령 요리사의 비법이 담긴 돈가스라 기대가 되었는데요.식전에 스프부터 돈까스의 비주얼까지 너무나도 고전적인 느낌 가득한 돈가스였습니다.돈가스는 굉장히 큼지막하고 소스는 누가 봐도 직접 만드는 비주얼과 맛을 가지고 있습니다.소스의 맛은 너무 자극적이지 않고 부드러운 맛이었습니다.돈가스도 추억의 경양식 돈가스인데 잘 튀겨져서 그런지 굉장히 맛있었습니다.열심히 먹다가 혹시 살짝 느끼하다면 빨갛고 새콤달콤한 깍두기를 한 입 해주면 입안 가득 한국 느낌의 돈가스 완성입니다.서울 강남구 은마상가 근처에 방문할 일이 있다면 할아버지돈까스를 추천드립니다.[메뉴정보]🎈메뉴돈가스 11,000매운돈가스 11,000카레돈가스 13,000치즈돈가스 13,000스페셜 13,000생선가스 11,000카레스파게티 8,000스파게티 8,000카레라이스 10,000🟠서울_강남구 할아버지돈까스🟠서울 강남구 삼성로 212 은마아파트🟠매일 10:00~20:00🟠매주 일요일 휴무🟠Tel 02-565-2727🟠불펌 및 크롤링 금지 ⓒ굥플레이스#굥플_강남구 #굥플_대치역',
#  '2483',
#  'g.yoooong_place',
#  ['#할아버지돈까스할아버지돈까스는', '#돈가스추억의', '#굥플_강남구', '#굥플_대치역']]

# %%
def next_page1(driver):
    next_page = driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/div/div/div/div[1]/div/div/div").click()
    time.sleep(3)
next_page1(driver)

# %%
def next_page2(driver):
    next_page = driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/div/div/div/div[1]/div/div/div[2]").click()
    time.sleep(3)
next_page2(driver)

# %%
word = "피자"    #검색어
url = searching(word)

# 검색페이지 접속
driver.get(url)
time.sleep(7)

# 첫 번째 게시글 열기
click_first(driver)

#크롤링 결과를담을 리스트 생성
result = [ ]

# 여러 게시글 수집하기
target = 1000      # 크롤링할 게시글 수
for i in range(target):
    # 게시글 수집에 오류 발생시 5초 대기후, 다음 게시글로 넘어가도록 예외처리 구문 활용
    try:
        data = get_content(driver)    # 게시글 정보 가져오기
        result.append(data)
        if i == 0:
            next_page1(driver)
        else:
            next_page2(driver)
    except:
        time.sleep(5)
        if i == 0:
            next_page1(driver)
        else:
            next_page2(driver)

# %%
result = pd.DataFrame(result, columns=["Contents", "Like", "ID", "Tags"])
result
# Out:
#                                               Contents         Like  \
# 0    우리는 지금 월드클래스 명동피자의 시대에 살고있습니다!!카타르 월드컵보다 더욱 핫한...         1493
# 1    오늘 늦은 저녁은 피자🍕🍕💙도미노에서 피자 1+1 행사를 하길래저녁은 도미노에서 포...          101
# 2    ✅ 제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보 : 🚨🚨🚨🚨🚨🚨🚨🚨🚨(9/10...          681
# 3    광안리 #포르타나광안리 필수코스라는치즈+토핑 가득미국 감성 피자맛집🍕 오션뷰 보면서...         1191
# 4    🍕피자덕후가 강추하는 존맛 #피자 모음집🍕진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ@...         1309
# ..                                                 ...          ...
# 995  #선팔하면맞팔#긍정적인생각#여자가을룩#조녜#맞팔그램#맞팔하면선팔#시베리아횡단열차#밴...            2
# 996  #리그램 - @hjsc.co.kr by @get_regrammer[새해기념 '너의 ...            1
# 997  #대교#긍정적인생각#가을계절#일상스타그램#맞팔그램#먹는순간기절#먹팔해요#밴드로고#입...            6
# 998  #수유타투잘하는곳#데일리#데일리그램#맞팔로우#어린이집졸업#일상사진#선팔후맞팔#맞팔해...  저 좋아요를 눌러보세
# 999  #피자알볼로 #옥수수피자 #라지 27,000원 #피자알볼로옥수수피자 #옥수수 #피자...            2
#
#                      ID                                               Tags
# 0        st_foodfighter  [#명동피자, #명동피자동대문점, #피자맛집, #파스타맛집, #동대문맛집, #피자,...
# 1          10tia____a04                                                 []
# 2           gyeongboki_  [#리보스코피자제주도, #리보스코피자, #맛집경보_제주, #제주여행, #제주맛집, ...
# 3          todays_busan                             [#포르타나광안리, #오늘의부산_광안리]
# 4           honey_unni_  [#피자, #피자스쿨, #피자맛집, #피자추천, #피자맛집, #피자맛집추천, #야식...
# ..                  ...                                                ...
# 995             iyangca  [#선팔하면맞팔, #긍정적인생각, #여자가을룩, #조녜, #맞팔그램, #맞팔하면선팔...
# 996          sukskm1004  [#리그램, #hj중공업, #2023, #새해, #새해소망, #소망, #이루어지길,...
# 997         guggweongil  [#대교, #긍정적인생각, #가을계절, #일상스타그램, #맞팔그램, #먹는순간기절,...
# 998  nicolahunter384at7  [#수유타투잘하는곳, #데일리, #데일리그램, #맞팔로우, #어린이집졸업, #일상사...
# 999              dk0108  [#피자알볼로, #옥수수피자, #라지, #피자알볼로옥수수피자, #옥수수, #피자, ...
#
# [1000 rows x 4 columns]

# %%
## 워드 클라우드 생성을 위한 패키지
from wordcloud import WordCloud
## 워드클라우드 모양을 변형시키고자 하는 이미지 활용에 사용 패키지
from PIL import Image
## 그래프 출력 패키지
import matplotlib.pyplot as plt
## 수치 연산 패키지
import numpy as np
## 데이터 핸들링
import pandas as pd

# %%
result.head()
# Out:
#                                             Contents  Like              ID  \
# 0  우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493  st_foodfighter
# 1  오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101    10tia____a04
# 2    제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681     gyeongboki_
# 3  광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191    todays_busan
# 4   피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309     honey_unni_
#
#                                                 Tags
# 0  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1                                                 []
# 2  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3                         ['#포르타나광안리', '#오늘의부산_광안리']
# 4  ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...

# %%
result["Contents"] = result["Contents"].str.replace(pat=r'[^\w]', repl=r' ', regex=True)
result["Contents"]
# Out:
# 0      우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...
# 1      오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...
# 2        제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...
# 3      광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...
# 4       피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...
#                              ...
# 995     선팔하면맞팔 긍정적인생각 여자가을룩 조녜 맞팔그램 맞팔하면선팔 시베리아횡단열차 밴...
# 996     리그램    hjsc co kr by  get_regrammer 새해기념  너의 ...
# 997     대교 긍정적인생각 가을계절 일상스타그램 맞팔그램 먹는순간기절 먹팔해요 밴드로고 입...
# 998     수유타투잘하는곳 데일리 데일리그램 맞팔로우 어린이집졸업 일상사진 선팔후맞팔 맞팔해...
# 999     피자알볼로  옥수수피자  라지 27 000원  피자알볼로옥수수피자  옥수수  피자...
# Name: Contents, Length: 1000, dtype: object

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  1000 non-null   object
#  1   Like      1000 non-null   object
#  2   ID        1000 non-null   object
#  3   Tags      1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
result.iloc[12,1] = 0
result.iloc[12]
# Out:
# Contents    뿅감  결론은 치킨과 부대찌개       메타포션  메타포션커피플랜트  metapo...
# Like                                                      0.0
# ID                                                 metapotion
# Tags        ['#메타포션', '#메타포션커피플랜트', '#metapotion', '#메타보이'...
# Name: 12, dtype: object

# %%
old_range = {'Like' : {'저 좋아요를 눌러보세':0}}
result = result.replace(old_range)
result

# result2[result2['Like'] == '저 좋아요를 눌러보세']
# Out:
#                                               Contents  Like  \
# 0    우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493
# 1    오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101
# 2      제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681
# 3    광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191
# 4     피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309
# ..                                                 ...   ...
# 995   선팔하면맞팔 긍정적인생각 여자가을룩 조녜 맞팔그램 맞팔하면선팔 시베리아횡단열차 밴...     2
# 996   리그램    hjsc co kr by  get_regrammer 새해기념  너의 ...     1
# 997   대교 긍정적인생각 가을계절 일상스타그램 맞팔그램 먹는순간기절 먹팔해요 밴드로고 입...     6
# 998   수유타투잘하는곳 데일리 데일리그램 맞팔로우 어린이집졸업 일상사진 선팔후맞팔 맞팔해...     0
# 999   피자알볼로  옥수수피자  라지 27 000원  피자알볼로옥수수피자  옥수수  피자...     2
#
#                      ID                                               Tags
# 0        st_foodfighter  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1          10tia____a04                                                 []
# 2           gyeongboki_  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3          todays_busan                         ['#포르타나광안리', '#오늘의부산_광안리']
# 4           honey_unni_  ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...
# ..                  ...                                                ...
# 995             iyangca  ['#선팔하면맞팔', '#긍정적인생각', '#여자가을룩', '#조녜', '#맞팔그램...
# 996          sukskm1004  ['#리그램', '#hj중공업', '#2023', '#새해', '#새해소망', '#...
# 997         guggweongil  ['#대교', '#긍정적인생각', '#가을계절', '#일상스타그램', '#맞팔그램'...
# 998  nicolahunter384at7  ['#수유타투잘하는곳', '#데일리', '#데일리그램', '#맞팔로우', '#어린이...
# 999              dk0108  ['#피자알볼로', '#옥수수피자', '#라지', '#피자알볼로옥수수피자', '#옥...
#
# [1000 rows x 4 columns]

# %%
result.head()
# Out:
#                                             Contents  Like              ID  \
# 0  우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493  st_foodfighter
# 1  오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101    10tia____a04
# 2    제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681     gyeongboki_
# 3  광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191    todays_busan
# 4   피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309     honey_unni_
#
#                                                 Tags
# 0  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1                                                 []
# 2  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3                         ['#포르타나광안리', '#오늘의부산_광안리']
# 4  ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...

# %%
# 저장
result.to_csv("data/피자1.csv", encoding="utf-8", index=False)

# %%
# 불러오기
result = pd.read_csv("data/피자1.csv")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  1000 non-null   object
#  1   Like      1000 non-null   int64
#  2   ID        1000 non-null   object
#  3   Tags      1000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB

# %%
import time
from tqdm import tqdm_notebook

content_all = ''
for i in tqdm_notebook(range(len(result["Contents"]))):
    content_all = content_all + ' ' + result["Contents"].loc[i]
# Out:
# C:\Users\mhpark\AppData\Local\Temp\ipykernel_158184\1026978283.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(result["Contents"]))):
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
import re
content_all = re.sub('[^ㄱ-ㅣ가-힣 ]',"",content_all)
content_all
# Out:
# ' 우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한 피자집이 있다고해서 논란의 곳이 있다고 해서 왔다  미칠듯이 늘어나는 명동피자의 쫜득함부터 고소한 치즈의 풍미를 품고 있는 저 모습이 보이는가  또 사이드메뉴들의 환상적인 궁합은 왤케 잘 어울려지는지 이게 진정한 핵가족급 콤보라고 말할수 있는  명동피자 명동을 넘어 동대문으로 명동피자를 방문했다  명동피자가 현대시티아울렛 안으로 투입됨에 현대사장님은 두손두발 다들고 환대각이었을 것이다  피자부터 파스타  에이드까지 머하나 부족함이 없는 이곳  치즈 끝판왕 피자에 치즈폭포를 만들어 치즈가 엄청나게 올려져서 나오는데 진짜 장관이다 현재직영매장이 동대문점  명동점을 빼고도 왕십리와 신논현에도 있다는게   서울을 집어삼킬 예정인가    그냥 미국의 시카고에 있는 핫플 피자가게를 복붙시켜놓은듯한 퓔링은 뽀너스  동대문에 있는 존맛피자맛집인 명동피자를 함께 스푸파 종합 게시판으로 알아보자      스푸파의 종합 게시판        명동피자 메뉴판  치즈끝판왕피자     투움바로제파스타     만수르피자     명란오일파스타    가게 주소   서울 중구 을지로가 장충단로길  현대시티아울렛 지하층 가게 영업시간        인스타      너 피자계의 손흥민이라고 들어는 봤냐     그게 바로 명동피자야    명동피자동대문점  피자맛집  파스타맛집  동대문맛집  피자      스푸파동대문 오늘 늦은 저녁은 피자   도미노에서 피자   행사를 하길래저녁은 도미노에서 포장해와서 먹었어요 제가 좋아하는 블랙타이거 슈림프 블랙앵거스 스테이크랑 포테이토 리얼불고기 더블치즈엣지  다들 오늘 저녁은 맛있는 거 드셨나요  모두 오늘 밤도 햅삐하게 보내시길 바라욥    제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보              개 제주돌담 몸통으로 박살내고 가야하는 피자집이다 쬰득쫄깃한 톳도우 위에 제주스러운 토핑 한가득  제주 연동  리보스코피자제주도 리보스코피자의 도우는 해녀가 잡은 톳으로부드러우면서 쫄깃한 도우를 만들어 더 맛있는데요 현무암이 잔뜩 올려진 제주도이색  현무암치킨피자 녹진한 오징어 먹물로 반죽한 현무암치킨인데요   일반 반죽보다 더 바삭하고 녹진한 치킨피자조합  통새우가 가득찬 한라산 용암치즈  한라산용암피자 칠리소스옷 입은 새우 최고급 치즈 쫀득한 톳도우  삼위일체고요    제주에 오시면 꼭 한번 드셔보세요 리보스코피자에서 직접만든 수제맥주는 필수에요  리보스코피자        제주 제주시 수목원길         매주 월요일 휴무  주차장 매장문의  현무암치킨 피자     한라산용암 피자     리보스코 맥주    맛집경보제주  제주여행  제주맛집  제주도맛집  제주시맛집  연동맛집 제주피자맛집추천  제주피자맛집  피자맛집 광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서 먹는피맥 조합도 상당한데 퐁실퐁실한 도우에힙한 분위기까지 찢었다    오션뷰 치즈 쭈아압 피자 ㄱ 위치부산광역시 수영구 광안로번길  오늘의부산광안리  피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ  오늘 피맥하쟈                         더 많은 꿀팁을 알고 싶다면      피자스쿨  피자맛집  피자추천  피자맛집  피자맛집추천  야식메뉴추천  야식추천메뉴  배달맛집  배달맛집추천  고구마피자  치즈피자  피자메뉴  서울맛집추천 딩동댕동  가성비 피자학교 입학준비   피자스쿨 출석할 시간이양   피자 땡기는데 너무 비싸다구 ㅜㅜ갓성비 피자맛집 피자스쿨이 있짜나  갈릭소스 추가는 필수인거 알지     인 판 도전각  ㅎㅎ     피자스쿨  피자추천  피자맛집  피자덕후  피자러버  가성비  가성비피자  피자스쿨메뉴  피자스쿨추천  피자스쿨메뉴추천  피자스쿨피자추천  야식  야식추천  메뉴추천  신메뉴  오지치즈포테이토피자  고구마피자  까르보네피자  더블갈릭바베큐피자  닭안심살피자  멕시칸바이트피자  비프퀘사디아피자  도이치바이트피자  고구마피자  포테이토피자  맛스타그램  피맥  피자스타그램 미스터피자에서 최애를 뽑는다면 단연 멕시칸 하바네로  멕시칸하바네로피자  미스터피자홈파티 하는데 피자가 빠질 수 없지 ㅋㅋ배달음식 이것저것 시키고 석화도 하프셸로 준비   멕시칸 하바네로     근데 멕시칸 하바네로 라지인줄 알았는데 레귤러로 잘못 시킴 ㅋㅋㅋㅋㅋ 아놔 빵이 반이네   그래도 다들 매콤하니 맛있다고 좋아했다 ㅋㅋㅋ 횐님들은 씬으로 라지 사이즈 꼭 드세요    멕시코 갈 필요 없습니다  맛있게 잘 먹었습니다   피자맛집  멕시칸  멕시코음식  배달맛집  홈파티  피자  미피  서울맛집  소통  일상  좋아요  선팔맞팔  먹팔  맛집   푸드스타그램   집밥스타그램  맛집스타그램  먹스타그램             세상 부러운 모태 마름쟁이들 특징 진짜 마른 사람들 너무 부러움근데 보면 마른 이유가 다 있더라    이거 너 아니냥       마른사람  모태마름  날씬  다이어트  음식  치킨  피자  고기  삼겹살  과자  간식  입짧음  활동량  활동적  기름진음식  배부름  야식  운동  체질 입짧은햇님님이 극찬한 그 피자 맞습니다   네모 모양의 피자에 기맥힌 토핑들이 꽉꽉  줄서는식당  생활의 달인  토요일은 밥이 좋아 등등 여러 미디어에서 극찬받은 어디서도 본 적 없는 특별한 피자겉바속촉한 식감을 구현해낸 네모 모양의 디트로이드 피자인데 아낌없이 꽉꽉 올라간 토핑 퀄리티마저 난리가 났어여     하와이안 갈릭쉬림프 파인애플 피자  는 뚱 뚱한 갈릭쉬림프  시나몬 파인애플 조합의 피자인데 토톡 터지는 왕새우랑 꼬수운 잣덕에 식감까지 예술 그 자체ㅠㅠ 새우덕후  하와이안피자 덕후라면 꼭꼭 사수하세요     텍사스 수비드 비프립 피자  는 피자덕후 피자힙 순위 메뉴   첫방문이라면 무조건 이거 드세요ㅠㅠ 주문하면 우선 훈연한 우대갈비가 연기 뿜으며 등장하는데 눈 앞에서 바로 손질해 도우 위에 뭉텅뭉텅 얹어주십니다  시간 수비드 조리한 우대갈비가 피자 토핑이라니   시각도 후각도 미각도 걍 넘 행복했어여  맥주랑두 찰떡 잘하는 집이 다 잘한다구 파스타두 잘해요ㅠㅠ 까르보나라 소스 가득한 에그톡까르보나라도 꾸우우우우덕한게 도랐   맥주는 선택 아닌 필쑤ㅠㅠㅠ 맛 보면 아십니당      피자덕후 피자힙 송리단길점  하와이안 갈릭 쉬림프 파인애플 피자    텍사스 수비드 비프립 피자    에그톡 까르보나라 리카토니      송파나루역 번 출구에서   매일               은쪼송파  송파맛집  송파나루역맛집  송리단길맛집  송리단길술집  송리단길피자  석촌맛집  잠실맛집  줄서는식당  디트로이드피자  피자  피자덕후피자힙  피자힙  선팔하면맞팔 캐논 고마운사람 첫줄반사 좋반 웨딩부케 소통합시다 밴드로고 소통하자 휴식시간 인스타일상 하동재첩국수 넘모맛있어 맞팔환영해요 밥상일기 시래기 피자 옛것들 먹어보자  퇴사하고싶다 데일리 금오동꽃집 맞팔로우 맞팔해요 맞팔하면선팔 선팔후맞팔 밴드로고 유치원입학 휴식시간 서우봉 하동재첩국수 음색깡패 백일상꾸미기 맞팔해용 시래기 피자 맛집스타그램 전시홀 오랜만에 피자    선팔하면맞팔 데일리 고마운사람 메시지 일상생활 일상생활 선팔후맞팔 맞팔해요우리 소통하자 맞팔환영 인스타일상 하동재첩국수 여름마켓 눈호강하고 댓글소통 애쉬브라운 피자 먹자그램 선팔맞팔  과슈 맛집 제작하기 너무맛있어 한국인의밥상 먹는순간기절 전용잔 감칠맛가성비 만원대 프로먹방꾼 두피문신 맞팔은댓글  좋튀 존맛탱 맞팔 피자 고냥이그램 반사  대교 리북집 구조도 조녜 좋반 갈월이골목 소통합시다 맞팔가요 소소한일상 익선동비밀 인스타일상 맞팔은댓글 맞팔좋아요 좋튀 차주문 맞좋튀 피자 소통그램 소소한행복 이 야밤에       겨울잠 자기엔 이미 늦은듯한데  난 왜 아직도 저장중인지    막노동자 일상마무리그램 피자        다이어트 떠먹는 피자나름 다이어트식양배추와 양파  오트밀로 피자도우를 만들고 직접 만든 토마토 소스와 향신료를 잔뜩 넣은 두부 크럼블  옥수수  올리브  치즈 올려서 마무리    다이어트  피자  양배추요리  나름  키토식단  치즈  두부                ...

# %%
from konlpy.tag import Okt
okt = Okt()
nouns_txt = okt.nouns(content_all)
nouns_txt
# Out:
# ['우리',
#  '지금',
#  '월드',
#  '클래스',
#  '명동',
#  '피자',
#  '시대',
#  '카타르',
#  '월드컵',
#  '더욱',
#  '핫',
#  '피자',
#  '집',
#  '고해',
#  '논란',
#  '곳',
#  '명동',
#  '피자',
#  '쫜득함',
#  '치즈',
#  '저',
#  '모습',
#  '또',
#  '사이드',
#  '메뉴',
#  '환상',
#  '궁합',
#  '왤케',
#  '이',
#  '핵가족',
#  '콤보',
#  '말',
#  '명동',
#  '피자',
#  '명동',
#  '동대문',
#  '명동',
#  '피자',
#  '방문',
#  '명동',
#  '피자',
#  '현대',
#  '시티',
#  '아울렛',
#  '안',
#  '투입',
#  '사장',
#  '손',
#  '두발',
#  '환대',
#  '각',
#  '것',
#  '피자',
#  '파스타',
#  '이드',
#  '머',
#  '하나',
#  '부족함',
#  '곳',
#  '치즈',
#  '끝판',
#  '피자',
#  '치즈',
#  '폭포',
#  '치즈',
#  '진짜',
#  '장관',
#  '재직',
#  '영매',
#  '동대문',
#  '점',
#  '명동',
#  '점',
#  '왕십리',
#  '논현',
#  '서울',
#  '예정',
#  '그냥',
#  '미국',
#  '시카고',
#  '핫',
#  '피자',
#  '가게',
#  '복',
#  '듯',
#  '퓔링',
#  '뽀너스',
#  '동대문',
#  '존맛',
#  '피자',
#  '맛집',
#  '명동',
#  '피자',
#  '스',
#  '푸파',
#  '종합',
#  '게시판',
#  '스푸파',
#  '종합',
#  '게시판',
#  '명동',
#  '피자',
#  '메뉴판',
#  '치즈',
#  '끝판',
#  '피자',
#  '투움',
#  '바로',
#  '파스타',
#  '만수르',
#  '피자',
#  '명란',
#  '오일',
#  '파스타',
#  '가게',
#  '주소',
#  '서울',
#  '중구',
#  '을지로',
#  '장충단로',
#  '길',
#  '현대',
#  '시티',
#  '아울렛',
#  '하층',
#  '가게',
#  '영업',
#  '시간',
#  '인스타',
#  '너',
#  '피자',
#  '손흥민',
#  '그게',
#  '바로',
#  '명동',
#  '피자',
#  '명동',
#  '피자',
#  '동대문',
#  '점',
#  '피자',
#  '맛집',
#  '파스타',
#  '맛집',
#  '동대문',
#  '맛집',
#  '피자',
#  '스',
#  '푸파',
#  '동대문',
#  '오늘',
#  '저녁',
#  '피자',
#  '도',
#  '미노',
#  '피자',
#  '행사',
#  '저녁',
#  '도',
#  '미노',
#  '포장',
#  '제',
#  '블랙',
#  '타이거',
#  '슈',
#  '림프',
#  '블랙',
#  '앵거스',
#  '스테이크',
#  '포테이토',
#  '리얼',
#  '불고기',
#  '더블',
#  '치즈',
#  '엣지',
#  '오늘',
#  '저녁',
#  '거',
#  '모두',
#  '오늘',
#  '밤',
#  '햅삐하',
#  '욥',
#  '제주',
#  '돌담',
#  '몸통',
#  '박살',
#  '가야',
#  '피자',
#  '집',
#  '맛집',
#  '경보',
#  '개',
#  '제주',
#  '돌담',
#  '몸통',
#  '박살',
#  '가야',
#  '피자',
#  '집',
#  '쬰득쫄깃',
#  '톳',
#  '도우',
#  '위',
#  '제주',
#  '토핑',
#  '제주',
#  '연동',
#  '리보스',
#  '코피',
#  '제주도',
#  '리보스',
#  '코피',
#  '도우',
#  '해녀',
#  '톳',
#  '쫄깃',
#  '도우',
#  '더',
#  '현무암',
#  '잔뜩',
#  '제주도',
#  '이색',
#  '현무암',
#  '치킨',
#  '피자',
#  '오징어',
#  '먹물',
#  '반죽',
#  '현무암',
#  '일반',
#  '반죽',
#  '더',
#  '바삭',
#  '치킨',
#  '피자',
#  '조합',
#  '통',
#  '새우',
#  '가득',
#  '찬',
#  '한라산',
#  '용암',
#  '치즈',
#  '한라산',
#  '용암',
#  '피자',
#  '칠리소스',
#  '옷',
#  '새우',
#  '최고급',
#  '치즈',
#  '쫀득',
#  '톳',
#  '도우',
#  '삼위일체',
#  '고요',
#  '제주',
#  '오시',
#  '꼭',
#  '한번',
#  '리보스',
#  '코피',
#  '직접',
#  '맥주',
#  '필수',
#  '리보스',
#  '코피',
#  '제주',
#  '제주시',
#  '수목원',
#  '길',
#  '월요일',
#  '휴무',
#  '주차장',
#  '매장',
#  '문의',
#  '현무암',
#  '치킨',
#  '피자',
#  '한라산',
#  '용암',
#  '피자',
#  '리보스',
#  '코',
#  '맥주',
#  '맛집',
#  '경보',
#  '제주',
#  '제주',
#  '여행',
#  '제주',
#  '맛집',
#  '제주도',
#  '맛집',
#  '제주시',
#  '맛집',
#  '연동',
#  '맛집',
#  '제주',
#  '피자',
#  '맛집',
#  '추천',
#  '제주',
#  '피자',
#  '맛집',
#  '피자',
#  '맛집',
#  '광안',
#  '리',
#  '포르타',
#  '광안',
#  '리',
#  '필수',
#  '코스',
#  '치즈',
#  '토핑',
#  '가득',
#  '미국',
#  '감성',
#  '피자',
#  '맛집',
#  '오션',
#  '뷰',
#  '피맥',
#  '조합',
#  '퐁실퐁실',
#  '도우',
#  '힙',
#  '분위기',
#  '오션',
#  '뷰',
#  '치즈',
#  '쭈아압',
#  '피자',
#  '위치',
#  '부산광역시',
#  '수영구',
#  '광안',
#  '로번',
#  '길',
#  '오늘',
#  '부산',
#  '광안',
#  '리',
#  '피자',
#  '덕후',
#  '강',
#  '존맛',
#  '피자',
#  '모음',
#  '집',
#  '진짜',
#  '시픈',
#  '비쥬',
#  '오늘',
#  '피맥하쟈',
#  '더',
#  '꿀팁',
#  '알',
#  '피자스쿨',
#  '피자',
#  '맛집',
#  '피자',
#  '추천',
#  '피자',
#  '맛집',
#  '피자',
#  '맛집',
#  '추천',
#  '야식',
#  '메뉴',
#  '추천',
#  '야식',
#  '추천',
#  '메뉴',
#  '배달',
#  '맛집',
#  '배달',
#  '맛집',
#  '추천',
#  '고구마',
#  '피자',
#  '치즈',
#  '피자',
#  '피자',
#  '메뉴',
#  '서울',
#  '맛집',
#  '추천',
#  '딩동댕동',
#  '가성',
#  '비',
#  '피자',
#  '학교',
#  '입학',
#  '준비',
#  '피자스쿨',
#  '출석',
#  '시간',
#  '이양',
#  '피자',
#  '성비',
#  '피자',
#  '맛집',
#  '피자스쿨',
#  '갈릭',
#  '소스',
#  '추가',
#  '필수',
#  '알',
#  '인',
#  '판',
#  '도전',
#  '각',
#  '피자스쿨',
#  '피자',
#  '추천',
#  '피자',
#  '맛집',
#  '피자',
#  '덕후',
#  '피자',
#  '러버',
#  '가성',
#  '비',
#  '가성',
#  '비',
#  '피자',
#  '피자스쿨',
#  '메뉴',
#  '피자스쿨',
#  '추천',
#  '피자스쿨',
#  '메뉴',
#  '추천',
#  '피자스쿨',
#  '피자',
#  '추천',
#  '야식',
#  '야식',
#  '추천',
#  '메뉴',
#  '추천',
#  '메뉴',
#  '오지',
#  '치즈',
#  '포테이토',
#  '피자',
#  '고구마',
#  '피자',
#  '르',
#  '피자',
#  '더블',
#  '갈릭',
#  '바베큐',
#  '피자',
#  '닭',
#  '안심',
#  '살피',
#  '멕시칸',
#  '바이트',
#  '피자',
#  '비프',
#  '퀘사디아',
#  '피자',
#  '도이치',
#  '바이트',
#  '피자',
#  '고구마',
#  '피자',
#  '포테이토',
#  '피자',
#  '맛스타',
#  '그램',
#  '피맥',
#  '피자',
#  '스타',
#  '그램',
#  '미스터피자',
#  '최애',
#  '단연',
#  '멕시칸',
#  '하바네로',
#  '멕시칸',
#  '하바네로',
#  '피자',
#  '미스터피자',
#  '홈파티',
#  '피자',
#  '수',
#  '배달',
#  '음식',
#  '것',
#  '것',
#  '석화',
#  '하프셸',
#  '준비',
#  '멕시칸',
#  '하바네로',
#  '멕시칸',
#  '하바네로',
#  '라지',
#  '줄',
#  '레귤러',
#  '잘못',
#  '시킴',
#  '빵',
#  '반',
#  '매콤',
#  '횐님들',
#  '씬',
#  '라지',
#  '사이즈',
#  '꼭',
#  '멕시코',
#  '필요',
#  '피자',
#  '맛집',
#  '멕시칸',
#  '멕시코',
#  '음식',
#  '배달',
#  '맛집',
#  '홈파티',
#  '피자',
#  '피',
#  '서울',
#  '맛집',
#  '소통',
#  '일상',
#  '선팔',
#  '맞팔',
#  '팔',
#  '맛집',
#  '푸드',
#  '스타',
#  '그램',
#  '집밥',
#  '스타',
#  '그램',
#  '맛집',
#  '스타',
#  '그램',
#  '스타',
#  '그램',
#  '세상',
#  '모태',
#  '마름',
#  '특징',
#  '진짜',
#  '사람',
#  '부러',
#  '움',
#  '이유',
#  '거',
#  '너',
#  '사람',
#  '모태',
#  '마름',
#  '날씬',
#  '다이어트',
#  '음식',
#  '치킨',
#  '피자',
#  '고기',
#  '삼겹살',
#  '과자',
#  '간식',
#  '입',
#  '활동',
#  '량',
#  '활동',
#  '음식',
#  '야식',
#  '운동',
#  '체질',
#  '입',
#  '햇님',
#  '극찬',
#  '그',
#  '피자',
#  '네모',
#  '모양',
#  '피자',
#  '기맥힌',
#  '토핑들',
#  '줄',
#  '식당',
#  '생활',
#  '달인',
#  '토요일',
#  '밥',
#  '등등',
#  '여러',
#  '미디어',
#  '극찬',
#  '어디',
#  '서도',
#  '적',
#  '피자',
#  '겉바',
#  '촉',
#  '식감',
#  '구현',
#  '네모',
#  '모양',
#  '디트로',
#  '이드',
#  '피자',
#  '토핑',
#  '퀄리티',
#  '난리',
#  '하와',
#  '이안',
#  '갈릭',
#  '쉬',
#  '림프',
#  '파인애플',
#  '피자',
#  '뚱',
#  '갈릭',
#  '쉬',
#  '림프',
#  '시나몬',
#  '파인애플',
#  '조합',
#  '피자',
#  '토톡',
#  '왕새우',
#  '꼬',
#  '수운',
#  '잣덕',
#  '식감',
#  '예술',
#  '그',
#  '자체',
#  '새우',
#  '덕후',
#  '하와',
#  '이안',
#  '피자',
#  '덕후',
#  '라면',
#  '꼭꼭',
#  '사수',
#  '텍사스',
#  '수비드',
#  '비프',
#  '립',
#  '피자',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '순위',
#  '메뉴',
#  '방문',
#  '라면',
#  '무조건',
#  '거',
#  '주문',
#  '우선',
#  '훈연',
#  '우대',
#  '갈비',
#  '연기',
#  '뿜으',
#  '등장',
#  '눈',
#  '앞',
#  '바로',
#  '손질',
#  '도우',
#  '위',
#  '뭉텅뭉텅',
#  '시간',
#  '수비드',
#  '조리',
#  '우대',
#  '갈비',
#  '피자',
#  '토핑',
#  '시각',
#  '후각',
#  '미각',
#  '맥주',
#  '찰떡',
#  '집',
#  '파스타',
#  '까르보나라',
#  '소스',
#  '톡',
#  '까르보나라',
#  '덕',
#  '게',
#  '맥주',
#  '선택',
#  '필',
#  '맛',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '송리단길점',
#  '하와',
#  '이안',
#  '갈릭',
#  '쉬',
#  '림프',
#  '파인애플',
#  '피자',
#  '텍사스',
#  '수비드',
#  '비프',
#  '립',
#  '피자',
#  '톡',
#  '까르보나라',
#  '리카',
#  '토니',
#  '송파',
#  '나루',
#  '역',
#  '번',
#  '출구',
#  '매일',
#  '은쪼',
#  '송파',
#  '송파',
#  '맛집',
#  '송파',
#  '나루',
#  '역',
#  '맛집',
#  '송리',
#  '맛집',
#  '송리',
#  '술집',
#  '송리',
#  '피자',
#  '석촌',
#  '맛집',
#  '잠실',
#  '맛집',
#  '줄',
#  '식당',
#  '디트로',
#  '이드',
#  '피자',
#  '피자',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '피자',
#  '힙',
#  '선팔',
#  '맞팔',
#  '캐논',
#  '사람',
#  '줄',
#  '반사',
#  '반',
#  '웨딩',
#  '부케',
#  '통합',
#  '시',
#  '밴드',
#  '소통',
#  '휴식시간',
#  '인스타',
#  '일상',
#  '하동',
#  '재첩',
#  '국수',
#  '모',
#  '맞팔',
#  '환영',
#  '해',
#  '밥상',
#  '일기',
#  '시래기',
#  '피자',
#  '것',
#  '퇴사',
#  '데',
#  '일리',
#  '금오동',
#  '꽃집',
#  '맞팔',
#  '로우',
#  '맞팔',
#  '맞팔',
#  '선팔',
#  '선팔',
#  '후',
#  '맞팔',
#  '밴드',
#  '유치원',
#  '입학',
#  '휴식시간',
#  '서우',
#  '봉',
#  '하동',
#  '재첩',
#  '국수',
#  '음색',
#  '깡패',
#  '일상',
#  '맞팔',
#  '시래기',
#  '피자',
#  '맛집',
#  '스타',
#  '그램',
#  '전시',
#  '홀',
#  '만',
#  '피자',
#  '선팔',
#  '맞팔',
#  '데',
#  '일리',
#  '사람',
#  '메시지',
#  '일상생활',
#  '일상생활',
#  '선팔',
#  '후',
#  '맞팔',
#  '맞팔',
#  '우리',
#  '소통',
#  '맞팔',
#  '환영',
#  '인스타',
#  '일상',
#  '하동',
#  '재첩',
#  '국수',
#  '여름',
#  '마켓',
#  '눈',
#  '호강',
#  '댓글',
#  '소통',
#  '애쉬',
#  '브라운',
#  '피자',
#  '그램',
#  '선팔',
#  '맞팔',
#  '과슈',
#  '맛집',
#  '제작',
#  '한국인',
#  '밥상',
#  '순간',
#  '기절',
#  '전용',
#  '잔',
#  '감칠맛',
#  '성비',
#  '만원',
#  '프로',
#  '먹방',
#  '두피',
#  '문신',
#  '맞팔',
#  '댓글',
#  '존맛',
#  '맞팔',
#  '피자',
#  '고냥이',
#  '그램',
#  '반사',
#  '대교',
#  '리북집',
#  '구조도',
#  '녜',
#  '반',
#  '월',
#  '골목',
#  '통합',
#  '시',
#  '맞팔',
#  '가요',
#  '일상',
#  '익선동',
#  '비밀',
#  '인스타',
#  '일상',
#  '맞팔',
#  '댓글',
#  '맞팔',
#  '차',
#  '주문',
#  '피자',
#  '소통',
#  '그램',
#  '행복',
#  '이',
#  '밤',
#  '겨울잠',
#  '자기',
#  '데',
#  '난',
#  '왜',
#  '저장',
#  '막노동',
#  '일상',
#  '마무리',
#  '그램',
#  '피자',
#  '다이어트',
#  '피자',
#  '나름',
#  '다이어트',
#  '양배추',
#  '양파',
#  '오트밀',
#  '피자',
#  '도우',
#  '직접',
#  '토마토',
#  '소스',
#  '향신료',
#  '잔뜩',
#  '두부',
#  '럼블',
#  '옥수수',
#  '올리브',
#  '치즈',
#  '마무리',
#  '다이어트',
#  '피자',
#  '양배추',
#  '요리',
#  '나름',
#  '키토',
#  '식단',
#  '치즈',
#  '두부',
#  '집밥',
#  '요리',
#  '스타',
#  '그램',
#  '일상',
#  '기록',
#  '음식',
#  '오늘',
#  '뭐',
#  '맞팔',
#  '돼지',
#  '멋',
#  '글씨',
#  '일상생활',
#  '일상사진',
#  '전용',
#  '잔',
#  '강릉',
#  '여행',
#  '일상',
#  '음식',
#  '그램',
#  '죠스',
#  '부천',
#  '맛집',
#  '추천',
#  '선팔',
#  '곧',
#  '맞팔',
#  '밥상',
#  '일기',
#  '피자',
#  '소통',
#  '맞팔',
#  '소통',
#  '영양',
#  '공급',
#  '맛집',
#  '줄',
#  '반',
#  '아이',
#  '교육',
#  '아이',
#  '고고',
#  '어린이집',
#  '졸업',
#  '일상생활',
#  '팔해',
#  '맛',
#  '입',
#  '간판',
#  '맞팔',
#  '환영',
#  '두피',
#  '문신',
#  '난',
#  ...]

# %%
from collections import Counter
count = Counter(nouns_txt)
count
rank_text = count.most_common()
rank_text
# Out:
# [('맞팔', 1990),
#  ('피자', 1543),
#  ('그램', 1028),
#  ('소통', 861),
#  ('맛집', 818),
#  ('일상', 752),
#  ('선팔', 527),
#  ('스타', 526),
#  ('먹방', 291),
#  ('음식', 281),
#  ('환영', 257),
#  ('파스타', 230),
#  ('댓글', 222),
#  ('반사', 211),
#  ('인스타', 203),
#  ('줄', 203),
#  ('댓', 200),
#  ('맛', 198),
#  ('추천', 189),
#  ('오늘', 178),
#  ('데', 157),
#  ('여행', 155),
#  ('반', 155),
#  ('일리', 154),
#  ('가족', 152),
#  ('광주', 146),
#  ('우리', 141),
#  ('일상생활', 140),
#  ('국수', 136),
#  ('밥상', 136),
#  ('행복', 129),
#  ('주문', 127),
#  ('시', 127),
#  ('가을', 127),
#  ('네일', 124),
#  ('배달', 123),
#  ('순간', 120),
#  ('점', 116),
#  ('이벤트', 115),
#  ('수유', 114),
#  ('집', 111),
#  ('아이', 102),
#  ('요리', 101),
#  ('치즈', 100),
#  ('메뉴', 98),
#  ('스테이크', 98),
#  ('스파게티', 97),
#  ('곳', 93),
#  ('존맛', 91),
#  ('시작', 88),
#  ('피가로', 88),
#  ('어린이집', 86),
#  ('샐러드', 86),
#  ('휴식시간', 85),
#  ('차', 83),
#  ('생각', 83),
#  ('음색', 80),
#  ('깡패', 80),
#  ('졸업', 80),
#  ('대학로', 79),
#  ('안', 77),
#  ('후', 77),
#  ('홀', 77),
#  ('팔해', 77),
#  ('눈', 76),
#  ('한국인', 76),
#  ('전시', 75),
#  ('추가', 74),
#  ('호강', 74),
#  ('뭐', 74),
#  ('침', 74),
#  ('옴', 73),
#  ('입', 72),
#  ('통합', 72),
#  ('강원도', 72),
#  ('것', 71),
#  ('해', 71),
#  ('로우', 71),
#  ('만원', 71),
#  ('에어비앤비', 71),
#  ('서귀포', 71),
#  ('긍정', 70),
#  ('네일아트', 70),
#  ('홍대', 70),
#  ('사람', 69),
#  ('돼지', 69),
#  ('곱창', 69),
#  ('신월동', 69),
#  ('새해', 69),
#  ('하동', 68),
#  ('예약', 68),
#  ('함', 68),
#  ('핫', 67),
#  ('유치원', 67),
#  ('기절', 67),
#  ('대교', 67),
#  ('월', 67),
#  ('강릉', 67),
#  ('곧', 67),
#  ('간판', 67),
#  ('먹기', 67),
#  ('재첩', 66),
#  ('퇴사', 66),
#  ('기록', 66),
#  ('댄스', 66),
#  ('타투', 66),
#  ('전대', 66),
#  ('고냥이', 65),
#  ('나들이', 65),
#  ('여자', 65),
#  ('팝핑', 65),
#  ('당첨', 65),
#  ('입학', 64),
#  ('두피', 64),
#  ('문신', 64),
#  ('익선동', 64),
#  ('아기', 64),
#  ('골프공', 64),
#  ('시래기', 63),
#  ('감칠맛', 63),
#  ('비밀', 63),
#  ('안압지', 63),
#  ('야경', 63),
#  ('에스컬레이터', 63),
#  ('편집', 63),
#  ('갈라', 63),
#  ('옷', 62),
#  ('메시지', 62),
#  ('마켓', 62),
#  ('난', 62),
#  ('죠스', 62),
#  ('시베리아', 62),
#  ('횡단', 62),
#  ('열차', 62),
#  ('계절', 62),
#  ('우회', 61),
#  ('선', 61),
#  ('성비', 60),
#  ('일기', 60),
#  ('녜', 60),
#  ('가요', 60),
#  ('끝', 60),
#  ('빵', 59),
#  ('밴드', 59),
#  ('여름', 59),
#  ('부천', 59),
#  ('전복', 59),
#  ('봉', 58),
#  ('프로', 58),
#  ('추억', 58),
#  ('잔', 57),
#  ('영양', 57),
#  ('공급', 57),
#  ('미니', 57),
#  ('이태원', 57),
#  ('구조도', 56),
#  ('쥬', 56),
#  ('칵테일', 56),
#  ('근교', 56),
#  ('꽃', 56),
#  ('캐디', 56),
#  ('미용', 56),
#  ('날', 56),
#  ('캐논', 55),
#  ('멋', 55),
#  ('글씨', 55),
#  ('전용', 54),
#  ('디디', 54),
#  ('서우', 53),
#  ('과슈', 53),
#  ('기', 53),
#  ('생신', 53),
#  ('등', 53),
#  ('골목', 52),
#  ('삼계탕', 52),
#  ('분관', 52),
#  ('버거', 52),
#  ('금오동', 51),
#  ('꽃집', 51),
#  ('단체', 51),
#  ('리북집', 50),
#  ('정신', 50),
#  ('선물', 50),
#  ('경품', 50),
#  ('저녁', 49),
#  ('제작', 49),
#  ('일상사진', 49),
#  ('시간', 48),
#  ('설빙', 48),
#  ('모임', 48),
#  ('여의도', 48),
#  ('썸', 47),
#  ('맛스타', 45),
#  ('애쉬', 45),
#  ('브라운', 45),
#  ('문어', 45),
#  ('교육', 44),
#  ('고고', 44),
#  ('카페', 44),
#  ('낚시', 44),
#  ('전남대', 44),
#  ('치킨', 43),
#  ('웨딩', 42),
#  ('부케', 42),
#  ('팔로우', 42),
#  ('샌드위치', 42),
#  ('소스', 41),
#  ('화덕', 41),
#  ('원', 41),
#  ('소망', 40),
#  ('층', 39),
#  ('더', 38),
#  ('데이트', 37),
#  ('맥주', 36),
#  ('수', 36),
#  ('모', 35),
#  ('수제', 35),
#  ('요기', 35),
#  ('도우', 33),
#  ('서울', 32),
#  ('발송', 32),
#  ('포테이토', 30),
#  ('친구', 30),
#  ('진짜', 29),
#  ('떡볶이', 29),
#  ('무료', 29),
#  ('가능', 29),
#  ('가득', 28),
#  ('및', 28),
#  ('랩', 28),
#  ('야식', 27),
#  ('마지막', 27),
#  ('타임', 27),
#  ('민족', 27),
#  ('명', 27),
#  ('또', 26),
#  ('고구마', 26),
#  ('준비', 26),
#  ('팔', 26),
#  ('새우', 25),
#  ('피자스쿨', 25),
#  ('갈비', 25),
#  ('공원', 25),
#  ('페퍼로니', 25),
#  ('점심', 25),
#  ('브레이크', 25),
#  ('주차장', 24),
#  ('텍사스', 24),
#  ('유기농', 24),
#  ('중공업', 24),
#  ('개인정보', 24),
#  ('불고기', 23),
#  ('피맥', 23),
#  ('필라프', 23),
#  ('북구', 23),
#  ('용봉동', 23),
#  ('때', 22),
#  ('커피', 22),
#  ('나', 22),
#  ('광역시', 22),
#  ('호산', 22),
#  ('동명', 22),
#  ('연중', 22),
#  ('무', 22),
#  ('후문', 22),
#  ('각종', 22),
#  ('가지', 21),
#  ('갈릭', 20),
#  ('토마토', 20),
#  ('인스타그램', 20),
#  ('림프', 19),
#  ('콜라', 19),
#  ('브런치', 19),
#  ('상품권', 19),
#  ('이', 18),
#  ('바로', 18),
#  ('제주', 18),
#  ('반죽', 18),
#  ('다이어트', 18),
#  ('쉬', 18),
#  ('신세계', 18),
#  ('사진', 18),
#  ('일', 18),
#  ('크림', 18),
#  ('참여', 18),
#  ('토핑', 17),
#  ('맘', 17),
#  ('내', 17),
#  ('감자', 17),
#  ('파파존스', 17),
#  ('리조또', 17),
#  ('상품', 17),
#  ('게시', 17),
#  ('수령', 17),
#  ('응모', 17),
#  ('방문', 16),
#  ('리', 16),
#  ('옥수수', 16),
#  ('인생', 16),
#  ('와인', 16),
#  ('양식', 16),
#  ('술', 16),
#  ('인테리어', 16),
#  ('고르곤졸라', 16),
#  ('년', 16),
#  ('기념', 16),
#  ('응원', 16),
#  ('추첨', 16),
#  ('물', 16),
#  ('수집', 16),
#  ('분위기', 15),
#  ('닭', 15),
#  ('푸드', 15),
#  ('매일', 15),
#  ('튀김', 15),
#  ('마르', 15),
#  ('할인', 15),
#  ('주말', 15),
#  ('여러분', 15),
#  ('위', 14),
#  ('꼭', 14),
#  ('감성', 14),
#  ('집밥', 14),
#  ('체험', 14),
#  ('정말', 14),
#  ('베이컨', 14),
#  ('금', 14),
#  ('마산', 14),
#  ('화', 14),
#  ('레스토랑', 14),
#  ('울산', 14),
#  ('도시락', 14),
#  ('인', 13),
#  ('분', 13),
#  ('오븐', 13),
#  ('판매', 13),
#  ('키친', 13),
#  ('영등포', 13),
#  ('방법', 13),
#  ('명동', 12),
#  ('저', 12),
#  ('말', 12),
#  ('너', 12),
#  ('조합', 12),
#  ('통', 12),
#  ('직접', 12),
#  ('비', 12),
#  ('식감', 12),
#  ('만', 12),
#  ('앤', 12),
#  ('신년', 12),
#  ('산', 12),
#  ('계란', 12),
#  ('배민', 12),
#  ('도미노피자', 12),
#  ('스파이', 12),
#  ('생면', 12),
#  ('하나', 11),
#  ('미국', 11),
#  ('길', 11),
#  ('도', 11),
#  ('포장', 11),
#  ('거', 11),
#  ('모두', 11),
#  ('문의', 11),
#  ('매콤', 11),
#  ('감', 11),
#  ('아들', 11),
#  ('코스트코', 11),
#  ('완전', 11),
#  ('조금', 11),
#  ('여기', 11),
#  ('전', 11),
#  ('다음', 11),
#  ('분당', 11),
#  ('맞이', 11),
#  ('쿠팡', 11),
#  ('츠', 11),
#  ('게리', 11),
#  ('사용', 11),
#  ('사이드', 10),
#  ('그냥', 10),
#  ('제주도', 10),
#  ('멕시칸', 10),
#  ('역', 10),
#  ('번', 10),
#  ('양배추', 10),
#  ('육아', 10),
#  ('가격', 10),
#  ('어제', 10),
#  ('오픈', 10),
#  ('위해', 10),
#  ('로', 10),
#  ('향', 10),
#  ('전주', 10),
#  ('하프', 10),
#  ('기도', 10),
#  ('구청', 10),
#  ('토', 10),
#  ('서현', 10),
#  ('일산', 10),
#  ('뇨끼', 10),
#  ('남해', 10),
#  ('안내', 10),
#  ('발표', 10),
#  ('가게', 9),
#  ('오일', 9),
#  ('덕후', 9),
#  ('가성', 9),
#  ('바베큐', 9),
#  ('식당', 9),
#  ('밥', 9),
#  ('페페로니', 9),
#  ('재료', 9),
#  ('회', 9),
#  ('태그', 9),
#  ('배송', 9),
#  ('성남', 9),
#  ('유머', 9),
#  ('참이슬', 9),
#  ('테라스', 9),
#  ('방어', 9),
#  ('병', 9),
#  ('안주', 9),
#  ('기간', 9),
#  ('중복', 9),
#  ('유지', 9),
#  ('지급', 9),
#  ('조선', 9),
#  ('제', 8),
#  ('개', 8),
#  ('한번', 8),
#  ('휴무', 8),
#  ('부산', 8),
#  ('운동', 8),
#  ('선택', 8),
#  ('만들기', 8),
#  ('엄마', 8),
#  ('사랑', 8),
#  ('동네', 8),
#  ('청년', 8),
#  ('최고', 8),
#  ('바', 8),
#  ('서비스', 8),
#  ('다른', 8),
#  ('중', 8),
#  ('피자헛', 8),
#  ('키즈', 8),
#  ('포레', 8),
#  ('디몬', 8),
#  ('방송국', 8),
#  ('그니', 8),
#  ('카라멜', 8),
#  ('라이즈', 8),
#  ('하와이', 8),
#  ('베트남', 8),
#  ('작성', 8),
#  ('달기', 8),
#  ('해시태그', 8),
#  ('확률', 8),
#  ('통해', 8),
#  ('선정', 8),
#  ('계정', 8),
#  ('결과', 8),
#  ('공지', 8),
#  ('한해', 8),
#  ('관', 8),
#  ('추후', 8),
#  ('자의', 8),
#  ('응답', 8),
#  ('불이익', 8),
#  ('본인', 8),
#  ('책임', 8),
#  ('파기', 8),
#  ('건설', 8),
#  ('월드', 7),
#  ('환상', 7),
#  ('손', 7),
#  ('시카고', 7),
#  ('주소', 7),
#  ('더블', 7),
#  ('쫄깃', 7),
#  ('바삭', 7),
#  ('바이트', 7),
#  ('고기', 7),
#  ('간식', 7),
#  ('잠실', 7),
#  ('왜', 7),
#  ('식단', 7),
#  ('살', 7),
#  ('막', 7),
#  ('이제', 7),
#  ('둘', 7),
#  ('마음', 7),
#  ('를', 7),
#  ('하루', 7),
#  ('인친', 7),
#  ('건대', 7),
#  ('처음', 7),
#  ('일요일', 7),
#  ('돈', 7),
#  ('듬뿍', 7),
#  ('제일', 7),
#  ('역시', 7),
#  ('고민', 7),
#  ('보이', 7),
#  ('이탈리안', 7),
#  ('부식', 7),
#  ('러스트', 7),
#  ('처', 7),
#  ('인분', 7),
#  ('반올림', 7),
#  ('미사', 7),
#  ('코지', 7),
#  ('동대문', 6),
#  ('사장', 6),
#  ('이드', 6),
#  ('영업', 6),
#  ('리보스', 6),
#  ('잔뜩', 6),
#  ('쫀득', 6),
#  ('매장', 6),
#  ('위치', 6),
#  ('알', 6),
#  ('사이즈', 6),
#  ('피', 6),
#  ('세상', 6),
#  ('이유', 6),
#  ('그', 6),
#  ('생활', 6),
#  ('퀄리티', 6),
#  ('앞', 6),
#  ('까르보나라', 6),
#  ('덕', 6),
#  ('베', 6),
#  ('커플', 6),
#  ('작가', 6),
#  ('이케아', 6),
#  ('보고', 6),
#  ('아빠', 6),
#  ('캠핑', 6),
#  ('김치', 6),
#  ('전서구', 6),
#  ('양송이', 6),
#  ('효과', 6),
#  ('막둥이', 6),
#  ('입맛', 6),
#  ('슈퍼', 6),
#  ('부림', 6),
#  ('족발', 6),
#  ('신촌', 6),
#  ('소세지', 6),
#  ('컨테이너', 6),
#  ('좀', 6),
#  ('단', 6),
#  ('초등학교', 6),
#  ('라스트', 6),
#  ('일주일', 6),
#  ('요즘', 6),
#  ('부터', 6),
#  ('드림', 6),
#  ('투어', 6),
#  ('빠', 6),
#  ('바질', 6),
#  ('모어', 6),
#  ('성북동', 6),
#  ('한남동', 6),
#  ('성수', 6),
#  ('밀', 6),
#  ('가래떡', 6),
#  ('겨울', 6),
#  ('취향', 6),
#  ('창원', 6),
#  ('풍동', 6),
#  ('기본', 6),
#  ('가로수길', 6),
#  ('고객', 6),
#  ('롯데', 6),
#  ('타바스코', 6),
#  ('앱', 6),
#  ('곡물', 6),
#  ('마녀', 6),
#  ('지금', 5),
#  ('밤', 5),
#  ('톳', 5),
#  ('코피', 5),
#  ('한라산', 5),
#  ('필수', 5),
#  ('광안', 5),
#  ('뷰', 5),
#  ('힙', 5),
#  ('비쥬', 5),
#  ('비프', 5),
#  ('하와', 5),
#  ('이안', 5),
#  ('수비드', 5),
#  ('게', 5),
#  ('술집', 5),
#  ('떡', 5),
#  ('띠', 5),
#  ('세트', 5),
#  ('먹음', 5),
#  ('다시', 5),
#  ('세라', 5),
#  ('라떼', 5),
#  ('완성', 5),
#  ('수업', 5),
#  ('마로', 5),
#  ('대전', 5),
#  ('종류', 5),
#  ('관저동', 5),
#  ('부분', 5),
#  ('트러플', 5),
#  ('개월', 5),
#  ('크런치', 5),
#  ('은', 5),
#  ('돈까스', 5),
#  ('콘치', 5),
#  ('느낌', 5),
#  ('미트', 5),
#  ('바스', 5),
#  ('음식사진', 5),
#  ('두', 5),
#  ('파', 5),
#  ('은평구', 5),
#  ('타코', 5),
#  ('콘', 5),
#  ('회식', 5),
#  ('덜', 5),
#  ('자극', 5),
#  ('국내', 5),
#  ('볶음밥', 5),
#  ('배', 5),
#  ('투', 5),
#  ('재미', 5),
#  ('소주', 5),
#  ('치코', 5),
#  ('성수동', 5),
#  ('컴퍼니', 5),
#  ('모짜렐라', 5),
#  ('이탈리아', 5),
#  ('힐', 5),
#  ('모든', 5),
#  ('진리', 5),
#  ('주부', 5),
#  ('네이버', 5),
#  ('혜택', 5),
#  ('화요일', 5),
#  ('삼총사', 5),
#  ('메', 5),
#  ('라운드', 5),
#  ('노', 5),
#  ('시장', 5),
#  ('본점', 5),
#  ('백종원', 5),
#  ('빽', 5),
#  ('얼', 5),
#  ('호치민', 5),
#  ('홈쿡', 5),
#  ('테이블', 5),
#  ('햄', 5),
#  ('면', 5),
#  ('쌀', 5),
#  ('창업', 5),
#  ('드', 5),
#  ('연남', 5),
#  ('껍질', 5),
#  ('야채', 5),
#  ('예정', 4),
#  ('스', 4),
#  ('미노', 4),
#  ('리얼', 4),
#  ('엣지', 4),
#  ('가야', 4),
#  ('해녀', 4),
#  ('현무암', 4),
#  ('먹물', 4),
#  ('용암', 4),
#  ('제주시', 4),
#  ('르', 4),
#  ('하바네로', 4),
#  ('레귤러', 4),
#  ('적', 4),
#  ('자체', 4),
#  ('라면', 4),
#  ('송파', 4),
#  ('올리브', 4),
#  ('시금치', 4),
#  ('형제', 4),
#  ('핫도그', 4),
#  ('원래', 4),
#  ('램', 4),
#  ('정도', 4),
#  ('근처', 4),
#  ('계', 4),
#  ('반지', 4),
#  ('귀걸이', 4),
#  ('뮤지컬', 4),
#  ('분식', 4),
#  ('닉', 4),
#  ('봄', 4),
#  ('레드', 4),
#  ('라자냐', 4),
#  ('이태리', 4),
#  ('트', 4),
#  ('무스', 4),
#  ('동생', 4),
#  ('치', 4),
#  ('라이스', 4),
#  ('뒤', 4),
#  ('이상', 4),
#  ('카', 4),
#  ('전화', 4),
#  ('백화점', 4),
#  ('심지어', 4),
#  ('시크릿', 4),
#  ('리뷰', 4),
#  ('기분', 4),
#  ('내일', 4),
#  ('칼로리', 4),
#  ('볼', 4),
#  ('리타', 4),
#  ('가장', 4),
#  ('콰트로', 4),
#  ('저희', 4),
#  ('음료', 4),
#  ('마늘', 4),
#  ('식사', 4),
#  ('정기', 4),
#  ('무한리필', 4),
#  ('늘', 4),
#  ('협찬', 4),
#  ('스튜디오', 4),
#  ('디핑', 4),
#  ('먼저', 4),
#  ('문자', 4),
#  ('장소', 4),
#  ('나이', 4),
#  ('중앙', 4),
#  ('생맥주', 4),
#  ('사이', 4),
#  ('평일', 4),
#  ('염', 4),
#  ('시카고피자', 4),
#  ('첫', 4),
#  ('연남동', 4),
#  ('제공', 4),
#  ('스토리', 4),
#  ('딸기', 4),
#  ('못', 4),
#  ('초', 4),
#  ('방학', 4),
#  ('연인', 4),
#  ('종로', 4),
#  ('한국', 4),
#  ('쭈꾸미', 4),
#  ('피클', 4),
#  ('베이', 4),
#  ('맛팔', 4),
#  ('김치찌개', 4),
#  ('직원', 4),
#  ('의정부', 4),
#  ('페스', 4),
#  ('비바', 4),
#  ('로마', 4),
#  ('한판', 4),
#  ('포', 4),
#  ('카드', 4),
#  ('결제', 4),
#  ('출근', 4),
#  ('목표', 4),
#  ('건강', 4),
#  ('모란', 4),
#  ('쏠쏠', 4),
#  ('이름', 4),
#  ('활짝', 4),
#  ('대연동', 4),
#  ('인천', 4),
#  ('납품', 4),
#  ('과천', 4),
#  ('간', 4),
#  ('보', 4),
#  ('쿠우', 4),
#  ('이자카야', 4),
#  ('속', 4),
#  ('오레가노', 4),
#  ('혼밥', 4),
#  ('알리오', 4),
#  ('행신동', 4),
#  ('마포구', 4),
#  ('강남', 4),
#  ('하남', 4),
#  ('광고', 4),
#  ('찹쌀', 4),
#  ('확인', 4),
#  ('화이팅', 4),
#  ('직영', 4),
#  ('영점', 4),
#  ('기회', 4),
#  ('진행', 4),
#  ('해공', 4),
#  ('호텔', 4),
#  ('하우스', 4),
#  ('랫댓', 4),
#  ('훈제오리', 4),
#  ('래미', 4),
#  ('해외', 4),
#  ('모습', 3),
#  ('궁합', 3),
#  ('콤보', 3),
#  ('각', 3),
#  ('복', 3),
#  ('듯', 3),
#  ('행사', 3),
#  ('블랙', 3),
#  ('수목원', 3),
#  ('월요일', 3),
#  ('코스', 3),
#  ('오션', 3),
#  ('판', 3),
#  ('미스터피자', 3),
#  ('최애', 3),
#  ('라지', 3),
#  ('잘못', 3),
#  ('씬', 3),
#  ('멕시코', 3),
#  ('움', 3),
#  ('삼겹살', 3),
#  ('극찬', 3),
#  ('모양', 3),
#  ('어디', 3),
#  ('파인애플', 3),
#  ('립', 3),
#  ('조리', 3),
#  ('톡', 3),
#  ('송리', 3),
#  ('마무리', 3),
#  ('양파', 3),
#  ('자매', 3),
#  ('수다', 3),
#  ('띠맘', 3),
#  ('이크', 3),
#  ('김', 3),
#  ('얼마', 3),
#  ('구미', 3),
#  ('실', 3),
#  ('습', 3),
#  ('블로그', 3),
#  ('크리', 3),
#  ('에디터', 3),
#  ('유트브', 3),
#  ('크루', 3),
#  ('악세사리', 3),
#  ('쇼핑몰', 3),
#  ('소상', 3),
#  ('공인', 3),
#  ('갈비탕', 3),
#  ('강강술래', 3),
#  ('영상', 3),
#  ('또띠아', 3),
#  ('사', 3),
#  ('햄버거', 3),
#  ('제대로', 3),
#  ('제로', 3),
#  ('남', 3),
#  ('메이드', 3),
#  ('버터', 3),
#  ('작업', 3),
#  ('걸', 3),
#  ('왕창', 3),
#  ('쥬스', 3),
#  ('외식', 3),
#  ('조각', 3),
#  ('피망', 3),
#  ('용인', 3),
#  ('딸', 3),
#  ('퇴근', 3),
#  ('한잔', 3),
#  ('파파스', 3),
#  ('위스키', 3),
#  ('자주', 3),
#  ('프로필', 3),
#  ('뇨', 3),
#  ('그림', 3),
#  ('널', 3),
#  ('세계', 3),
#  ('동안', 3),
#  ('살이', 3),
#  ('우동', 3),
#  ('만족', 3),
#  ('꽤', 3),
#  ('체다', 3),
#  ('겨울방학', 3),
#  ('표', 3),
#  ('세종시', 3),
#  ('당신', 3),
#  ('클래식', 3),
#  ('게다가', 3),
#  ('편', 3),
#  ('핫소스', 3),
#  ('성남시', 3),
#  ('분당구', 3),
#  ('돌', 3),
#  ('효자', 3),
#  ('촌', 3),
#  ('프라자', 3),
#  ('학년', 3),
#  ('공휴일', 3),
#  ('방과후', 3),
#  ('율동', 3),
#  ('실내', 3),
#  ('절로', 3),
#  ('디', 3),
#  ('지층', 3),
#  ('직장인', 3),
#  ('플롭', 3),
#  ('휴가', 3),
#  ('피드', 3),
#  ('당근', 3),
#  ('붕어빵', 3),
#  ('감자탕', 3),
#  ('야시장', 3),
#  ('싱글', 3),
#  ('찬스', 3),
#  ('춥다', 3),
#  ('이프', 3),
#  ('버섯', 3),
#  ('밀가루', 3),
#  ('목', 3),
#  ('서현역', 3),
#  ('메이', 3),
#  ('로제', 3),
#  ('절친', 3),
#  ('남편', 3),
#  ('광택', 3),
#  ('유리', 3),
#  ('코팅', 3),
#  ('최소', 3),
#  ('대신', 3),
#  ('답', 3),
#  ('휴일', 3),
#  ('인기', 3),
#  ('킹', 3),
#  ('매력', 3),
#  ('해수욕장', 3),
#  ('종종', 3),
#  ('집들이', 3),
#  ('탕', 3),
#  ('캬', 3),
#  ('상봉', 3),
#  ('푸드코트', 3),
#  ('출시', 3),
#  ('재', 3),
#  ('첩국', 3),
#  ('냉동', 3),
#  ('골프', 3),
#  ('무엇', 3),
#  ('택배', 3),
#  ('날씨', 3),
#  ('외출', 3),
#  ('월일', 3),
#  ('감사', 3),
#  ('봉덕동', 3),
#  ('당일', 3),
#  ('잎', 3),
#  ('덕천', 3),
#  ('만덕', 3),
#  ('올해', 3),
#  ('인연', 3),
#  ('일전', 3),
#  ('누브', 3),
#  ('티스', 3),
#  ('넥타이', 3),
#  ('박물관', 3),
#  ('소개', 3),
#  ('달콤', 3),
#  ('둘째', 3),
#  ('누구', 3),
#  ('당장', 3),
#  ('스트리트', 3),
#  ('문', 3),
#  ('아주', 3),
#  ('메인', 3),
#  ('이번', 3),
#  ('마루', 3),
#  ('특허', 3),
#  ('미세먼지', 3),
#  ('하늘', 3),
#  ('힐링', 3),
#  ('티', 3),
#  ('매번', 3),
#  ('마을', 3),
#  ('전부', 3),
#  ('안덕면', 3),
#  ('중문', 3),
#  ('설', 3),
#  ('키트', 3),
#  ('디저트', 3),
#  ('토핑킹', 3),
#  ('조화', 3),
#  ...]

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from konlpy.tag import Okt
from konlpy.corpus import kolaw
import nltk
from wordcloud import WordCloud

# %%
wc = WordCloud(max_font_size=40, background_color="white", max_words=1000,
               font_path="C:\\Windows\\Fonts\\malgun.ttf").generate_from_frequencies(dict(rank_text))

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
result2 = result
result2
# Out:
#                                               Contents  Like  \
# 0    우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493
# 1    오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101
# 2      제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681
# 3    광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191
# 4     피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309
# ..                                                 ...   ...
# 995   선팔하면맞팔 긍정적인생각 여자가을룩 조녜 맞팔그램 맞팔하면선팔 시베리아횡단열차 밴...     2
# 996   리그램    hjsc co kr by  get_regrammer 새해기념  너의 ...     1
# 997   대교 긍정적인생각 가을계절 일상스타그램 맞팔그램 먹는순간기절 먹팔해요 밴드로고 입...     6
# 998   수유타투잘하는곳 데일리 데일리그램 맞팔로우 어린이집졸업 일상사진 선팔후맞팔 맞팔해...     0
# 999   피자알볼로  옥수수피자  라지 27 000원  피자알볼로옥수수피자  옥수수  피자...     2
#
#                      ID                                               Tags
# 0        st_foodfighter  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1          10tia____a04                                                 []
# 2           gyeongboki_  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3          todays_busan                         ['#포르타나광안리', '#오늘의부산_광안리']
# 4           honey_unni_  ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...
# ..                  ...                                                ...
# 995             iyangca  ['#선팔하면맞팔', '#긍정적인생각', '#여자가을룩', '#조녜', '#맞팔그램...
# 996          sukskm1004  ['#리그램', '#hj중공업', '#2023', '#새해', '#새해소망', '#...
# 997         guggweongil  ['#대교', '#긍정적인생각', '#가을계절', '#일상스타그램', '#맞팔그램'...
# 998  nicolahunter384at7  ['#수유타투잘하는곳', '#데일리', '#데일리그램', '#맞팔로우', '#어린이...
# 999              dk0108  ['#피자알볼로', '#옥수수피자', '#라지', '#피자알볼로옥수수피자', '#옥...
#
# [1000 rows x 4 columns]

# %%
result2 = result2[result2['Contents'].str.contains('추천|협찬|광고|피자', na = False)]
result2
# Out:
#                                               Contents  Like  \
# 0    우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493
# 1    오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101
# 2      제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681
# 3    광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191
# 4     피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309
# ..                                                 ...   ...
# 995   선팔하면맞팔 긍정적인생각 여자가을룩 조녜 맞팔그램 맞팔하면선팔 시베리아횡단열차 밴...     2
# 996   리그램    hjsc co kr by  get_regrammer 새해기념  너의 ...     1
# 997   대교 긍정적인생각 가을계절 일상스타그램 맞팔그램 먹는순간기절 먹팔해요 밴드로고 입...     6
# 998   수유타투잘하는곳 데일리 데일리그램 맞팔로우 어린이집졸업 일상사진 선팔후맞팔 맞팔해...     0
# 999   피자알볼로  옥수수피자  라지 27 000원  피자알볼로옥수수피자  옥수수  피자...     2
#
#                      ID                                               Tags
# 0        st_foodfighter  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1          10tia____a04                                                 []
# 2           gyeongboki_  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3          todays_busan                         ['#포르타나광안리', '#오늘의부산_광안리']
# 4           honey_unni_  ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...
# ..                  ...                                                ...
# 995             iyangca  ['#선팔하면맞팔', '#긍정적인생각', '#여자가을룩', '#조녜', '#맞팔그램...
# 996          sukskm1004  ['#리그램', '#hj중공업', '#2023', '#새해', '#새해소망', '#...
# 997         guggweongil  ['#대교', '#긍정적인생각', '#가을계절', '#일상스타그램', '#맞팔그램'...
# 998  nicolahunter384at7  ['#수유타투잘하는곳', '#데일리', '#데일리그램', '#맞팔로우', '#어린이...
# 999              dk0108  ['#피자알볼로', '#옥수수피자', '#라지', '#피자알볼로옥수수피자', '#옥...
#
# [951 rows x 4 columns]

# %%
# 저장
result2.to_csv("data/피자2.csv", encoding="utf-8", index=False)

# %%
# 불러오기
result2 = pd.read_csv("data/피자2.csv")

# %%
result2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  951 non-null    object
#  1   Like      951 non-null    int64
#  2   ID        951 non-null    object
#  3   Tags      951 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 29.8+ KB

# %%
import time
from tqdm import tqdm_notebook

content_all = ''
for i in tqdm_notebook(range(len(result2["Contents"]))):
    content_all = content_all + ' ' + result2["Contents"].loc[i]
# Out:
# C:\Users\mhpark\AppData\Local\Temp\ipykernel_158184\1966288685.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(result2["Contents"]))):
#   0%|          | 0/951 [00:00<?, ?it/s]

# %%
import re
content_all = re.sub('[^ㄱ-ㅣ가-힣 ]',"",content_all)
content_all
# Out:
# ' 우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한 피자집이 있다고해서 논란의 곳이 있다고 해서 왔다  미칠듯이 늘어나는 명동피자의 쫜득함부터 고소한 치즈의 풍미를 품고 있는 저 모습이 보이는가  또 사이드메뉴들의 환상적인 궁합은 왤케 잘 어울려지는지 이게 진정한 핵가족급 콤보라고 말할수 있는  명동피자 명동을 넘어 동대문으로 명동피자를 방문했다  명동피자가 현대시티아울렛 안으로 투입됨에 현대사장님은 두손두발 다들고 환대각이었을 것이다  피자부터 파스타  에이드까지 머하나 부족함이 없는 이곳  치즈 끝판왕 피자에 치즈폭포를 만들어 치즈가 엄청나게 올려져서 나오는데 진짜 장관이다 현재직영매장이 동대문점  명동점을 빼고도 왕십리와 신논현에도 있다는게   서울을 집어삼킬 예정인가    그냥 미국의 시카고에 있는 핫플 피자가게를 복붙시켜놓은듯한 퓔링은 뽀너스  동대문에 있는 존맛피자맛집인 명동피자를 함께 스푸파 종합 게시판으로 알아보자      스푸파의 종합 게시판        명동피자 메뉴판  치즈끝판왕피자     투움바로제파스타     만수르피자     명란오일파스타    가게 주소   서울 중구 을지로가 장충단로길  현대시티아울렛 지하층 가게 영업시간        인스타      너 피자계의 손흥민이라고 들어는 봤냐     그게 바로 명동피자야    명동피자동대문점  피자맛집  파스타맛집  동대문맛집  피자      스푸파동대문 오늘 늦은 저녁은 피자   도미노에서 피자   행사를 하길래저녁은 도미노에서 포장해와서 먹었어요 제가 좋아하는 블랙타이거 슈림프 블랙앵거스 스테이크랑 포테이토 리얼불고기 더블치즈엣지  다들 오늘 저녁은 맛있는 거 드셨나요  모두 오늘 밤도 햅삐하게 보내시길 바라욥    제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보              개 제주돌담 몸통으로 박살내고 가야하는 피자집이다 쬰득쫄깃한 톳도우 위에 제주스러운 토핑 한가득  제주 연동  리보스코피자제주도 리보스코피자의 도우는 해녀가 잡은 톳으로부드러우면서 쫄깃한 도우를 만들어 더 맛있는데요 현무암이 잔뜩 올려진 제주도이색  현무암치킨피자 녹진한 오징어 먹물로 반죽한 현무암치킨인데요   일반 반죽보다 더 바삭하고 녹진한 치킨피자조합  통새우가 가득찬 한라산 용암치즈  한라산용암피자 칠리소스옷 입은 새우 최고급 치즈 쫀득한 톳도우  삼위일체고요    제주에 오시면 꼭 한번 드셔보세요 리보스코피자에서 직접만든 수제맥주는 필수에요  리보스코피자        제주 제주시 수목원길         매주 월요일 휴무  주차장 매장문의  현무암치킨 피자     한라산용암 피자     리보스코 맥주    맛집경보제주  제주여행  제주맛집  제주도맛집  제주시맛집  연동맛집 제주피자맛집추천  제주피자맛집  피자맛집 광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서 먹는피맥 조합도 상당한데 퐁실퐁실한 도우에힙한 분위기까지 찢었다    오션뷰 치즈 쭈아압 피자 ㄱ 위치부산광역시 수영구 광안로번길  오늘의부산광안리  피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ  오늘 피맥하쟈                         더 많은 꿀팁을 알고 싶다면      피자스쿨  피자맛집  피자추천  피자맛집  피자맛집추천  야식메뉴추천  야식추천메뉴  배달맛집  배달맛집추천  고구마피자  치즈피자  피자메뉴  서울맛집추천 딩동댕동  가성비 피자학교 입학준비   피자스쿨 출석할 시간이양   피자 땡기는데 너무 비싸다구 ㅜㅜ갓성비 피자맛집 피자스쿨이 있짜나  갈릭소스 추가는 필수인거 알지     인 판 도전각  ㅎㅎ     피자스쿨  피자추천  피자맛집  피자덕후  피자러버  가성비  가성비피자  피자스쿨메뉴  피자스쿨추천  피자스쿨메뉴추천  피자스쿨피자추천  야식  야식추천  메뉴추천  신메뉴  오지치즈포테이토피자  고구마피자  까르보네피자  더블갈릭바베큐피자  닭안심살피자  멕시칸바이트피자  비프퀘사디아피자  도이치바이트피자  고구마피자  포테이토피자  맛스타그램  피맥  피자스타그램 미스터피자에서 최애를 뽑는다면 단연 멕시칸 하바네로  멕시칸하바네로피자  미스터피자홈파티 하는데 피자가 빠질 수 없지 ㅋㅋ배달음식 이것저것 시키고 석화도 하프셸로 준비   멕시칸 하바네로     근데 멕시칸 하바네로 라지인줄 알았는데 레귤러로 잘못 시킴 ㅋㅋㅋㅋㅋ 아놔 빵이 반이네   그래도 다들 매콤하니 맛있다고 좋아했다 ㅋㅋㅋ 횐님들은 씬으로 라지 사이즈 꼭 드세요    멕시코 갈 필요 없습니다  맛있게 잘 먹었습니다   피자맛집  멕시칸  멕시코음식  배달맛집  홈파티  피자  미피  서울맛집  소통  일상  좋아요  선팔맞팔  먹팔  맛집   푸드스타그램   집밥스타그램  맛집스타그램  먹스타그램             세상 부러운 모태 마름쟁이들 특징 진짜 마른 사람들 너무 부러움근데 보면 마른 이유가 다 있더라    이거 너 아니냥       마른사람  모태마름  날씬  다이어트  음식  치킨  피자  고기  삼겹살  과자  간식  입짧음  활동량  활동적  기름진음식  배부름  야식  운동  체질 입짧은햇님님이 극찬한 그 피자 맞습니다   네모 모양의 피자에 기맥힌 토핑들이 꽉꽉  줄서는식당  생활의 달인  토요일은 밥이 좋아 등등 여러 미디어에서 극찬받은 어디서도 본 적 없는 특별한 피자겉바속촉한 식감을 구현해낸 네모 모양의 디트로이드 피자인데 아낌없이 꽉꽉 올라간 토핑 퀄리티마저 난리가 났어여     하와이안 갈릭쉬림프 파인애플 피자  는 뚱 뚱한 갈릭쉬림프  시나몬 파인애플 조합의 피자인데 토톡 터지는 왕새우랑 꼬수운 잣덕에 식감까지 예술 그 자체ㅠㅠ 새우덕후  하와이안피자 덕후라면 꼭꼭 사수하세요     텍사스 수비드 비프립 피자  는 피자덕후 피자힙 순위 메뉴   첫방문이라면 무조건 이거 드세요ㅠㅠ 주문하면 우선 훈연한 우대갈비가 연기 뿜으며 등장하는데 눈 앞에서 바로 손질해 도우 위에 뭉텅뭉텅 얹어주십니다  시간 수비드 조리한 우대갈비가 피자 토핑이라니   시각도 후각도 미각도 걍 넘 행복했어여  맥주랑두 찰떡 잘하는 집이 다 잘한다구 파스타두 잘해요ㅠㅠ 까르보나라 소스 가득한 에그톡까르보나라도 꾸우우우우덕한게 도랐   맥주는 선택 아닌 필쑤ㅠㅠㅠ 맛 보면 아십니당      피자덕후 피자힙 송리단길점  하와이안 갈릭 쉬림프 파인애플 피자    텍사스 수비드 비프립 피자    에그톡 까르보나라 리카토니      송파나루역 번 출구에서   매일               은쪼송파  송파맛집  송파나루역맛집  송리단길맛집  송리단길술집  송리단길피자  석촌맛집  잠실맛집  줄서는식당  디트로이드피자  피자  피자덕후피자힙  피자힙  선팔하면맞팔 캐논 고마운사람 첫줄반사 좋반 웨딩부케 소통합시다 밴드로고 소통하자 휴식시간 인스타일상 하동재첩국수 넘모맛있어 맞팔환영해요 밥상일기 시래기 피자 옛것들 먹어보자  퇴사하고싶다 데일리 금오동꽃집 맞팔로우 맞팔해요 맞팔하면선팔 선팔후맞팔 밴드로고 유치원입학 휴식시간 서우봉 하동재첩국수 음색깡패 백일상꾸미기 맞팔해용 시래기 피자 맛집스타그램 전시홀 오랜만에 피자    선팔하면맞팔 데일리 고마운사람 메시지 일상생활 일상생활 선팔후맞팔 맞팔해요우리 소통하자 맞팔환영 인스타일상 하동재첩국수 여름마켓 눈호강하고 댓글소통 애쉬브라운 피자 먹자그램 선팔맞팔  과슈 맛집 제작하기 너무맛있어 한국인의밥상 먹는순간기절 전용잔 감칠맛가성비 만원대 프로먹방꾼 두피문신 맞팔은댓글  좋튀 존맛탱 맞팔 피자 고냥이그램 반사  대교 리북집 구조도 조녜 좋반 갈월이골목 소통합시다 맞팔가요 소소한일상 익선동비밀 인스타일상 맞팔은댓글 맞팔좋아요 좋튀 차주문 맞좋튀 피자 소통그램 소소한행복 이 야밤에       겨울잠 자기엔 이미 늦은듯한데  난 왜 아직도 저장중인지    막노동자 일상마무리그램 피자        다이어트 떠먹는 피자나름 다이어트식양배추와 양파  오트밀로 피자도우를 만들고 직접 만든 토마토 소스와 향신료를 잔뜩 넣은 두부 크럼블  옥수수  올리브  치즈 올려서 마무리    다이어트  피자  양배추요리  나름  키토식단  치즈  두부                ...

# %%
from konlpy.tag import Okt
okt = Okt()
nouns_txt = okt.nouns(content_all)
nouns_txt
# Out:
# ['우리',
#  '지금',
#  '월드',
#  '클래스',
#  '명동',
#  '피자',
#  '시대',
#  '카타르',
#  '월드컵',
#  '더욱',
#  '핫',
#  '피자',
#  '집',
#  '고해',
#  '논란',
#  '곳',
#  '명동',
#  '피자',
#  '쫜득함',
#  '치즈',
#  '저',
#  '모습',
#  '또',
#  '사이드',
#  '메뉴',
#  '환상',
#  '궁합',
#  '왤케',
#  '이',
#  '핵가족',
#  '콤보',
#  '말',
#  '명동',
#  '피자',
#  '명동',
#  '동대문',
#  '명동',
#  '피자',
#  '방문',
#  '명동',
#  '피자',
#  '현대',
#  '시티',
#  '아울렛',
#  '안',
#  '투입',
#  '사장',
#  '손',
#  '두발',
#  '환대',
#  '각',
#  '것',
#  '피자',
#  '파스타',
#  '이드',
#  '머',
#  '하나',
#  '부족함',
#  '곳',
#  '치즈',
#  '끝판',
#  '피자',
#  '치즈',
#  '폭포',
#  '치즈',
#  '진짜',
#  '장관',
#  '재직',
#  '영매',
#  '동대문',
#  '점',
#  '명동',
#  '점',
#  '왕십리',
#  '논현',
#  '서울',
#  '예정',
#  '그냥',
#  '미국',
#  '시카고',
#  '핫',
#  '피자',
#  '가게',
#  '복',
#  '듯',
#  '퓔링',
#  '뽀너스',
#  '동대문',
#  '존맛',
#  '피자',
#  '맛집',
#  '명동',
#  '피자',
#  '스',
#  '푸파',
#  '종합',
#  '게시판',
#  '스푸파',
#  '종합',
#  '게시판',
#  '명동',
#  '피자',
#  '메뉴판',
#  '치즈',
#  '끝판',
#  '피자',
#  '투움',
#  '바로',
#  '파스타',
#  '만수르',
#  '피자',
#  '명란',
#  '오일',
#  '파스타',
#  '가게',
#  '주소',
#  '서울',
#  '중구',
#  '을지로',
#  '장충단로',
#  '길',
#  '현대',
#  '시티',
#  '아울렛',
#  '하층',
#  '가게',
#  '영업',
#  '시간',
#  '인스타',
#  '너',
#  '피자',
#  '손흥민',
#  '그게',
#  '바로',
#  '명동',
#  '피자',
#  '명동',
#  '피자',
#  '동대문',
#  '점',
#  '피자',
#  '맛집',
#  '파스타',
#  '맛집',
#  '동대문',
#  '맛집',
#  '피자',
#  '스',
#  '푸파',
#  '동대문',
#  '오늘',
#  '저녁',
#  '피자',
#  '도',
#  '미노',
#  '피자',
#  '행사',
#  '저녁',
#  '도',
#  '미노',
#  '포장',
#  '제',
#  '블랙',
#  '타이거',
#  '슈',
#  '림프',
#  '블랙',
#  '앵거스',
#  '스테이크',
#  '포테이토',
#  '리얼',
#  '불고기',
#  '더블',
#  '치즈',
#  '엣지',
#  '오늘',
#  '저녁',
#  '거',
#  '모두',
#  '오늘',
#  '밤',
#  '햅삐하',
#  '욥',
#  '제주',
#  '돌담',
#  '몸통',
#  '박살',
#  '가야',
#  '피자',
#  '집',
#  '맛집',
#  '경보',
#  '개',
#  '제주',
#  '돌담',
#  '몸통',
#  '박살',
#  '가야',
#  '피자',
#  '집',
#  '쬰득쫄깃',
#  '톳',
#  '도우',
#  '위',
#  '제주',
#  '토핑',
#  '제주',
#  '연동',
#  '리보스',
#  '코피',
#  '제주도',
#  '리보스',
#  '코피',
#  '도우',
#  '해녀',
#  '톳',
#  '쫄깃',
#  '도우',
#  '더',
#  '현무암',
#  '잔뜩',
#  '제주도',
#  '이색',
#  '현무암',
#  '치킨',
#  '피자',
#  '오징어',
#  '먹물',
#  '반죽',
#  '현무암',
#  '일반',
#  '반죽',
#  '더',
#  '바삭',
#  '치킨',
#  '피자',
#  '조합',
#  '통',
#  '새우',
#  '가득',
#  '찬',
#  '한라산',
#  '용암',
#  '치즈',
#  '한라산',
#  '용암',
#  '피자',
#  '칠리소스',
#  '옷',
#  '새우',
#  '최고급',
#  '치즈',
#  '쫀득',
#  '톳',
#  '도우',
#  '삼위일체',
#  '고요',
#  '제주',
#  '오시',
#  '꼭',
#  '한번',
#  '리보스',
#  '코피',
#  '직접',
#  '맥주',
#  '필수',
#  '리보스',
#  '코피',
#  '제주',
#  '제주시',
#  '수목원',
#  '길',
#  '월요일',
#  '휴무',
#  '주차장',
#  '매장',
#  '문의',
#  '현무암',
#  '치킨',
#  '피자',
#  '한라산',
#  '용암',
#  '피자',
#  '리보스',
#  '코',
#  '맥주',
#  '맛집',
#  '경보',
#  '제주',
#  '제주',
#  '여행',
#  '제주',
#  '맛집',
#  '제주도',
#  '맛집',
#  '제주시',
#  '맛집',
#  '연동',
#  '맛집',
#  '제주',
#  '피자',
#  '맛집',
#  '추천',
#  '제주',
#  '피자',
#  '맛집',
#  '피자',
#  '맛집',
#  '광안',
#  '리',
#  '포르타',
#  '광안',
#  '리',
#  '필수',
#  '코스',
#  '치즈',
#  '토핑',
#  '가득',
#  '미국',
#  '감성',
#  '피자',
#  '맛집',
#  '오션',
#  '뷰',
#  '피맥',
#  '조합',
#  '퐁실퐁실',
#  '도우',
#  '힙',
#  '분위기',
#  '오션',
#  '뷰',
#  '치즈',
#  '쭈아압',
#  '피자',
#  '위치',
#  '부산광역시',
#  '수영구',
#  '광안',
#  '로번',
#  '길',
#  '오늘',
#  '부산',
#  '광안',
#  '리',
#  '피자',
#  '덕후',
#  '강',
#  '존맛',
#  '피자',
#  '모음',
#  '집',
#  '진짜',
#  '시픈',
#  '비쥬',
#  '오늘',
#  '피맥하쟈',
#  '더',
#  '꿀팁',
#  '알',
#  '피자스쿨',
#  '피자',
#  '맛집',
#  '피자',
#  '추천',
#  '피자',
#  '맛집',
#  '피자',
#  '맛집',
#  '추천',
#  '야식',
#  '메뉴',
#  '추천',
#  '야식',
#  '추천',
#  '메뉴',
#  '배달',
#  '맛집',
#  '배달',
#  '맛집',
#  '추천',
#  '고구마',
#  '피자',
#  '치즈',
#  '피자',
#  '피자',
#  '메뉴',
#  '서울',
#  '맛집',
#  '추천',
#  '딩동댕동',
#  '가성',
#  '비',
#  '피자',
#  '학교',
#  '입학',
#  '준비',
#  '피자스쿨',
#  '출석',
#  '시간',
#  '이양',
#  '피자',
#  '성비',
#  '피자',
#  '맛집',
#  '피자스쿨',
#  '갈릭',
#  '소스',
#  '추가',
#  '필수',
#  '알',
#  '인',
#  '판',
#  '도전',
#  '각',
#  '피자스쿨',
#  '피자',
#  '추천',
#  '피자',
#  '맛집',
#  '피자',
#  '덕후',
#  '피자',
#  '러버',
#  '가성',
#  '비',
#  '가성',
#  '비',
#  '피자',
#  '피자스쿨',
#  '메뉴',
#  '피자스쿨',
#  '추천',
#  '피자스쿨',
#  '메뉴',
#  '추천',
#  '피자스쿨',
#  '피자',
#  '추천',
#  '야식',
#  '야식',
#  '추천',
#  '메뉴',
#  '추천',
#  '메뉴',
#  '오지',
#  '치즈',
#  '포테이토',
#  '피자',
#  '고구마',
#  '피자',
#  '르',
#  '피자',
#  '더블',
#  '갈릭',
#  '바베큐',
#  '피자',
#  '닭',
#  '안심',
#  '살피',
#  '멕시칸',
#  '바이트',
#  '피자',
#  '비프',
#  '퀘사디아',
#  '피자',
#  '도이치',
#  '바이트',
#  '피자',
#  '고구마',
#  '피자',
#  '포테이토',
#  '피자',
#  '맛스타',
#  '그램',
#  '피맥',
#  '피자',
#  '스타',
#  '그램',
#  '미스터피자',
#  '최애',
#  '단연',
#  '멕시칸',
#  '하바네로',
#  '멕시칸',
#  '하바네로',
#  '피자',
#  '미스터피자',
#  '홈파티',
#  '피자',
#  '수',
#  '배달',
#  '음식',
#  '것',
#  '것',
#  '석화',
#  '하프셸',
#  '준비',
#  '멕시칸',
#  '하바네로',
#  '멕시칸',
#  '하바네로',
#  '라지',
#  '줄',
#  '레귤러',
#  '잘못',
#  '시킴',
#  '빵',
#  '반',
#  '매콤',
#  '횐님들',
#  '씬',
#  '라지',
#  '사이즈',
#  '꼭',
#  '멕시코',
#  '필요',
#  '피자',
#  '맛집',
#  '멕시칸',
#  '멕시코',
#  '음식',
#  '배달',
#  '맛집',
#  '홈파티',
#  '피자',
#  '피',
#  '서울',
#  '맛집',
#  '소통',
#  '일상',
#  '선팔',
#  '맞팔',
#  '팔',
#  '맛집',
#  '푸드',
#  '스타',
#  '그램',
#  '집밥',
#  '스타',
#  '그램',
#  '맛집',
#  '스타',
#  '그램',
#  '스타',
#  '그램',
#  '세상',
#  '모태',
#  '마름',
#  '특징',
#  '진짜',
#  '사람',
#  '부러',
#  '움',
#  '이유',
#  '거',
#  '너',
#  '사람',
#  '모태',
#  '마름',
#  '날씬',
#  '다이어트',
#  '음식',
#  '치킨',
#  '피자',
#  '고기',
#  '삼겹살',
#  '과자',
#  '간식',
#  '입',
#  '활동',
#  '량',
#  '활동',
#  '음식',
#  '야식',
#  '운동',
#  '체질',
#  '입',
#  '햇님',
#  '극찬',
#  '그',
#  '피자',
#  '네모',
#  '모양',
#  '피자',
#  '기맥힌',
#  '토핑들',
#  '줄',
#  '식당',
#  '생활',
#  '달인',
#  '토요일',
#  '밥',
#  '등등',
#  '여러',
#  '미디어',
#  '극찬',
#  '어디',
#  '서도',
#  '적',
#  '피자',
#  '겉바',
#  '촉',
#  '식감',
#  '구현',
#  '네모',
#  '모양',
#  '디트로',
#  '이드',
#  '피자',
#  '토핑',
#  '퀄리티',
#  '난리',
#  '하와',
#  '이안',
#  '갈릭',
#  '쉬',
#  '림프',
#  '파인애플',
#  '피자',
#  '뚱',
#  '갈릭',
#  '쉬',
#  '림프',
#  '시나몬',
#  '파인애플',
#  '조합',
#  '피자',
#  '토톡',
#  '왕새우',
#  '꼬',
#  '수운',
#  '잣덕',
#  '식감',
#  '예술',
#  '그',
#  '자체',
#  '새우',
#  '덕후',
#  '하와',
#  '이안',
#  '피자',
#  '덕후',
#  '라면',
#  '꼭꼭',
#  '사수',
#  '텍사스',
#  '수비드',
#  '비프',
#  '립',
#  '피자',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '순위',
#  '메뉴',
#  '방문',
#  '라면',
#  '무조건',
#  '거',
#  '주문',
#  '우선',
#  '훈연',
#  '우대',
#  '갈비',
#  '연기',
#  '뿜으',
#  '등장',
#  '눈',
#  '앞',
#  '바로',
#  '손질',
#  '도우',
#  '위',
#  '뭉텅뭉텅',
#  '시간',
#  '수비드',
#  '조리',
#  '우대',
#  '갈비',
#  '피자',
#  '토핑',
#  '시각',
#  '후각',
#  '미각',
#  '맥주',
#  '찰떡',
#  '집',
#  '파스타',
#  '까르보나라',
#  '소스',
#  '톡',
#  '까르보나라',
#  '덕',
#  '게',
#  '맥주',
#  '선택',
#  '필',
#  '맛',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '송리단길점',
#  '하와',
#  '이안',
#  '갈릭',
#  '쉬',
#  '림프',
#  '파인애플',
#  '피자',
#  '텍사스',
#  '수비드',
#  '비프',
#  '립',
#  '피자',
#  '톡',
#  '까르보나라',
#  '리카',
#  '토니',
#  '송파',
#  '나루',
#  '역',
#  '번',
#  '출구',
#  '매일',
#  '은쪼',
#  '송파',
#  '송파',
#  '맛집',
#  '송파',
#  '나루',
#  '역',
#  '맛집',
#  '송리',
#  '맛집',
#  '송리',
#  '술집',
#  '송리',
#  '피자',
#  '석촌',
#  '맛집',
#  '잠실',
#  '맛집',
#  '줄',
#  '식당',
#  '디트로',
#  '이드',
#  '피자',
#  '피자',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '피자',
#  '힙',
#  '선팔',
#  '맞팔',
#  '캐논',
#  '사람',
#  '줄',
#  '반사',
#  '반',
#  '웨딩',
#  '부케',
#  '통합',
#  '시',
#  '밴드',
#  '소통',
#  '휴식시간',
#  '인스타',
#  '일상',
#  '하동',
#  '재첩',
#  '국수',
#  '모',
#  '맞팔',
#  '환영',
#  '해',
#  '밥상',
#  '일기',
#  '시래기',
#  '피자',
#  '것',
#  '퇴사',
#  '데',
#  '일리',
#  '금오동',
#  '꽃집',
#  '맞팔',
#  '로우',
#  '맞팔',
#  '맞팔',
#  '선팔',
#  '선팔',
#  '후',
#  '맞팔',
#  '밴드',
#  '유치원',
#  '입학',
#  '휴식시간',
#  '서우',
#  '봉',
#  '하동',
#  '재첩',
#  '국수',
#  '음색',
#  '깡패',
#  '일상',
#  '맞팔',
#  '시래기',
#  '피자',
#  '맛집',
#  '스타',
#  '그램',
#  '전시',
#  '홀',
#  '만',
#  '피자',
#  '선팔',
#  '맞팔',
#  '데',
#  '일리',
#  '사람',
#  '메시지',
#  '일상생활',
#  '일상생활',
#  '선팔',
#  '후',
#  '맞팔',
#  '맞팔',
#  '우리',
#  '소통',
#  '맞팔',
#  '환영',
#  '인스타',
#  '일상',
#  '하동',
#  '재첩',
#  '국수',
#  '여름',
#  '마켓',
#  '눈',
#  '호강',
#  '댓글',
#  '소통',
#  '애쉬',
#  '브라운',
#  '피자',
#  '그램',
#  '선팔',
#  '맞팔',
#  '과슈',
#  '맛집',
#  '제작',
#  '한국인',
#  '밥상',
#  '순간',
#  '기절',
#  '전용',
#  '잔',
#  '감칠맛',
#  '성비',
#  '만원',
#  '프로',
#  '먹방',
#  '두피',
#  '문신',
#  '맞팔',
#  '댓글',
#  '존맛',
#  '맞팔',
#  '피자',
#  '고냥이',
#  '그램',
#  '반사',
#  '대교',
#  '리북집',
#  '구조도',
#  '녜',
#  '반',
#  '월',
#  '골목',
#  '통합',
#  '시',
#  '맞팔',
#  '가요',
#  '일상',
#  '익선동',
#  '비밀',
#  '인스타',
#  '일상',
#  '맞팔',
#  '댓글',
#  '맞팔',
#  '차',
#  '주문',
#  '피자',
#  '소통',
#  '그램',
#  '행복',
#  '이',
#  '밤',
#  '겨울잠',
#  '자기',
#  '데',
#  '난',
#  '왜',
#  '저장',
#  '막노동',
#  '일상',
#  '마무리',
#  '그램',
#  '피자',
#  '다이어트',
#  '피자',
#  '나름',
#  '다이어트',
#  '양배추',
#  '양파',
#  '오트밀',
#  '피자',
#  '도우',
#  '직접',
#  '토마토',
#  '소스',
#  '향신료',
#  '잔뜩',
#  '두부',
#  '럼블',
#  '옥수수',
#  '올리브',
#  '치즈',
#  '마무리',
#  '다이어트',
#  '피자',
#  '양배추',
#  '요리',
#  '나름',
#  '키토',
#  '식단',
#  '치즈',
#  '두부',
#  '집밥',
#  '요리',
#  '스타',
#  '그램',
#  '일상',
#  '기록',
#  '음식',
#  '오늘',
#  '뭐',
#  '맞팔',
#  '돼지',
#  '멋',
#  '글씨',
#  '일상생활',
#  '일상사진',
#  '전용',
#  '잔',
#  '강릉',
#  '여행',
#  '일상',
#  '음식',
#  '그램',
#  '죠스',
#  '부천',
#  '맛집',
#  '추천',
#  '선팔',
#  '곧',
#  '맞팔',
#  '밥상',
#  '일기',
#  '피자',
#  '소통',
#  '맞팔',
#  '소통',
#  '영양',
#  '공급',
#  '맛집',
#  '줄',
#  '반',
#  '아이',
#  '교육',
#  '아이',
#  '고고',
#  '어린이집',
#  '졸업',
#  '일상생활',
#  '팔해',
#  '맛',
#  '입',
#  '간판',
#  '맞팔',
#  '환영',
#  '두피',
#  '문신',
#  '난',
#  ...]

# %%
from collections import Counter
count = Counter(nouns_txt)
count
rank_text = count.most_common()
rank_text
# Out:
# [('맞팔', 1990),
#  ('피자', 1543),
#  ('그램', 1028),
#  ('소통', 861),
#  ('맛집', 813),
#  ('일상', 751),
#  ('선팔', 527),
#  ('스타', 526),
#  ('먹방', 291),
#  ('음식', 273),
#  ('환영', 257),
#  ('파스타', 222),
#  ('댓글', 222),
#  ('반사', 211),
#  ('줄', 203),
#  ('인스타', 202),
#  ('댓', 200),
#  ('추천', 189),
#  ('맛', 181),
#  ('오늘', 164),
#  ('데', 157),
#  ('여행', 155),
#  ('반', 155),
#  ('일리', 154),
#  ('가족', 152),
#  ('광주', 146),
#  ('우리', 140),
#  ('일상생활', 140),
#  ('국수', 136),
#  ('밥상', 136),
#  ('행복', 129),
#  ('가을', 127),
#  ('시', 125),
#  ('주문', 124),
#  ('네일', 124),
#  ('배달', 121),
#  ('순간', 120),
#  ('점', 115),
#  ('이벤트', 115),
#  ('수유', 114),
#  ('집', 108),
#  ('아이', 102),
#  ('요리', 101),
#  ('치즈', 98),
#  ('스파게티', 97),
#  ('스테이크', 95),
#  ('존맛', 90),
#  ('곳', 89),
#  ('피가로', 88),
#  ('어린이집', 86),
#  ('시작', 86),
#  ('휴식시간', 85),
#  ('메뉴', 84),
#  ('차', 83),
#  ('생각', 83),
#  ('음색', 80),
#  ('깡패', 80),
#  ('졸업', 80),
#  ('대학로', 79),
#  ('후', 77),
#  ('홀', 77),
#  ('팔해', 77),
#  ('눈', 76),
#  ('한국인', 76),
#  ('안', 75),
#  ('전시', 75),
#  ('호강', 74),
#  ('침', 74),
#  ('뭐', 73),
#  ('옴', 73),
#  ('입', 72),
#  ('통합', 72),
#  ('강원도', 72),
#  ('로우', 71),
#  ('만원', 71),
#  ('에어비앤비', 71),
#  ('서귀포', 71),
#  ('긍정', 70),
#  ('네일아트', 70),
#  ('홍대', 70),
#  ('사람', 69),
#  ('돼지', 69),
#  ('곱창', 69),
#  ('신월동', 69),
#  ('것', 68),
#  ('추가', 68),
#  ('하동', 68),
#  ('해', 68),
#  ('함', 68),
#  ('핫', 67),
#  ('유치원', 67),
#  ('기절', 67),
#  ('대교', 67),
#  ('강릉', 67),
#  ('곧', 67),
#  ('간판', 67),
#  ('샐러드', 67),
#  ('새해', 67),
#  ('재첩', 66),
#  ('퇴사', 66),
#  ('댄스', 66),
#  ('타투', 66),
#  ('전대', 66),
#  ('고냥이', 65),
#  ('기록', 65),
#  ('먹기', 65),
#  ('나들이', 65),
#  ('여자', 65),
#  ('팝핑', 65),
#  ('당첨', 65),
#  ('입학', 64),
#  ('두피', 64),
#  ('문신', 64),
#  ('월', 64),
#  ('익선동', 64),
#  ('아기', 64),
#  ('골프공', 64),
#  ('시래기', 63),
#  ('비밀', 63),
#  ('안압지', 63),
#  ('야경', 63),
#  ('에스컬레이터', 63),
#  ('편집', 63),
#  ('갈라', 63),
#  ('옷', 62),
#  ('메시지', 62),
#  ('마켓', 62),
#  ('난', 62),
#  ('죠스', 62),
#  ('시베리아', 62),
#  ('횡단', 62),
#  ('열차', 62),
#  ('계절', 62),
#  ('우회', 61),
#  ('성비', 60),
#  ('일기', 60),
#  ('녜', 60),
#  ('가요', 60),
#  ('선', 60),
#  ('밴드', 59),
#  ('여름', 59),
#  ('부천', 59),
#  ('끝', 59),
#  ('전복', 59),
#  ('예약', 59),
#  ('봉', 58),
#  ('감칠맛', 58),
#  ('추억', 58),
#  ('빵', 57),
#  ('잔', 57),
#  ('프로', 57),
#  ('영양', 57),
#  ('공급', 57),
#  ('미니', 57),
#  ('이태원', 57),
#  ('구조도', 56),
#  ('쥬', 56),
#  ('칵테일', 56),
#  ('근교', 56),
#  ('꽃', 56),
#  ('캐디', 56),
#  ('미용', 56),
#  ('캐논', 55),
#  ('멋', 55),
#  ('글씨', 55),
#  ('전용', 54),
#  ('디디', 54),
#  ('서우', 53),
#  ('과슈', 53),
#  ('기', 53),
#  ('생신', 53),
#  ('삼계탕', 52),
#  ('분관', 52),
#  ('등', 52),
#  ('날', 52),
#  ('버거', 52),
#  ('금오동', 51),
#  ('꽃집', 51),
#  ('리북집', 50),
#  ('골목', 50),
#  ('정신', 50),
#  ('경품', 50),
#  ('제작', 49),
#  ('일상사진', 49),
#  ('선물', 49),
#  ('설빙', 48),
#  ('단체', 48),
#  ('모임', 48),
#  ('여의도', 48),
#  ('저녁', 47),
#  ('썸', 47),
#  ('맛스타', 45),
#  ('애쉬', 45),
#  ('브라운', 45),
#  ('문어', 45),
#  ('교육', 44),
#  ('고고', 44),
#  ('낚시', 44),
#  ('전남대', 44),
#  ('웨딩', 42),
#  ('부케', 42),
#  ('카페', 42),
#  ('팔로우', 42),
#  ('시간', 41),
#  ('화덕', 41),
#  ('소망', 40),
#  ('소스', 39),
#  ('원', 39),
#  ('층', 37),
#  ('데이트', 37),
#  ('치킨', 36),
#  ('모', 35),
#  ('요기', 35),
#  ('도우', 33),
#  ('맥주', 33),
#  ('발송', 32),
#  ('서울', 31),
#  ('더', 31),
#  ('수제', 31),
#  ('포테이토', 30),
#  ('수', 30),
#  ('친구', 30),
#  ('떡볶이', 29),
#  ('진짜', 28),
#  ('무료', 28),
#  ('가능', 28),
#  ('야식', 27),
#  ('및', 27),
#  ('민족', 27),
#  ('명', 27),
#  ('가득', 26),
#  ('팔', 26),
#  ('마지막', 26),
#  ('피자스쿨', 25),
#  ('갈비', 25),
#  ('공원', 25),
#  ('페퍼로니', 25),
#  ('브레이크', 25),
#  ('타임', 25),
#  ('또', 24),
#  ('주차장', 24),
#  ('준비', 24),
#  ('텍사스', 24),
#  ('점심', 24),
#  ('유기농', 24),
#  ('중공업', 24),
#  ('개인정보', 24),
#  ('필라프', 23),
#  ('북구', 23),
#  ('용봉동', 23),
#  ('고구마', 22),
#  ('커피', 22),
#  ('광역시', 22),
#  ('호산', 22),
#  ('동명', 22),
#  ('연중', 22),
#  ('무', 22),
#  ('후문', 22),
#  ('각종', 22),
#  ('불고기', 21),
#  ('피맥', 20),
#  ('인스타그램', 20),
#  ('나', 20),
#  ('때', 20),
#  ('림프', 19),
#  ('갈릭', 19),
#  ('토마토', 19),
#  ('콜라', 19),
#  ('브런치', 19),
#  ('상품권', 19),
#  ('제주', 18),
#  ('새우', 18),
#  ('다이어트', 18),
#  ('쉬', 18),
#  ('신세계', 18),
#  ('참여', 18),
#  ('바로', 17),
#  ('토핑', 17),
#  ('맘', 17),
#  ('사진', 17),
#  ('파파존스', 17),
#  ('일', 17),
#  ('크림', 17),
#  ('상품', 17),
#  ('게시', 17),
#  ('수령', 17),
#  ('응모', 17),
#  ('이', 16),
#  ('옥수수', 16),
#  ('내', 16),
#  ('인생', 16),
#  ('양식', 16),
#  ('리조또', 16),
#  ('인테리어', 16),
#  ('년', 16),
#  ('기념', 16),
#  ('응원', 16),
#  ('추첨', 16),
#  ('물', 16),
#  ('수집', 16),
#  ('방문', 15),
#  ('반죽', 15),
#  ('리', 15),
#  ('분위기', 15),
#  ('닭', 15),
#  ('감자', 15),
#  ('튀김', 15),
#  ('마르', 15),
#  ('술', 15),
#  ('고르곤졸라', 15),
#  ('가지', 15),
#  ('할인', 15),
#  ('여러분', 15),
#  ('위', 14),
#  ('감성', 14),
#  ('푸드', 14),
#  ('집밥', 14),
#  ('매일', 14),
#  ('체험', 14),
#  ('와인', 14),
#  ('금', 14),
#  ('화', 14),
#  ('레스토랑', 14),
#  ('울산', 14),
#  ('영등포', 13),
#  ('방법', 13),
#  ('주말', 13),
#  ('너', 12),
#  ('조합', 12),
#  ('통', 12),
#  ('비', 12),
#  ('만', 12),
#  ('오븐', 12),
#  ('정말', 12),
#  ('베이컨', 12),
#  ('신년', 12),
#  ('계란', 12),
#  ('배민', 12),
#  ('도미노피자', 12),
#  ('생면', 12),
#  ('명동', 11),
#  ('미국', 11),
#  ('꼭', 11),
#  ('직접', 11),
#  ('인', 11),
#  ('매콤', 11),
#  ('코스트코', 11),
#  ('판매', 11),
#  ('완전', 11),
#  ('앤', 11),
#  ('여기', 11),
#  ('분당', 11),
#  ('맞이', 11),
#  ('쿠팡', 11),
#  ('츠', 11),
#  ('게리', 11),
#  ('사용', 11),
#  ('저', 10),
#  ('말', 10),
#  ('하나', 10),
#  ('도', 10),
#  ('거', 10),
#  ('제주도', 10),
#  ('멕시칸', 10),
#  ('역', 10),
#  ('번', 10),
#  ('감', 10),
#  ('육아', 10),
#  ('오픈', 10),
#  ('전주', 10),
#  ('하프', 10),
#  ('전', 10),
#  ('구청', 10),
#  ('다음', 10),
#  ('서현', 10),
#  ('산', 10),
#  ('스파이', 10),
#  ('일산', 10),
#  ('남해', 10),
#  ('안내', 10),
#  ('발표', 10),
#  ('사이드', 9),
#  ('가게', 9),
#  ('포장', 9),
#  ('문의', 9),
#  ('덕후', 9),
#  ('가성', 9),
#  ('바베큐', 9),
#  ('밥', 9),
#  ('양배추', 9),
#  ('페페로니', 9),
#  ('아들', 9),
#  ('어제', 9),
#  ('위해', 9),
#  ('분', 9),
#  ('로', 9),
#  ('토', 9),
#  ('태그', 9),
#  ('배송', 9),
#  ('성남', 9),
#  ('유머', 9),
#  ('참이슬', 9),
#  ('테라스', 9),
#  ('병', 9),
#  ('기간', 9),
#  ('중복', 9),
#  ('유지', 9),
#  ('지급', 9),
#  ('조선', 9),
#  ('오일', 8),
#  ('모두', 8),
#  ('개', 8),
#  ('부산', 8),
#  ('운동', 8),
#  ('선택', 8),
#  ('가격', 8),
#  ('만들기', 8),
#  ('키친', 8),
#  ('엄마', 8),
#  ('사랑', 8),
#  ('동네', 8),
#  ('청년', 8),
#  ('회', 8),
#  ('바', 8),
#  ('서비스', 8),
#  ('피자헛', 8),
#  ('키즈', 8),
#  ('조금', 8),
#  ('포레', 8),
#  ('디몬', 8),
#  ('방송국', 8),
#  ('그니', 8),
#  ('카라멜', 8),
#  ('라이즈', 8),
#  ('하와이', 8),
#  ('베트남', 8),
#  ('작성', 8),
#  ('달기', 8),
#  ('기도', 8),
#  ('해시태그', 8),
#  ('확률', 8),
#  ('통해', 8),
#  ('선정', 8),
#  ('계정', 8),
#  ('결과', 8),
#  ('공지', 8),
#  ('한해', 8),
#  ('관', 8),
#  ('추후', 8),
#  ('자의', 8),
#  ('응답', 8),
#  ('불이익', 8),
#  ('본인', 8),
#  ('책임', 8),
#  ('파기', 8),
#  ('건설', 8),
#  ('도시락', 8),
#  ('월드', 7),
#  ('환상', 7),
#  ('그냥', 7),
#  ('시카고', 7),
#  ('주소', 7),
#  ('길', 7),
#  ('제', 7),
#  ('더블', 7),
#  ('한번', 7),
#  ('바이트', 7),
#  ('고기', 7),
#  ('식당', 7),
#  ('잠실', 7),
#  ('식단', 7),
#  ('살', 7),
#  ('막', 7),
#  ('최고', 7),
#  ('인친', 7),
#  ('중', 7),
#  ('건대', 7),
#  ('처음', 7),
#  ('재료', 7),
#  ('듬뿍', 7),
#  ('제일', 7),
#  ('역시', 7),
#  ('보이', 7),
#  ('이탈리안', 7),
#  ('부식', 7),
#  ('러스트', 7),
#  ('처', 7),
#  ('뇨끼', 7),
#  ('안주', 7),
#  ('인분', 7),
#  ('반올림', 7),
#  ('미사', 7),
#  ('코지', 7),
#  ('동대문', 6),
#  ('사장', 6),
#  ('이드', 6),
#  ('리보스', 6),
#  ('쫄깃', 6),
#  ('바삭', 6),
#  ('매장', 6),
#  ('사이즈', 6),
#  ('세상', 6),
#  ('간식', 6),
#  ('생활', 6),
#  ('식감', 6),
#  ('퀄리티', 6),
#  ('앞', 6),
#  ('까르보나라', 6),
#  ('덕', 6),
#  ('왜', 6),
#  ('베', 6),
#  ('이제', 6),
#  ('둘', 6),
#  ('커플', 6),
#  ('작가', 6),
#  ('이케아', 6),
#  ('보고', 6),
#  ('아빠', 6),
#  ('캠핑', 6),
#  ('김치', 6),
#  ('전서구', 6),
#  ('막둥이', 6),
#  ('입맛', 6),
#  ('슈퍼', 6),
#  ('부림', 6),
#  ('족발', 6),
#  ('신촌', 6),
#  ('하루', 6),
#  ('를', 6),
#  ('좀', 6),
#  ('초등학교', 6),
#  ('일요일', 6),
#  ('향', 6),
#  ('마음', 6),
#  ('요즘', 6),
#  ('드림', 6),
#  ('빠', 6),
#  ('고민', 6),
#  ('모어', 6),
#  ('성북동', 6),
#  ('한남동', 6),
#  ('성수', 6),
#  ('밀', 6),
#  ('가래떡', 6),
#  ('풍동', 6),
#  ('가로수길', 6),
#  ('고객', 6),
#  ('롯데', 6),
#  ('타바스코', 6),
#  ('앱', 6),
#  ('마녀', 6),
#  ('지금', 5),
#  ('손', 5),
#  ('밤', 5),
#  ('톳', 5),
#  ('코피', 5),
#  ('잔뜩', 5),
#  ('한라산', 5),
#  ('필수', 5),
#  ('뷰', 5),
#  ('힙', 5),
#  ('위치', 5),
#  ('비프', 5),
#  ('피', 5),
#  ('그', 5),
#  ('하와', 5),
#  ('이안', 5),
#  ('게', 5),
#  ('술집', 5),
#  ('띠', 5),
#  ('세트', 5),
#  ('먹음', 5),
#  ('세라', 5),
#  ('완성', 5),
#  ('마로', 5),
#  ('대전', 5),
#  ('종류', 5),
#  ('관저동', 5),
#  ('개월', 5),
#  ('크런치', 5),
#  ('은', 5),
#  ('돈까스', 5),
#  ('콘치', 5),
#  ('미트', 5),
#  ('음식사진', 5),
#  ('두', 5),
#  ('파', 5),
#  ('은평구', 5),
#  ('타코', 5),
#  ('일주일', 5),
#  ('회식', 5),
#  ('돈', 5),
#  ('덜', 5),
#  ('투어', 5),
#  ('라스트', 5),
#  ('볶음밥', 5),
#  ('배', 5),
#  ('투', 5),
#  ('소주', 5),
#  ('치코', 5),
#  ('성수동', 5),
#  ('컴퍼니', 5),
#  ('모짜렐라', 5),
#  ('힐', 5),
#  ('모든', 5),
#  ('진리', 5),
#  ('주부', 5),
#  ('혜택', 5),
#  ('삼총사', 5),
#  ('메', 5),
#  ('라운드', 5),
#  ('노', 5),
#  ('시장', 5),
#  ('겨울', 5),
#  ('본점', 5),
#  ('백종원', 5),
#  ('빽', 5),
#  ('호치민', 5),
#  ('홈쿡', 5),
#  ('테이블', 5),
#  ('면', 5),
#  ('쌀', 5),
#  ('창업', 5),
#  ('기본', 5),
#  ('연남', 5),
#  ('껍질', 5),
#  ('스', 4),
#  ('영업', 4),
#  ('미노', 4),
#  ('리얼', 4),
#  ('엣지', 4),
#  ('가야', 4),
#  ('해녀', 4),
#  ('현무암', 4),
#  ('먹물', 4),
#  ('용암', 4),
#  ('제주시', 4),
#  ('휴무', 4),
#  ('광안', 4),
#  ('비쥬', 4),
#  ('르', 4),
#  ('하바네로', 4),
#  ('이유', 4),
#  ('적', 4),
#  ('라면', 4),
#  ('수비드', 4),
#  ('송파', 4),
#  ('올리브', 4),
#  ('시금치', 4),
#  ('형제', 4),
#  ('원래', 4),
#  ('근처', 4),
#  ('계', 4),
#  ('반지', 4),
#  ('귀걸이', 4),
#  ('뮤지컬', 4),
#  ('분식', 4),
#  ('닉', 4),
#  ('라떼', 4),
#  ('이태리', 4),
#  ('무스', 4),
#  ('동생', 4),
#  ('카', 4),
#  ('전화', 4),
#  ('백화점', 4),
#  ('심지어', 4),
#  ('시크릿', 4),
#  ('리뷰', 4),
#  ('기분', 4),
#  ('내일', 4),
#  ('칼로리', 4),
#  ('볼', 4),
#  ('리타', 4),
#  ('가장', 4),
#  ('콰트로', 4),
#  ('다른', 4),
#  ('음료', 4),
#  ('느낌', 4),
#  ('무한리필', 4),
#  ('늘', 4),
#  ('협찬', 4),
#  ('스튜디오', 4),
#  ('단', 4),
#  ('디핑', 4),
#  ('먼저', 4),
#  ('문자', 4),
#  ('장소', 4),
#  ('나이', 4),
#  ('중앙', 4),
#  ('생맥주', 4),
#  ('평일', 4),
#  ('콘', 4),
#  ('염', 4),
#  ('시카고피자', 4),
#  ('첫', 4),
#  ('연남동', 4),
#  ('부터', 4),
#  ('딸기', 4),
#  ('초', 4),
#  ('방학', 4),
#  ('연인', 4),
#  ('바스', 4),
#  ('종로', 4),
#  ('쭈꾸미', 4),
#  ('피클', 4),
#  ('베이', 4),
#  ('맛팔', 4),
#  ('김치찌개', 4),
#  ('직원', 4),
#  ('의정부', 4),
#  ('바질', 4),
#  ('페스', 4),
#  ('이탈리아', 4),
#  ('비바', 4),
#  ('로마', 4),
#  ('한판', 4),
#  ('포', 4),
#  ('카드', 4),
#  ('결제', 4),
#  ('출근', 4),
#  ('목표', 4),
#  ('화요일', 4),
#  ('모란', 4),
#  ('재미', 4),
#  ('쏠쏠', 4),
#  ('자극', 4),
#  ('대연동', 4),
#  ('납품', 4),
#  ('과천', 4),
#  ('취향', 4),
#  ('간', 4),
#  ('보', 4),
#  ('쿠우', 4),
#  ('오레가노', 4),
#  ('효과', 4),
#  ('혼밥', 4),
#  ('알리오', 4),
#  ('행신동', 4),
#  ('마포구', 4),
#  ('강남', 4),
#  ('하남', 4),
#  ('광고', 4),
#  ('직영', 4),
#  ('영점', 4),
#  ('기회', 4),
#  ('진행', 4),
#  ('해공', 4),
#  ('드', 4),
#  ('호텔', 4),
#  ('랫댓', 4),
#  ('해외', 4),
#  ('모습', 3),
#  ('궁합', 3),
#  ('콤보', 3),
#  ('각', 3),
#  ('듯', 3),
#  ('행사', 3),
#  ('블랙', 3),
#  ('수목원', 3),
#  ('코스', 3),
#  ('오션', 3),
#  ('알', 3),
#  ('판', 3),
#  ('미스터피자', 3),
#  ('최애', 3),
#  ('라지', 3),
#  ('레귤러', 3),
#  ('잘못', 3),
#  ('씬', 3),
#  ('멕시코', 3),
#  ('움', 3),
#  ('삼겹살', 3),
#  ('극찬', 3),
#  ('모양', 3),
#  ('어디', 3),
#  ('파인애플', 3),
#  ('자체', 3),
#  ('립', 3),
#  ('톡', 3),
#  ('송리', 3),
#  ('마무리', 3),
#  ('양파', 3),
#  ('떡', 3),
#  ('자매', 3),
#  ('수다', 3),
#  ('띠맘', 3),
#  ('이크', 3),
#  ('핫도그', 3),
#  ('램', 3),
#  ('얼마', 3),
#  ('구미', 3),
#  ('실', 3),
#  ('블로그', 3),
#  ('크리', 3),
#  ('에디터', 3),
#  ('유트브', 3),
#  ('크루', 3),
#  ('악세사리', 3),
#  ('쇼핑몰', 3),
#  ('소상', 3),
#  ('공인', 3),
#  ('갈비탕', 3),
#  ('강강술래', 3),
#  ('봄', 3),
#  ('수업', 3),
#  ('영상', 3),
#  ('또띠아', 3),
#  ('사', 3),
#  ('트', 3),
#  ('햄버거', 3),
#  ('제대로', 3),
#  ('제로', 3),
#  ('메이드', 3),
#  ('쥬스', 3),
#  ('외식', 3),
#  ('조각', 3),
#  ('피망', 3),
#  ('용인', 3),
#  ('딸', 3),
#  ('퇴근', 3),
#  ('한잔', 3),
#  ('파파스', 3),
#  ('위스키', 3),
#  ('자주', 3),
#  ('프로필', 3),
#  ('뇨', 3),
#  ('그림', 3),
#  ('널', 3),
#  ('세계', 3),
#  ('동안', 3),
#  ('살이', 3),
#  ('우동', 3),
#  ('정도', 3),
#  ('만족', 3),
#  ('저희', 3),
#  ('소세지', 3),
#  ('체다', 3),
#  ('겨울방학', 3),
#  ('세종시', 3),
#  ('클래식', 3),
#  ('게다가', 3),
#  ('편', 3),
#  ('핫소스', 3),
#  ('성남시', 3),
#  ('분당구', 3),
#  ('돌', 3),
#  ('효자', 3),
#  ('촌', 3),
#  ('프라자', 3),
#  ('학년', 3),
#  ('공휴일', 3),
#  ('방과후', 3),
#  ('율동', 3),
#  ('실내', 3),
#  ('레드', 3),
#  ('사이', 3),
#  ('절로', 3),
#  ('직장인', 3),
#  ('플롭', 3),
#  ('제공', 3),
#  ('휴가', 3),
#  ('피드', 3),
#  ('스토리', 3),
#  ('당근', 3),
#  ('붕어빵', 3),
#  ('감자탕', 3),
#  ('국내', 3),
#  ('야시장', 3),
#  ('싱글', 3),
#  ('찬스', 3),
#  ('이프', 3),
#  ('이상', 3),
#  ('밀가루', 3),
#  ('식사', 3),
#  ('목', 3),
#  ('서현역', 3),
#  ('로제', 3),
#  ('절친', 3),
#  ('남편', 3),
#  ('광택', 3),
#  ('유리', 3),
#  ('코팅', 3),
#  ('최소', 3),
#  ('대신', 3),
#  ('답', 3),
#  ('휴일', 3),
#  ('한국', 3),
#  ('인기', 3),
#  ('킹', 3),
#  ('해수욕장', 3),
#  ('종종', 3),
#  ('집들이', 3),
#  ('탕', 3),
#  ('상봉', 3),
#  ('푸드코트', 3),
#  ('출시', 3),
#  ('재', 3),
#  ('첩국', 3),
#  ('냉동', 3),
#  ('골프', 3),
#  ('택배', 3),
#  ('라자냐', 3),
#  ('날씨', 3),
#  ('외출', 3),
#  ('봉덕동', 3),
#  ('네이버', 3),
#  ('덕천', 3),
#  ('만덕', 3),
#  ('올해', 3),
#  ('건강', 3),
#  ('인연', 3),
#  ('누브', 3),
#  ('티스', 3),
#  ('넥타이', 3),
#  ('박물관', 3),
#  ('소개', 3),
#  ('달콤', 3),
#  ('누구', 3),
#  ('당장', 3),
#  ('스트리트', 3),
#  ('이름', 3),
#  ('아주', 3),
#  ('메인', 3),
#  ('이번', 3),
#  ('마루', 3),
#  ('인천', 3),
#  ('힐링', 3),
#  ('다시', 3),
#  ('티', 3),
#  ('마을', 3),
#  ('전부', 3),
#  ('안덕면', 3),
#  ('중문', 3),
#  ('키트', 3),
#  ('디저트', 3),
#  ('토핑킹', 3),
#  ('조화', 3),
#  ('얼', 3),
#  ('홈', 3),
#  ('번가', 3),
#  ('나트랑', 3),
#  ('리오', 3),
#  ('브리', 3),
#  ('항정살', 3),
#  ('메주', 3),
#  ('당', 3),
#  ('실장', 3),
#  ('공간', 3),
#  ('디자인', 3),
#  ('디아', 3),
#  ('달', 3),
#  ('책', 3),
#  ('신제품', 3),
#  ('롱', 3),
#  ('토마토소스', 3),
#  ('트러플', 3),
#  ('해산물', 3),
#  ('라비올리', 3),
#  ('확인', 3),
#  ('아현', 3),
#  ('한우', 3),
#  ('변', 3),
#  ('식전', 3),
#  ('공짜', 3),
#  ('천국', 3),
#  ('주방', 3),
#  ('프로모션', 3),
#  ('쿠폰', 3),
#  ('하우스', 3),
#  ('진영', 3),
#  ('교현', 3),
#  ('웨이팅', 3),
#  ('목동', 3),
#  ('양천구', 3),
#  ('민벅', 3),
#  ('임실', 3),
#  ('등산', 3),
#  ('미이라', 3),
#  ('링겔', 3),
#  ('히비스커스', 3),
#  ('마사지', 3),
#  ('무이네', 3),
#  ('알볼', 3),
#  ('클래스', 2),
#  ('현대', 2),
#  ('시티', 2),
#  ('아울렛', 2),
#  ('끝판', 2),
#  ('왕십리', 2),
#  ('논현', 2),
#  ('예정', 2),
#  ('복', 2),
#  ('푸파', 2),
#  ('종합', 2),
#  ('게시판', 2),
#  ('메뉴판', 2),
#  ('중구', 2),
#  ('하층', 2),
#  ('타이거', 2),
#  ('욥', 2),
#  ...]

# %%
wc = WordCloud(max_font_size=40, background_color="white", max_words=1000,
               font_path="C:\\Windows\\Fonts\\malgun.ttf").generate_from_frequencies(dict(rank_text))

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# 불러오기
result3 = pd.read_csv("data/피자2.csv")

# %%
result3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951 entries, 0 to 950
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  951 non-null    object
#  1   Like      951 non-null    int64
#  2   ID        951 non-null    object
#  3   Tags      951 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 29.8+ KB

# %%
result3['Like'].mean()
# Out:
# 19.400630914826497

# %%
result3 = result3[result3['Like']>=19]
result3
# Out:
#                                               Contents  Like              ID  \
# 0    우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493  st_foodfighter
# 1    오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101    10tia____a04
# 2      제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681     gyeongboki_
# 3    광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191    todays_busan
# 4     피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309     honey_unni_
# ..                                                 ...   ...             ...
# 877  강남역에 마녀가 있다구 마녀주방에 가면 마녀와 마주할 수 있다 들어서자마자 신기했다...    19       adpr_song
# 916   피자스톰  _ 내돈내산  자주 배달시켜 먹는 곳이에요  우연히 시켜 먹었다가 맛있...    59    baebae_plate
# 929     나트랑 Day  2쌀국수 맛집이군  현지식은 호텔 조식만 먹어도 충분할듯  비...    27      nation.top
# 930   무이네  맛집스타그램 어제 오늘 들른 두 식당 다 바다 바로 옆이라  분위기맛집 ...    29        ggonyage
# 944  이것은 그냥 피맥이 아니여다이빙 하고 나와서 먹는 피맥이여   피맥  피자  맥주 ...    55    glorious.o_o
#
#                                                   Tags
# 0    ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1                                                   []
# 2    ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3                           ['#포르타나광안리', '#오늘의부산_광안리']
# 4    ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...
# ..                                                 ...
# 877  ['#강남', '#마녀주방', '#마녀', '#미이라', '#피자', '#미이라포테...
# 916  ['#내돈내산].자주', '#먹스타', '#먹스타그램', '#먹부림', '#야식스타...
# 929  ['#베트남', '#나트랑', '#여행', '#호캉스', '#조식', '#피자', ...
# 930  ['#무이네', '#맛집스타그램', '#분위기맛집', '#matadorgrillba...
# 944  ['#피맥', '#피자', '#맥주', '#산미구엘', '#먹스타그램', '#필리핀...
#
# [115 rows x 4 columns]

# %%
# 저장
result3.to_csv("data/피자3.csv", encoding="utf-8", index=False)

# %%
# 불러오기
result3 = pd.read_csv("data/피자3.csv")

# %%
result3
# Out:
#                                               Contents  Like              ID  \
# 0    우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1493  st_foodfighter
# 1    오늘 늦은 저녁은 피자   도미노에서 피자 1 1 행사를 하길래저녁은 도미노에서 포...   101    10tia____a04
# 2      제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   681     gyeongboki_
# 3    광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서...  1191    todays_busan
# 4     피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ ...  1309     honey_unni_
# ..                                                 ...   ...             ...
# 110  강남역에 마녀가 있다구 마녀주방에 가면 마녀와 마주할 수 있다 들어서자마자 신기했다...    19       adpr_song
# 111   피자스톰  _ 내돈내산  자주 배달시켜 먹는 곳이에요  우연히 시켜 먹었다가 맛있...    59    baebae_plate
# 112     나트랑 Day  2쌀국수 맛집이군  현지식은 호텔 조식만 먹어도 충분할듯  비...    27      nation.top
# 113   무이네  맛집스타그램 어제 오늘 들른 두 식당 다 바다 바로 옆이라  분위기맛집 ...    29        ggonyage
# 114  이것은 그냥 피맥이 아니여다이빙 하고 나와서 먹는 피맥이여   피맥  피자  맥주 ...    55    glorious.o_o
#
#                                                   Tags
# 0    ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 1                                                   []
# 2    ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# 3                           ['#포르타나광안리', '#오늘의부산_광안리']
# 4    ['#피자', '#피자스쿨', '#피자맛집', '#피자추천', '#피자맛집', '#...
# ..                                                 ...
# 110  ['#강남', '#마녀주방', '#마녀', '#미이라', '#피자', '#미이라포테...
# 111  ['#내돈내산].자주', '#먹스타', '#먹스타그램', '#먹부림', '#야식스타...
# 112  ['#베트남', '#나트랑', '#여행', '#호캉스', '#조식', '#피자', ...
# 113  ['#무이네', '#맛집스타그램', '#분위기맛집', '#matadorgrillba...
# 114  ['#피맥', '#피자', '#맥주', '#산미구엘', '#먹스타그램', '#필리핀...
#
# [115 rows x 4 columns]

# %%
import time
from tqdm import tqdm_notebook

content_all = ''
for i in tqdm_notebook(range(len(result3["Contents"]))):
    content_all = content_all + ' ' + result3["Contents"].loc[i]
# Out:
# C:\Users\mhpark\AppData\Local\Temp\ipykernel_158184\1924726849.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(result3["Contents"]))):
#   0%|          | 0/115 [00:00<?, ?it/s]

# %%
import re
content_all = re.sub('[^ㄱ-ㅣ가-힣 ]',"",content_all)
content_all
# Out:
# ' 우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한 피자집이 있다고해서 논란의 곳이 있다고 해서 왔다  미칠듯이 늘어나는 명동피자의 쫜득함부터 고소한 치즈의 풍미를 품고 있는 저 모습이 보이는가  또 사이드메뉴들의 환상적인 궁합은 왤케 잘 어울려지는지 이게 진정한 핵가족급 콤보라고 말할수 있는  명동피자 명동을 넘어 동대문으로 명동피자를 방문했다  명동피자가 현대시티아울렛 안으로 투입됨에 현대사장님은 두손두발 다들고 환대각이었을 것이다  피자부터 파스타  에이드까지 머하나 부족함이 없는 이곳  치즈 끝판왕 피자에 치즈폭포를 만들어 치즈가 엄청나게 올려져서 나오는데 진짜 장관이다 현재직영매장이 동대문점  명동점을 빼고도 왕십리와 신논현에도 있다는게   서울을 집어삼킬 예정인가    그냥 미국의 시카고에 있는 핫플 피자가게를 복붙시켜놓은듯한 퓔링은 뽀너스  동대문에 있는 존맛피자맛집인 명동피자를 함께 스푸파 종합 게시판으로 알아보자      스푸파의 종합 게시판        명동피자 메뉴판  치즈끝판왕피자     투움바로제파스타     만수르피자     명란오일파스타    가게 주소   서울 중구 을지로가 장충단로길  현대시티아울렛 지하층 가게 영업시간        인스타      너 피자계의 손흥민이라고 들어는 봤냐     그게 바로 명동피자야    명동피자동대문점  피자맛집  파스타맛집  동대문맛집  피자      스푸파동대문 오늘 늦은 저녁은 피자   도미노에서 피자   행사를 하길래저녁은 도미노에서 포장해와서 먹었어요 제가 좋아하는 블랙타이거 슈림프 블랙앵거스 스테이크랑 포테이토 리얼불고기 더블치즈엣지  다들 오늘 저녁은 맛있는 거 드셨나요  모두 오늘 밤도 햅삐하게 보내시길 바라욥    제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보              개 제주돌담 몸통으로 박살내고 가야하는 피자집이다 쬰득쫄깃한 톳도우 위에 제주스러운 토핑 한가득  제주 연동  리보스코피자제주도 리보스코피자의 도우는 해녀가 잡은 톳으로부드러우면서 쫄깃한 도우를 만들어 더 맛있는데요 현무암이 잔뜩 올려진 제주도이색  현무암치킨피자 녹진한 오징어 먹물로 반죽한 현무암치킨인데요   일반 반죽보다 더 바삭하고 녹진한 치킨피자조합  통새우가 가득찬 한라산 용암치즈  한라산용암피자 칠리소스옷 입은 새우 최고급 치즈 쫀득한 톳도우  삼위일체고요    제주에 오시면 꼭 한번 드셔보세요 리보스코피자에서 직접만든 수제맥주는 필수에요  리보스코피자        제주 제주시 수목원길         매주 월요일 휴무  주차장 매장문의  현무암치킨 피자     한라산용암 피자     리보스코 맥주    맛집경보제주  제주여행  제주맛집  제주도맛집  제주시맛집  연동맛집 제주피자맛집추천  제주피자맛집  피자맛집 광안리  포르타나광안리 필수코스라는치즈 토핑 가득미국 감성 피자맛집  오션뷰 보면서 먹는피맥 조합도 상당한데 퐁실퐁실한 도우에힙한 분위기까지 찢었다    오션뷰 치즈 쭈아압 피자 ㄱ 위치부산광역시 수영구 광안로번길  오늘의부산광안리  피자덕후가 강추하는 존맛  피자 모음집 진짜 다 먹어버리고 시픈 비쥬얼이당 ㅠㅠ  오늘 피맥하쟈                         더 많은 꿀팁을 알고 싶다면      피자스쿨  피자맛집  피자추천  피자맛집  피자맛집추천  야식메뉴추천  야식추천메뉴  배달맛집  배달맛집추천  고구마피자  치즈피자  피자메뉴  서울맛집추천 딩동댕동  가성비 피자학교 입학준비   피자스쿨 출석할 시간이양   피자 땡기는데 너무 비싸다구 ㅜㅜ갓성비 피자맛집 피자스쿨이 있짜나  갈릭소스 추가는 필수인거 알지     인 판 도전각  ㅎㅎ     피자스쿨  피자추천  피자맛집  피자덕후  피자러버  가성비  가성비피자  피자스쿨메뉴  피자스쿨추천  피자스쿨메뉴추천  피자스쿨피자추천  야식  야식추천  메뉴추천  신메뉴  오지치즈포테이토피자  고구마피자  까르보네피자  더블갈릭바베큐피자  닭안심살피자  멕시칸바이트피자  비프퀘사디아피자  도이치바이트피자  고구마피자  포테이토피자  맛스타그램  피맥  피자스타그램 미스터피자에서 최애를 뽑는다면 단연 멕시칸 하바네로  멕시칸하바네로피자  미스터피자홈파티 하는데 피자가 빠질 수 없지 ㅋㅋ배달음식 이것저것 시키고 석화도 하프셸로 준비   멕시칸 하바네로     근데 멕시칸 하바네로 라지인줄 알았는데 레귤러로 잘못 시킴 ㅋㅋㅋㅋㅋ 아놔 빵이 반이네   그래도 다들 매콤하니 맛있다고 좋아했다 ㅋㅋㅋ 횐님들은 씬으로 라지 사이즈 꼭 드세요    멕시코 갈 필요 없습니다  맛있게 잘 먹었습니다   피자맛집  멕시칸  멕시코음식  배달맛집  홈파티  피자  미피  서울맛집  소통  일상  좋아요  선팔맞팔  먹팔  맛집   푸드스타그램   집밥스타그램  맛집스타그램  먹스타그램             세상 부러운 모태 마름쟁이들 특징 진짜 마른 사람들 너무 부러움근데 보면 마른 이유가 다 있더라    이거 너 아니냥       마른사람  모태마름  날씬  다이어트  음식  치킨  피자  고기  삼겹살  과자  간식  입짧음  활동량  활동적  기름진음식  배부름  야식  운동  체질 입짧은햇님님이 극찬한 그 피자 맞습니다   네모 모양의 피자에 기맥힌 토핑들이 꽉꽉  줄서는식당  생활의 달인  토요일은 밥이 좋아 등등 여러 미디어에서 극찬받은 어디서도 본 적 없는 특별한 피자겉바속촉한 식감을 구현해낸 네모 모양의 디트로이드 피자인데 아낌없이 꽉꽉 올라간 토핑 퀄리티마저 난리가 났어여     하와이안 갈릭쉬림프 파인애플 피자  는 뚱 뚱한 갈릭쉬림프  시나몬 파인애플 조합의 피자인데 토톡 터지는 왕새우랑 꼬수운 잣덕에 식감까지 예술 그 자체ㅠㅠ 새우덕후  하와이안피자 덕후라면 꼭꼭 사수하세요     텍사스 수비드 비프립 피자  는 피자덕후 피자힙 순위 메뉴   첫방문이라면 무조건 이거 드세요ㅠㅠ 주문하면 우선 훈연한 우대갈비가 연기 뿜으며 등장하는데 눈 앞에서 바로 손질해 도우 위에 뭉텅뭉텅 얹어주십니다  시간 수비드 조리한 우대갈비가 피자 토핑이라니   시각도 후각도 미각도 걍 넘 행복했어여  맥주랑두 찰떡 잘하는 집이 다 잘한다구 파스타두 잘해요ㅠㅠ 까르보나라 소스 가득한 에그톡까르보나라도 꾸우우우우덕한게 도랐   맥주는 선택 아닌 필쑤ㅠㅠㅠ 맛 보면 아십니당      피자덕후 피자힙 송리단길점  하와이안 갈릭 쉬림프 파인애플 피자    텍사스 수비드 비프립 피자    에그톡 까르보나라 리카토니      송파나루역 번 출구에서   매일               은쪼송파  송파맛집  송파나루역맛집  송리단길맛집  송리단길술집  송리단길피자  석촌맛집  잠실맛집  줄서는식당  디트로이드피자  피자  피자덕후피자힙  피자힙 나 야근한다고 우리회사 동네까지 와서피자 사주고 카페 사주고 우리동네로 같이 퇴근함   이 사람이랑 같은 기숙사 살고싶다  이미 별거했지만서두 ㅜㅜ  천안  청년피자  피자  시크릿더블크런치  시크릿더블크런치피자  나초치즈감자튀김  감자튀김  콜라  탄산  먹스타그램  치즈볼  맛있다그램  맛스타그램  먹스타그램                                                                                                                                                                                                                                                                                                            피자                    냠냠         오늘의 야식파파존스 슈퍼파파스 피자 야식  피자  파파존스  슈퍼파파스  존맛  존맛탱 맛있다그램  맛스타그램  먹스타그램  피자스타그램  맥주  테라   일상  소통  좋아요                                              여행  여행스타그램  오이타현  벳푸  온천 피자  맛집   공복  주회 운동 회 휴식하루에 사이클 분 ...

# %%
from konlpy.tag import Okt
okt = Okt()
nouns_txt = okt.nouns(content_all)
nouns_txt
# Out:
# ['우리',
#  '지금',
#  '월드',
#  '클래스',
#  '명동',
#  '피자',
#  '시대',
#  '카타르',
#  '월드컵',
#  '더욱',
#  '핫',
#  '피자',
#  '집',
#  '고해',
#  '논란',
#  '곳',
#  '명동',
#  '피자',
#  '쫜득함',
#  '치즈',
#  '저',
#  '모습',
#  '또',
#  '사이드',
#  '메뉴',
#  '환상',
#  '궁합',
#  '왤케',
#  '이',
#  '핵가족',
#  '콤보',
#  '말',
#  '명동',
#  '피자',
#  '명동',
#  '동대문',
#  '명동',
#  '피자',
#  '방문',
#  '명동',
#  '피자',
#  '현대',
#  '시티',
#  '아울렛',
#  '안',
#  '투입',
#  '사장',
#  '손',
#  '두발',
#  '환대',
#  '각',
#  '것',
#  '피자',
#  '파스타',
#  '이드',
#  '머',
#  '하나',
#  '부족함',
#  '곳',
#  '치즈',
#  '끝판',
#  '피자',
#  '치즈',
#  '폭포',
#  '치즈',
#  '진짜',
#  '장관',
#  '재직',
#  '영매',
#  '동대문',
#  '점',
#  '명동',
#  '점',
#  '왕십리',
#  '논현',
#  '서울',
#  '예정',
#  '그냥',
#  '미국',
#  '시카고',
#  '핫',
#  '피자',
#  '가게',
#  '복',
#  '듯',
#  '퓔링',
#  '뽀너스',
#  '동대문',
#  '존맛',
#  '피자',
#  '맛집',
#  '명동',
#  '피자',
#  '스',
#  '푸파',
#  '종합',
#  '게시판',
#  '스푸파',
#  '종합',
#  '게시판',
#  '명동',
#  '피자',
#  '메뉴판',
#  '치즈',
#  '끝판',
#  '피자',
#  '투움',
#  '바로',
#  '파스타',
#  '만수르',
#  '피자',
#  '명란',
#  '오일',
#  '파스타',
#  '가게',
#  '주소',
#  '서울',
#  '중구',
#  '을지로',
#  '장충단로',
#  '길',
#  '현대',
#  '시티',
#  '아울렛',
#  '하층',
#  '가게',
#  '영업',
#  '시간',
#  '인스타',
#  '너',
#  '피자',
#  '손흥민',
#  '그게',
#  '바로',
#  '명동',
#  '피자',
#  '명동',
#  '피자',
#  '동대문',
#  '점',
#  '피자',
#  '맛집',
#  '파스타',
#  '맛집',
#  '동대문',
#  '맛집',
#  '피자',
#  '스',
#  '푸파',
#  '동대문',
#  '오늘',
#  '저녁',
#  '피자',
#  '도',
#  '미노',
#  '피자',
#  '행사',
#  '저녁',
#  '도',
#  '미노',
#  '포장',
#  '제',
#  '블랙',
#  '타이거',
#  '슈',
#  '림프',
#  '블랙',
#  '앵거스',
#  '스테이크',
#  '포테이토',
#  '리얼',
#  '불고기',
#  '더블',
#  '치즈',
#  '엣지',
#  '오늘',
#  '저녁',
#  '거',
#  '모두',
#  '오늘',
#  '밤',
#  '햅삐하',
#  '욥',
#  '제주',
#  '돌담',
#  '몸통',
#  '박살',
#  '가야',
#  '피자',
#  '집',
#  '맛집',
#  '경보',
#  '개',
#  '제주',
#  '돌담',
#  '몸통',
#  '박살',
#  '가야',
#  '피자',
#  '집',
#  '쬰득쫄깃',
#  '톳',
#  '도우',
#  '위',
#  '제주',
#  '토핑',
#  '제주',
#  '연동',
#  '리보스',
#  '코피',
#  '제주도',
#  '리보스',
#  '코피',
#  '도우',
#  '해녀',
#  '톳',
#  '쫄깃',
#  '도우',
#  '더',
#  '현무암',
#  '잔뜩',
#  '제주도',
#  '이색',
#  '현무암',
#  '치킨',
#  '피자',
#  '오징어',
#  '먹물',
#  '반죽',
#  '현무암',
#  '일반',
#  '반죽',
#  '더',
#  '바삭',
#  '치킨',
#  '피자',
#  '조합',
#  '통',
#  '새우',
#  '가득',
#  '찬',
#  '한라산',
#  '용암',
#  '치즈',
#  '한라산',
#  '용암',
#  '피자',
#  '칠리소스',
#  '옷',
#  '새우',
#  '최고급',
#  '치즈',
#  '쫀득',
#  '톳',
#  '도우',
#  '삼위일체',
#  '고요',
#  '제주',
#  '오시',
#  '꼭',
#  '한번',
#  '리보스',
#  '코피',
#  '직접',
#  '맥주',
#  '필수',
#  '리보스',
#  '코피',
#  '제주',
#  '제주시',
#  '수목원',
#  '길',
#  '월요일',
#  '휴무',
#  '주차장',
#  '매장',
#  '문의',
#  '현무암',
#  '치킨',
#  '피자',
#  '한라산',
#  '용암',
#  '피자',
#  '리보스',
#  '코',
#  '맥주',
#  '맛집',
#  '경보',
#  '제주',
#  '제주',
#  '여행',
#  '제주',
#  '맛집',
#  '제주도',
#  '맛집',
#  '제주시',
#  '맛집',
#  '연동',
#  '맛집',
#  '제주',
#  '피자',
#  '맛집',
#  '추천',
#  '제주',
#  '피자',
#  '맛집',
#  '피자',
#  '맛집',
#  '광안',
#  '리',
#  '포르타',
#  '광안',
#  '리',
#  '필수',
#  '코스',
#  '치즈',
#  '토핑',
#  '가득',
#  '미국',
#  '감성',
#  '피자',
#  '맛집',
#  '오션',
#  '뷰',
#  '피맥',
#  '조합',
#  '퐁실퐁실',
#  '도우',
#  '힙',
#  '분위기',
#  '오션',
#  '뷰',
#  '치즈',
#  '쭈아압',
#  '피자',
#  '위치',
#  '부산광역시',
#  '수영구',
#  '광안',
#  '로번',
#  '길',
#  '오늘',
#  '부산',
#  '광안',
#  '리',
#  '피자',
#  '덕후',
#  '강',
#  '존맛',
#  '피자',
#  '모음',
#  '집',
#  '진짜',
#  '시픈',
#  '비쥬',
#  '오늘',
#  '피맥하쟈',
#  '더',
#  '꿀팁',
#  '알',
#  '피자스쿨',
#  '피자',
#  '맛집',
#  '피자',
#  '추천',
#  '피자',
#  '맛집',
#  '피자',
#  '맛집',
#  '추천',
#  '야식',
#  '메뉴',
#  '추천',
#  '야식',
#  '추천',
#  '메뉴',
#  '배달',
#  '맛집',
#  '배달',
#  '맛집',
#  '추천',
#  '고구마',
#  '피자',
#  '치즈',
#  '피자',
#  '피자',
#  '메뉴',
#  '서울',
#  '맛집',
#  '추천',
#  '딩동댕동',
#  '가성',
#  '비',
#  '피자',
#  '학교',
#  '입학',
#  '준비',
#  '피자스쿨',
#  '출석',
#  '시간',
#  '이양',
#  '피자',
#  '성비',
#  '피자',
#  '맛집',
#  '피자스쿨',
#  '갈릭',
#  '소스',
#  '추가',
#  '필수',
#  '알',
#  '인',
#  '판',
#  '도전',
#  '각',
#  '피자스쿨',
#  '피자',
#  '추천',
#  '피자',
#  '맛집',
#  '피자',
#  '덕후',
#  '피자',
#  '러버',
#  '가성',
#  '비',
#  '가성',
#  '비',
#  '피자',
#  '피자스쿨',
#  '메뉴',
#  '피자스쿨',
#  '추천',
#  '피자스쿨',
#  '메뉴',
#  '추천',
#  '피자스쿨',
#  '피자',
#  '추천',
#  '야식',
#  '야식',
#  '추천',
#  '메뉴',
#  '추천',
#  '메뉴',
#  '오지',
#  '치즈',
#  '포테이토',
#  '피자',
#  '고구마',
#  '피자',
#  '르',
#  '피자',
#  '더블',
#  '갈릭',
#  '바베큐',
#  '피자',
#  '닭',
#  '안심',
#  '살피',
#  '멕시칸',
#  '바이트',
#  '피자',
#  '비프',
#  '퀘사디아',
#  '피자',
#  '도이치',
#  '바이트',
#  '피자',
#  '고구마',
#  '피자',
#  '포테이토',
#  '피자',
#  '맛스타',
#  '그램',
#  '피맥',
#  '피자',
#  '스타',
#  '그램',
#  '미스터피자',
#  '최애',
#  '단연',
#  '멕시칸',
#  '하바네로',
#  '멕시칸',
#  '하바네로',
#  '피자',
#  '미스터피자',
#  '홈파티',
#  '피자',
#  '수',
#  '배달',
#  '음식',
#  '것',
#  '것',
#  '석화',
#  '하프셸',
#  '준비',
#  '멕시칸',
#  '하바네로',
#  '멕시칸',
#  '하바네로',
#  '라지',
#  '줄',
#  '레귤러',
#  '잘못',
#  '시킴',
#  '빵',
#  '반',
#  '매콤',
#  '횐님들',
#  '씬',
#  '라지',
#  '사이즈',
#  '꼭',
#  '멕시코',
#  '필요',
#  '피자',
#  '맛집',
#  '멕시칸',
#  '멕시코',
#  '음식',
#  '배달',
#  '맛집',
#  '홈파티',
#  '피자',
#  '피',
#  '서울',
#  '맛집',
#  '소통',
#  '일상',
#  '선팔',
#  '맞팔',
#  '팔',
#  '맛집',
#  '푸드',
#  '스타',
#  '그램',
#  '집밥',
#  '스타',
#  '그램',
#  '맛집',
#  '스타',
#  '그램',
#  '스타',
#  '그램',
#  '세상',
#  '모태',
#  '마름',
#  '특징',
#  '진짜',
#  '사람',
#  '부러',
#  '움',
#  '이유',
#  '거',
#  '너',
#  '사람',
#  '모태',
#  '마름',
#  '날씬',
#  '다이어트',
#  '음식',
#  '치킨',
#  '피자',
#  '고기',
#  '삼겹살',
#  '과자',
#  '간식',
#  '입',
#  '활동',
#  '량',
#  '활동',
#  '음식',
#  '야식',
#  '운동',
#  '체질',
#  '입',
#  '햇님',
#  '극찬',
#  '그',
#  '피자',
#  '네모',
#  '모양',
#  '피자',
#  '기맥힌',
#  '토핑들',
#  '줄',
#  '식당',
#  '생활',
#  '달인',
#  '토요일',
#  '밥',
#  '등등',
#  '여러',
#  '미디어',
#  '극찬',
#  '어디',
#  '서도',
#  '적',
#  '피자',
#  '겉바',
#  '촉',
#  '식감',
#  '구현',
#  '네모',
#  '모양',
#  '디트로',
#  '이드',
#  '피자',
#  '토핑',
#  '퀄리티',
#  '난리',
#  '하와',
#  '이안',
#  '갈릭',
#  '쉬',
#  '림프',
#  '파인애플',
#  '피자',
#  '뚱',
#  '갈릭',
#  '쉬',
#  '림프',
#  '시나몬',
#  '파인애플',
#  '조합',
#  '피자',
#  '토톡',
#  '왕새우',
#  '꼬',
#  '수운',
#  '잣덕',
#  '식감',
#  '예술',
#  '그',
#  '자체',
#  '새우',
#  '덕후',
#  '하와',
#  '이안',
#  '피자',
#  '덕후',
#  '라면',
#  '꼭꼭',
#  '사수',
#  '텍사스',
#  '수비드',
#  '비프',
#  '립',
#  '피자',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '순위',
#  '메뉴',
#  '방문',
#  '라면',
#  '무조건',
#  '거',
#  '주문',
#  '우선',
#  '훈연',
#  '우대',
#  '갈비',
#  '연기',
#  '뿜으',
#  '등장',
#  '눈',
#  '앞',
#  '바로',
#  '손질',
#  '도우',
#  '위',
#  '뭉텅뭉텅',
#  '시간',
#  '수비드',
#  '조리',
#  '우대',
#  '갈비',
#  '피자',
#  '토핑',
#  '시각',
#  '후각',
#  '미각',
#  '맥주',
#  '찰떡',
#  '집',
#  '파스타',
#  '까르보나라',
#  '소스',
#  '톡',
#  '까르보나라',
#  '덕',
#  '게',
#  '맥주',
#  '선택',
#  '필',
#  '맛',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '송리단길점',
#  '하와',
#  '이안',
#  '갈릭',
#  '쉬',
#  '림프',
#  '파인애플',
#  '피자',
#  '텍사스',
#  '수비드',
#  '비프',
#  '립',
#  '피자',
#  '톡',
#  '까르보나라',
#  '리카',
#  '토니',
#  '송파',
#  '나루',
#  '역',
#  '번',
#  '출구',
#  '매일',
#  '은쪼',
#  '송파',
#  '송파',
#  '맛집',
#  '송파',
#  '나루',
#  '역',
#  '맛집',
#  '송리',
#  '맛집',
#  '송리',
#  '술집',
#  '송리',
#  '피자',
#  '석촌',
#  '맛집',
#  '잠실',
#  '맛집',
#  '줄',
#  '식당',
#  '디트로',
#  '이드',
#  '피자',
#  '피자',
#  '피자',
#  '덕후',
#  '피자',
#  '힙',
#  '피자',
#  '힙',
#  '나',
#  '야근',
#  '우리',
#  '회사',
#  '동네',
#  '피자',
#  '카페',
#  '우리동네',
#  '퇴근',
#  '함',
#  '이',
#  '사람',
#  '기숙사',
#  '별거',
#  '서두',
#  '천안',
#  '청년',
#  '피자',
#  '피자',
#  '시크릿',
#  '더블',
#  '크런치',
#  '시크릿',
#  '더블',
#  '크런치',
#  '피자',
#  '나초',
#  '치즈',
#  '감자',
#  '튀김',
#  '감자',
#  '튀김',
#  '콜라',
#  '탄산',
#  '스타',
#  '그램',
#  '치즈볼',
#  '그램',
#  '맛스타',
#  '그램',
#  '스타',
#  '그램',
#  '피자',
#  '오늘',
#  '야식',
#  '파파존스',
#  '슈퍼',
#  '파파스',
#  '피자',
#  '야식',
#  '피자',
#  '파파존스',
#  '슈퍼',
#  '파파스',
#  '존맛',
#  '존맛',
#  '그램',
#  '맛스타',
#  '그램',
#  '스타',
#  '그램',
#  '피자',
#  '스타',
#  '그램',
#  '맥주',
#  '테라',
#  '일상',
#  '소통',
#  '여행',
#  '여행',
#  '스타',
#  '그램',
#  '오이타현',
#  '벳푸',
#  '온천',
#  '피자',
#  '맛집',
#  '공복',
#  '회',
#  '운동',
#  '회',
#  '휴식',
#  '하루',
#  '사이클',
#  '분',
#  '강도',
#  '가장',
#  '뻑뻑',
#  '식단',
#  '두유',
#  '쌀밥',
#  '닭',
#  '쌀밥',
#  '닭',
#  '고구마',
#  '닭',
#  '고구마',
#  '닭',
#  '닭',
#  '운동',
#  '헬스',
#  '수원',
#  '영통',
#  '바디',
#  '프로필',
#  '운동',
#  '기록',
#  '육아',
#  '피자',
#  '피자스쿨',
#  '피치',
#  '저녁',
#  '지기',
#  '치킨',
#  '피자',
#  '운동',
#  '데',
#  '일리',
#  '일상',
#  '선팔',
#  '맞팔',
#  '선팔',
#  '맞팔',
#  '선팔',
#  '맞팔',
#  '반',
#  '테러',
#  '테러',
#  '인친',
#  '환영',
#  '이틀',
#  '연속',
#  '음식사진',
#  '연습',
#  '세종시',
#  '세종시',
#  '맛집',
#  '너',
#  '맛스타',
#  '그램',
#  '파스타',
#  '피자',
#  '고운동',
#  '고운동',
#  '맛집',
#  '굿',
#  '음식사진',
#  '점심식사',
#  '어제',
#  '오늘',
#  '번',
#  '맛',
#  '샐러드',
#  '리조또',
#  '세종시',
#  '옷가게',
#  '세종',
#  '옷가게',
#  '라벨',
#  '르',
#  '더',
#  '라벨',
#  '르',
#  '늘',
#  '도',
#  '미노',
#  '얼마',
#  '전',
#  '처음',
#  '피자헛',
#  '주문',
#  '과',
#  '미가',
#  '이',
#  '기름기',
#  '것',
#  '손꾸락',
#  '질문',
#  '질',
#  '피자',
#  '기름기',
#  '클래식',
#  '옛날',
#  '사람',
#  '피자헛',
#  '슈퍼',
#  '슈프림',
#  '리치',
#  '골드',
#  '엣지',
#  '피자',
#  '먹방',
#  '협찬',
#  '피자',
#  '떡볶이',
#  '조합',
#  '가게',
#  '피자',
#  '스튜디오',
#  '영등포',
#  '구청',
#  '점',
#  '위치',
#  '서울',
#  '영등포구',
#  '당산로',
#  '길',
#  '피자',
#  '스튜디오',
#  '메뉴',
#  '피떡',
#  '치즈',
#  '페퍼로니',
#  '피자',
#  '떡볶이',
#  '원',
#  '콜라',
#  '원',
#  '리뷰',
#  '영등포',
#  '구청',
#  '역',
#  '번',
#  '출구',
#  '근처',
#  '아지트',
#  '곳',
#  '위치',
#  '피자',
#  '만',
#  '떡볶이',
#  '금',
#  '천화',
#  '피떡',
#  '세트',
#  '페퍼로니',
#  '치즈',
#  '두',
#  '맛',
#  '한번',
#  '수',
#  '개인',
#  '치즈',
#  ...]

# %%
from collections import Counter
count = Counter(nouns_txt)
count
rank_text = count.most_common()
rank_text
# Out:
# [('피자', 394),
#  ('맛집', 147),
#  ('그램', 113),
#  ('스타', 102),
#  ('파스타', 68),
#  ('치즈', 58),
#  ('맞팔', 45),
#  ('일상', 33),
#  ('원', 32),
#  ('맛', 30),
#  ('메뉴', 29),
#  ('소스', 29),
#  ('소통', 29),
#  ('집', 28),
#  ('오늘', 28),
#  ('음식', 25),
#  ('추천', 22),
#  ('또', 20),
#  ('도우', 19),
#  ('더', 19),
#  ('맛스타', 19),
#  ('팔', 19),
#  ('여행', 18),
#  ('카페', 18),
#  ('제주', 16),
#  ('치킨', 16),
#  ('주문', 16),
#  ('저녁', 15),
#  ('점심', 15),
#  ('피자스쿨', 14),
#  ('야식', 14),
#  ('배달', 14),
#  ('선팔', 14),
#  ('요리', 14),
#  ('곳', 13),
#  ('서울', 13),
#  ('반죽', 13),
#  ('환영', 13),
#  ('영등포', 13),
#  ('때', 13),
#  ('스파게티', 13),
#  ('것', 12),
#  ('점', 12),
#  ('스테이크', 12),
#  ('포테이토', 12),
#  ('수', 12),
#  ('사람', 12),
#  ('페퍼로니', 12),
#  ('생면', 12),
#  ('명동', 11),
#  ('진짜', 11),
#  ('시간', 11),
#  ('토핑', 11),
#  ('맥주', 11),
#  ('집밥', 11),
#  ('나', 11),
#  ('먹방', 11),
#  ('계란', 11),
#  ('림프', 10),
#  ('피맥', 10),
#  ('갈릭', 10),
#  ('멕시칸', 10),
#  ('반', 10),
#  ('감자', 10),
#  ('튀김', 10),
#  ('구청', 10),
#  ('팔로우', 10),
#  ('마르', 10),
#  ('양식', 10),
#  ('술', 10),
#  ('서귀포', 10),
#  ('미국', 9),
#  ('존맛', 9),
#  ('분위기', 9),
#  ('덕후', 9),
#  ('비', 9),
#  ('다이어트', 9),
#  ('쉬', 9),
#  ('역', 9),
#  ('토마토', 9),
#  ('제주도', 8),
#  ('고구마', 8),
#  ('닭', 8),
#  ('기록', 8),
#  ('떡볶이', 8),
#  ('옥수수', 8),
#  ('크림', 8),
#  ('데이트', 8),
#  ('병', 8),
#  ('이벤트', 8),
#  ('저', 7),
#  ('방문', 7),
#  ('가게', 7),
#  ('조합', 7),
#  ('새우', 7),
#  ('직접', 7),
#  ('준비', 7),
#  ('인', 7),
#  ('고기', 7),
#  ('식당', 7),
#  ('번', 7),
#  ('매일', 7),
#  ('샐러드', 7),
#  ('오픈', 7),
#  ('뭐', 7),
#  ('화덕', 7),
#  ('고르곤졸라', 7),
#  ('제일', 7),
#  ('차', 7),
#  ('게리', 7),
#  ('행복', 7),
#  ('부식', 7),
#  ('앤', 7),
#  ('일', 7),
#  ('명', 7),
#  ('참이슬', 7),
#  ('인분', 7),
#  ('판매', 7),
#  ('미사', 7),
#  ('코지', 7),
#  ('도시락', 7),
#  ('동대문', 6),
#  ('안', 6),
#  ('이드', 6),
#  ('시카고', 6),
#  ('도', 6),
#  ('제', 6),
#  ('불고기', 6),
#  ('더블', 6),
#  ('빵', 6),
#  ('매콤', 6),
#  ('푸드', 6),
#  ('운동', 6),
#  ('콜라', 6),
#  ('분', 6),
#  ('식단', 6),
#  ('데', 6),
#  ('어제', 6),
#  ('리조또', 6),
#  ('다음', 6),
#  ('내', 6),
#  ('오븐', 6),
#  ('시', 6),
#  ('생각', 6),
#  ('월', 6),
#  ('모어', 6),
#  ('한남동', 6),
#  ('친구', 6),
#  ('와인', 6),
#  ('베트남', 6),
#  ('물', 6),
#  ('타바스코', 6),
#  ('마녀', 6),
#  ('우리', 5),
#  ('핫', 5),
#  ('바로', 5),
#  ('모두', 5),
#  ('개', 5),
#  ('위', 5),
#  ('리보스', 5),
#  ('꼭', 5),
#  ('리', 5),
#  ('감성', 5),
#  ('힙', 5),
#  ('가성', 5),
#  ('추가', 5),
#  ('줄', 5),
#  ('생활', 5),
#  ('식감', 5),
#  ('덕', 5),
#  ('일리', 5),
#  ('처음', 5),
#  ('피자헛', 5),
#  ('파', 5),
#  ('보고', 5),
#  ('은평구', 5),
#  ('날', 5),
#  ('층', 5),
#  ('태그', 5),
#  ('화', 5),
#  ('브런치', 5),
#  ('가지', 5),
#  ('가족', 5),
#  ('치코', 5),
#  ('코스트코', 5),
#  ('팔해', 5),
#  ('힐', 5),
#  ('만원', 5),
#  ('러스트', 5),
#  ('일산', 5),
#  ('주부', 5),
#  ('성수', 5),
#  ('베이컨', 5),
#  ('호치민', 5),
#  ('배송', 5),
#  ('창업', 5),
#  ('칵테일', 5),
#  ('지금', 4),
#  ('이', 4),
#  ('하나', 4),
#  ('오일', 4),
#  ('주소', 4),
#  ('길', 4),
#  ('인스타', 4),
#  ('엣지', 4),
#  ('거', 4),
#  ('코피', 4),
#  ('현무암', 4),
#  ('잔뜩', 4),
#  ('먹물', 4),
#  ('바삭', 4),
#  ('가득', 4),
#  ('한번', 4),
#  ('필수', 4),
#  ('제주시', 4),
#  ('광안', 4),
#  ('위치', 4),
#  ('바이트', 4),
#  ('비프', 4),
#  ('하바네로', 4),
#  ('사이즈', 4),
#  ('피', 4),
#  ('세상', 4),
#  ('간식', 4),
#  ('입', 4),
#  ('그', 4),
#  ('밥', 4),
#  ('적', 4),
#  ('까르보나라', 4),
#  ('게', 4),
#  ('송파', 4),
#  ('인친', 4),
#  ('음식사진', 4),
#  ('스튜디오', 4),
#  ('두', 4),
#  ('등', 4),
#  ('좀', 4),
#  ('끝', 4),
#  ('디핑', 4),
#  ('이태원', 4),
#  ('염', 4),
#  ('회식', 4),
#  ('레스토랑', 4),
#  ('사랑', 4),
#  ('투어', 4),
#  ('막', 4),
#  ('피클', 4),
#  ('양배추', 4),
#  ('김치찌개', 4),
#  ('댓글', 4),
#  ('미트', 4),
#  ('여러분', 4),
#  ('가능', 4),
#  ('이탈리아', 4),
#  ('주말', 4),
#  ('사진', 4),
#  ('정말', 4),
#  ('라운드', 4),
#  ('납품', 4),
#  ('간', 4),
#  ('시작', 4),
#  ('안주', 4),
#  ('감', 4),
#  ('신촌', 4),
#  ('홈쿡', 4),
#  ('밥상', 4),
#  ('행신동', 4),
#  ('바', 4),
#  ('뇨끼', 4),
#  ('새해', 4),
#  ('면', 4),
#  ('캠핑', 4),
#  ('참여', 4),
#  ('환상', 3),
#  ('말', 3),
#  ('각', 3),
#  ('그냥', 3),
#  ('너', 3),
#  ('미노', 3),
#  ('포장', 3),
#  ('밤', 3),
#  ('가야', 3),
#  ('톳', 3),
#  ('해녀', 3),
#  ('한라산', 3),
#  ('용암', 3),
#  ('매장', 3),
#  ('문의', 3),
#  ('뷰', 3),
#  ('부산', 3),
#  ('판', 3),
#  ('르', 3),
#  ('레귤러', 3),
#  ('멕시코', 3),
#  ('이유', 3),
#  ('퀄리티', 3),
#  ('하와', 3),
#  ('이안', 3),
#  ('파인애플', 3),
#  ('자체', 3),
#  ('수비드', 3),
#  ('톡', 3),
#  ('선택', 3),
#  ('송리', 3),
#  ('동네', 3),
#  ('청년', 3),
#  ('시크릿', 3),
#  ('크런치', 3),
#  ('슈퍼', 3),
#  ('회', 3),
#  ('하루', 3),
#  ('가장', 3),
#  ('세종시', 3),
#  ('늘', 3),
#  ('클래식', 3),
#  ('협찬', 3),
#  ('금', 3),
#  ('핫소스', 3),
#  ('레드', 3),
#  ('생맥주', 3),
#  ('타코', 3),
#  ('향', 3),
#  ('마음', 3),
#  ('해', 3),
#  ('돈', 3),
#  ('산', 3),
#  ('아이', 3),
#  ('조금', 3),
#  ('덜', 3),
#  ('요즘', 3),
#  ('부림', 3),
#  ('만들기', 3),
#  ('부터', 3),
#  ('휴가', 3),
#  ('볼', 3),
#  ('먹기', 3),
#  ('커피', 3),
#  ('이프', 3),
#  ('콰트로', 3),
#  ('초', 3),
#  ('시금치', 3),
#  ('올리브', 3),
#  ('라스트', 3),
#  ('방학', 3),
#  ('도미노피자', 3),
#  ('광택', 3),
#  ('유리', 3),
#  ('코팅', 3),
#  ('카', 3),
#  ('역시', 3),
#  ('휴일', 3),
#  ('이제', 3),
#  ('수제', 3),
#  ('집들이', 3),
#  ('소주', 3),
#  ('후', 3),
#  ('일기', 3),
#  ('상봉', 3),
#  ('푸드코트', 3),
#  ('베이', 3),
#  ('택배', 3),
#  ('외출', 3),
#  ('봉덕동', 3),
#  ('인연', 3),
#  ('스트리트', 3),
#  ('종로', 3),
#  ('반사', 3),
#  ('듬뿍', 3),
#  ('성수동', 3),
#  ('예약', 3),
#  ('안덕면', 3),
#  ('중문', 3),
#  ('토핑킹', 3),
#  ('페페로니', 3),
#  ('홈', 3),
#  ('리타', 3),
#  ('브리', 3),
#  ('테이블', 3),
#  ('라떼', 3),
#  ('혼밥', 3),
#  ('밀', 3),
#  ('롱', 3),
#  ('트러플', 3),
#  ('라비올리', 3),
#  ('기회', 3),
#  ('하남', 3),
#  ('변', 3),
#  ('주방', 3),
#  ('호텔', 3),
#  ('하우스', 3),
#  ('진영', 3),
#  ('교현', 3),
#  ('임실', 3),
#  ('등산', 3),
#  ('미이라', 3),
#  ('빠', 3),
#  ('링겔', 3),
#  ('히비스커스', 3),
#  ('마사지', 3),
#  ('무이네', 3),
#  ('사이드', 2),
#  ('현대', 2),
#  ('시티', 2),
#  ('아울렛', 2),
#  ('사장', 2),
#  ('손', 2),
#  ('끝판', 2),
#  ('왕십리', 2),
#  ('스', 2),
#  ('푸파', 2),
#  ('종합', 2),
#  ('게시판', 2),
#  ('하층', 2),
#  ('영업', 2),
#  ('블랙', 2),
#  ('타이거', 2),
#  ('리얼', 2),
#  ('돌담', 2),
#  ('몸통', 2),
#  ('박살', 2),
#  ('경보', 2),
#  ('연동', 2),
#  ('쫄깃', 2),
#  ('쫀득', 2),
#  ('월요일', 2),
#  ('휴무', 2),
#  ('주차장', 2),
#  ('코스', 2),
#  ('오션', 2),
#  ('비쥬', 2),
#  ('알', 2),
#  ('성비', 2),
#  ('미스터피자', 2),
#  ('최애', 2),
#  ('홈파티', 2),
#  ('라지', 2),
#  ('잘못', 2),
#  ('씬', 2),
#  ('모태', 2),
#  ('마름', 2),
#  ('활동', 2),
#  ('극찬', 2),
#  ('네모', 2),
#  ('모양', 2),
#  ('토핑들', 2),
#  ('어디', 2),
#  ('겉바', 2),
#  ('촉', 2),
#  ('디트로', 2),
#  ('난리', 2),
#  ('라면', 2),
#  ('텍사스', 2),
#  ('립', 2),
#  ('무조건', 2),
#  ('우대', 2),
#  ('갈비', 2),
#  ('눈', 2),
#  ('앞', 2),
#  ('나루', 2),
#  ('출구', 2),
#  ('퇴근', 2),
#  ('함', 2),
#  ('파파존스', 2),
#  ('파파스', 2),
#  ('공복', 2),
#  ('쌀밥', 2),
#  ('수원', 2),
#  ('피치', 2),
#  ('테러', 2),
#  ('고운동', 2),
#  ('옷가게', 2),
#  ('세종', 2),
#  ('라벨', 2),
#  ('얼마', 2),
#  ('전', 2),
#  ('기름기', 2),
#  ('옛날', 2),
#  ('피떡', 2),
#  ('리뷰', 2),
#  ('근처', 2),
#  ('만', 2),
#  ('세트', 2),
#  ('강추', 2),
#  ('완전', 2),
#  ('게다가', 2),
#  ('편', 2),
#  ('쫀득쫀득해', 2),
#  ('국물', 2),
#  ('단', 2),
#  ('마산', 2),
#  ('연초', 2),
#  ('가요', 2),
#  ('당산동', 2),
#  ('현지', 2),
#  ('베이스', 2),
#  ('최고', 2),
#  ('인테리어', 2),
#  ('심지어', 2),
#  ('느낌', 2),
#  ('국적', 2),
#  ('대박', 2),
#  ('절로', 2),
#  ('프렌치프라이', 2),
#  ('보기', 2),
#  ('공유', 2),
#  ('및', 2),
#  ('다른', 2),
#  ('공주', 2),
#  ('제공', 2),
#  ('유주', 2),
#  ('뿐', 2),
#  ('키즈', 2),
#  ('피즈', 2),
#  ('악동', 2),
#  ('형제', 2),
#  ('왕', 2),
#  ('돈까스', 2),
#  ('아내', 2),
#  ('아빠', 2),
#  ('알라', 2),
#  ('딸기', 2),
#  ('모임', 2),
#  ('찬스', 2),
#  ('유', 2),
#  ('별로', 2),
#  ('플롭', 2),
#  ('쿼터', 2),
#  ('종류', 2),
#  ('서비스', 2),
#  ('줌', 2),
#  ('명지대', 2),
#  ('노스', 2),
#  ('아쉬움', 2),
#  ('반찬', 2),
#  ('맞춤', 2),
#  ('저녁밥', 2),
#  ('식사', 2),
#  ('감탄', 2),
#  ('고민', 2),
#  ('정도', 2),
#  ('아반떼', 2),
#  ('스포츠', 2),
#  ('투', 2),
#  ('코트', 2),
#  ('작업', 2),
#  ('왁스', 2),
#  ('보이', 2),
#  ('재고', 2),
#  ('연마', 2),
#  ('최소', 2),
#  ('대신', 2),
#  ('답', 2),
#  ('한국', 2),
#  ('프리미엄', 2),
#  ('콘', 2),
#  ('허니', 2),
#  ('왜', 2),
#  ('내일', 2),
#  ('선물', 2),
#  ('다이소', 2),
#  ('축하', 2),
#  ('닭도리탕', 2),
#  ('볶음', 2),
#  ('캬', 2),
#  ('찍', 2),
#  ('블리', 2),
#  ('자주', 2),
#  ('양송이', 2),
#  ('스프', 2),
#  ('베', 2),
#  ('이크', 2),
#  ('마트', 2),
#  ('선명', 2),
#  ('치폴레', 2),
#  ('를', 2),
#  ('만약', 2),
#  ('홀', 2),
#  ('중', 2),
#  ('호랭이', 2),
#  ('성안길', 2),
#  ('재', 2),
#  ('디져트', 2),
#  ('무엇', 2),
#  ('품평', 2),
#  ('당근', 2),
#  ('농부', 2),
#  ('일상사진', 2),
#  ('크리스마스', 2),
#  ('할아버지', 2),
#  ('한판', 2),
#  ('모든', 2),
#  ('브레이크', 2),
#  ('둘', 2),
#  ('얼굴', 2),
#  ('팔로잉', 2),
#  ('잭슨', 2),
#  ('출근', 2),
#  ('머릿속', 2),
#  ('계획', 2),
#  ('목표', 2),
#  ('꽃', 2),
#  ('인생', 2),
#  ('화요일', 2),
#  ('건강', 2),
#  ('노력', 2),
#  ('양', 2),
#  ('익선동', 2),
#  ('메', 2),
#  ('종파', 2),
#  ('이름', 2),
#  ('파이프', 2),
#  ('사', 2),
#  ('노릇', 2),
#  ('자극', 2),
#  ('정신', 2),
#  ('아주', 2),
#  ('메인', 2),
#  ('점수', 2),
#  ('호', 2),
#  ('뚜띠쿠치', 2),
#  ('겨울', 2),
#  ('모시', 2),
#  ('맘', 2),
#  ('딸', 2),
#  ('마늘', 2),
#  ('놀러와', 2),
#  ('마리', 2),
#  ('똥집', 2),
#  ('감자탕', 2),
#  ('창원', 2),
#  ('대관', 2),
#  ('디노', 2),
#  ('평리', 2),
#  ('일요일', 2),
#  ('단식', 2),
#  ('아침', 2),
#  ('보', 2),
#  ('런치', 2),
#  ('제로', 2),
#  ('다이어트식단', 2),
#  ('홈트', 2),
#  ('직원', 2),
#  ('순간', 2),
#  ('소세지', 2),
#  ('전체', 2),
#  ('조화', 2),
#  ('번가', 2),
#  ('홍대', 2),
#  ('폭탄', 2),
#  ('호짬', 2),
#  ('동생', 2),
#  ('행', 2),
#  ('독거', 2),
#  ('알리오', 2),
#  ('리오', 2),
#  ('바질', 2),
#  ('세라', 2),
#  ('애월', 2),
#  ('마노', 2),
#  ('앤디', 2),
#  ('스몰', 2),
#  ('부부', 2),
#  ('감귤', 2),
#  ('골프', 2),
#  ('국수', 2),
#  ('혼자', 2),
#  ('간단', 2),
#  ('금주', 2),
#  ('무료', 2),
#  ('북동', 2),
#  ('기대', 2),
#  ('고객', 2),
#  ('디아', 2),
#  ('볼릭', 2),
#  ('리조', 2),
#  ('로', 2),
#  ('이용', 2),
#  ('부조화', 2),
#  ('숲', 2),
#  ('포', 2),
#  ('아델', 2),
#  ('라다', 2),
#  ('셰프', 2),
#  ('토', 2),
#  ('레', 2),
#  ('숏', 2),
#  ('케리', 2),
#  ('방법', 2),
#  ('토마토소스', 2),
#  ('시칠리아', 2),
#  ('아란치니', 2),
#  ('모짜렐라', 2),
#  ('라자냐', 2),
#  ('메이드', 2),
#  ('카카오', 2),
#  ('접수', 2),
#  ('결재', 2),
#  ('확인', 2),
#  ('파스', 2),
#  ('타바', 2),
#  ('키트', 2),
#  ('애견', 2),
#  ('이번', 2),
#  ('메모', 2),
#  ('여기', 2),
#  ('식전', 2),
#  ('헬스장', 2),
#  ('광고', 2),
#  ('다가', 2),
#  ('급술', 2),
#  ('실장', 2),
#  ('스리', 2),
#  ('라차', 2),
#  ('브렛', 2),
#  ('종종', 2),
#  ('밀라노', 2),
#  ('기사', 2),
#  ('기본', 2),
#  ('시장', 2),
#  ('킴스', 2),
#  ('값', 2),
#  ('영점', 2),
#  ('년', 2),
#  ('학기', 2),
#  ('취향', 2),
#  ('직장인', 2),
#  ('카츠', 2),
#  ('백련산', 2),
#  ('명산', 2),
#  ('스톰', 2),
#  ('바이킹', 2),
#  ('나트랑', 2),
#  ('조식', 2),
#  ('아들', 2),
#  ('수업', 2),
#  ('수영장', 2),
#  ('춥다', 2),
#  ('전신', 2),
#  ('필리핀', 2),
#  ('월드', 1),
#  ('클래스', 1),
#  ('시대', 1),
#  ('카타르', 1),
#  ('월드컵', 1),
#  ('더욱', 1),
#  ('고해', 1),
#  ('논란', 1),
#  ('쫜득함', 1),
#  ('모습', 1),
#  ('궁합', 1),
#  ('왤케', 1),
#  ('핵가족', 1),
#  ('콤보', 1),
#  ('투입', 1),
#  ('두발', 1),
#  ('환대', 1),
#  ('머', 1),
#  ('부족함', 1),
#  ('폭포', 1),
#  ('장관', 1),
#  ('재직', 1),
#  ('영매', 1),
#  ('논현', 1),
#  ('예정', 1),
#  ('복', 1),
#  ('듯', 1),
#  ('퓔링', 1),
#  ('뽀너스', 1),
#  ('스푸파', 1),
#  ('메뉴판', 1),
#  ('투움', 1),
#  ('만수르', 1),
#  ('명란', 1),
#  ('중구', 1),
#  ('을지로', 1),
#  ('장충단로', 1),
#  ('손흥민', 1),
#  ('그게', 1),
#  ('행사', 1),
#  ('슈', 1),
#  ('앵거스', 1),
#  ('햅삐하', 1),
#  ('욥', 1),
#  ('쬰득쫄깃', 1),
#  ('이색', 1),
#  ('오징어', 1),
#  ('일반', 1),
#  ('통', 1),
#  ('찬', 1),
#  ('칠리소스', 1),
#  ('옷', 1),
#  ('최고급', 1),
#  ('삼위일체', 1),
#  ('고요', 1),
#  ('오시', 1),
#  ('수목원', 1),
#  ('코', 1),
#  ('포르타', 1),
#  ('퐁실퐁실', 1),
#  ('쭈아압', 1),
#  ('부산광역시', 1),
#  ('수영구', 1),
#  ('로번', 1),
#  ('강', 1),
#  ('모음', 1),
#  ('시픈', 1),
#  ('피맥하쟈', 1),
#  ('꿀팁', 1),
#  ('딩동댕동', 1),
#  ('학교', 1),
#  ('입학', 1),
#  ('출석', 1),
#  ('이양', 1),
#  ('도전', 1),
#  ('러버', 1),
#  ('오지', 1),
#  ('바베큐', 1),
#  ('안심', 1),
#  ('살피', 1),
#  ('퀘사디아', 1),
#  ('도이치', 1),
#  ('단연', 1),
#  ('석화', 1),
#  ('하프셸', 1),
#  ('시킴', 1),
#  ('횐님들', 1),
#  ('필요', 1),
#  ('특징', 1),
#  ('부러', 1),
#  ('움', 1),
#  ('날씬', 1),
#  ('삼겹살', 1),
#  ('과자', 1),
#  ('량', 1),
#  ('체질', 1),
#  ('햇님', 1),
#  ('기맥힌', 1),
#  ('달인', 1),
#  ('토요일', 1),
#  ('등등', 1),
#  ('여러', 1),
#  ('미디어', 1),
#  ('서도', 1),
#  ('구현', 1),
#  ('뚱', 1),
#  ('시나몬', 1),
#  ('토톡', 1),
#  ('왕새우', 1),
#  ('꼬', 1),
#  ('수운', 1),
#  ('잣덕', 1),
#  ('예술', 1),
#  ('꼭꼭', 1),
#  ('사수', 1),
#  ('순위', 1),
#  ('우선', 1),
#  ('훈연', 1),
#  ('연기', 1),
#  ('뿜으', 1),
#  ('등장', 1),
#  ('손질', 1),
#  ('뭉텅뭉텅', 1),
#  ('조리', 1),
#  ('시각', 1),
#  ('후각', 1),
#  ('미각', 1),
#  ('찰떡', 1),
#  ('필', 1),
#  ('송리단길점', 1),
#  ('리카', 1),
#  ('토니', 1),
#  ('은쪼', 1),
#  ('술집', 1),
#  ('석촌', 1),
#  ('잠실', 1),
#  ('야근', 1),
#  ('회사', 1),
#  ('우리동네', 1),
#  ('기숙사', 1),
#  ('별거', 1),
#  ('서두', 1),
#  ('천안', 1),
#  ('나초', 1),
#  ('탄산', 1),
#  ('치즈볼', 1),
#  ('테라', 1),
#  ('오이타현', 1),
#  ('벳푸', 1),
#  ('온천', 1),
#  ('휴식', 1),
#  ('사이클', 1),
#  ('강도', 1),
#  ('뻑뻑', 1),
#  ('두유', 1),
#  ('헬스', 1),
#  ('영통', 1),
#  ('바디', 1),
#  ('프로필', 1),
#  ('육아', 1),
#  ('지기', 1),
#  ('이틀', 1),
#  ('연속', 1),
#  ('연습', 1),
#  ('굿', 1),
#  ('점심식사', 1),
#  ('과', 1),
#  ('미가', 1),
#  ('손꾸락', 1),
#  ('질문', 1),
#  ('질', 1),
#  ('슈프림', 1),
#  ('리치', 1),
#  ('골드', 1),
#  ('영등포구', 1),
#  ('당산로', 1),
#  ('아지트', 1),
#  ('천화', 1),
#  ('개인', 1),
#  ('툼', 1),
#  ('스타잉', 1),
#  ('두께', 1),
#  ('감칠맛', 1),
#  ('김말이', 1),
#  ('셀프', 1),
#  ('코너', 1),
#  ('가루', 1),
#  ('만큼', 1),
#  ('조', 1),
#  ('대서', 1),
#  ('당산', 1),
#  ('비자', 1),
#  ('제조', 1),
#  ('질의', 1),
#  ('재료', 1),
#  ('우주', 1),
#  ('락', 1),
#  ('블', 1),
#  ('취급', 1),
#  ('이미지', 1),
#  ('주민', 1),
#  ('사이', 1),
#  ('외관', 1),
#  ('내부', 1),
#  ('뿜뿜뿜어져', 1),
#  ('제대로', 1),
#  ('착각', 1),
#  ('후피맥', 1),
#  ('고수', 1),
#  ('특유', 1),
#  ('라임', 1),
#  ('즙', 1),
#  ('소리', 1),
#  ('탄생', 1),
#  ('향신료', 1),
#  ('워낙', 1),
#  ('풍요', 1),
#  ('롭다', 1),
#  ('갓', 1),
#  ('왕창', 1),
#  ('콧노래', 1),
#  ('콘서트', 1),
#  ('아차', 1),
#  ('로즈마리', 1),
#  ('은평', 1),
#  ('로길', 1),
#  ('정기', 1),
#  ('평일', 1),
#  ('기억', 1),
#  ('저장', 1),
#  ('불펌', 1),
#  ('크롤', 1),
#  ('링', 1),
#  ('금지', 1),
#  ('모라', 1),
#  ('생맥', 1),
#  ('응암동', 1),
#  ('응암', 1),
#  ('응암역', 1),
#  ('역촌동', 1),
#  ('역촌역', 1),
#  ('녹번동', 1),
#  ('녹번역', 1),
#  ('태', 1),
#  ('평점', 1),
#  ('간이', 1),
#  ('지도', 1),
#  ('동안', 1),
#  ('전보', 1),
#  ('하달', 1),
#  ('제품', 1),
#  ('개월', 1),
#  ('놀이', 1),
#  ('창의력', 1),
#  ('밀키', 1),
#  ('초벌', 1),
#  ('울', 1),
#  ('애기', 1),
#  ('오전', 1),
#  ('온라인', 1),
#  ('마이', 1),
#  ...]

# %%
wc = WordCloud(max_font_size=40, background_color="white", max_words=1000,
               font_path="C:\\Windows\\Fonts\\malgun.ttf").generate_from_frequencies(dict(rank_text))

plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
