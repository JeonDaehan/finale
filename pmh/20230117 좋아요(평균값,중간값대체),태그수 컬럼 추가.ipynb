# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model 
from tensorflow.keras.layers import Dense, Flatten, Input, concatenate, Conv2D, MaxPool2D, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pyperclip
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# 불러오기
result = pd.read_csv("data/치킨2000.csv")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  2000 non-null   object
#  1   Like      2000 non-null   object
#  2   ID        2000 non-null   object
#  3   Tags      2000 non-null   object
# dtypes: object(4)
# memory usage: 62.6+ KB

# %%
result["Like_avg"] = result["Like"]
result
# Out:
#                                                Contents              Like  \
# 0     둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1      협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2     돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                            얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4       노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
# ...                                                 ...               ...
# 1995   논어  공부가되는논어이야기  방학독서 책읽기습관  책스타그램  책추천 아이들과함께...                41
# 1996                                   어떻게 라면에 주먹밥이 팔천원                74
# 1997  오늘 먹은거솥밥 넘 맛났당윤선빵과 함께      커플스타그램 럽스타그램 먹스타그램 ...                21
# 1998  엄마도 외출나가고 동생도 칭구집 가서 나 혼자 혼 치 조지기   빠삭빠삭 잘 튀겨졌...                11
# 1999                골라서 먹을수있는 재미    철인3종세트 순살  양념 간장 홍갈                15
#
#                      ID                                               Tags  \
# 0               z.e.o.m  ['#동근이숯불두마리치킨', '#동근이숯불두마리치킨', '#치킨', '#치킨맛집',...
# 1      foodgangster_fgg  ['#치킨매니아', '#푸드갱_배달', '#배달맛집', '#치킨맛집', '#떡볶이맛...
# 2        bboong_bbang_2                                                 []
# 3             dhrkspths                                                 []
# 4           a_a_bl0s2om  ['#대구맛집', '#먹방', '#instafood', '#요리스타그램', '#요리...
# ...                 ...                                                ...
# 1995           lee_hk79  ['#논어', '#공부가되는논어이야기', '#방학독서', '#책읽기습관', '#책스...
# 1996  stomach_endoscope                                                 []
# 1997             nolgoo  ['#커플스타그램', '#럽스타그램', '#먹스타그램', '#솥밥', '#도미관자솥...
# 1998      kimtaelee_092  ['#혼치킨🍗', '#혼밥', '#치킨매니아', '#먹는거에진심인편', '#존맛탱구...
# 1999        cheolin7_cw                                                 []
#
#               Like_avg
# 0                 1040
# 1                  109
# 2                  109
# 3                    9
# 4     rila님 여러 명이 좋아합니
# ...                ...
# 1995                41
# 1996                74
# 1997                21
# 1998                11
# 1999                15
#
# [2000 rows x 5 columns]

# %%
result["Like_mid"] = result["Like"]
result
# Out:
#                                                Contents              Like  \
# 0     둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1      협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2     돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                            얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4       노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
# ...                                                 ...               ...
# 1995   논어  공부가되는논어이야기  방학독서 책읽기습관  책스타그램  책추천 아이들과함께...                41
# 1996                                   어떻게 라면에 주먹밥이 팔천원                74
# 1997  오늘 먹은거솥밥 넘 맛났당윤선빵과 함께      커플스타그램 럽스타그램 먹스타그램 ...                21
# 1998  엄마도 외출나가고 동생도 칭구집 가서 나 혼자 혼 치 조지기   빠삭빠삭 잘 튀겨졌...                11
# 1999                골라서 먹을수있는 재미    철인3종세트 순살  양념 간장 홍갈                15
#
#                      ID                                               Tags  \
# 0               z.e.o.m  ['#동근이숯불두마리치킨', '#동근이숯불두마리치킨', '#치킨', '#치킨맛집',...
# 1      foodgangster_fgg  ['#치킨매니아', '#푸드갱_배달', '#배달맛집', '#치킨맛집', '#떡볶이맛...
# 2        bboong_bbang_2                                                 []
# 3             dhrkspths                                                 []
# 4           a_a_bl0s2om  ['#대구맛집', '#먹방', '#instafood', '#요리스타그램', '#요리...
# ...                 ...                                                ...
# 1995           lee_hk79  ['#논어', '#공부가되는논어이야기', '#방학독서', '#책읽기습관', '#책스...
# 1996  stomach_endoscope                                                 []
# 1997             nolgoo  ['#커플스타그램', '#럽스타그램', '#먹스타그램', '#솥밥', '#도미관자솥...
# 1998      kimtaelee_092  ['#혼치킨🍗', '#혼밥', '#치킨매니아', '#먹는거에진심인편', '#존맛탱구...
# 1999        cheolin7_cw                                                 []
#
#               Like_avg          Like_mid
# 0                 1040              1040
# 1                  109               109
# 2                  109               109
# 3                    9                 9
# 4     rila님 여러 명이 좋아합니  rila님 여러 명이 좋아합니
# ...                ...               ...
# 1995                41                41
# 1996                74                74
# 1997                21                21
# 1998                11                11
# 1999                15                15
#
# [2000 rows x 6 columns]

# %%
# 평균값
num = result[~(result["Like_avg"].str.contains("좋아합니")|result["Like_avg"].str.contains("눌러보세"))]["Like_avg"]
num = num.astype(int)
num.sum()/len(num)
# Out:
# 61.235632183908045

# %%
result["Like_avg"].str.contains("좋아합니").value_counts()
# Out:
# False    1797
# True      203
# Name: Like_avg, dtype: int64

# %%
result["Like_avg"].str.contains("눌러보세").value_counts()
# Out:
# False    1943
# True       57
# Name: Like_avg, dtype: int64

# %%
like_str_idx = result[result["Like_avg"].str.contains("좋아합니")].index
like_0_idx = result[result["Like_avg"].str.contains("눌러보세")].index

# %%
for i in range(len(result)):
    for j in like_str_idx:
        for k in like_0_idx:
            if i==j:
                result["Like_avg"][j]=61.23
            elif i==k:
                result["Like_avg"][k]=0
            else:
                continue

# %%
result["Like_avg"].str.contains("좋아합니").value_counts()
# Out:
# False    1740
# Name: Like_avg, dtype: int64

# %%
result["Like_avg"].str.contains("눌러보세").value_counts()
# Out:
# False    1740
# Name: Like_avg, dtype: int64

# %%
result["Like_avg"] = result["Like_avg"].astype("int")

# %%
#중간값
num = result[~(result["Like_mid"].str.contains("좋아합니")|result["Like_mid"].str.contains("눌러보세"))]["Like_mid"]
num = num.astype(int)
num.median()
# Out:
# 19.0

# %%
result["Like_mid"].str.contains("좋아합니").value_counts()
# Out:
# False    1797
# True      203
# Name: Like_mid, dtype: int64

# %%
result["Like_mid"].str.contains("눌러보세").value_counts()
# Out:
# False    1943
# True       57
# Name: Like_mid, dtype: int64

# %%
like_str_idx = result[result["Like_mid"].str.contains("좋아합니")].index
like_0_idx = result[result["Like_mid"].str.contains("눌러보세")].index

# %%
for i in range(len(result)):
    for j in like_str_idx:
        for k in like_0_idx:
            if i==j:
                result["Like_mid"][j]=19
            elif i==k:
                result["Like_mid"][k]=0
            else:
                continue
# Out:
# C:\Users\mhpark\AppData\Local\Temp\ipykernel_34772\3429159571.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result["Like_mid"][j]=19
# C:\Users\mhpark\AppData\Local\Temp\ipykernel_34772\3429159571.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result["Like_mid"][k]=0

# %%
result["Like_mid"].str.contains("좋아합니").value_counts()
# Out:
# False    1740
# Name: Like_mid, dtype: int64

# %%
result["Like_mid"].str.contains("눌러보세").value_counts()
# Out:
# False    1740
# Name: Like_mid, dtype: int64

# %%
result["Like_mid"] = result["Like_mid"].astype("int")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  2000 non-null   object
#  1   Like      2000 non-null   object
#  2   ID        2000 non-null   object
#  3   Tags      2000 non-null   object
#  4   Like_avg  2000 non-null   int32
#  5   Like_mid  2000 non-null   int32
# dtypes: int32(2), object(4)
# memory usage: 78.2+ KB

# %%
# tags # 제외한 특수 기호 제거
result["Tags"] = result["Tags"].str.strip("]['")
result["Tags"] = result["Tags"].str.replace("'", repl=r"", regex=True)

# %%
result.head()
# Out:
#                                             Contents              Like  \
# 0  둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1   협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2  돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                         얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4    노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
#
#                  ID                                               Tags  \
# 0           z.e.o.m  #동근이숯불두마리치킨, #동근이숯불두마리치킨, #치킨, #치킨맛집, #배달치킨, #...
# 1  foodgangster_fgg  #치킨매니아, #푸드갱_배달, #배달맛집, #치킨맛집, #떡볶이맛집, #배달음식추천...
# 2    bboong_bbang_2
# 3         dhrkspths
# 4       a_a_bl0s2om  #대구맛집, #먹방, #instafood, #요리스타그램, #요리, #맛스타그램, ...
#
#    Like_avg  Like_mid  tag_sum
# 0      1040      1040       11
# 1       109       109        9
# 2       109       109        0
# 3         9         9        0
# 4        61        19       28

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  2000 non-null   object
#  1   Like      2000 non-null   object
#  2   ID        2000 non-null   object
#  3   Tags      2000 non-null   object
#  4   Like_avg  2000 non-null   int32
#  5   Like_mid  2000 non-null   int32
# dtypes: int32(2), object(4)
# memory usage: 78.2+ KB

# %%
result["Tags"].isna()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1995    False
# 1996     True
# 1997    False
# 1998    False
# 1999     True
# Name: Tags, Length: 2000, dtype: bool

# %%
result = result
result["Tags"] = result["Tags"].fillna("")
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Contents  2000 non-null   object
#  1   Like      2000 non-null   object
#  2   ID        2000 non-null   object
#  3   Tags      2000 non-null   object
#  4   Like_avg  2000 non-null   int64
#  5   Like_mid  2000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 93.9+ KB

# %%
result
# Out:
#                                                Contents              Like  \
# 0     둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1      협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2     돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                            얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4       노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
# ...                                                 ...               ...
# 1995   논어  공부가되는논어이야기  방학독서 책읽기습관  책스타그램  책추천 아이들과함께...                41
# 1996                                   어떻게 라면에 주먹밥이 팔천원                74
# 1997  오늘 먹은거솥밥 넘 맛났당윤선빵과 함께      커플스타그램 럽스타그램 먹스타그램 ...                21
# 1998  엄마도 외출나가고 동생도 칭구집 가서 나 혼자 혼 치 조지기   빠삭빠삭 잘 튀겨졌...                11
# 1999                골라서 먹을수있는 재미    철인3종세트 순살  양념 간장 홍갈                15
#
#                      ID                                               Tags  \
# 0               z.e.o.m  #동근이숯불두마리치킨, #동근이숯불두마리치킨, #치킨, #치킨맛집, #배달치킨, #...
# 1      foodgangster_fgg  #치킨매니아, #푸드갱_배달, #배달맛집, #치킨맛집, #떡볶이맛집, #배달음식추천...
# 2        bboong_bbang_2
# 3             dhrkspths
# 4           a_a_bl0s2om  #대구맛집, #먹방, #instafood, #요리스타그램, #요리, #맛스타그램, ...
# ...                 ...                                                ...
# 1995           lee_hk79  #논어, #공부가되는논어이야기, #방학독서, #책읽기습관, #책스타그램, #책추천,...
# 1996  stomach_endoscope
# 1997             nolgoo  #커플스타그램, #럽스타그램, #먹스타그램, #솥밥, #도미관자솥밥, #전복솥밥, ...
# 1998      kimtaelee_092  #혼치킨🍗, #혼밥, #치킨매니아, #먹는거에진심인편, #존맛탱구리, #치킨, #사...
# 1999        cheolin7_cw
#
#       Like_avg  Like_mid  tag_sum
# 0         1040      1040       11
# 1          109       109        9
# 2          109       109        0
# 3            9         9        0
# 4           61        19       28
# ...        ...       ...      ...
# 1995        41        41       29
# 1996        74        74        0
# 1997        21        21       25
# 1998        11        11        9
# 1999        15        15        0
#
# [2000 rows x 7 columns]

# %%
example_list = ['치킨', '먹스타그램', '맛집', '맛스타그램', '수', '치킨맛집', '좋아요', '치맥', '일상'] # 밑에 워드클라우드 전처리과정에서 빈도수 상위10개 추출
test = '|'.join(example_list)
result["Tags"].str.split("'#'")[0].count(example_list[0])
# Out:
# 0

# %%
test
# Out:
# '치킨|먹스타그램|맛집|맛스타그램|수|치킨맛집|좋아요|치맥|일상|먹방'

# %%
Tags_count = [ ]
sentence = result["Tags"].str.split("#")[4][1:]
tmp=0
for j in range(len(example_list)):
    tmp += sum(map(lambda x : 1 if example_list[j] in x else 0, sentence))
Tags_count.append(tmp)

Tags_count
# Out:
# [6]

# %%
example_list = ['치킨', '먹스타그램', '맛집', '맛스타그램', '수', '치킨맛집', '좋아요', '치맥', '일상', '먹방']
Tags_count = [ ]
for i in range(len(result)):
    sentence = result["Tags"].str.split("#")[i][1:]
    tmp=0
    for j in range(len(example_list)):
        tmp += sum(map(lambda x : 1 if example_list[j] in x else 0, sentence))
    Tags_count.append(tmp)

result["tags_count"] = Tags_count

# %%
result
# Out:
#                                                Contents              Like  \
# 0     둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1      협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2     돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                            얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4       노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
# ...                                                 ...               ...
# 1995   논어  공부가되는논어이야기  방학독서 책읽기습관  책스타그램  책추천 아이들과함께...                41
# 1996                                   어떻게 라면에 주먹밥이 팔천원                74
# 1997  오늘 먹은거솥밥 넘 맛났당윤선빵과 함께      커플스타그램 럽스타그램 먹스타그램 ...                21
# 1998  엄마도 외출나가고 동생도 칭구집 가서 나 혼자 혼 치 조지기   빠삭빠삭 잘 튀겨졌...                11
# 1999                골라서 먹을수있는 재미    철인3종세트 순살  양념 간장 홍갈                15
#
#                      ID                                               Tags  \
# 0               z.e.o.m  #동근이숯불두마리치킨, #동근이숯불두마리치킨, #치킨, #치킨맛집, #배달치킨, #...
# 1      foodgangster_fgg  #치킨매니아, #푸드갱_배달, #배달맛집, #치킨맛집, #떡볶이맛집, #배달음식추천...
# 2        bboong_bbang_2
# 3             dhrkspths
# 4           a_a_bl0s2om  #대구맛집, #먹방, #instafood, #요리스타그램, #요리, #맛스타그램, ...
# ...                 ...                                                ...
# 1995           lee_hk79  #논어, #공부가되는논어이야기, #방학독서, #책읽기습관, #책스타그램, #책추천,...
# 1996  stomach_endoscope
# 1997             nolgoo  #커플스타그램, #럽스타그램, #먹스타그램, #솥밥, #도미관자솥밥, #전복솥밥, ...
# 1998      kimtaelee_092  #혼치킨🍗, #혼밥, #치킨매니아, #먹는거에진심인편, #존맛탱구리, #치킨, #사...
# 1999        cheolin7_cw
#
#       Like_avg  Like_mid  tag_sum  tags_count  tag_rate
# 0         1040      1040       11          12    109.09
# 1          109       109        9           8     88.89
# 2          109       109        0           0       NaN
# 3            9         9        0           0       NaN
# 4           61        19       28           6     21.43
# ...        ...       ...      ...         ...       ...
# 1995        41        41       29           4     13.79
# 1996        74        74        0           0       NaN
# 1997        21        21       25           2      8.00
# 1998        11        11        9           4     44.44
# 1999        15        15        0           0       NaN
#
# [2000 rows x 9 columns]

# %%
tag_sum = [ ]
for i in range(len(result)):
    if len(result["Tags"].str.split("#")[1]) >= 1:
        tag_sum.append(len(result["Tags"].str.split("#")[i][1:]))
        
result["tag_sum"] = tag_sum

# %%
result["Tags"] = result["Tags"].fillna("")

# %%
result["Tags"] = result["Tags"].astype("str")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Contents    2000 non-null   object
#  1   Like        2000 non-null   object
#  2   ID          2000 non-null   object
#  3   Tags        2000 non-null   object
#  4   Like_avg    2000 non-null   int64
#  5   Like_mid    2000 non-null   int64
#  6   tag_sum     2000 non-null   int64
#  7   Tags_count  2000 non-null   int64
#  8   tags_count  2000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 140.8+ KB

# %%
result["tag_rate"] = ((result["tags_count"] / result["tag_sum"]) * 100) .round(2)
result.head()
# Out:
#                                             Contents              Like  \
# 0  둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1   협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2  돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                         얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4    노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
#
#                  ID                                               Tags  \
# 0           z.e.o.m  #동근이숯불두마리치킨, #동근이숯불두마리치킨, #치킨, #치킨맛집, #배달치킨, #...
# 1  foodgangster_fgg  #치킨매니아, #푸드갱_배달, #배달맛집, #치킨맛집, #떡볶이맛집, #배달음식추천...
# 2    bboong_bbang_2
# 3         dhrkspths
# 4       a_a_bl0s2om  #대구맛집, #먹방, #instafood, #요리스타그램, #요리, #맛스타그램, ...
#
#    Like_avg  Like_mid  tag_sum  tags_count  tag_rate
# 0      1040      1040       11          12    109.09
# 1       109       109        9           8     88.89
# 2       109       109        0           0       NaN
# 3         9         9        0           0       NaN
# 4        61        19       28           6     21.43

# %%
result
# Out:
#                                                Contents              Like  \
# 0     둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1      협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2     돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                            얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4       노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
# ...                                                 ...               ...
# 1995   논어  공부가되는논어이야기  방학독서 책읽기습관  책스타그램  책추천 아이들과함께...                41
# 1996                                   어떻게 라면에 주먹밥이 팔천원                74
# 1997  오늘 먹은거솥밥 넘 맛났당윤선빵과 함께      커플스타그램 럽스타그램 먹스타그램 ...                21
# 1998  엄마도 외출나가고 동생도 칭구집 가서 나 혼자 혼 치 조지기   빠삭빠삭 잘 튀겨졌...                11
# 1999                골라서 먹을수있는 재미    철인3종세트 순살  양념 간장 홍갈                15
#
#                      ID                                               Tags  \
# 0               z.e.o.m  #동근이숯불두마리치킨, #동근이숯불두마리치킨, #치킨, #치킨맛집, #배달치킨, #...
# 1      foodgangster_fgg  #치킨매니아, #푸드갱_배달, #배달맛집, #치킨맛집, #떡볶이맛집, #배달음식추천...
# 2        bboong_bbang_2
# 3             dhrkspths
# 4           a_a_bl0s2om  #대구맛집, #먹방, #instafood, #요리스타그램, #요리, #맛스타그램, ...
# ...                 ...                                                ...
# 1995           lee_hk79  #논어, #공부가되는논어이야기, #방학독서, #책읽기습관, #책스타그램, #책추천,...
# 1996  stomach_endoscope
# 1997             nolgoo  #커플스타그램, #럽스타그램, #먹스타그램, #솥밥, #도미관자솥밥, #전복솥밥, ...
# 1998      kimtaelee_092  #혼치킨🍗, #혼밥, #치킨매니아, #먹는거에진심인편, #존맛탱구리, #치킨, #사...
# 1999        cheolin7_cw
#
#       Like_avg  Like_mid  tag_sum  tags_count  tag_rate
# 0         1040      1040       11          12    109.09
# 1          109       109        9           8     88.89
# 2          109       109        0           0      0.00
# 3            9         9        0           0      0.00
# 4           61        19       28           6     21.43
# ...        ...       ...      ...         ...       ...
# 1995        41        41       29           4     13.79
# 1996        74        74        0           0      0.00
# 1997        21        21       25           2      8.00
# 1998        11        11        9           4     44.44
# 1999        15        15        0           0      0.00
#
# [2000 rows x 9 columns]

# %%
result["tag_rate"] = result["tag_rate"].fillna(0)
result["tag_rate"]
# Out:
# 0       109.09
# 1        88.89
# 2         0.00
# 3         0.00
# 4        21.43
#          ...
# 1995     13.79
# 1996      0.00
# 1997      8.00
# 1998     44.44
# 1999      0.00
# Name: tag_rate, Length: 2000, dtype: float64

# %%
result['Like_avg_normal1'] = result['Like_avg'] / abs(result['Like_avg'].max())
result['Like_avg_normal1'].head()
# Out:
# 0    0.175646
# 1    0.018409
# 2    0.018409
# 3    0.001520
# 4    0.010302
# Name: Like_avg_normal1, dtype: float64

# %%
min_x = result['Like_avg'] - result['Like_avg'].min()
min_max = result['Like_avg'].max() - result['Like_avg'].min()

result['Like_avg_normal2'] = min_x / min_max
result['Like_avg_normal2'].head()
# Out:
# 0    0.175646
# 1    0.018409
# 2    0.018409
# 3    0.001520
# 4    0.010302
# Name: Like_avg_normal2, dtype: float64

# %%
result['Like_mid_normal1'] = result['Like_mid'] / abs(result['Like_mid'].max())
result['Like_mid_normal1'].head()
# Out:
# 0    0.175646
# 1    0.018409
# 2    0.018409
# 3    0.001520
# 4    0.003209
# Name: Like_mid_normal1, dtype: float64

# %%
min_x = result['Like_mid'] - result['Like_mid'].min()
min_max = result['Like_mid'].max() - result['Like_mid'].min()

result['Like_mid_normal2'] = min_x / min_max
result['Like_mid_normal2'].head()
# Out:
# 0    0.175646
# 1    0.018409
# 2    0.018409
# 3    0.001520
# 4    0.003209
# Name: Like_mid_normal2, dtype: float64

# %%
result.head()
# Out:
#                                             Contents              Like  \
# 0  둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기...              1040
# 1   협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는...               109
# 2  돼지 사료 일지   506  지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 ...               109
# 3                         얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임                 9
# 4    노랑통닭ㆍㆍㆍ 대구맛집  먹방  instafood  요리스타그램  요리  맛스타...  rila님 여러 명이 좋아합니
#
#                  ID                                               Tags  \
# 0           z.e.o.m  #동근이숯불두마리치킨, #동근이숯불두마리치킨, #치킨, #치킨맛집, #배달치킨, #...
# 1  foodgangster_fgg  #치킨매니아, #푸드갱_배달, #배달맛집, #치킨맛집, #떡볶이맛집, #배달음식추천...
# 2    bboong_bbang_2
# 3         dhrkspths
# 4       a_a_bl0s2om  #대구맛집, #먹방, #instafood, #요리스타그램, #요리, #맛스타그램, ...
#
#    Like_avg  Like_mid  tag_sum  tags_count  tag_rate  Like_avg_normal1  \
# 0      1040      1040       11          12    109.09          0.175646
# 1       109       109        9           8     88.89          0.018409
# 2       109       109        0           0      0.00          0.018409
# 3         9         9        0           0      0.00          0.001520
# 4        61        19       28           6     21.43          0.010302
#
#    Like_avg_normal2  Like_mid_normal1  Like_mid_normal2
# 0          0.175646          0.175646          0.175646
# 1          0.018409          0.018409          0.018409
# 2          0.018409          0.018409          0.018409
# 3          0.001520          0.001520          0.001520
# 4          0.010302          0.003209          0.003209

# %%
# 저장
result.to_csv("data/치킨2000-1.csv", encoding="utf-8", index=False)

# %%
# 불러오기
result = pd.read_csv("data/피자2000.csv")

# %%
result.info()
# Out:
#                                                Contents         Like  \
# 0     피자 좋아하는 대식가들 여기 당장가야되요 사장님 걱정될 정도로 미친듯이 토핑이 부어...         1051
# 1     우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...         1496
# 2                                      피자힙 도우는 신세계라던데             60
# 3     피자의 한 획을 그은 그 피자집이에요토핑으로 빽빽하게 채운 디트로이트 피자로 다양한...          494
# 4       제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...          972
# ...                                                 ...          ...
# 1995   영양공급 긍정적인생각 고마운사람 조녜 한국인의밥상 일상생활 먹팔해요 맞팔가요 유치...            2
# 1996   일상스타그램 팝핑댄스 가을계절 너무맛있어 맞팔그램 먹는순간기절 먹팔해요 강릉여행중...            2
# 1997   대교 맞팔100 여자가을룩 첫줄반사 맞팔그램 먹는순간기절 이태원칵테일 감칠맛가성비...  저 좋아요를 눌러보세
# 1998  오늘의 비건 식단  브로콜리 피자랑 미트프리 치킨 피자   세일해서 3유로씩 했다 ...            6
# 1999   과슈 맞팔100 돼지 구구전복삼계탕 한국인의밥상 일상생활 음식이랑썸탐 맛이좋아요 ...  저 좋아요를 눌러보세
#
#                        ID                                               Tags
# 0              _yamiyomi_  ['#홍대', '#백스트리트피자', '#피자', '#피자맛집', '#대왕피자', '...
# 1          st_foodfighter  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 2            ahfflqmepsja                                                 []
# 3            mari_mukkkkk  ['#피자덕후피자힙', '#압구정맛집', '#압구정로데오맛집', '#신사맛집', '...
# 4             gyeongboki_  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# ...                   ...                                                ...
# 1995    bellawilkins812mz  ['#영양공급', '#긍정적인생각', '#고마운사람', '#조녜', '#한국인의밥상...
# 1996  gabriellenash718ikk  ['#일상스타그램', '#팝핑댄스', '#가을계절', '#너무맛있어', '#맞팔그램...
# 1997            yomnyong1  ['#대교', '#맞팔100', '#여자가을룩', '#첫줄반사', '#맞팔그램', ...
# 1998          emily_vivid  ['#유럽', '#유럽일상', '#식단', '#비건', '#vegan', '#piz...
# 1999       emilymay3105jf  ['#과슈', '#맞팔100', '#돼지', '#구구전복삼계탕', '#한국인의밥상'...
#
# [2000 rows x 4 columns]

# %%
import time
from tqdm import tqdm_notebook

content_all = ''
for i in tqdm_notebook(range(len(result["Contents"]))):
    content_all = content_all + ' ' + result["Contents"].loc[i]
# Out:
# C:\Users\mhpark\AppData\Local\Temp\ipykernel_34772\1026978283.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(len(result["Contents"]))):
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
import re
content_all = re.sub('[^ㄱ-ㅣ가-힣 ]',"",content_all)
content_all
# Out:
# ' 둥근해 대신 올해는  동근 해가 떴습니다  우동사리에 치밥까지 치킨으로 풀코스 즐기는 법 바베큐치킨 먹을 때 됐으면     동근이숯불두마리치킨 입안가득 숯불구이향   야들촉촉 식감으로 꽉찼어요  동근이표 독보적인 양념엔 우동사리 치밥은 무조건임  소금구이는 담백하니 살 안찌는거 아시죠  꽤나 뻔뻔 꼬 소한 치즈스틱과 치즈볼은 정신차리고보니 추가함 동상이몽 요리대첩에 나온 그 치킨 드디어 먹어봤어요한마리는 살짝 서운한데 가성비 두마리치킨이라 좋고 바베큐만 아니라 튀긴치킨도 있어서 싸울일은 없어요요즘 세상에 배달비 없는곳이 있다구요    청주복대점배달구역 전부무료   가경 강서 개신 죽림 산남 수곡    동근이숯불두마리치킨 청주복대점     숯불양념 소금세트    치즈볼    치즈스틱     치킨  치킨맛집  배달치킨  배달맛집  숯불바베큐 치킨추천  복대동맛집  청주맛집  청주배달맛집  협찬  떡볶이에 타피오카 펄 쏟은 줄 알았다  버블티같은 떡볶이다  맥주를 부르는 맛이다    치킨매니아  한국식 버블티다  치킨이랑 떡볶이의 조합이 이렇게 좋은 줄 처음 알았다  동글동글한 구슬떡볶이라 숟가락으로 퍼먹기 딱 좋다  소스도 진짜 꾸덕하고 진하다  왕새우치킨은 이름값 제대로 한다  블랙타이거만한 새우가 바삭하게 튀겨졌다  치킨도 먹고 새우튀김도 먹고 일석이조다  푸드갱배달  배달맛집  치킨맛집  떡볶이맛집  배달음식추천  야식추천  치맥  치킨추천 돼지 사료 일지     지코바 성정점뿡빵쓰가 스트레스 받으면 주기적 수혈하는 대장   신라면생라면   맥주     엽떡   그리고   지코바  양념순살 매운맛                   저도 모르게 이 메뉴들을 찾고 있으면 스트레스 받거나 힐링하고 싶을때 더라구요  매운맛 음식 후후하하 먹어주다보면 자연스럽게 행복감으로 바뀌니깐 간단하게 기분 좋아지고 싶을때는 꼬옥 찾게 되네요  지코바는 무조건 떡사리 추가해서 드시고   순살   닭다리살로만 되어있어서 진짜 핵 맛   로 시키셔야하고  스트레스 확 풀리게 혹은 술안주로 드시고싶다  그럼 매운맛 고고 하세요  후회 안하실껍니다 진쟈루  저희 어머니가 주먹밥 장인이신데  참기름이랑 김 낭낭하게 뿌셔서 만든 주먹밥에 소스 푸욱 찍어서 먹으면 이맛은 진짜 찐행복이예요 오늘도 월요팅 잘 하셨나요  날이 또 갑자기 추워졌네요  저는 감기가 올라고 하는데  여러분들은 감기 조심하세요    지코바 양념 순살 매운맛   원   떡사리 서비스 얼마나 맛있었으면 포장까지ㄷㄷㄷ    범맥주 임   노랑통닭 대구맛집  먹방    요리스타그램  요리  맛스타그램  먹스타그램  선팔  맞팔  선팔하면맞팔  선팔해요    맞팔해요  팔로우  팔로잉  팔로미  팔로워  데일리  팔로우미  소통  소통해요  셀피  카페스타그램  댓글    좋아요반사  좋아요      협찬  소떡소떡 밀어내고 이제는 치떡 시대야식 하면 가장 먼저 생각나는 치킨과 떡볶이가만났다구요  이건 도대체 안먹을수가 없는 조합이에여  부산시장 스타일의 꾸덕하고 감칠맛 가득한 소스에동글동글한 구슬떡   치킨을 소스에 찍어먹어도 맛있고 그냥 숟가락으로 떡만 퍼먹어도 세상 행복 왕새우치킨은 바삭바삭한 튀김옷 안에 탱글한 새우가 있어서 누가 먹어도 좋아할 맛과 식감이에여    치킨매니아   치킨맛집  떡볶이맛집  치킨추천  떡볶이추천  배달맛집 네네치킨 신상 국물게티레드마블 네네치킨에서 신메뉴를 선보입니다  넉넉한 국물에 떡볶이 양념이 잔뜩 밴  국물게티 와 매콤달콤한  레드마블치킨 이 그 주인공입니다 국물게티는 로제맛  매콤맛 두 가지로 취향에 맞게 즐길 수 있는데요  깊고 진한맛의 특제 떡볶이 소스가 스파게티면에 잔뜩 들러 붙어 입안에 풍미가 가득한데  바삭한 치킨과 함께 즐기기 좋아요 이번 네네치킨 신상  국물게티 와  레드마블치킨  세트를 쿠캣 신상마켓에서   할인된 가격으로 먼저 만나보세요   쿠캣 신상마켓 보러가기   프로필링크   네네치킨  네네치킨신상  신상마켓  쿠캣신상마켓  국물게티  로제게티  매콤게티  레드마블치킨  레드마블  치킨  치킨추천  스파게티  파스타  홈술  분식  야식  저메추  쿠캣  쿠캣마켓  신상리뷰  쿠캣매거진  쿠캣디       맵찔이도 폭풍흡입하는   고추바사삭   볼케이노   오늘은 굽네치킨입니다    배달  굽네치킨제 최애치킨인 굽네치킨 고추바사삭은 왜 매일 땡기는거죠 더 매운게 땡길땐 볼케이노와 함께 행복한 고민에 빠집니다  그렇다고 반반시키기엔 튀김옷이 없는 굽네 특성상 양이 적다  괜찮아요 한마리   한마리 세트가 있으니까요총 두마리가 오는 세트 구성이라니요 이 구성 매우 칭찬합니다  볼케이노는 치밥으로 유명하죠  볼케이노 시키면 마그마소스는 항상 따로 주는데 이거 진짜 맘에 들더라구요너무 맵지도 않고 맵찔이들도 충분히 맛있게 먹을 수 있어요  고추바사삭은 고블링 마블링 소스가 진짜 존맛탱  ㅠㅠㅠㅠㅠ오늘 저녁 치맥은 굽네치킨으로 해야겠어요      굽네치킨 치 치 세트     우뉴배달 배달음식  배달맛집  고추바사삭  볼케이노  굽네치킨메뉴 참숯치킨은 절대 못참지   치즈소스도 못참지     훌랄라치킨  훌랄라참숯바베큐치킨  광고 제가 참숯치킨 참 좋아하는데요   치킨은 역시 훌랄라 훌랄라는 참숯향이 아주 일품인 촉촉한 치킨이에요 오븐에 촉촉하게 구워내어 참숯에서 한번 더 구워주시는  맛있는 양념옷을 입고 탄생하는 존맛 치킨 양념된 치킨구이에 치즈소스가 뿌려진다면   이건 완전 꿀조합이라 안먹어봐도 맛있쥬  약간 매콤한 양념에 치즈가 더해져 짝을 제대로 만났어용 치즈볼과 라면사리까지 추가해주시면 탄단지 제대로ㅋㅋㅋ라면사리 추가하면 소스에 같이 비벼져 나오는데 엄지척  치킨이랑 같이 먹으면 그렇게 맛있을수가 없네요ㅠㅠ앞으로 치킨은 여기로 정착합니닷     월 배달의 민족 매주 수요일  원 할인  배달의 민족 월  일 포장 기획전  원 할인  요기요 월 매일 신메뉴 종  원 할인중 훌랄라치킨  안산맛집 인천맛집 치킨맛집 숯불치킨 숯불바베큐 서산맛집  대전맛집  동탄맛집  대구맛집  파주맛집  서울맛집  경기도맛집  치킨  양념치킨                 하하호호오늘 넘 많이 웃었다 대화가 되는 나이가 됐군   좀 천천히 커주라    햄버거셔틀   상전아들 바쁜 남편대신 예약했더니호텔인줄 알고 왔는데콘도였어   하   어쩔수 없지하고 들어왔는데생각보다 뷰도 좋고 넓직하고리모델링해서 깔끔하다   싄나싄나   춤추고난리 ㅎㅎㅎㅎ 야식  치킨 모시러갔다 맨발의청춘  영하도  뛰고뛰고또뛰고  추워도좋아  눈이좋아 감사            휘닉스평창  리그램          당치땡 행운의부적 인증샷 이벤트      당치땡이 준비한 행운의 부적과 함께하는여러분의 일상을 공유해주세요      추첨을 통해 당치땡 교환권을 드립니다       참여 방법 당치땡을 주문하고  행운의 부적 을 받는다 부적과 함께 찍은 사진을 인스타그램 피드 또는 스토리에 올린다  필수 계정태그      필수 해시태그    당치땡  부적인증샷  당치땡부적       당치땡 팔로우 게시물 좋아요 시 당첨 확률         응모 기간     수       화       당첨자 발표     월       당첨자 경품당치땡 만원권 명        참여 시 주의사항  당치땡 공식 계정을 꼭 태그해주세요   주문 시 랜덤 부적 제공 여부 및 수령 조건을 꼭 확인해주세요   랜덤 부적은 지점별 선착순 제공되어 조기 소진될 수 있습니다   비공개 계정일 경우 게시물 확인이 어려워 당첨 대상에서 제외될 수 있습니다  당치땡  당신은지금치킨이땡긴다  치킨  치킨추천  이벤트    행운의부적  신년부적  새해부적  당치땡부적  인증샷이벤트                                                치킨    후라이드치킨                         저녁                                            저녁  집밥  국수  미트볼  치킨  고기  홈메이드  홈쿡  냠냠  먹스타그램  맛스타그램  맛있다  존맛  좋아요  라이프스타일  일상  데일리  치킨 아이들 방학집에서 치킨 만들어서 먹으니 아들이 더 맛있다고 하네요    맘 ...

# %%
from konlpy.tag import Okt
okt = Okt()
nouns_txt = okt.nouns(content_all)
nouns_txt
# Out:
# ['대신',
#  '올해',
#  '해',
#  '우동',
#  '사리',
#  '치밥',
#  '치킨',
#  '풀',
#  '코스',
#  '법',
#  '바베큐치킨',
#  '때',
#  '숯불',
#  '마리',
#  '치킨',
#  '입안',
#  '가득',
#  '숯불',
#  '이향',
#  '촉촉',
#  '식감',
#  '표',
#  '독보',
#  '양념',
#  '우동',
#  '사리',
#  '치밥',
#  '무조건',
#  '임',
#  '금구',
#  '살',
#  '아시',
#  '꽤',
#  '뻔뻔',
#  '꼬',
#  '소한',
#  '치즈스틱',
#  '치즈볼',
#  '추가',
#  '함',
#  '동상',
#  '이몽',
#  '요리',
#  '대첩',
#  '그',
#  '치킨',
#  '마리',
#  '살짝',
#  '가성',
#  '비',
#  '마리',
#  '치킨',
#  '바베큐',
#  '치킨',
#  '일',
#  '요즘',
#  '세상',
#  '배달',
#  '비',
#  '곳',
#  '청주',
#  '복대',
#  '점',
#  '배달',
#  '구역',
#  '전부',
#  '무료',
#  '가경',
#  '강서',
#  '죽림',
#  '산남',
#  '곡',
#  '숯불',
#  '마리',
#  '치킨',
#  '청주',
#  '복대',
#  '점',
#  '숯불',
#  '양념',
#  '소금',
#  '세트',
#  '치즈볼',
#  '치즈스틱',
#  '치킨',
#  '치킨',
#  '맛집',
#  '배달',
#  '치킨',
#  '배달',
#  '맛집',
#  '숯불',
#  '바베큐',
#  '치킨',
#  '추천',
#  '복대동',
#  '맛집',
#  '청주',
#  '맛집',
#  '청주',
#  '배달',
#  '맛집',
#  '협찬',
#  '떡볶이',
#  '타피오카',
#  '펄',
#  '줄',
#  '버블티',
#  '떡볶이',
#  '맥주',
#  '맛',
#  '치킨',
#  '매니아',
#  '한국',
#  '버블티',
#  '치킨',
#  '떡볶이',
#  '조합',
#  '줄',
#  '처음',
#  '동글동글',
#  '구슬',
#  '떡볶이',
#  '숟가락',
#  '퍼',
#  '먹기',
#  '소스',
#  '진짜',
#  '덕',
#  '왕새우',
#  '치킨',
#  '이름',
#  '값',
#  '제대로',
#  '블랙타이',
#  '새우',
#  '바삭',
#  '치킨',
#  '새우',
#  '튀김',
#  '일석이조',
#  '푸드',
#  '갱',
#  '배달',
#  '배달',
#  '맛집',
#  '치킨',
#  '맛집',
#  '떡볶이',
#  '맛집',
#  '배달',
#  '음식',
#  '추천',
#  '야식',
#  '추천',
#  '치맥',
#  '치킨',
#  '추천',
#  '돼지',
#  '사료',
#  '일지',
#  '코바',
#  '정점',
#  '뿡빵',
#  '스트레스',
#  '기적',
#  '수혈',
#  '대장',
#  '신라면',
#  '생',
#  '라면',
#  '맥주',
#  '엽떡',
#  '코바',
#  '양념',
#  '살',
#  '맛',
#  '저',
#  '이',
#  '메뉴',
#  '스트레스',
#  '힐링',
#  '때',
#  '맛',
#  '음식',
#  '자연',
#  '행복감',
#  '기분',
#  '때',
#  '코바',
#  '무조건',
#  '떡',
#  '사리',
#  '추가',
#  '살',
#  '닭다리',
#  '살로',
#  '진짜',
#  '핵',
#  '맛',
#  '로',
#  '스트레스',
#  '확',
#  '술안주',
#  '맛',
#  '고고',
#  '후회',
#  '껍니',
#  '진쟈루',
#  '저희',
#  '어머니',
#  '주먹밥',
#  '장인',
#  '데',
#  '참기름',
#  '김',
#  '낭낭',
#  '뿌셔',
#  '주먹밥',
#  '소스',
#  '푸욱',
#  '맛',
#  '진짜',
#  '행복',
#  '오늘',
#  '월요팅',
#  '날',
#  '또',
#  '갑자기',
#  '저',
#  '감기',
#  '여러분',
#  '감기',
#  '코바',
#  '양념',
#  '살',
#  '맛',
#  '원',
#  '떡',
#  '사리',
#  '서비스',
#  '얼마나',
#  '포장',
#  '범',
#  '맥주',
#  '임',
#  '노랑',
#  '통닭',
#  '대구',
#  '맛집',
#  '먹방',
#  '요리',
#  '스타',
#  '그램',
#  '요리',
#  '맛스타',
#  '그램',
#  '스타',
#  '그램',
#  '선팔',
#  '맞팔',
#  '선팔',
#  '맞팔',
#  '선팔',
#  '맞팔',
#  '팔로우',
#  '팔로잉',
#  '로미',
#  '팔로워',
#  '데',
#  '일리',
#  '팔로',
#  '우미',
#  '소통',
#  '소통',
#  '셀피',
#  '카페',
#  '스타',
#  '그램',
#  '댓글',
#  '반사',
#  '협찬',
#  '떡',
#  '떡',
#  '이제',
#  '치떡',
#  '시대',
#  '야식',
#  '가장',
#  '먼저',
#  '치킨',
#  '떡볶이',
#  '이건',
#  '도대체',
#  '조합',
#  '부산시',
#  '스타일',
#  '덕',
#  '감칠맛',
#  '소스',
#  '동글동글',
#  '구슬',
#  '떡',
#  '치킨',
#  '소스',
#  '그냥',
#  '숟가락',
#  '떡',
#  '퍼먹어',
#  '세상',
#  '행복',
#  '왕새우',
#  '치킨',
#  '튀김',
#  '옷',
#  '안',
#  '글',
#  '새우',
#  '누가',
#  '맛',
#  '식감',
#  '치킨',
#  '매니아',
#  '치킨',
#  '맛집',
#  '떡볶이',
#  '맛집',
#  '치킨',
#  '추천',
#  '떡볶이',
#  '추천',
#  '배달',
#  '맛집',
#  '치킨',
#  '신상',
#  '국물',
#  '티',
#  '레드',
#  '마블',
#  '치킨',
#  '메뉴',
#  '국물',
#  '떡볶이',
#  '양념',
#  '잔뜩',
#  '국물',
#  '티',
#  '매콤',
#  '레드',
#  '마블',
#  '치킨',
#  '이',
#  '그',
#  '주인공',
#  '국물',
#  '티',
#  '로',
#  '맛',
#  '매콤',
#  '맛',
#  '두',
#  '가지',
#  '취향',
#  '수',
#  '맛',
#  '특제',
#  '떡볶이',
#  '소스',
#  '스파게티',
#  '면',
#  '잔뜩',
#  '입안',
#  '미가',
#  '바삭',
#  '치킨',
#  '이번',
#  '치킨',
#  '신상',
#  '국물',
#  '티',
#  '레드',
#  '마블',
#  '치킨',
#  '세트',
#  '쿠캣',
#  '신상',
#  '마켓',
#  '할인',
#  '가격',
#  '먼저',
#  '쿠캣',
#  '신상',
#  '마켓',
#  '프로필',
#  '링크',
#  '치킨',
#  '치킨',
#  '신상',
#  '신상',
#  '마켓',
#  '쿠캣',
#  '신상',
#  '마켓',
#  '국물',
#  '티',
#  '로제',
#  '티',
#  '매콤',
#  '티',
#  '레드',
#  '마블',
#  '치킨',
#  '레드',
#  '마블',
#  '치킨',
#  '치킨',
#  '추천',
#  '스파게티',
#  '파스타',
#  '홈술',
#  '분식',
#  '야식',
#  '메추',
#  '쿠캣',
#  '쿠캣',
#  '마켓',
#  '신상',
#  '리뷰',
#  '쿠캣',
#  '쿠캣디',
#  '맵',
#  '폭풍',
#  '흡입',
#  '고추',
#  '볼케이노',
#  '오늘',
#  '굽네치킨',
#  '배달',
#  '굽네치킨',
#  '제',
#  '최애',
#  '치킨',
#  '굽네치킨',
#  '고추',
#  '은',
#  '왜',
#  '매일',
#  '더',
#  '땐',
#  '볼케이노',
#  '고민',
#  '키기',
#  '튀김',
#  '옷',
#  '굽',
#  '특성',
#  '양',
#  '마리',
#  '마리',
#  '세트',
#  '총',
#  '마리',
#  '세트',
#  '구성',
#  '니요',
#  '이',
#  '구성',
#  '매우',
#  '칭찬',
#  '볼케이노',
#  '치밥',
#  '볼케이노',
#  '마그마',
#  '소스',
#  '항상',
#  '거',
#  '진짜',
#  '맘',
#  '맵',
#  '수',
#  '고추',
#  '은',
#  '고블링',
#  '마블링',
#  '소스',
#  '진짜',
#  '존맛',
#  '오늘',
#  '저녁',
#  '치맥',
#  '굽네치킨',
#  '굽네치킨',
#  '치',
#  '치',
#  '세트',
#  '뉴',
#  '배달',
#  '배달',
#  '음식',
#  '배달',
#  '맛집',
#  '고추',
#  '볼케이노',
#  '굽네치킨',
#  '메뉴',
#  '참숯',
#  '치킨',
#  '절대',
#  '치즈',
#  '소스',
#  '훌',
#  '치킨',
#  '훌',
#  '참숯',
#  '바베큐치킨',
#  '광고',
#  '제',
#  '참숯',
#  '치킨',
#  '치킨',
#  '역시',
#  '훌랄',
#  '훌랄',
#  '참숯',
#  '향',
#  '아주',
#  '일품',
#  '치킨',
#  '오븐',
#  '참숯',
#  '한번',
#  '더',
#  '양념',
#  '옷',
#  '탄생',
#  '존맛',
#  '치킨',
#  '양념',
#  '치킨',
#  '구이',
#  '치즈',
#  '소스',
#  '이건',
#  '완전',
#  '꿀',
#  '조합',
#  '맛있쥬',
#  '약간',
#  '매콤',
#  '양념',
#  '치즈',
#  '짝',
#  '제대로',
#  '치즈볼',
#  '라면',
#  '사리',
#  '추가',
#  '단지',
#  '제대로',
#  '라면',
#  '사리',
#  '추가',
#  '소스',
#  '엄지',
#  '척',
#  '치킨',
#  '앞',
#  '치킨',
#  '여기',
#  '정착',
#  '합',
#  '닷',
#  '월',
#  '배달',
#  '민족',
#  '수요일',
#  '원',
#  '할인',
#  '배달',
#  '민족',
#  '월',
#  '일',
#  '포장',
#  '기획전',
#  '원',
#  '할인',
#  '요기',
#  '월',
#  '매일',
#  '메뉴',
#  '종',
#  '원',
#  '할인',
#  '훌',
#  '치킨',
#  '안산',
#  '맛집',
#  '인천',
#  '맛집',
#  '치킨',
#  '맛집',
#  '숯불',
#  '치킨',
#  '숯불',
#  '바베큐',
#  '서산',
#  '맛집',
#  '대전',
#  '맛집',
#  '동탄',
#  '맛집',
#  '대구',
#  '맛집',
#  '파주',
#  '맛집',
#  '서울',
#  '맛집',
#  '경기도',
#  '맛집',
#  '치킨',
#  '양념치킨',
#  '하하호호',
#  '오늘',
#  '대화',
#  '나이',
#  '좀',
#  '햄버거',
#  '셔틀',
#  '상전',
#  '아들',
#  '남편',
#  '대신',
#  '예약',
#  '호텔',
#  '줄',
#  '알',
#  '콘도',
#  '수',
#  '생각',
#  '뷰',
#  '모델링',
#  '싄나싄',
#  '난리',
#  '야식',
#  '치킨',
#  '발의',
#  '청춘',
#  '영하',
#  '또',
#  '눈',
#  '감사',
#  '휘닉스',
#  '평창',
#  '리그',
#  '램',
#  '치땡',
#  '행운',
#  '부적',
#  '인증샷',
#  '이벤트',
#  '치땡',
#  '준비',
#  '행운',
#  '부적',
#  '여러분',
#  '일상',
#  '공유',
#  '추첨',
#  '통해',
#  '치땡',
#  '교환',
#  '참여',
#  '방법',
#  '치땡',
#  '주문',
#  '행운',
#  '부적',
#  '부적',
#  '사진',
#  '인스타그램',
#  '피드',
#  '스토리',
#  '올린다',
#  '필수',
#  '계정',
#  '태그',
#  '필수',
#  '해시태그',
#  '치땡',
#  '부적',
#  '인증샷',
#  '치땡',
#  '부적',
#  '치땡',
#  '팔로우',
#  '게시',
#  '물',
#  '시',
#  '당첨',
#  '확률',
#  '응모',
#  '기간',
#  '수',
#  '화',
#  '당첨',
#  '발표',
#  '월',
#  '당첨',
#  '경품',
#  '치땡',
#  '만원',
#  '명',
#  '참여',
#  '시',
#  '주의',
#  '사항',
#  '치땡',
#  '공식',
#  '계정',
#  '꼭',
#  '태그',
#  '주문',
#  '시',
#  '랜덤',
#  '부적',
#  '제공',
#  '여부',
#  '및',
#  '수령',
#  '조건',
#  '꼭',
#  '확인',
#  '랜덤',
#  '부적',
#  '지점',
#  '별',
#  '선착순',
#  '제공',
#  '조기',
#  '소진',
#  '수',
#  '비공개',
#  '계정일',
#  '경우',
#  '게시',
#  '물',
#  '확인',
#  '당첨',
#  '대상',
#  '제외',
#  '수',
#  '치땡',
#  '당신',
#  '지금',
#  '치킨',
#  '치킨',
#  '치킨',
#  '추천',
#  '이벤트',
#  '행운',
#  '부적',
#  '신년',
#  '부적',
#  '새해',
#  '부적',
#  '치땡',
#  '부적',
#  '인증샷',
#  '이벤트',
#  '치킨',
#  '후라이드',
#  '치킨',
#  '저녁',
#  '저녁',
#  '집밥',
#  '국수',
#  '미트볼',
#  '치킨',
#  '고기',
#  '홈',
#  '메이드',
#  '홈쿡',
#  '스타',
#  '그램',
#  '맛스타',
#  '그램',
#  '존맛',
#  '라이프스타일',
#  '일상',
#  '데',
#  '일리',
#  '치킨',
#  '아이',
#  '방학',
#  '집',
#  '치킨',
#  '아들',
#  '더',
#  '맘스',
#  '터치',
#  '치킨',
#  '치킨',
#  '야식',
#  '맘스',
#  '터치',
#  '치킨',
#  '맘스',
#  '터치',
#  '양념치킨',
#  '간장',
#  '마늘',
#  '치킨',
#  '블로거',
#  '남자',
#  '치',
#  '느님',
#  '치팅',
#  '데이',
#  '치킨',
#  '맛집',
#  '신혼부부',
#  '신혼',
#  '부부',
#  '일상',
#  '부부',
#  '스타',
#  '그램',
#  '신혼부부',
#  '밥상',
#  '신혼부부',
#  '그램',
#  '집밥',
#  '치킨',
#  '계',
#  '치킨',
#  '치킨',
#  '처갓집',
#  '양념치킨',
#  '치킨',
#  '라면',
#  '유부초밥',
#  '초밥',
#  '물회',
#  '회덮밥',
#  '딸기',
#  '치즈',
#  '돈가스',
#  '디저트',
#  '카페',
#  '음식',
#  '스타',
#  '그램',
#  '먹방',
#  '북',
#  '런던',
#  '더비',
#  '완승',
#  '런던',
#  '레드',
#  '랍니',
#  '우리',
#  '홈인',
#  '줄',
#  '모야',
#  '북',
#  '런던',
#  '더비',
#  '아스날',
#  '토트넘',
#  '음식사진',
#  '광어',
#  '우럭',
#  '회',
#  '낙곱새',
#  '바스크',
#  '치즈케이크',
#  '코타',
#  '치즈',
#  '샐러드',
#  '치킨',
#  '성공',
#  '사업',
#  '서포터',
#  '소규모',
#  '외식',
#  '업',
#  '창업',
#  '아이템',
#  '선정',
#  '기획',
#  '점포',
#  '개발',
#  '메뉴',
#  '개발',
#  '교육',
#  '운영',
#  '등',
#  '신규',
#  '브랜드',
#  '론칭',
#  '신규',
#  '외식',
#  '브랜드',
#  '론칭',
#  '전분',
#  '사업',
#  '타당성',
#  '분석',
#  '브랜드',
#  '컨셉',
#  '메뉴',
#  '개발',
#  '본사',
#  '수익률',
#  '기획',
#  '디자인',
#  '인테리어',
#  '컵',
#  '개발',
#  '매뉴얼',
#  '개발',
#  '및',
#  '교육',
#  '상권',
#  '분석',
#  '및',
#  '개발',
#  '가맹',
#  '사업',
#  '진행',
#  '사후관리',
#  '메뉴',
#  '개발',
#  '개인',
#  '및',
#  '기업',
#  '뉴',
#  '리뉴얼',
#  '및',
#  '신규',
#  '뉴',
#  '개발',
#  '각종',
#  '인',
#  '허가',
#  '및',
#  '식품',
#  '제조',
#  '허가',
#  '진행',
#  '및',
#  '사후관리',
#  '각종',
#  '문의',
#  '인스타',
#  '이메일',
#  '카카오',
#  '톡',
#  '소규모',
#  '창업',
#  '외식',
#  '업',
#  '창업',
#  '커피',
#  '카페',
#  '디저트',
#  '베이커리',
#  '치킨',
#  '샌드위치',
#  '브런치',
#  '햅썹',
#  '인증',
#  '식품',
#  '제조',
#  '허가',
#  '메뉴',
#  '개발',
#  '신규',
#  '브랜드',
#  '사업',
#  '타당성',
#  '메뉴',
#  '엔지니어링',
#  '메뉴',
#  '원가',
#  '손익',
#  '물레',
#  '션',
#  '샐러드',
#  '밀',
#  '키트',
#  '상권',
#  '조사',
#  '개발',
#  '개인',
#  '매장',
#  '아이템',
#  '개발',
#  '교육',
#  '운영',
#  ...]

# %%
from collections import Counter
count = Counter(nouns_txt)
count
rank_text = count.most_common()
rank_text
# Out:
# [('치킨', 5480),
#  ('맛집', 2246),
#  ('그램', 1942),
#  ('스타', 1682),
#  ('추천', 601),
#  ('메뉴', 593),
#  ('닭', 577),
#  ('맞팔', 514),
#  ('맥주', 513),
#  ('맛', 505),
#  ('먹방', 448),
#  ('일상', 418),
#  ('배달', 410),
#  ('야식', 388),
#  ('맛스타', 356),
#  ('이벤트', 354),
#  ('치맥', 350),
#  ('통닭', 332),
#  ('오늘', 320),
#  ('술', 317),
#  ('신년', 290),
#  ('음식', 289),
#  ('수', 288),
#  ('살', 268),
#  ('저녁', 265),
#  ('집', 263),
#  ('떡볶이', 248),
#  ('후라이드', 246),
#  ('쌈닭', 221),
#  ('소통', 219),
#  ('누구', 218),
#  ('선팔', 217),
#  ('일', 216),
#  ('소스', 214),
#  ('홀딱', 208),
#  ('팔로우', 206),
#  ('주말', 205),
#  ('회', 204),
#  ('마리', 196),
#  ('월', 194),
#  ('안주', 190),
#  ('더', 188),
#  ('튀김', 187),
#  ('모임', 186),
#  ('요리', 181),
#  ('부산', 180),
#  ('파티', 174),
#  ('구이', 171),
#  ('시간', 165),
#  ('후', 164),
#  ('양념', 158),
#  ('피자', 158),
#  ('점', 157),
#  ('사랑', 156),
#  ('치', 151),
#  ('오븐', 150),
#  ('불금', 150),
#  ('서울', 148),
#  ('팔', 139),
#  ('날', 138),
#  ('환영', 138),
#  ('데이트', 135),
#  ('소주', 134),
#  ('밥', 131),
#  ('반', 129),
#  ('양념치킨', 128),
#  ('데', 126),
#  ('주문', 126),
#  ('존맛', 125),
#  ('당첨', 125),
#  ('개발', 125),
#  ('때', 123),
#  ('카페', 122),
#  ('다이어트', 122),
#  ('년', 121),
#  ('친구', 121),
#  ('숯불', 120),
#  ('진짜', 120),
#  ('명', 120),
#  ('나', 120),
#  ('간장', 117),
#  ('푸드', 114),
#  ('일리', 112),
#  ('반사', 112),
#  ('술집', 112),
#  ('시', 110),
#  ('집밥', 110),
#  ('원', 109),
#  ('바베큐', 108),
#  ('치즈', 108),
#  ('회식', 108),
#  ('할인', 106),
#  ('및', 106),
#  ('곳', 104),
#  ('매콤', 104),
#  ('또', 102),
#  ('참여', 101),
#  ('바삭', 100),
#  ('광고', 100),
#  ('댓글', 98),
#  ('새해', 98),
#  ('것', 97),
#  ('떡', 96),
#  ('여행', 96),
#  ('내', 95),
#  ('비', 94),
#  ('등', 93),
#  ('인생', 92),
#  ('운동', 92),
#  ('대구', 91),
#  ('매장', 91),
#  ('분', 89),
#  ('만', 89),
#  ('샐러드', 87),
#  ('문의', 87),
#  ('뭐', 87),
#  ('점심', 86),
#  ('장소', 86),
#  ('사진', 85),
#  ('핫', 85),
#  ('저', 84),
#  ('역시', 84),
#  ('교촌치킨', 84),
#  ('버거', 83),
#  ('이', 82),
#  ('하루', 82),
#  ('볼', 81),
#  ('한식', 81),
#  ('가지', 80),
#  ('예약', 78),
#  ('창업', 78),
#  ('뿌', 78),
#  ('생맥주', 78),
#  ('선물', 77),
#  ('콤보', 77),
#  ('느님', 76),
#  ('우리', 76),
#  ('야채', 76),
#  ('오픈', 76),
#  ('사이드', 76),
#  ('광주', 76),
#  ('조합', 75),
#  ('포장', 75),
#  ('엄마', 75),
#  ('생일', 75),
#  ('간식', 74),
#  ('브랜드', 73),
#  ('삼겹살', 73),
#  ('고추', 72),
#  ('하나', 72),
#  ('교촌', 72),
#  ('한잔', 72),
#  ('마늘', 71),
#  ('세트', 70),
#  ('파스타', 70),
#  ('민족', 70),
#  ('감자', 70),
#  ('금요일', 70),
#  ('먹기', 69),
#  ('준비', 68),
#  ('바로', 68),
#  ('중', 68),
#  ('닭강정', 68),
#  ('아이', 67),
#  ('인스타', 67),
#  ('사람', 66),
#  ('뷔페', 66),
#  ('로', 64),
#  ('전', 64),
#  ('블랙', 64),
#  ('티', 63),
#  ('한번', 63),
#  ('알', 63),
#  ('최고', 63),
#  ('닭다리', 62),
#  ('레드', 62),
#  ('생각', 62),
#  ('꼭', 62),
#  ('링클', 62),
#  ('전문점', 62),
#  ('인스타그램', 61),
#  ('금', 61),
#  ('추가', 60),
#  ('한국', 60),
#  ('거', 60),
#  ('완전', 60),
#  ('데이', 60),
#  ('위', 60),
#  ('가족', 60),
#  ('맘', 59),
#  ('길', 59),
#  ('럽', 58),
#  ('그', 57),
#  ('국물', 57),
#  ('방법', 57),
#  ('기간', 57),
#  ('발표', 57),
#  ('퇴근', 57),
#  ('줄', 56),
#  ('후기', 56),
#  ('링크', 55),
#  ('말', 55),
#  ('배', 55),
#  ('곱창', 55),
#  ('방문', 55),
#  ('투어', 55),
#  ('소맥', 55),
#  ('가격', 54),
#  ('킹', 54),
#  ('정말', 54),
#  ('여기', 53),
#  ('공유', 53),
#  ('경품', 53),
#  ('도', 53),
#  ('처음', 52),
#  ('제주', 52),
#  ('크림', 52),
#  ('쌈', 52),
#  ('포차', 52),
#  ('라면', 51),
#  ('여러분', 51),
#  ('안', 51),
#  ('리뷰', 51),
#  ('커피', 51),
#  ('새우', 50),
#  ('술안주', 50),
#  ('기록', 50),
#  ('어제', 50),
#  ('옛날', 50),
#  ('탕', 50),
#  ('향', 49),
#  ('사업', 49),
#  ('제품', 49),
#  ('부림', 49),
#  ('번', 49),
#  ('시작', 49),
#  ('느낌', 49),
#  ('일루', 49),
#  ('해', 48),
#  ('좀', 48),
#  ('게시', 48),
#  ('인', 48),
#  ('전화', 48),
#  ('와인', 48),
#  ('요즘', 47),
#  ('입', 47),
#  ('우동', 46),
#  ('치즈볼', 46),
#  ('만원', 46),
#  ('각종', 46),
#  ('브런치', 46),
#  ('단', 46),
#  ('설날', 46),
#  ('차', 46),
#  ('개', 46),
#  ('요', 46),
#  ('마', 46),
#  ('분위기', 46),
#  ('운', 46),
#  ('로제', 45),
#  ('고기', 45),
#  ('터치', 45),
#  ('외식', 45),
#  ('마음', 45),
#  ('아침', 45),
#  ('식사', 45),
#  ('함', 44),
#  ('진행', 44),
#  ('복', 44),
#  ('정답', 44),
#  ('허니', 44),
#  ('토요일', 44),
#  ('상품', 44),
#  ('보험', 44),
#  ('이제', 43),
#  ('양', 43),
#  ('아들', 43),
#  ('필수', 43),
#  ('지금', 43),
#  ('호', 43),
#  ('스', 43),
#  ('프로필', 42),
#  ('왜', 42),
#  ('앞', 42),
#  ('물', 42),
#  ('신규', 42),
#  ('식단', 42),
#  ('인친', 42),
#  ('사용', 42),
#  ('쿠폰', 42),
#  ('청주', 41),
#  ('이번', 41),
#  ('계', 41),
#  ('개인', 41),
#  ('를', 41),
#  ('돈', 41),
#  ('맘스', 40),
#  ('월요일', 40),
#  ('산', 40),
#  ('김밥', 40),
#  ('황금', 40),
#  ('콜라', 40),
#  ('진리', 40),
#  ('연말', 40),
#  ('처', 40),
#  ('일요일', 40),
#  ('성신여대', 40),
#  ('무료', 39),
#  ('그냥', 39),
#  ('확률', 39),
#  ('확인', 39),
#  ('모두', 39),
#  ('끝', 39),
#  ('케이크', 39),
#  ('호식', 39),
#  ('또띠아', 39),
#  ('바베큐치킨', 38),
#  ('행복', 38),
#  ('글', 38),
#  ('제', 38),
#  ('계정', 38),
#  ('밤', 38),
#  ('무한리필', 38),
#  ('가능', 38),
#  ('레쉬', 38),
#  ('탐방', 38),
#  ('비비큐', 38),
#  ('이웃', 38),
#  ('통해', 37),
#  ('일기', 37),
#  ('셀카', 37),
#  ('올리브', 37),
#  ('기름', 37),
#  ('조금', 37),
#  ('위해', 37),
#  ('아빠', 37),
#  ('닭발', 37),
#  ('가성', 36),
#  ('아주', 36),
#  ('태그', 36),
#  ('덕천', 36),
#  ('마무리', 36),
#  ('보고', 36),
#  ('동두천', 36),
#  ('의정부', 36),
#  ('볶음', 36),
#  ('치밥', 35),
#  ('코바', 35),
#  ('매일', 35),
#  ('요기', 35),
#  ('램', 35),
#  ('무', 35),
#  ('가슴', 35),
#  ('살이', 35),
#  ('감', 35),
#  ('다시', 35),
#  ('화히타', 35),
#  ('도로', 35),
#  ('은', 34),
#  ('치땡', 34),
#  ('홈쿡', 34),
#  ('처갓집', 34),
#  ('교육', 34),
#  ('조리', 34),
#  ('애', 34),
#  ('골뱅이', 34),
#  ('서비스', 33),
#  ('디저트', 33),
#  ('운영', 33),
#  ('건강', 33),
#  ('사장', 33),
#  ('윙', 33),
#  ('갈비', 33),
#  ('반찬', 33),
#  ('가루', 33),
#  ('단체', 33),
#  ('캠핑', 33),
#  ('끼', 33),
#  ('다음', 33),
#  ('횟집', 33),
#  ('고', 33),
#  ('시크릿', 33),
#  ('노랑', 32),
#  ('신상', 32),
#  ('굽네치킨', 32),
#  ('톡', 32),
#  ('판매', 32),
#  ('걸', 32),
#  ('에어', 32),
#  ('카레', 32),
#  ('강남', 32),
#  ('계묘년', 32),
#  ('모든', 32),
#  ('항상', 31),
#  ('햄버거', 31),
#  ('리그', 31),
#  ('업', 31),
#  ('팔해', 31),
#  ('주', 31),
#  ('바', 31),
#  ('타임', 31),
#  ('다리', 31),
#  ('축하', 31),
#  ('혼술', 31),
#  ('불', 31),
#  ('식당', 31),
#  ('배민', 31),
#  ('협찬', 30),
#  ('가장', 30),
#  ('절대', 30),
#  ('화', 30),
#  ('남자', 30),
#  ('허가', 30),
#  ('선택', 30),
#  ('부천', 30),
#  ('너', 30),
#  ('타워', 30),
#  ('프랜차이즈', 30),
#  ('얼', 30),
#  ('하이', 30),
#  ('종류', 30),
#  ('구리', 30),
#  ('기본', 30),
#  ('수원', 30),
#  ('스테이크', 30),
#  ('목포', 30),
#  ('가득', 29),
#  ('힐링', 29),
#  ('기분', 29),
#  ('고민', 29),
#  ('홈', 29),
#  ('부부', 29),
#  ('샌드위치', 29),
#  ('달달', 29),
#  ('정보', 29),
#  ('구매', 29),
#  ('테이블', 29),
#  ('알바', 29),
#  ('인기', 29),
#  ('문화', 29),
#  ('포항', 29),
#  ('문정동', 29),
#  ('저희', 28),
#  ('남', 28),
#  ('회사', 28),
#  ('가게', 28),
#  ('울산', 28),
#  ('위치', 28),
#  ('어묵', 28),
#  ('포천', 28),
#  ('충주', 28),
#  ('김', 27),
#  ('뉴', 27),
#  ('꿀', 27),
#  ('감사', 27),
#  ('완료', 27),
#  ('마지막', 27),
#  ('재료', 27),
#  ('제일', 27),
#  ('토끼', 27),
#  ('소망', 27),
#  ('과', 27),
#  ('계속', 27),
#  ('숯', 27),
#  ('겨울', 27),
#  ('빵', 27),
#  ('영업', 27),
#  ('문정역', 27),
#  ('천원', 27),
#  ('렐라', 27),
#  ('식감', 26),
#  ('생', 26),
#  ('스타일', 26),
#  ('옷', 26),
#  ('아이템', 26),
#  ('추억', 26),
#  ('동안', 26),
#  ('여자', 26),
#  ('속', 26),
#  ('프라이어', 26),
#  ('거리', 26),
#  ('김치', 26),
#  ('층', 26),
#  ('달', 26),
#  ('수제', 26),
#  ('먹음', 26),
#  ('육아', 26),
#  ('만리', 26),
#  ('팩', 26),
#  ('사리', 25),
#  ('눈', 25),
#  ('성공', 25),
#  ('인테리어', 25),
#  ('식품', 25),
#  ('의', 25),
#  ('오후', 25),
#  ('가라아게', 25),
#  ('직장인', 25),
#  ('동생', 25),
#  ('소개', 25),
#  ('근처', 25),
#  ('플레이', 25),
#  ('청대', 25),
#  ('먹거리', 25),
#  ('소금', 24),
#  ('스트레스', 24),
#  ('분식', 24),
#  ('굽', 24),
#  ('분석', 24),
#  ('가맹', 24),
#  ('인증', 24),
#  ('자주', 24),
#  ('경기', 24),
#  ('내일', 24),
#  ('몸', 24),
#  ('방', 24),
#  ('혼자', 24),
#  ('볶음밥', 24),
#  ('때문', 24),
#  ('전기', 24),
#  ('냠', 24),
#  ('족발', 24),
#  ('맛팔', 24),
#  ('어디', 24),
#  ('혼밥', 24),
#  ('새벽', 24),
#  ('못', 24),
#  ('통', 24),
#  ('기프티콘', 24),
#  ('테라', 24),
#  ('보장', 24),
#  ('계획', 24),
#  ('로우', 24),
#  ('지갑', 24),
#  ('오사카', 24),
#  ('남해', 24),
#  ('살짝', 23),
#  ('세상', 23),
#  ('최애', 23),
#  ('초밥', 23),
#  ('기획', 23),
#  ('닭고기', 23),
#  ('날씨', 23),
#  ('테러', 23),
#  ('퀴즈', 23),
#  ('맥', 23),
#  ('오운완', 23),
#  ('칠곡', 23),
#  ('덕분', 23),
#  ('파닭', 23),
#  ('깻잎', 23),
#  ('드', 23),
#  ('골드', 23),
#  ('다른', 23),
#  ('이상', 23),
#  ('모집', 23),
#  ('피치', 23),
#  ('종로', 23),
#  ('몬스터', 23),
#  ('돌담', 23),
#  ('라멘', 23),
#  ('빈티', 23),
#  ('표', 22),
#  ('임', 22),
#  ('매니아', 22),
#  ('후회', 22),
#  ('남편', 22),
#  ('추첨', 22),
#  ('밥상', 22),
#  ('소규모', 22),
#  ('기념', 22),
#  ('주머니', 22),
#  ('휴무', 22),
#  ('사실', 22),
#  ('대표', 22),
#  ('동네', 22),
#  ('난', 22),
#  ('화명동', 22),
#  ('만덕', 22),
#  ('손', 22),
#  ('정도', 22),
#  ('본점', 22),
#  ('중독', 22),
#  ('언제', 22),
#  ('바이브', 22),
#  ('보쌈', 22),
#  ('이름', 21),
#  ('팔로워', 21),
#  ('맵', 21),
#  ('딸기', 21),
#  ('상권', 21),
#  ('칼로리', 21),
#  ('피', 21),
#  ('꿀맛', 21),
#  ('오빠', 21),
#  ('해물', 21),
#  ('쉬', 21),
#  ('슈프림', 21),
#  ('돈까스', 21),
#  ('콘', 21),
#  ('오뎅', 21),
#  ('가요', 21),
#  ('직접', 21),
#  ('거기', 21),
#  ('진해', 21),
#  ('감성', 21),
#  ('채소', 21),
#  ('봉', 21),
#  ('지인', 21),
#  ('리', 21),
#  ('휴일', 21),
#  ('그림', 21),
#  ('원주', 21),
#  ('대신', 20),
#  ('올해', 20),
#  ('종', 20),
#  ('당신', 20),
#  ('론칭', 20),
#  ('타당성', 20),
#  ('매뉴얼', 20),
#  ('사후관리', 20),
#  ('제조', 20),
#  ('카카오', 20),
#  ('냉동', 20),
#  ('뼈', 20),
#  ('레시피', 20),
#  ('킨', 20),
#  ('겉바', 20),
#  ('촉', 20),
#  ('파', 20),
#  ('참고', 20),
#  ('딸', 20),
#  ('정', 20),
#  ('구', 20),
#  ('짬뽕', 20),
#  ('이용', 20),
#  ('공간', 20),
#  ('퓨전', 20),
#  ('리지', 20),
#  ('쌈무', 20),
#  ('관리', 20),
#  ('쌈닭종', 20),
#  ('도시락', 20),
#  ('계란', 20),
#  ('상담', 20),
#  ('건어물', 20),
#  ('무조건', 19),
#  ('꽤', 19),
#  ('값', 19),
#  ('제대로', 19),
#  ('팔로', 19),
#  ('스파게티', 19),
#  ('행운', 19),
#  ('메이드', 19),
#  ('별로', 19),
#  ('더욱', 19),
#  ('홍대', 19),
#  ('설', 19),
#  ('안내', 19),
#  ('앱', 19),
#  ('고객', 19),
#  ('콤', 19),
#  ('손님', 19),
#  ('클릭', 19),
#  ('닭갈비', 19),
#  ('트', 19),
#  ('숙취', 19),
#  ('수익', 19),
#  ('징', 19),
#  ('송파', 19),
#  ('굴', 19),
#  ('카나', 19),
#  ('작성', 19),
#  ('양주', 19),
#  ('상', 19),
#  ('자체', 19),
#  ('방어', 19),
#  ('닭꼬치', 19),
#  ('만두', 19),
#  ('여의도', 19),
#  ('주부', 19),
#  ('꼬치', 19),
#  ('예정', 19),
#  ('목', 19),
#  ('출사', 19),
#  ('폰', 19),
#  ('생활', 19),
#  ('껍질', 19),
#  ('자취', 19),
#  ('전부', 18),
#  ('덕', 18),
#  ('돼지', 18),
#  ('감기', 18),
#  ('수요일', 18),
#  ('인천', 18),
#  ('호텔', 18),
#  ('체험', 18),
#  ('도리', 18),
#  ('롯데', 18),
#  ('생맥', 18),
#  ('해당', 18),
#  ('약속', 18),
#  ('유머', 18),
#  ('프랑', 18),
#  ('배송', 18),
#  ('토핑', 18),
#  ('미국', 18),
#  ('복희', 18),
#  ('출장', 18),
#  ('천안', 18),
#  ('페리', 18),
#  ('날치', 18),
#  ('재', 18),
#  ('영화', 18),
#  ('맛봉', 18),
#  ('남양주', 18),
#  ('빈', 18),
#  ('양산', 18),
#  ('스프', 18),
#  ('고양이', 18),
#  ('익선동', 18),
#  ('수프', 18),
#  ('취향', 17),
#  ('마켓', 17),
#  ('땐', 17),
#  ('대전', 17),
#  ('피드', 17),
#  ('스토리', 17),
#  ('컨셉', 17),
#  ('밀', 17),
#  ('늘', 17),
#  ('무엇', 17),
#  ('후추', 17),
#  ('쇼핑', 17),
#  ('과일', 17),
#  ('모', 17),
#  ('클럽', 17),
#  ('헬스', 17),
#  ('대박', 17),
#  ('싸이', 17),
#  ('맞이', 17),
#  ('서면', 17),
#  ('한해', 17),
#  ('꿈', 17),
#  ('팬', 17),
#  ('구미', 17),
#  ('반한', 17),
#  ('청년', 17),
#  ('상큼', 17),
#  ('토', 17),
#  ('기', 17),
#  ('듯', 17),
#  ('발송', 17),
#  ('캔', 17),
#  ('첫', 17),
#  ('상품권', 17),
#  ('람빅', 17),
#  ('자연', 16),
#  ('음식사진', 16),
#  ('키트', 16),
#  ('얼마', 16),
#  ('화이팅', 16),
#  ('토마토', 16),
#  ('겉', 16),
#  ('누룽지', 16),
#  ('봄', 16),
#  ('냄새', 16),
#  ('시장', 16),
#  ('소고기', 16),
#  ('불고기', 16),
#  ('용', 16),
#  ('보시', 16),
#  ('초', 16),
#  ('겸', 16),
#  ('머', 16),
#  ('양식', 16),
#  ('찜', 16),
#  ('해바라기', 16),
#  ('셀', 16),
#  ('일본', 16),
#  ('현대', 16),
#  ('닭도리탕', 16),
#  ('채널', 16),
#  ('설치', 16),
#  ('홍보', 16),
#  ('당일', 16),
#  ('블로그', 16),
#  ('노래방', 16),
#  ('또래', 16),
#  ('골목', 16),
#  ('유튜브', 16),
#  ('안심', 16),
#  ('마블', 15),
#  ('구성', 15),
#  ('매우', 15),
#  ('온', 15),
#  ('뿌링클', 15),
#  ('건', 15),
#  ('수영', 15),
#  ('쿡스', 15),
#  ('혜자', 15),
#  ('고구마', 15),
#  ('찌', 15),
#  ('미리', 15),
#  ('응원', 15),
#  ('연락', 15),
#  ('보', 15),
#  ('육회', 15),
#  ('연어', 15),
#  ('관심', 15),
#  ('병원', 15),
#  ('비밀', 15),
#  ('부', 15),
#  ('신청', 15),
#  ('널', 15),
#  ('콘서트', 15),
#  ('팅', 15),
#  ('오', 15),
#  ('중앙', 15),
#  ('원래', 15),
#  ('쥬', 15),
#  ('자메이카', 15),
#  ('위생', 15),
#  ('공릉', 15),
#  ('매몰', 15),
#  ('소환', 15),
#  ('부모님', 15),
#  ('날개', 15),
#  ('호점', 15),
#  ('저녁식사', 15),
#  ('광역시', 15),
#  ('꼬', 14),
#  ('엽떡', 14),
#  ('살로', 14),
#  ('갑자기', 14),
#  ('총', 14),
#  ('참숯', 14),
#  ('약간', 14),
#  ('부적', 14),
#  ('신혼', 14),
#  ('전분', 14),
#  ('본사', 14),
#  ('컵', 14),
#  ('리뉴얼', 14),
#  ('투', 14),
#  ('마트', 14),
#  ('입맛', 14),
#  ('영등포', 14),
#  ('저녁밥', 14),
#  ('밥스', 14),
#  ('뭔가', 14),
#  ('해운대', 14),
#  ('세', 14),
#  ('크리스', 14),
#  ('강서구', 14),
#  ('레몬', 14),
#  ('북구', 14),
#  ('공원', 14),
#  ('플러스', 14),
#  ('정성', 14),
#  ('강아지', 14),
#  ('커리', 14),
#  ('메이', 14),
#  ('강추', 14),
#  ('레스토랑', 14),
#  ('일찍', 14),
#  ('유', 14),
#  ('하우스', 14),
#  ('나주', 14),
#  ('언니', 14),
#  ('채', 14),
#  ('닭봉', 14),
#  ('둘', 14),
#  ('젤', 14),
#  ('출근', 14),
#  ('땅땅치킨', 14),
#  ('행사', 14),
#  ('자극', 14),
#  ('메이커', 14),
#  ('완성', 14),
#  ('개별', 14),
#  ('생생', 14),
#  ('부담', 14),
#  ('가입', 14),
#  ('고대', 14),
#  ('불스', 14),
#  ('호프', 14),
#  ('명절', 14),
#  ('관', 14),
#  ('진심', 14),
#  ('상무동', 14),
#  ('정읍', 14),
#  ('법', 13),
#  ('얼마나', 13),
#  ('셀피', 13),
#  ('먼저', 13),
#  ('훌', 13),
#  ('응모', 13),
#  ('방학', 13),
#  ('치팅', 13),
#  ('신혼부부', 13),
#  ('베이커리', 13),
#  ('맛초킹', 13),
#  ('기대', 13),
#  ('주소', 13),
#  ('양천구', 13),
#  ('해주시', 13),
#  ('한강', 13),
#  ('게', 13),
#  ('투자', 13),
#  ('하단', 13),
#  ('그릇', 13),
#  ('양파', 13),
#  ('소세지', 13),
#  ('재미', 13),
#  ('오리', 13),
#  ('갈릭', 13),
#  ('차로', 13),
#  ('간', 13),
#  ('담', 13),
#  ('마카', 13),
#  ('불당', 13),
#  ('로제쫄볶', 13),
#  ('설탕', 13),
#  ('자리', 13),
#  ('강동구', 13),
#  ('킹폭립', 13),
#  ('폭립', 13),
#  ('옆', 13),
#  ('여성', 13),
#  ('리조또', 13),
#  ('쌀국수', 13),
#  ('서현', 13),
#  ('이마트', 13),
#  ('안암', 13),
#  ('홈파티', 13),
#  ('간만', 13),
#  ('신세계', 13),
#  ('마이크', 13),
#  ('퀸', 13),
#  ('회하', 13),
#  ('선생님', 13),
#  ('책', 13),
#  ('용가리', 13),
#  ('면', 12),
#  ('단지', 12),
#  ('안산', 12),
#  ('제공', 12),
#  ('디자인', 12),
#  ('원가', 12),
#  ('일주일', 12),
#  ('뒤', 12),
#  ('기부', 12),
#  ('금액', 12),
#  ('국내', 12),
#  ('듬뿍', 12),
#  ('이미지', 12),
#  ('직원', 12),
#  ('양념통닭', 12),
#  ('조각', 12),
#  ('베', 12),
#  ('쫄깃', 12),
#  ('주방', 12),
#  ('신월동', 12),
#  ('소면', 12),
#  ('몰래', 12),
#  ('기사', 12),
#  ('평일', 12),
#  ('꼬꼬', 12),
#  ('냥', 12),
#  ('막걸리', 12),
#  ('옥', 12),
#  ('앤', 12),
#  ('태안', 12),
#  ('펜션', 12),
#  ('무제한', 12),
#  ('국', 12),
#  ('탑', 12),
#  ('일단', 12),
#  ('닝', 12),
#  ('바기오', 12),
#  ('타코마', 12),
#  ('쫄면', 12),
#  ('짐', 12),
#  ('벌써', 12),
#  ('순대', 12),
#  ('선생', 12),
#  ('포', 12),
#  ('남포동', 12),
#  ('찜닭', 12),
#  ('타고', 12),
#  ('혜택', 12),
#  ('부업', 12),
#  ('참이슬', 12),
#  ('스크린', 12),
#  ('스노', 12),
#  ('불토', 12),
#  ('스타벅스', 12),
#  ('발라', 12),
#  ('도매', 12),
#  ...]

# %%
rank_text
# Out:
# [('맞팔', 3924),
#  ('피자', 3088),
#  ('그램', 2114),
#  ('소통', 1772),
#  ('맛집', 1691),
#  ('일상', 1432),
#  ('선팔', 1098),
#  ('스타', 1075),
#  ('먹방', 636),
#  ('음식', 601),
#  ('환영', 523),
#  ('파스타', 458),
#  ('추천', 409),
#  ('댓글', 399),
#  ('반사', 393),
#  ('맛', 386),
#  ('인스타', 372),
#  ('줄', 362),
#  ('댓', 350),
#  ('오늘', 348),
#  ('데', 329),
#  ('일리', 328),
#  ('가족', 323),
#  ('광주', 309),
#  ('밥상', 303),
#  ('여행', 295),
#  ('우리', 274),
#  ('국수', 274),
#  ('반', 265),
#  ('일상생활', 260),
#  ('배달', 241),
#  ('가을', 238),
#  ('행복', 236),
#  ('주문', 234),
#  ('순간', 233),
#  ('스테이크', 231),
#  ('수유', 227),
#  ('치즈', 224),
#  ('네일', 215),
#  ('집', 213),
#  ('점', 190),
#  ('아이', 189),
#  ('스파게티', 171),
#  ('빵', 170),
#  ('입', 169),
#  ('것', 168),
#  ('존맛', 168),
#  ('피가로', 168),
#  ('시작', 167),
#  ('차', 167),
#  ('시', 166),
#  ('졸업', 165),
#  ('어린이집', 164),
#  ('일기', 163),
#  ('샐러드', 162),
#  ('사람', 156),
#  ('곳', 151),
#  ('간판', 148),
#  ('추가', 146),
#  ('메뉴', 146),
#  ('옴', 146),
#  ('곱창', 146),
#  ('안', 145),
#  ('프로', 144),
#  ('후', 143),
#  ('함', 142),
#  ('대학로', 142),
#  ('날', 139),
#  ('생각', 138),
#  ('끝', 138),
#  ('생신', 138),
#  ('미용', 138),
#  ('유치원', 136),
#  ('통합', 136),
#  ('팔해', 135),
#  ('먹기', 135),
#  ('꽃', 135),
#  ('월', 135),
#  ('전대', 135),
#  ('요리', 134),
#  ('휴식시간', 134),
#  ('비밀', 134),
#  ('곧', 134),
#  ('눈', 134),
#  ('핫', 133),
#  ('뭐', 132),
#  ('입학', 132),
#  ('열차', 132),
#  ('강릉', 131),
#  ('기록', 131),
#  ('성비', 131),
#  ('시베리아', 131),
#  ('횡단', 131),
#  ('계절', 130),
#  ('한국인', 130),
#  ('나들이', 130),
#  ('익선동', 130),
#  ('감칠맛', 130),
#  ('하동', 129),
#  ('재첩', 129),
#  ('갈라', 129),
#  ('홍대', 128),
#  ('근교', 125),
#  ('골목', 124),
#  ('음색', 124),
#  ('깡패', 124),
#  ('옷', 123),
#  ('추억', 123),
#  ('썸', 123),
#  ('네일아트', 123),
#  ('아기', 122),
#  ('전복', 122),
#  ('부천', 122),
#  ('강원도', 121),
#  ('해', 121),
#  ('고냥이', 121),
#  ('만원', 120),
#  ('대교', 120),
#  ('삼계탕', 120),
#  ('난', 120),
#  ('가요', 120),
#  ('에스컬레이터', 119),
#  ('밴드', 119),
#  ('죠스', 119),
#  ('모', 119),
#  ('두피', 119),
#  ('문신', 119),
#  ('선물', 119),
#  ('잔', 118),
#  ('기', 118),
#  ('야경', 118),
#  ('설빙', 118),
#  ('홀', 118),
#  ('봉', 118),
#  ('팝핑', 117),
#  ('댄스', 117),
#  ('안압지', 117),
#  ('마켓', 116),
#  ('메시지', 116),
#  ('리북집', 116),
#  ('제작', 116),
#  ('브라운', 116),
#  ('돼지', 115),
#  ('여자', 115),
#  ('카페', 115),
#  ('문어', 115),
#  ('서우', 115),
#  ('긍정', 114),
#  ('선', 114),
#  ('퇴사', 113),
#  ('멋', 113),
#  ('글씨', 113),
#  ('낚시', 113),
#  ('주말', 112),
#  ('여름', 112),
#  ('칵테일', 112),
#  ('미니', 112),
#  ('데이트', 112),
#  ('신월동', 111),
#  ('애쉬', 111),
#  ('이태원', 110),
#  ('에어비앤비', 110),
#  ('타투', 110),
#  ('구조도', 110),
#  ('골프공', 110),
#  ('분관', 109),
#  ('과슈', 109),
#  ('서귀포', 109),
#  ('우회', 109),
#  ('디디', 108),
#  ('쥬', 108),
#  ('정신', 108),
#  ('전시', 108),
#  ('기절', 107),
#  ('전용', 107),
#  ('호강', 106),
#  ('녜', 105),
#  ('침', 105),
#  ('로우', 105),
#  ('모임', 104),
#  ('편집', 104),
#  ('캐논', 103),
#  ('단체', 102),
#  ('금오동', 102),
#  ('꽃집', 102),
#  ('캐디', 102),
#  ('일상사진', 102),
#  ('시래기', 102),
#  ('웨딩', 98),
#  ('맛스타', 98),
#  ('등', 98),
#  ('영양', 97),
#  ('공급', 96),
#  ('부케', 96),
#  ('화덕', 96),
#  ('치킨', 92),
#  ('예약', 90),
#  ('레스토랑', 89),
#  ('시간', 83),
#  ('고고', 81),
#  ('교육', 80),
#  ('전남대', 78),
#  ('저녁', 73),
#  ('맥주', 67),
#  ('육회', 63),
#  ('민족', 62),
#  ('타임', 60),
#  ('가능', 60),
#  ('성북동', 60),
#  ('페퍼로니', 59),
#  ('도우', 59),
#  ('갈비', 56),
#  ('요기', 56),
#  ('층', 55),
#  ('무', 54),
#  ('수', 52),
#  ('리조또', 52),
#  ('더', 50),
#  ('마지막', 49),
#  ('고구마', 49),
#  ('그', 48),
#  ('필라프', 48),
#  ('브레이크', 48),
#  ('소스', 47),
#  ('무료', 47),
#  ('텍사스', 46),
#  ('주차장', 46),
#  ('점심', 45),
#  ('후문', 45),
#  ('피자헛', 44),
#  ('사진', 44),
#  ('연중', 43),
#  ('와인', 43),
#  ('크림', 43),
#  ('만', 42),
#  ('이탈리안', 42),
#  ('각종', 42),
#  ('비빔밥', 42),
#  ('유기농', 41),
#  ('진짜', 40),
#  ('나', 40),
#  ('서울', 39),
#  ('베이컨', 39),
#  ('광역시', 39),
#  ('북구', 39),
#  ('용봉동', 39),
#  ('호산', 39),
#  ('동명', 39),
#  ('피맥', 38),
#  ('분위기', 38),
#  ('갈릭', 38),
#  ('술', 38),
#  ('토핑', 37),
#  ('야식', 37),
#  ('푸드', 37),
#  ('포테이토', 37),
#  ('샌드위치', 37),
#  ('또', 36),
#  ('팔', 36),
#  ('비', 36),
#  ('더블', 36),
#  ('모짜렐라', 36),
#  ('대전', 35),
#  ('미사', 35),
#  ('운동', 34),
#  ('러스트', 34),
#  ('듬뿍', 33),
#  ('때', 33),
#  ('부산', 33),
#  ('간식', 33),
#  ('대구', 33),
#  ('제주', 32),
#  ('감자', 32),
#  ('친구', 32),
#  ('일', 31),
#  ('위', 30),
#  ('일요일', 30),
#  ('양식', 30),
#  ('누브', 30),
#  ('티스', 30),
#  ('넥타이', 30),
#  ('박물관', 30),
#  ('내', 29),
#  ('다이어트', 29),
#  ('토마토', 29),
#  ('불고기', 29),
#  ('안주', 28),
#  ('길', 28),
#  ('인', 28),
#  ('슈프림', 28),
#  ('사랑', 27),
#  ('포장', 27),
#  ('엣지', 27),
#  ('매장', 26),
#  ('토요일', 26),
#  ('튀김', 26),
#  ('브런치', 26),
#  ('방문', 25),
#  ('거', 24),
#  ('오픈', 24),
#  ('수퍼', 24),
#  ('여기', 23),
#  ('사장', 23),
#  ('힙', 23),
#  ('마루', 23),
#  ('다시', 23),
#  ('감', 23),
#  ('잠실', 23),
#  ('새해', 23),
#  ('연남동', 23),
#  ('맘', 23),
#  ('술집', 22),
#  ('한번', 22),
#  ('가지', 22),
#  ('커피', 22),
#  ('분', 22),
#  ('새우', 21),
#  ('저', 21),
#  ('그냥', 21),
#  ('영업', 21),
#  ('식당', 21),
#  ('리', 21),
#  ('집밥', 21),
#  ('떡볶이', 21),
#  ('아들', 21),
#  ('엄마', 21),
#  ('볼', 21),
#  ('외식', 21),
#  ('랩', 21),
#  ('밥', 21),
#  ('도미노피자', 21),
#  ('정도', 20),
#  ('명동', 20),
#  ('말', 20),
#  ('소주', 20),
#  ('도', 20),
#  ('하루', 20),
#  ('배', 20),
#  ('소고기', 20),
#  ('피', 20),
#  ('번', 19),
#  ('리뷰', 19),
#  ('중', 19),
#  ('밤', 19),
#  ('생일', 19),
#  ('고르곤졸라', 19),
#  ('살', 19),
#  ('한잔', 19),
#  ('하프', 19),
#  ('수제', 19),
#  ('나폴리', 19),
#  ('김해', 19),
#  ('파티', 18),
#  ('디트로이트', 18),
#  ('제주도', 18),
#  ('식단', 18),
#  ('로', 18),
#  ('꿀', 18),
#  ('인생', 18),
#  ('완전', 18),
#  ('정말', 18),
#  ('투어', 18),
#  ('특', 18),
#  ('팔로우', 18),
#  ('만들기', 18),
#  ('알', 18),
#  ('팔공산', 18),
#  ('쉬', 17),
#  ('이', 17),
#  ('항상', 17),
#  ('트', 17),
#  ('할인', 17),
#  ('다음', 17),
#  ('오븐', 17),
#  ('건강', 17),
#  ('페스', 17),
#  ('원', 17),
#  ('캠핑', 17),
#  ('애', 17),
#  ('어제', 17),
#  ('림프', 16),
#  ('가게', 16),
#  ('조합', 16),
#  ('식사', 16),
#  ('재료', 16),
#  ('역시', 16),
#  ('년', 16),
#  ('앤', 16),
#  ('루꼴', 16),
#  ('포', 16),
#  ('바질', 16),
#  ('잼', 16),
#  ('날씨', 16),
#  ('전주', 16),
#  ('조선', 16),
#  ('최고', 15),
#  ('압구정', 15),
#  ('셀카', 15),
#  ('인친', 15),
#  ('부림', 15),
#  ('남양주', 15),
#  ('딸기', 15),
#  ('보고', 15),
#  ('내일', 15),
#  ('마르', 15),
#  ('가장', 15),
#  ('데이', 15),
#  ('무조건', 14),
#  ('월드', 14),
#  ('문의', 14),
#  ('겨울', 14),
#  ('향', 14),
#  ('육아', 14),
#  ('울산', 14),
#  ('살짝', 14),
#  ('세트', 14),
#  ('남매', 14),
#  ('와플', 14),
#  ('역', 14),
#  ('마산', 14),
#  ('직접', 13),
#  ('홈쿡', 13),
#  ('덕', 13),
#  ('마을', 13),
#  ('둘', 13),
#  ('전', 13),
#  ('이번', 13),
#  ('장소', 13),
#  ('페페로니', 13),
#  ('고기', 13),
#  ('디저트', 13),
#  ('매콤', 13),
#  ('산', 13),
#  ('준비', 13),
#  ('피자스쿨', 13),
#  ('바', 13),
#  ('하우스', 13),
#  ('코지', 13),
#  ('하남', 13),
#  ('끼', 13),
#  ('원주', 13),
#  ('개인', 12),
#  ('단', 12),
#  ('가성', 12),
#  ('하나', 12),
#  ('스', 12),
#  ('덕후', 12),
#  ('꼭', 12),
#  ('코스', 12),
#  ('홈', 12),
#  ('혼자', 12),
#  ('요즘', 12),
#  ('조금', 12),
#  ('제', 12),
#  ('이벤트', 12),
#  ('서면', 12),
#  ('못', 12),
#  ('닭', 12),
#  ('다른', 12),
#  ('키즈', 12),
#  ('촬영', 12),
#  ('몸', 12),
#  ('감사', 12),
#  ('왜', 12),
#  ('애견', 12),
#  ('라자냐', 12),
#  ('탕', 12),
#  ('느낌', 12),
#  ('누룽지', 12),
#  ('도시락', 12),
#  ('토마토소스', 12),
#  ('바로', 11),
#  ('개', 11),
#  ('바삭', 11),
#  ('광안', 11),
#  ('아침', 11),
#  ('판매', 11),
#  ('호', 11),
#  ('오후', 11),
#  ('본점', 11),
#  ('바베큐', 11),
#  ('힐링', 11),
#  ('이재', 11),
#  ('콘치', 11),
#  ('이제', 11),
#  ('모두', 11),
#  ('안산', 11),
#  ('상무지구', 11),
#  ('삼겹살', 11),
#  ('구', 11),
#  ('콜라', 11),
#  ('동생', 11),
#  ('토', 11),
#  ('생', 11),
#  ('트러플', 11),
#  ('가격', 11),
#  ('직원', 11),
#  ('이탈리아', 11),
#  ('한국', 11),
#  ('창원', 11),
#  ('국밥', 11),
#  ('체험', 11),
#  ('레시피', 11),
#  ('건대', 11),
#  ('모든', 10),
#  ('예정', 10),
#  ('사이드', 10),
#  ('이드', 10),
#  ('메뉴판', 10),
#  ('오일', 10),
#  ('과', 10),
#  ('재미', 10),
#  ('제일', 10),
#  ('가득', 10),
#  ('월요일', 10),
#  ('테이블', 10),
#  ('고객', 10),
#  ('남해', 10),
#  ('마음', 10),
#  ('케이크', 10),
#  ('마무리', 10),
#  ('롯데', 10),
#  ('조각', 10),
#  ('허니', 10),
#  ('알볼', 10),
#  ('에어', 10),
#  ('김치', 10),
#  ('동반', 10),
#  ('설', 10),
#  ('알바', 10),
#  ('판', 10),
#  ('미리', 10),
#  ('낮술', 10),
#  ('장인', 10),
#  ('저희', 10),
#  ('명절', 10),
#  ('우만동', 10),
#  ('아주대', 10),
#  ('공구', 10),
#  ('공주', 10),
#  ('다리', 10),
#  ('초밥', 10),
#  ('태권도', 10),
#  ('송탄', 10),
#  ('청주', 10),
#  ('동대문', 9),
#  ('듯', 9),
#  ('너', 9),
#  ('종류', 9),
#  ('휴무', 9),
#  ('감성', 9),
#  ('주시', 9),
#  ('타고', 9),
#  ('탐방', 9),
#  ('웨이', 9),
#  ('콘', 9),
#  ('네이버', 9),
#  ('주변', 9),
#  ('전체', 9),
#  ('처음', 9),
#  ('서비스', 9),
#  ('아빠', 9),
#  ('이용', 9),
#  ('재', 9),
#  ('처', 9),
#  ('업', 9),
#  ('적', 9),
#  ('비건', 9),
#  ('부라타', 9),
#  ('게리', 9),
#  ('입맛', 9),
#  ('계정', 9),
#  ('남편', 9),
#  ('해운대', 9),
#  ('돈', 9),
#  ('볶음밥', 9),
#  ('배민', 9),
#  ('위례', 9),
#  ('펍', 9),
#  ('수원', 9),
#  ('돈까스', 9),
#  ('기분', 9),
#  ('관저동', 9),
#  ('짬뽕', 9),
#  ('성수동', 9),
#  ('세', 9),
#  ('버슬립스', 9),
#  ('딸', 9),
#  ('통닭', 9),
#  ('사용', 9),
#  ('치즈볼', 9),
#  ('스타일', 9),
#  ('전서구', 9),
#  ('계란', 9),
#  ('강변', 9),
#  ('보라매', 9),
#  ('기장', 9),
#  ('놀이터', 9),
#  ('평택', 9),
#  ('걱정', 8),
#  ('매일', 8),
#  ('강', 8),
#  ('필수', 8),
#  ('위치', 8),
#  ('메이드', 8),
#  ('오전', 8),
#  ('달달', 8),
#  ('콤비네이션', 8),
#  ('기억', 8),
#  ('바스', 8),
#  ('패션', 8),
#  ('런치', 8),
#  ('광교', 8),
#  ('레이스', 8),
#  ('미노', 8),
#  ('간만', 8),
#  ('시흥', 8),
#  ('위해', 8),
#  ('가슴', 8),
#  ('붕어빵', 8),
#  ('미트', 8),
#  ('프리미엄', 8),
#  ('얼', 8),
#  ('기본', 8),
#  ('화', 8),
#  ('홈파티', 8),
#  ('축하', 8),
#  ('아주', 8),
#  ('근처', 8),
#  ('선택', 8),
#  ('언제', 8),
#  ('온', 8),
#  ('먹음', 8),
#  ('피클', 8),
#  ('장', 8),
#  ('좀', 8),
#  ('명', 8),
#  ('델리', 8),
#  ('맞이', 8),
#  ('천안', 8),
#  ('골프', 8),
#  ('회', 8),
#  ('띠', 8),
#  ('쌈', 8),
#  ('물', 8),
#  ('퇴근', 8),
#  ('츄리', 8),
#  ('리코', 8),
#  ('가산', 8),
#  ('굿', 8),
#  ('프로필', 8),
#  ('자주', 8),
#  ('인스타그램', 8),
#  ('이유', 8),
#  ('진주', 8),
#  ('바디', 8),
#  ('포레', 8),
#  ('햇님', 8),
#  ('자리', 8),
#  ('슬픔', 8),
#  ('밀크', 8),
#  ('봉화산', 8),
#  ('연말', 7),
#  ('더욱', 7),
#  ('현대', 7),
#  ('아울렛', 7),
#  ('손', 7),
#  ('립', 7),
#  ('로데오', 7),
#  ('정보', 7),
#  ('떡', 7),
#  ('해결', 7),
#  ('팅', 7),
#  ('걸', 7),
#  ('덕분', 7),
#  ('건', 7),
#  ('청년', 7),
#  ('두부', 7),
#  ('셀', 7),
#  ('럽', 7),
#  ('디핑', 7),
#  ('워크샵', 7),
#  ('간', 7),
#  ('거리', 7),
#  ('불꽃', 7),
#  ('둘이서', 7),
#  ('밀가루', 7),
#  ('반올림', 7),
#  ('영화', 7),
#  ('주', 7),
#  ('젠', 7),
#  ('디지털', 7),
#  ('호텔', 7),
#  ('쿠팡', 7),
#  ('스파', 7),
#  ('계속', 7),
#  ('강남', 7),
#  ('스시', 7),
#  ('살이', 7),
#  ('레이더스', 7),
#  ('하이', 7),
#  ('스프', 7),
#  ('르', 7),
#  ('달', 7),
#  ('맛팔', 7),
#  ('버섯', 7),
#  ('에프', 7),
#  ('어디', 7),
#  ('드로잉', 7),
#  ('김밥', 7),
#  ('동안', 7),
#  ('뇨끼', 7),
#  ('셰프', 7),
#  ('슈퍼', 7),
#  ('충전', 7),
#  ('제리', 7),
#  ('벌써', 7),
#  ('목동', 7),
#  ('리뉴얼', 7),
#  ('참고', 7),
#  ('하와', 7),
#  ('신혼', 7),
#  ('폰', 7),
#  ('금요일', 7),
#  ('커플', 7),
#  ('경북', 7),
#  ('커플링', 7),
#  ('양가', 7),
#  ('결혼기념일', 7),
#  ('순금', 7),
#  ('매입', 7),
#  ('일식집', 7),
#  ('중국집', 7),
#  ('양', 7),
#  ('스트레스', 7),
#  ('완성', 7),
#  ('해장', 7),
#  ('덜', 7),
#  ('배곧', 7),
#  ('인테리어', 7),
#  ('햄', 7),
#  ('라면', 7),
#  ('미스', 7),
#  ('그것', 7),
#  ('석촌호수', 7),
#  ('관악구', 7),
#  ('동작구', 7),
#  ('스트리트', 6),
#  ('출구', 6),
#  ('술안주', 6),
#  ('지금', 6),
#  ('미국', 6),
#  ('중구', 6),
#  ('은', 6),
#  ('수비드', 6),
#  ('반죽', 6),
#  ('일반', 6),
#  ('통', 6),
#  ('제주시', 6),
#  ('유머', 6),
#  ('냉동', 6),
#  ('플레이', 6),
#  ('혼밥', 6),
#  ('손님', 6),
#  ('아이스크림', 6),
#  ('뉴욕', 6),
#  ('집들이', 6),
#  ('볶음', 6),
#  ('불토', 6),
#  ('땐', 6),
#  ('부', 6),
#  ('구매', 6),
#  ('낭트', 6),
#  ('언니', 6),
#  ('햄버거', 6),
#  ('부산여행', 6),
#  ('축제', 6),
#  ('필라테스', 6),
#  ('두', 6),
#  ('요', 6),
#  ('노', 6),
#  ('오지', 6),
#  ('광고', 6),
#  ('중앙', 6),
#  ('짐', 6),
#  ('행사', 6),
#  ('그림', 6),
#  ('음식사진', 6),
#  ('연어', 6),
#  ('직장인', 6),
#  ('만남', 6),
#  ('아메리카노', 6),
#  ('체다', 6),
#  ('수다', 6),
#  ('봄', 6),
#  ('막걸리', 6),
#  ('사', 6),
#  ('킹', 6),
#  ('까르보나라', 6),
#  ('수업', 6),
#  ('게', 6),
#  ('식감', 6),
#  ('망원동', 6),
#  ('망원', 6),
#  ('고양이', 6),
#  ('라떼', 6),
#  ('밖', 6),
#  ('옐로우', 6),
#  ('생맥주', 6),
#  ('파이브', 6),
#  ('가세', 6),
#  ('초', 6),
#  ('답', 6),
#  ('이안', 6),
#  ('분양', 6),
#  ('블로그', 6),
#  ('남자', 6),
#  ('베이스', 6),
#  ('링크', 6),
#  ('양파', 6),
#  ('츠', 6),
#  ('남', 6),
#  ('음료', 6),
#  ('헤', 6),
#  ('일산', 6),
#  ('나우', 6),
#  ('어스', 6),
#  ('율', 6),
#  ('녀', 6),
#  ('시장', 6),
#  ('바게트', 6),
#  ('샤워', 6),
#  ('양배추', 6),
#  ('뽁', 6),
#  ('소금', 6),
#  ('리타', 6),
#  ('주차', 6),
#  ('아라르', 6),
#  ('변', 6),
#  ('나무', 6),
#  ('우울', 6),
#  ('맥', 6),
#  ('신상', 6),
#  ('어니언', 6),
#  ('교동', 6),
#  ('마린시티', 6),
#  ('패티', 6),
#  ('중독', 5),
#  ('쫀득', 5),
#  ('궁합', 5),
#  ('홍대입구역', 5),
#  ('시티', 5),
#  ('종합', 5),
#  ('공원', 5),
#  ('가야', 5),
#  ('리보스', 5),
#  ('코', 5),
#  ('뷰', 5),
#  ('한판', 5),
#  ('한식', 5),
#  ('피자피자', 5),
#  ('버거', 5),
#  ('자체', 5),
#  ('공연', 5),
#  ('둔산동', 5),
#  ('가로수길', 5),
#  ('전부', 5),
#  ('정', 5),
#  ('파파존스', 5),
#  ('도리', 5),
#  ('취향', 5),
#  ('기름', 5),
#  ('갑자기', 5),
#  ('앞', 5),
#  ('스타벅스', 5),
#  ('강아지', 5),
#  ('파리', 5),
#  ('엄빠', 5),
#  ('여유', 5),
#  ('삼성', 5),
#  ('군', 5),
#  ('서도', 5),
#  ('제빵', 5),
#  ('누구', 5),
#  ('축구', 5),
#  ('쇼핑', 5),
#  ('협찬', 5),
#  ('진심', 5),
#  ('빽', 5),
#  ('일단', 5),
#  ('바운스', 5),
#  ('도비', 5),
#  ('옆', 5),
#  ('인기', 5),
#  ('먹거리', 5),
#  ('숙성', 5),
#  ('매드', 5),
#  ('규', 5),
#  ('방콕', 5),
#  ('센스', 5),
#  ('임신', 5),
#  ('과일', 5),
#  ('훈제', 5),
#  ('인천', 5),
#  ('당근', 5),
#  ('꿀맛', 5),
#  ('연휴', 5),
#  ('이후', 5),
#  ('해피', 5),
#  ('휘', 5),
#  ('비어', 5),
#  ('취미', 5),
#  ('해물', 5),
#  ('천원', 5),
#  ('테', 5),
#  ('보장', 5),
#  ('부부', 5),
#  ('드라이브', 5),
#  ('완료', 5),
#  ('겸', 5),
#  ('담', 5),
#  ('옥수수', 5),
#  ('무스', 5),
#  ('막국수', 5),
#  ('감기', 5),
#  ('핏', 5),
#  ('베리', 5),
#  ('피망', 5),
#  ('활짝', 5),
#  ('골뱅이', 5),
#  ('베이비', 5),
#  ('안내', 5),
#  ('커리', 5),
#  ('라스트', 5),
#  ('컴퍼니', 5),
#  ('냉면', 5),
#  ('테라스', 5),
#  ('후기', 5),
#  ('테라', 5),
#  ('냉장고', 5),
#  ('정상', 5),
#  ('티몬', 5),
#  ('일본', 5),
#  ('지구', 5),
#  ('피크닉', 5),
#  ('쉐프', 5),
#  ('또띠아', 5),
#  ('야채', 5),
#  ('분명', 5),
#  ('대표', 5),
#  ('폴로', 5),
#  ('운정', 5),
#  ('공유', 5),
#  ('양평', 5),
#  ('게시', 5),
#  ('램', 5),
#  ('파', 5),
#  ('날치', 5),
#  ('브라', 5),
#  ('운', 5),
#  ('머쉬룸', 5),
#  ('마늘', 5),
#  ('부분', 5),
#  ('골든', 5),
#  ('리피', 5),
#  ('책', 5),
#  ('유사', 5),
#  ('대신', 5),
#  ('검색', 5),
#  ('음악', 5),
#  ('누군가', 5),
#  ('만두', 5),
#  ('니스', 5),
#  ('불당동', 5),
#  ('야외', 5),
#  ('이서', 5),
#  ('건가', 5),
#  ('찜닭', 5),
#  ('로스팅', 5),
#  ('문래', 5),
#  ('계란찜', 5),
#  ('일광', 5),
#  ('룸서비스', 5),
#  ('킬러', 5),
#  ('가든', 5),
#  ('리조트', 5),
#  ('나트랑', 5),
#  ('해외여행', 5),
#  ('래미', 5),
#  ('비전동', 5),
#  ('크기', 4),
#  ('뭘', 4),
#  ('잔뜩', 4),
#  ('코젤', 4),
#  ('모습', 4),
#  ('환상', 4),
#  ('각', 4),
#  ('머', 4),
#  ('명란', 4),
#  ('주소', 4),
#  ...]

# %%
print(result["Tags"][0])
print(len(result["Tags"][0]))
# Out:
# ['#홍대', '#백스트리트피자', '#피자', '#피자맛집', '#대왕피자', '#피맥', '#맥주안주', '#술안주', '#홍대맛집', '#홍대술집']
# 86

# %%
Tag = []
for i in result["Tags"]:
    ex = i[2:-2].split("', '")
    for j in ex:
        Tag.append(j)
Tag
# Out:
# ['#홍대',
#  '#백스트리트피자',
#  '#피자',
#  '#피자맛집',
#  '#대왕피자',
#  '#피맥',
#  '#맥주안주',
#  '#술안주',
#  '#홍대맛집',
#  '#홍대술집',
#  '#명동피자',
#  '#명동피자동대문점',
#  '#피자맛집',
#  '#파스타맛집',
#  '#동대문맛집',
#  '#피자',
#  '#pizza',
#  '#pasta',
#  '#스푸파_동대문',
#  '',
#  '#피자덕후피자힙',
#  '#압구정맛집',
#  '#압구정로데오맛집',
#  '#신사맛집',
#  '#도산공원맛집',
#  '#청담맛집',
#  '#서울맛집',
#  '#리보스코피자제주도',
#  '#리보스코피자',
#  '#맛집경보_제주',
#  '#제주여행',
#  '#제주맛집',
#  '#제주도맛집',
#  '#제주시맛집',
#  '#연동맛집',
#  '#제주피자맛집추천',
#  '#제주피자맛집',
#  '#피자맛집',
#  '#포르타나광안리',
#  '#오늘의부산_광안리',
#  '',
#  '#아침',
#  '#점심',
#  '#저녁',
#  '#플레이팅',
#  '#그릇',
#  '#그릇스타그램',
#  '#집밥',
#  '#혼밥',
#  '#집밥스타그램',
#  '#상차림',
#  '#오늘의밥상',
#  '#오늘뭐먹지',
#  '#홈스위트홈',
#  '#홈쿡',
#  '#아침메뉴',
#  '#점심메뉴',
#  '#저녁메뉴',
#  '#홈메이드',
#  '#온더테이블',
#  '#가정식',
#  '#한식',
#  '#식사',
#  '#아이밥상',
#  '#방학식단',
#  '#주말점심메뉴',
#  '#피자',
#  '#냉동피자',
#  '#떡꼬치',
#  '#피자마루증산점',
#  '#피자마루웅상점',
#  '#피자마루덕계점',
#  '#단체주문환영',
#  '#영양공급',
#  '#긍정적인생각',
#  '#가을계절',
#  '#아이교육은아이고고',
#  '#한국인의밥상',
#  '#맞팔은댓',
#  '#스파게티',
#  '#강릉여행중',
#  '#2만원대',
#  '#맞팔댓',
#  '#배고프당',
#  '#신월동네일',
#  '#여름마켓',
#  '#홍대편집샵',
#  '#일상소통',
#  '#요리그램',
#  '#피자',
#  '#맛집스타그램',
#  '#반사',
#  '#너기',
#  '#캐논800d',
#  '#돼지',
#  '#소통좋아요',
#  '#맞팔선팔',
#  '#먹는순간기절',
#  '#먹팔해요',
#  '#광주근교나들이',
#  '#먹방찍고옴',
#  '#곱창국수',
#  '#인스타일상',
#  '#에스컬레이터',
#  '#즐거운추억하나추가',
#  '#가족들과함께',
#  '#먹방시작',
#  '#맞팔',
#  '#피자',
#  '#소통그램',
#  '#오늘먹방끝',
#  '#대교',
#  '#팝핑댄스',
#  '#가을계절',
#  '#조녜',
#  '#맞팔그램',
#  '#먹는순간기절',
#  '#전용잔',
#  '#밴드로고',
#  '#소통하자',
#  '#휴식시간',
#  '#맞팔선팔환영',
#  '#일상기록',
#  '#여름마켓',
#  '#맞팔하자',
#  '#일상소통',
#  '#가족여행',
#  '#피자',
#  '#소통해요',
#  '#반사',
#  '#일상',
#  '#맞팔좋아요',
#  '#선팔은맞팔',
#  '#메시지',
#  '#맞팔선팔',
#  '#아기옷스타그램',
#  '#소통',
#  '#맛이좋아요',
#  '#맞팔은댓',
#  '#익선동비밀',
#  '#인스타일상',
#  '#일상기록',
#  '#instafood',
#  '#백일상꾸미기',
#  '#일상소통',
#  '#네일샵',
#  '#피자',
#  '#소통그램',
#  '#소소한행복',
#  '#피자',
#  '#실화냐',
#  '#피자치즈',
#  '#토핑',
#  '#pizza',
#  '#italianfood',
#  '#pizzalover',
#  '#pizzatime',
#  '#cheese',
#  '#pasta',
#  '#mozzarella',
#  '#pizzaporn',
#  '#pizzas',
#  '#italian',
#  '#pizzeria',
#  '#pizzaria',
#  '#피자',
#  '#margherita',
#  '#dinner',
#  '#ピザ',
#  '#pizzaparty',
#  '#napoli',
#  '#pizzaislife',
#  '#pizzalovers',
#  '#foodgasm',
#  '#pizzalove',
#  '#선팔은맞팔',
#  '#맛집',
#  '#데일리그램',
#  '#구구전복삼계탕',
#  '#맞팔그램',
#  '#먹는순간기절',
#  '#이태원칵테일',
#  '#맛이좋아요',
#  '#먹방찍고옴',
#  '#강원도에어비앤비',
#  '#죠스',
#  '#맞팔해여',
#  '#안압지야경',
#  '#소통',
#  '#먹방시작',
#  '#심심해',
#  '#피자',
#  '#맛집스타그램',
#  '#반사',
#  '#퇴사하고싶다',
#  '#리북집',
#  '#금오동꽃집',
#  '#메시지',
#  '#맞팔해요',
#  '#먹는순간기절',
#  '#먹팔해요',
#  '#맞팔해',
#  '#먹방찍고옴',
#  '#음식그램',
#  '#일상',
#  '#일상기록',
#  '#instafood',
#  '#백일상꾸미기',
#  '#맞팔해용',
#  '#맞좋튀',
#  '#피자',
#  '#옛것들',
#  '#먹는순간은행복',
#  '#수유타투잘하는곳',
#  '#리북집',
#  '#고마운사람',
#  '#너무맛있어',
#  '#어린이집졸업',
#  '#아기옷스타그램',
#  '#선팔후맞팔',
#  '#감칠맛가성비',
#  '#맛있는음식',
#  '#익선동비밀',
#  '#죠스',
#  '#하동재첩국수',
#  '#넘모맛있어',
#  '#좋튀',
#  '#존맛탱',
#  '#요리그램',
#  '#피자',
#  '#소통해요우리',
#  '#소소한행복',
#  '#선팔하면맞팔',
#  '#맛집',
#  '#고마운사람',
#  '#캐디',
#  '#좋반',
#  '#디디미니언쥬',
#  '#분관',
#  '#밴드로고',
#  '#입간판',
#  '#익선동비밀',
#  '#일상',
#  '#난먹기만할거야',
#  '#안압지야경',
#  '#소통',
#  '#존맛탱',
#  '#맞팔',
#  '#피자',
#  '#소통해요',
#  '#먹는순간은행복',
#  '#과슈',
#  '#긍정적인생각',
#  '#가을계절',
#  '#조녜',
#  '#한국인의밥상',
#  '#웨딩부케',
#  '#전용잔',
#  '#맞팔해',
#  '#유치원입학',
#  '#곱창국수',
#  '#인스타일상',
#  '#맛있어',
#  '#생신꽃배달',
#  '#가족들과함께',
#  '#댓글소통',
#  '#맞좋튀',
#  '#피자',
#  '#옛것들',
#  '#맞팔소통',
#  '#오늘뭐먹지',
#  '#팝핑댄스',
#  '#고마운사람',
#  '#조녜',
#  '#어린이집졸업',
#  '#갈월이골목',
#  '#음식이랑썸탐',
#  '#맞팔가요',
#  '#소소한일상',
#  '#프로먹방꾼',
#  '#인스타일상',
#  '#맛있어',
#  '#안압지야경',
#  '#맞팔환영해요',
#  '#먹방시작',
#  '#맞좋튀',
#  '#피자',
#  '#옛것들',
#  '#오늘먹방끝',
#  '#일상',
#  '#맞팔100',
#  '#제작하기',
#  '#첫줄반사',
#  '#좋반',
#  '#맞팔하면선팔',
#  '#음식이랑썸탐',
#  '#밴드로고',
#  '#유치원입학',
#  '#익선동비밀',
#  '#두피문신',
#  '#부천맛집추천',
#  '#여름마켓',
#  '#좋튀',
#  '#맞팔해용',
#  '#심심해',
#  '#피자',
#  '#맛집스타그램',
#  '#먹어보자',
#  '#일상',
#  '#수유설빙',
#  '#여자가을룩',
#  '#메시지',
#  '#맞팔선팔',
#  '#일상사진',
#  '#음식이랑썸탐',
#  '#댓글소통',
#  '#입간판',
#  '#곱창국수',
#  '#두피문신',
#  '#일상기록',
#  '#즐거운추억하나추가',
#  '#맞팔하자',
#  '#좋아요반사',
#  '#시래기',
#  '#피자',
#  '#침나올라그램',
#  '#반사',
#  '#영양공급',
#  '#캐논800d',
#  '#가을계절',
#  '#소통좋아요',
#  '#일상생활',
#  '#특별한날특별한선물',
#  '#선팔후맞팔',
#  '#서귀포딱새우회',
#  '#먹방찍고옴',
#  '#프로먹방꾼',
#  '#인스타일상',
#  '#부천맛집추천',
#  '#선팔은곧맞팔',
#  '#좋튀',
#  '#3차주문',
#  '#요리그램',
#  '#피자',
#  '#맛집스타그램',
#  '#선팔맞팔',
#  '#일상스타그램',
#  '#캐논800d',
#  '#제작하기',
#  '#메시지',
#  '#맞팔그램',
#  '#맞팔하면선팔',
#  '#시베리아횡단열차',
#  '#댓글소통',
#  '#소소한일상',
#  '#맞팔댓',
#  '#일상',
#  '#하동재첩국수',
#  '#넘모맛있어',
#  '#맞팔하자',
#  '#3차주문',
#  '#가족여행',
#  '#피자',
#  '#고냥이그램',
#  '#먹어보자',
#  '#수유타투잘하는곳',
#  '#수유설빙',
#  '#데일리그램',
#  '#소통좋아요',
#  '#맞팔선팔',
#  '#일상사진',
#  '#전용잔',
#  '#감칠맛가성비',
#  '#2만원대',
#  '#맞팔댓',
#  '#맞팔선팔환영',
#  '#일상기록',
#  '#instafood',
#  '#가족들과함께',
#  '#댓글소통',
#  '#네일샵',
#  '#피자',
#  '#옛것들',
#  '#빵',
#  '#pizza',
#  '#italianfood',
#  '#pizzalover',
#  '#pizzatime',
#  '#cheese',
#  '#pasta',
#  '#mozzarella',
#  '#pizzaporn',
#  '#pizzas',
#  '#italian',
#  '#pizzeria',
#  '#pizzaria',
#  '#피자',
#  '#margherita',
#  '#dinner',
#  '#ピザ',
#  '#pizzaparty',
#  '#napoli',
#  '#pizzaislife',
#  '#pizzalovers',
#  '#foodgasm',
#  '#pizzalove',
#  '#oonikoda',
#  '#ooni',
#  '#오늘뭐먹지',
#  '#맞팔좋아요',
#  '#여자가을룩',
#  '#맞팔로우',
#  '#맞팔해요',
#  '#특별한날특별한선물',
#  '#소통합시다',
#  '#강릉여행중',
#  '#유치원입학',
#  '#맞팔댓',
#  '#인스타일상',
#  '#부천맛집추천',
#  '#안압지야경',
#  '#소통환영',
#  '#3차주문',
#  '#애쉬브라운',
#  '#피자',
#  '#소통그램',
#  '#소소한행복',
#  '#제주도',
#  '#인제사거리',
#  '#노벰버라운지',
#  '#더노벰버러운지',
#  '#24시간영업',
#  '#카페',
#  '#피자',
#  '#로제베이컨쉬프림피자',
#  '#아포카토',
#  '#커피',
#  '#제주도카페',
#  '#너기',
#  '#맞팔100',
#  '#여자가을룩',
#  '#메시지',
#  '#맞팔해요',
#  '#갈월이골목',
#  '#먹팔해요',
#  '#맞팔해',
#  '#소통하자',
#  '#음식그램',
#  '#배고프당',
#  '#하동재첩국수',
#  '#여름마켓',
#  '#맞팔환영해요',
#  '#존맛탱',
#  '#시래기',
#  '#피자',
#  '#맛집스타그램',
#  '#미용',
#  '#대교',
#  '#인스타데일리',
#  '#소통스타그램',
#  '#첫줄반사',
#  '#일상생활',
#  '#갈월이골목',
#  '#스파게티',
#  '#강릉여행중',
#  '#2만원대',
#  '#강원도에어비앤비',
#  '#배고프당',
#  '#신월동네일',
#  '#음색깡패',
#  '#눈호강하고',
#  '#존맛탱',
#  '#정신없다',
#  '#피자',
#  '#소통해요',
#  '#전시홀',
#  '#선팔하면맞팔',
#  '#데일리',
#  '#구조도',
#  '#멋글씨',
#  '#같이먹자',
#  '#맞팔하면선팔',
#  '#시베리아횡단열차',
#  '#강릉여행중',
#  '#소통하자',
#  '#프로먹방꾼',
#  '#문어낚시',
#  '#맛있어',
#  '#instafood',
#  '#소통',
#  '#밥상일기',
#  '#요리그램',
#  '#피자',
#  '#먹자그램',
#  '#맞팔소통',
#  '#오늘뭐먹지',
#  '#리북집',
#  '#구조도',
#  '#메시지',
#  '#좋반',
#  '#특별한날특별한선물',
#  '#시베리아횡단열차',
#  '#맞팔해',
#  '#유치원입학',
#  '#강원도에어비앤비',
#  '#먹는게좋아',
#  '#맞팔은댓글',
#  '#음색깡패',
#  '#좋튀',
#  '#맞팔해용',
#  '#애쉬브라운',
#  '#피자',
#  '#옛것들',
#  '#먹는순간은행복',
#  '#너기',
#  '#팝핑댄스',
#  '#여자가을룩',
#  '#구구전복삼계탕',
#  '#어린이집졸업',
#  '#디디미니언쥬',
#  '#음식이랑썸탐',
#  '#맞팔해요우리',
#  '#맛있는음식',
#  '#맞팔댓',
#  '#문어낚시',
#  '#맞팔은댓글',
#  '#생신꽃배달',
#  '#가족들과함께',
#  '#먹방시작',
#  '#심심해',
#  '#피자',
#  '#일상',
#  '#반사',
#  '#너기',
#  '#맞팔좋아요',
#  '#구조도',
#  '#소통좋아요',
#  '#좋반',
#  '#디디미니언쥬',
#  '#음식이랑썸탐',
#  '#감칠맛가성비',
#  '#맛있는음식',
#  '#대학로맛집추천',
#  '#배고프당',
#  '#에스컬레이터',
#  '#음색깡패',
#  '#소통환영',
#  '#맞팔해용',
#  '#심심해',
#  '#피자',
#  '#네일아트',
#  '#맞팔소통',
#  '#과슈',
#  '#팝핑댄스',
#  '#여자가을룩',
#  '#맞팔로우',
#  '#좋반',
#  '#웨딩부케',
#  '#먹팔해요',
#  '#서귀포딱새우회',
#  '#입간판',
#  '#강원도에어비앤비',
#  '#일상',
#  '#에스컬레이터',
#  '#안압지야경',
#  '#맞팔환영해요',
#  '#맞팔해용',
#  '#가족여행',
#  '#피자',
#  '#일상',
#  '#빵',
#  '#너기',
#  '#수유설빙',
#  '#돼지',
#  '#일상스타그램',
#  '#한국인의밥상',
#  '#특별한날특별한선물',
#  '#스파게티',
#  '#맞팔해요우리',
#  '#소통하자',
#  '#음식그램',
#  '#죠스',
#  '#하동재첩국수',
#  '#음색깡패',
#  '#소통',
#  '#3차주문',
#  '#맞팔스타그램',
#  '#피자',
#  '#소통해요',
#  '#빵',
#  '#피자',
#  '#야식은피자',
#  '#맛있다',
#  '#야식타임',
#  '#언넝자자',
#  '#먹고자자',
#  '#맛있네',
#  '#살찐다',
#  '#오늘도',
#  '#먹방',
#  '#피자피자',
#  '#치즈',
#  '#좋아요반사',
#  '#맞팔환영',
#  '#퇴사하고싶다',
#  '#맛집',
#  '#금오동꽃집',
#  '#소통좋아요',
#  '#한국인의밥상',
#  '#갈월이골목',
#  '#먹팔해요',
#  '#서귀포딱새우회',
#  '#맞팔은댓',
#  '#곱창국수',
#  '#맞팔선팔환영',
#  '#에스컬레이터',
#  '#선팔은곧맞팔',
#  '#홍대편집샵',
#  '#밥상일기',
#  '#네일샵',
#  '#피자',
#  '#맛집스타그램',
#  '#소소한행복',
#  '#영양공급',
#  '#긍정적인생각',
#  '#가을계절',
#  '#일상스타그램',
#  '#맞팔해요',
#  '#먹는순간기절',
#  '#시베리아횡단열차',
#  '#밴드로고',
#  '#맞팔은댓',
#  '#프로먹방꾼',
#  '#죠스',
#  '#신월동네일',
#  '#instafood',
#  '#백일상꾸미기',
#  '#존맛탱',
#  '#가족여행',
#  '#피자',
#  '#먹자그램',
#  '#소소한행복',
#  '#대교',
#  '#팝핑댄스',
#  '#구조도',
#  '#메시지',
#  '#맞팔선팔',
#  '#맞팔하면선팔',
#  '#시베리아횡단열차',
#  '#댓글소통',
#  '#집에안갈라함',
#  '#휴식시간',
#  '#두피문신',
#  '#에스컬레이터',
#  '#즐거운추억하나추가',
#  '#소통환영',
#  '#밥상일기',
#  '#심심해',
#  '#피자',
#  '#일상',
#  '#전시홀',
#  '#수유타투잘하는곳',
#  '#선맞팔',
#  '#가을계절',
#  '#구구전복삼계탕',
#  '#같이먹자',
#  '#특별한날특별한선물',
#  '#시베리아횡단열차',
#  '#맞팔해요우리',
#  '#맞팔은댓',
#  '#맞팔댓',
#  '#인스타일상',
#  '#맛있어',
#  '#안압지야경',
#  '#가족들과함께',
#  '#밥상일기',
#  '#네일샵',
#  '#피자',
#  '#소통그램',
#  '#먹는순간은행복',
#  '#퇴사하고싶다',
#  '#맞팔100',
#  '#돼지',
#  '#일상스타그램',
#  '#일상생활',
#  '#특별한날특별한선물',
#  '#전용잔',
#  '#밴드로고',
#  '#먹방찍고옴',
#  '#익선동비밀',
#  '#인스타일상',
#  '#난먹기만할거야',
#  '#넘모맛있어',
#  '#좋튀',
#  '#맞팔해용',
#  '#심심해',
#  '#피자',
#  '#고냥이그램',
#  '#맞팔소통',
#  '#선팔하면맞팔',
#  '#인스타데일리',
#  '#돼지',
#  '#맞팔로우',
#  '#좋반',
#  '#갈월이골목',
#  '#시베리아횡단열차',
#  '#감칠맛가성비',
#  '#맛있는음식',
#  '#휴식시간',
#  '#먹는게좋아',
#  '#맞팔해여',
#  '#즐거운추억하나추가',
#  '#맞팔하자',
#  '#존맛탱',
#  '#심심해',
#  '#피자',
#  '#소통해요',
#  '#반사',
#  '#선팔은맞팔',
#  '#팝핑댄스',
#  '#선팔은맞팔',
#  '#캐디',
#  '#어린이집졸업',
#  '#특별한날특별한선물',
#  '#소통',
#  '#맞팔해요우리',
#  '#입간판',
#  '#휴식시간',
#  '#죠스',
#  '#부천맛집추천',
#  '#안압지야경',
#  '#홍대편집샵',
#  '#댓글소통',
#  '#시래기',
#  '#피자',
#  '#네일아트',
#  '#먹는순간은행복',
#  '#대교',
#  '#맛집',
#  '#고마운사람',
#  '#맞팔로우',
#  '#어린이집졸업',
#  '#먹는순간기절',
#  '#음식이랑썸탐',
#  '#맞팔해요우리',
#  '#2만원대',
#  '#휴식시간',
#  '#먹는게좋아',
#  '#하동재첩국수',
#  '#음색깡패',
#  '#소통환영',
#  '#좋아요반사',
#  '#맞팔',
#  '#피자',
#  '#먹자그램',
#  '#먹는순간은행복',
#  '#피자덕후',
#  '#한명숙피자',
#  '#요거트소스',
#  '#찍먹',
#  '#피자',
#  '#콤비네이션피자',
#  '#페퍼로니피자',
#  '#한명숙피자구로',
#  '#한명숙피자오류동',
#  '#오류동피자집',
#  '#피맥',
#  '#피콜',
#  '#점심메뉴',
#  '#먹방',
#  '#피자추천',
#  '#야식',
#  '#먹팔',
#  '#맞팔',
#  '#선팔',
#  '#한명숙피자추천',
#  '#구로구피자',
#  '#피자맛집',
#  '#맛집',
#  '#피자집',
#  '#페퍼로니피자최고',
#  '#너기',
#  '#데일리',
#  '#금오동꽃집',
#  '#구구전복삼계탕',
#  '#맞팔그램',
#  '#먹는순간기절',
#  '#이태원칵테일',
#  '#맞팔해요우리',
#  '#집에안갈라함',
#  '#맞팔댓',
#  '#죠스',
#  '#맛있어',
#  '#생신꽃배달',
#  '#눈호강하고',
#  '#맞팔해용',
#  '#맞팔스타그램',
#  '#피자',
#  '#옛것들',
#  '#빵',
#  '#너기',
#  '#팝핑댄스',
#  '#선팔은맞팔',
#  '#첫줄반사',
#  '#맞팔그램',
#  '#먹는순간기절',
#  '#소통',
#  '#맛이좋아요',
#  '#소소한일상',
#  '#맞팔환영',
#  '#맞팔선팔환영',
#  '#맞팔은댓글',
#  '#선팔은곧맞팔',
#  '#홍대편집샵',
#  '#밥상일기',
#  '#맞좋튀',
#  '#피자',
#  '#침나올라그램',
#  '#먹는순간은행복',
#  '#goodmorning',
#  '#morning',
#  '#breakfast',
#  '#honey',
#  '#cheese',
#  '#pizza',
#  '#bread',
#  '#breadlover',
#  '#jmt',
#  '#yummy',
#  '#lifestyle',
#  '#daily',
#  '#굿모닝',
#  '#아침',
#  '#꿀',
#  '#치즈',
#  '#피자',
#  '#빵',
#  '#식빵',
#  '#빵스타그램',
#  '#빵순이',
#  '#냠냠',
#  '#먹스타그램',
#  '#맛스타그램',
#  '#맛있다',
#  '#존맛',
#  '#좋아요',
#  '#라이프스타일',
#  '#일상',
#  '#데일리',
#  '#너기',
#  '#리북집',
#  '#구조도',
#  '#구구전복삼계탕',
#  '#맞팔그램',
#  '#특별한날특별한선물',
#  '#시베리아횡단열차',
#  '#밴드로고',
#  '#소소한일상',
#  '#음식그램',
#  '#일상',
#  '#맞팔해여',
#  '#여름마켓',
#  '#맞팔환영해요',
#  '#일상소통',
#  '#네일샵',
#  '#피자',
#  '#소통그램',
#  '#반사',
#  '',
#  '#일상스타그램',
#  '#캐논800d',
#  '#선팔은맞팔',
#  '#일상스타그램',
#  '#맞팔해요',
#  '#맞팔하면선팔',
#  '#음식이랑썸탐',
#  '#감칠맛가성비',
#  '#먹방찍고옴',
#  '#맞팔댓',
#  '#서우봉',
#  '#맞팔해여',
#  '#음색깡패',
#  '#소통',
#  '#밥상일기',
#  '#맞팔',
#  '#피자',
#  '#맛집스타그램',
#  '#전시홀',
#  '#완벽한인생남해본점',
#  '#치킨',
#  '#버거',
#  '#남해맛집',
#  '#스테이크',
#  '#독일마을맛집',
#  '#남해맛집완벽한인생',
#  '#경남맛집',
#  '#바베큐',
#  '#피자맛집',
#  '#남해맛집추천',
#  '#피자',
#  '#피맥',
#  '#슈니첼',
#  '#과슈',
#  '#선맞팔',
#  '#여자가을룩',
#  '#소통좋아요',
#  '#맞팔선팔',
#  '#맞팔하면선팔',
#  '#이태원칵테일',
#  '#광주근교나들이',
#  '#2만원대',
#  '#곱창국수',
#  '#두피문신',
#  '#하동재첩국수',
#  '#즐거운추억하나추가',
#  '#홍대편집샵',
#  '#좋아요반사',
#  '#심심해',
#  '#피자',
#  '#맛집스타그램',
#  '#빵',
#  '#너기',
#  '#선맞팔',
#  '#가을계절',
#  '#구구전복삼계탕',
#  '#맞팔그램',
#  '#아기옷스타그램',
#  '#선팔후맞팔',
#  '#댓글소통',
#  '#맛있는음식',
#  '#휴식시간',
#  '#서우봉',
#  '#일상기록',
#  '#선팔은곧맞팔',
#  '#소통',
#  '#밥상일기',
#  '#맞팔',
#  '#피자',
#  '#침나올라그램',
#  '#전시홀',
#  '#오늘뭐먹지',
#  '#캐논800d',
#  '#선팔은맞팔',
#  '#맞팔로우',
#  '#한국인의밥상',
#  '#맞팔은댓',
#  '#선팔후맞팔',
#  '#강릉여행중',
#  '#유치원입학',
#  '#곱창국수',
#  '#두피문신',
#  '#맛있어',
#  '#첫줄',
#  '#소통',
#  '#댓글소통',
#  '#네일샵',
#  '#피자',
#  '#소통해요우리',
#  '#빵',
#  '#대교',
#  '#수유설빙',
#  '#구조도',
#  '#맞팔로우',
#  '#좋반',
#  '#갈월이골목',
#  '#분관',
#  '#서귀포딱새우회',
#  '#집에안갈라함',
#  '#휴식시간',
#  '#먹는게좋아',
#  '#맛있어',
#  '#맞팔좋아요',
#  '#맞팔환영해요',
#  '#댓글소통',
#  '#맞좋튀',
#  '#피자',
#  '#일상',
#  '#반사',
#  '#선팔은맞팔',
#  '#선맞팔',
#  '#여자가을룩',
#  '#첫줄반사',
#  '#같이먹자',
#  '#특별한날특별한선물',
#  '#소통합시다',
#  '#맞팔해',
#  '#집에안갈라함',
#  '#익선동비밀',
#  '#배고프당',
#  '#하동재첩국수',
#  '#맞팔좋아요',
#  '#소통',
#  '#존맛탱',
#  '#맞좋튀',
#  '#피자',
#  '#일상',
#  '#맞팔소통',
#  '#일상',
#  '#맞팔좋아요',
#  '#데일리그램',
#  ...]

# %%
Tag_count = Counter(Tag)
Tag_count
# Out:
# Counter({'#홍대': 1,
#          '#백스트리트피자': 2,
#          '#피자': 1840,
#          '#피자맛집': 83,
#          '#대왕피자': 1,
#          '#피맥': 24,
#          '#맥주안주': 4,
#          '#술안주': 3,
#          '#홍대맛집': 7,
#          '#홍대술집': 2,
#          '#명동피자': 2,
#          '#명동피자동대문점': 1,
#          '#파스타맛집': 14,
#          '#동대문맛집': 3,
#          '#pizza': 123,
#          '#pasta': 44,
#          '#스푸파_동대문': 1,
#          '': 98,
#          '#피자덕후피자힙': 2,
#          '#압구정맛집': 2,
#          '#압구정로데오맛집': 2,
#          '#신사맛집': 1,
#          '#도산공원맛집': 1,
#          '#청담맛집': 1,
#          '#서울맛집': 4,
#          '#리보스코피자제주도': 1,
#          '#리보스코피자': 1,
#          '#맛집경보_제주': 1,
#          '#제주여행': 1,
#          '#제주맛집': 1,
#          '#제주도맛집': 1,
#          '#제주시맛집': 3,
#          '#연동맛집': 1,
#          '#제주피자맛집추천': 1,
#          '#제주피자맛집': 1,
#          '#포르타나광안리': 1,
#          '#오늘의부산_광안리': 1,
#          '#아침': 3,
#          '#점심': 14,
#          '#저녁': 19,
#          '#플레이팅': 1,
#          '#그릇': 1,
#          '#그릇스타그램': 1,
#          '#집밥': 11,
#          '#혼밥': 6,
#          '#집밥스타그램': 4,
#          '#상차림': 1,
#          '#오늘의밥상': 1,
#          '#오늘뭐먹지': 114,
#          '#홈스위트홈': 1,
#          '#홈쿡': 11,
#          '#아침메뉴': 1,
#          '#점심메뉴': 4,
#          '#저녁메뉴': 7,
#          '#홈메이드': 2,
#          '#온더테이블': 1,
#          '#가정식': 2,
#          '#한식': 2,
#          '#식사': 4,
#          '#아이밥상': 1,
#          '#방학식단': 1,
#          '#주말점심메뉴': 1,
#          '#냉동피자': 2,
#          '#떡꼬치': 1,
#          '#피자마루증산점': 2,
#          '#피자마루웅상점': 2,
#          '#피자마루덕계점': 2,
#          '#단체주문환영': 6,
#          '#영양공급': 96,
#          '#긍정적인생각': 113,
#          '#가을계절': 130,
#          '#아이교육은아이고고': 77,
#          '#한국인의밥상': 129,
#          '#맞팔은댓': 209,
#          '#스파게티': 143,
#          '#강릉여행중': 130,
#          '#2만원대': 115,
#          '#맞팔댓': 141,
#          '#배고프당': 138,
#          '#신월동네일': 111,
#          '#여름마켓': 109,
#          '#홍대편집샵': 101,
#          '#일상소통': 152,
#          '#요리그램': 101,
#          '#맛집스타그램': 129,
#          '#반사': 109,
#          '#너기': 114,
#          '#캐논800d': 103,
#          '#돼지': 106,
#          '#소통좋아요': 119,
#          '#맞팔선팔': 158,
#          '#먹는순간기절': 107,
#          '#먹팔해요': 135,
#          '#광주근교나들이': 125,
#          '#먹방찍고옴': 144,
#          '#곱창국수': 144,
#          '#인스타일상': 253,
#          '#에스컬레이터': 119,
#          '#즐거운추억하나추가': 113,
#          '#가족들과함께': 107,
#          '#먹방시작': 151,
#          '#맞팔': 145,
#          '#소통그램': 123,
#          '#오늘먹방끝': 121,
#          '#대교': 120,
#          '#팝핑댄스': 117,
#          '#조녜': 105,
#          '#맞팔그램': 160,
#          '#전용잔': 101,
#          '#밴드로고': 119,
#          '#소통하자': 151,
#          '#휴식시간': 134,
#          '#맞팔선팔환영': 113,
#          '#일상기록': 123,
#          '#맞팔하자': 114,
#          '#가족여행': 115,
#          '#소통해요': 150,
#          '#일상': 382,
#          '#맞팔좋아요': 213,
#          '#선팔은맞팔': 239,
#          '#메시지': 115,
#          '#아기옷스타그램': 118,
#          '#소통': 290,
#          '#맛이좋아요': 118,
#          '#익선동비밀': 130,
#          '#instafood': 135,
#          '#백일상꾸미기': 131,
#          '#네일샵': 103,
#          '#소소한행복': 113,
#          '#실화냐': 1,
#          '#피자치즈': 2,
#          '#토핑': 2,
#          '#italianfood': 5,
#          '#pizzalover': 7,
#          '#pizzatime': 8,
#          '#cheese': 8,
#          '#mozzarella': 6,
#          '#pizzaporn': 8,
#          '#pizzas': 5,
#          '#italian': 4,
#          '#pizzeria': 6,
#          '#pizzaria': 6,
#          '#margherita': 6,
#          '#dinner': 7,
#          '#ピザ': 22,
#          '#pizzaparty': 5,
#          '#napoli': 8,
#          '#pizzaislife': 5,
#          '#pizzalovers': 4,
#          '#foodgasm': 5,
#          '#pizzalove': 5,
#          '#맛집': 190,
#          '#데일리그램': 98,
#          '#구구전복삼계탕': 119,
#          '#이태원칵테일': 105,
#          '#강원도에어비앤비': 109,
#          '#죠스': 119,
#          '#맞팔해여': 125,
#          '#안압지야경': 117,
#          '#심심해': 112,
#          '#퇴사하고싶다': 113,
#          '#리북집': 116,
#          '#금오동꽃집': 102,
#          '#맞팔해요': 160,
#          '#맞팔해': 130,
#          '#음식그램': 136,
#          '#맞팔해용': 135,
#          '#맞좋튀': 112,
#          '#옛것들': 115,
#          '#먹는순간은행복': 119,
#          '#수유타투잘하는곳': 110,
#          '#고마운사람': 117,
#          '#너무맛있어': 120,
#          '#어린이집졸업': 161,
#          '#선팔후맞팔': 120,
#          '#감칠맛가성비': 129,
#          '#맛있는음식': 143,
#          '#하동재첩국수': 129,
#          '#넘모맛있어': 114,
#          '#좋튀': 148,
#          '#존맛탱': 150,
#          '#소통해요우리': 126,
#          '#선팔하면맞팔': 105,
#          '#캐디': 102,
#          '#좋반': 157,
#          '#디디미니언쥬': 108,
#          '#분관': 109,
#          '#입간판': 147,
#          '#난먹기만할거야': 115,
#          '#과슈': 109,
#          '#웨딩부케': 96,
#          '#유치원입학': 131,
#          '#맛있어': 121,
#          '#생신꽃배달': 134,
#          '#댓글소통': 279,
#          '#맞팔소통': 133,
#          '#갈월이골목': 122,
#          '#음식이랑썸탐': 123,
#          '#맞팔가요': 115,
#          '#소소한일상': 136,
#          '#프로먹방꾼': 139,
#          '#맞팔환영해요': 109,
#          '#맞팔100': 95,
#          '#제작하기': 114,
#          '#첫줄반사': 130,
#          '#맞팔하면선팔': 106,
#          '#두피문신': 119,
#          '#부천맛집추천': 118,
#          '#먹어보자': 112,
#          '#수유설빙': 117,
#          '#여자가을룩': 108,
#          '#일상사진': 102,
#          '#좋아요반사': 151,
#          '#시래기': 102,
#          '#침나올라그램': 105,
#          '#일상생활': 260,
#          '#특별한날특별한선물': 92,
#          '#서귀포딱새우회': 109,
#          '#선팔은곧맞팔': 126,
#          '#3차주문': 153,
#          '#선팔맞팔': 109,
#          '#일상스타그램': 224,
#          '#시베리아횡단열차': 131,
#          '#고냥이그램': 121,
#          '#빵': 143,
#          '#oonikoda': 1,
#          '#ooni': 1,
#          '#맞팔로우': 103,
#          '#소통합시다': 136,
#          '#소통환영': 133,
#          '#애쉬브라운': 111,
#          '#제주도': 4,
#          '#인제사거리': 1,
#          '#노벰버라운지': 1,
#          '#더노벰버러운지': 1,
#          '#24시간영업': 1,
#          '#카페': 22,
#          '#로제베이컨쉬프림피자': 1,
#          '#아포카토': 1,
#          '#커피': 10,
#          '#제주도카페': 2,
#          '#미용': 138,
#          '#인스타데일리': 97,
#          '#소통스타그램': 99,
#          '#음색깡패': 124,
#          '#눈호강하고': 105,
#          '#정신없다': 108,
#          '#전시홀': 108,
#          '#데일리': 130,
#          '#구조도': 110,
#          '#멋글씨': 113,
#          '#같이먹자': 151,
#          '#문어낚시': 112,
#          '#밥상일기': 158,
#          '#먹자그램': 121,
#          '#먹는게좋아': 112,
#          '#맞팔은댓글': 119,
#          '#맞팔해요우리': 115,
#          '#대학로맛집추천': 138,
#          '#네일아트': 123,
#          '#맞팔스타그램': 111,
#          '#야식은피자': 1,
#          '#맛있다': 17,
#          '#야식타임': 2,
#          '#언넝자자': 1,
#          '#먹고자자': 1,
#          '#맛있네': 1,
#          '#살찐다': 1,
#          '#오늘도': 1,
#          '#먹방': 46,
#          '#피자피자': 2,
#          '#치즈': 14,
#          '#맞팔환영': 134,
#          '#집에안갈라함': 129,
#          '#선맞팔': 110,
#          '#피자덕후': 3,
#          '#한명숙피자': 1,
#          '#요거트소스': 1,
#          '#찍먹': 1,
#          '#콤비네이션피자': 3,
#          '#페퍼로니피자': 20,
#          '#한명숙피자구로': 1,
#          '#한명숙피자오류동': 1,
#          '#오류동피자집': 1,
#          '#피콜': 1,
#          '#피자추천': 17,
#          '#야식': 19,
#          '#먹팔': 34,
#          '#선팔': 19,
#          '#한명숙피자추천': 1,
#          '#구로구피자': 1,
#          '#피자집': 2,
#          '#페퍼로니피자최고': 1,
#          '#goodmorning': 1,
#          '#morning': 1,
#          '#breakfast': 1,
#          '#honey': 2,
#          '#bread': 4,
#          '#breadlover': 1,
#          '#jmt': 4,
#          '#yummy': 3,
#          '#lifestyle': 1,
#          '#daily': 21,
#          '#굿모닝': 1,
#          '#꿀': 2,
#          '#식빵': 1,
#          '#빵스타그램': 1,
#          '#빵순이': 2,
#          '#냠냠': 4,
#          '#먹스타그램': 151,
#          '#맛스타그램': 93,
#          '#존맛': 6,
#          '#좋아요': 30,
#          '#라이프스타일': 1,
#          '#서우봉': 112,
#          '#완벽한인생남해본점': 1,
#          '#치킨': 37,
#          '#버거': 2,
#          '#남해맛집': 2,
#          '#스테이크': 108,
#          '#독일마을맛집': 2,
#          '#남해맛집완벽한인생': 2,
#          '#경남맛집': 2,
#          '#바베큐': 6,
#          '#남해맛집추천': 2,
#          '#슈니첼': 2,
#          '#첫줄': 128,
#          '#골프공': 110,
#          '#음식': 137,
#          '#첫줄좋반': 93,
#          '#맛이가너무좋아요': 126,
#          '#집들이음식': 1,
#          '#맛있고배부르고': 1,
#          '#좋은사람들과좋은시간': 1,
#          '#떡국': 2,
#          '#가지볶음🍆': 1,
#          '#두부요리': 1,
#          '#감바스': 3,
#          '#와인🍷': 1,
#          '#떡볶이': 12,
#          '#공연회의': 1,
#          '#뜨거웠던': 1,
#          '#막차타고': 1,
#          '#예술해방전선': 1,
#          '#우리들의이야기': 1,
#          '#효동': 1,
#          '#지안': 1,
#          '#파스타': 167,
#          '#대전': 4,
#          '#둔산동': 2,
#          '#강릉': 1,
#          '#가로수길': 3,
#          '#00': 1,
#          '#23': 1,
#          '#대학생': 1,
#          '#패션': 2,
#          '#데일리룩': 1,
#          '#서울': 8,
#          '#셀카': 13,
#          '#셀피': 1,
#          '#셀스타그램': 5,
#          '#인친': 9,
#          '#f4f': 2,
#          '#like': 5,
#          '#likeme': 1,
#          '#followback': 1,
#          '#먹팔맞팔': 137,
#          '#완벽한인생남해본점세상': 1,
#          '#혼피': 1,
#          '#프로맛집러': 1,
#          '#오늘의추천': 1,
#          '#오늘의메뉴': 4,
#          '#오늘의식당': 1,
#          '#맛집추천': 52,
#          '#음식추천': 2,
#          '#음식점추천': 1,
#          '#식당추천': 1,
#          '#맛집탐방': 9,
#          '#디너': 3,
#          '#디너추천': 1,
#          '#런치': 3,
#          '#런치추천': 1,
#          '#등촌역': 1,
#          '#판교': 1,
#          '#서판교맛집': 1,
#          '#미쿡식당': 1,
#          '#일식': 1,
#          '#불토': 3,
#          '#판교맛집': 1,
#          '#food': 28,
#          '#운중동': 1,
#          '#판교역': 1,
#          '#라디오베이': 1,
#          '#이자카야': 1,
#          '#restaurant': 33,
#          '#콥샐러드': 1,
#          '#샐러드': 73,
#          '#minipizza': 1,
#          '#tasty': 3,
#          '#피자': 7,
#          '#ピザ': 2,
#          '#チーズ': 1,
#          '#kaas': 1,
#          '#queso': 1,
#          '#käse': 1,
#          '#tastyfood': 2,
#          '#foodie': 6,
#          '#foods': 1,
#          '#traiteur': 1,
#          '#thon': 1,
#          '#チキン': 1,
#          '#quick': 1,
#          '#foodlover': 2,
#          '#foodblogger': 2,
#          '#cheeses': 1,
#          '#olive': 1,
#          '#instagram': 3,
#          '#chef': 1,
#          '#cooking': 3,
#          '#bakery': 1,
#          '#hautescuisines': 1,
#          '#코르트스튜디오': 1,
#          '#courtestudio': 1,
#          '#피자힙': 10,
#          '#우대갈비': 1,
#          '#압구정로데오': 4,
#          '#라미스콘': 1,
#          '#도산분식': 1,
#          '#커피반점': 1,
#          '#앨리웨이광교': 1,
#          '#닭발': 2,
#          '#먹부림': 14,
#          '#먹스타': 29,
#          '#럽스타그램': 6,
#          '#남양주': 1,
#          '#팔당': 1,
#          '#피맥플레이스': 1,
#          '#치즈피자': 8,
#          '#감자튀김': 7,
#          '#남양주맛집': 10,
#          '#늦은밤🌙': 1,
#          '#경주나들이🎈': 1,
#          '#황리단길': 1,
#          '#향화정': 1,
#          '#쫀드기': 1,
#          '#십원빵존맛탱🧀': 1,
#          '#버드와이저🍺': 1,
#          '#아들덕에엄마가힐링하네❤️': 1,
#          '#우리는뭉쳐야제맛': 1,
#          '#2mins': 1,
#          '#파파존스': 2,
#          '#파파존스신메뉴': 1,
#          '#스노우볼피자': 1,
#          '#딸기생크림케이크': 1,
#          '#생크림케이크': 1,
#          '#브래드1947': 1,
#          '#피자워크샵잠실점': 3,
#          '#잠실점': 3,
#          '#방이동': 3,
#          '#포장할인': 1,
#          '#네이버영수증리뷰이벤트': 1,
#          '#파리': 1,
#          '#파리여행': 1,
#          '#프랑스': 1,
#          '#낭트': 1,
#          '#스타벅스': 1,
#          '#개': 1,
#          '#🐕': 1,
#          '#즐거웠다': 1,
#          '#🥺': 1,
#          '#❤️': 2,
#          '#🙌': 1,
#          '#🔥': 1,
#          '#👏': 1,
#          '#😍': 2,
#          '#selfie': 3,
#          '#selflove': 1,
#          '#instagood': 8,
#          '#instalike': 3,
#          '#instadaily': 7,
#          '#멍스타그램': 1,
#          '#풍경사진': 2,
#          '#풍경스타그램': 1,
#          '#여행': 12,
#          '#멍팔맞팔': 1,
#          '#카페투어': 1,
#          '#서면': 3,
#          '#부산여행': 5,
#          '#서울여행': 1,
#          '#새해': 6,
#          '#불꽃축제': 1,
#          '#화랑유원지': 1,
#          '#타종행사': 1,
#          '#🎆': 1,
#          '#🎇': 1,
#          '#팡팡': 1,
#          '#반짝반짝': 1,
#          '#불꽃': 1,
#          '#폭죽': 1,
#          '#🎉': 1,
#          '#안산': 2,
#          '#커플스타그램': 2,
#          '#데이트': 24,
#          '#2023년': 2,
#          '#첫날': 1,
#          '#피자선생': 1,
#          '#🍕': 11,
#          '#연애일기': 1,
#          '#반올림피자샵': 4,
#          '#추천': 3,
#          '#foodstagram': 42,
#          '#인친환영': 3,
#          '#selca': 1,
#          '#likesforlike': 2,
#          '#맛스타': 4,
#          '#먹스타맞팔': 18,
#          '#imstagram': 1,
#          '#고구마피자': 5,
#          '#네가지맛피자': 2,
#          '#알콜스타그램': 2,
#          '#카페스타그램': 4,
#          '#음식스타그램': 14,
#          '#스폰티니': 2,
#          '#거셀': 1,
#          '#거셀본능🤳': 1,
#          '#시은토리서우패밀리👨\\u200d👩\\u200d👦': 1,
#          '#주말일상': 10,
#          '#아이와함께': 1,
#          '#상무지구맛집': 1,
#          '#상무지구': 1,
#          '#상무지구맥스': 2,
#          '#광주서구맛집': 1,
#          '#치평동맛집': 1,
#          '#상무지구롯데마트맥스': 1,
#          '#광주피자': 1,
#          '#광주피자맛집': 3,
#          '#상무지구피자맛집': 1,
#          '#상무지구스파게티': 1,
#          '#광주스파게티': 1,
#          '#상무지구핫플': 1,
#          '#상무지구데이트': 1,
#          '#먹팔환영': 12,
#          '#주말': 25,
#          '#eat': 1,
#          '#광주창고형매장': 1,
#          '#쌍촌동맛집': 1,
#          '#쌍촌동피자': 1,
#          '#상무지구간식': 1,
#          '#일반식유지어터': 1,
#          '#메드포갈릭': 1,
#          '#고르곤졸라피자': 5,
#          '#오늘도오운완': 1,
#          '#오늘도👌오운완': 1,
#          '#매력적인': 1,
#          '#운동': 5,
#          '#운동하는여자': 4,
#          '#필라테스': 2,
#          '#필라테스강사': 1,
#          '#매력적인운동': 1,
#          '#힐링': 5,
#          '#힐링타임': 1,
#          '#시작': 1,
#          '#술': 9,
#          '#술스타그램': 15,
#          '#저녁식사': 3,
#          '#안주': 11,
#          '#선팔': 5,
#          '#맞팔': 5,
#          '#좋반': 2,
#          '#먹스타그램': 8,
#          '#맛집': 3,
#          '#맛스타그램': 5,
#          '#푸드스타그램': 3,
#          '#푸드': 3,
#          '#먹스타맞팔': 3,
#          '#먹팔': 3,
#          '#맛스타': 3,
#          '#먹스타': 3,
#          '#맛집투어': 11,
#          '#시흥': 2,
#          '#시흥카페': 2,
#          '#아빠랑': 1,
#          '#월욜부터힘드다요': 1,
#          '#배고파': 1,
#          '#한남동': 2,
#          '#육아': 7,
#          '#잘먹는아들': 1,
#          '#크긴컸구나': 1,
#          '#삼성디지털프라자': 1,
#          '#삼성전자': 1,
#          '#삼성': 1,
#          '#야식스타그램': 1,
#          '#야식추천': 2,
#          '#맛나요': 2,
#          '#다이어트식단': 4,
#          '#다이어트간식': 1,
#          '#건강식단': 2,
#          '#다이어트그램': 1,
#          '#칼맞팔': 1,
#          '#fff': 3,
#          '#좋아요반사❤️': 2,
#          '#좋반환영': 2,
#          '#좋반테러': 4,
#          '#집쿡': 2,
#          '#부산롯데호텔': 1,
#          '#풀사이드바': 1,
#          '#칵테일': 4,
#          '#붕어빵': 2,
#          '#붕어빵아이스크림': 1,
#          '#계동피자': 1,
#          '#차먹방': 1,
#          '#혼자서도잘먹어요': 1,
#          '#혼자서도잘돌아다녀요': 1,
#          '#혼자서도잘놀아요': 1,
#          '#관종아재': 1,
#          '#사소한것에서행복찾기': 1,
#          '#혼자놀기달인': 1,
#          '#혼자놀기만렙': 1,
#          '#사는재미가없으면사는재미라도': 1,
#          '#오지게힐링': 1,
#          '#아이같은나': 1,
#          '#오지게혼자서놀기': 1,
#          '#사는재미': 1,
#          '#하고싶은대로살아도괜찮아': 1,
#          '#일상기록📷': 1,
#          '#인스타일기장✍🏻': 1,
#          '#즐겁다그램🎶': 1,
#          '#잠실촌놈': 1,
#          '#잠실촌놈의일상': 1,
#          '#잠실촌놈의일상이야기': 1,
#          '#광고역시': 1,
#          '#피자헛': 14,
#          '#PIZZAHUT': 1,
#          '#토킹핑피자': 1,
#          '#피자헛토핑킹피자': 1,
#          '#피자헛프리미엄피자': 1,
#          '#피자스타그램': 18,
#          '#토핑킹': 1,
#          '#피자헛토핑킹': 1,
#          '#미트토핑': 1,
#          '#미트토핑피자': 1,
#          '#프리미엄피자': 2,
#          '#피자헛피자': 1,
#          '#피자헛배달': 1,
#          '#피자헛포장': 1,
#          '#피자헛픽업': 1,
#          '#피자헛할인': 1,
#          '#피자헛포장할인': 1,
#          '#피자배달': 4,
#          '#피자포장': 3,
#          '#피자포장할인': 1,
#          '#비달의민족': 1,
#          '#요기요배달': 1,
#          '#쿠팡잇츠배달': 1,
#          '#자가제빵선명희피자❤️': 1,
#          '#반반피자❤️': 1,
#          '#치즈오븐스파게티요즘': 1,
#          '#야구': 1,
#          '#축구': 2,
#          '#산행에미치다': 1,
#          '#등산': 2,
#          '#미국': 1,
#          '#쇼핑': 3,
#          '#쇼핑몰': 2,
#          '#신발': 1,
#          '#그림': 3,
#          '#소주': 5,
#          '#맥주': 21,
#          '#와인': 16,
#          '#영화': 2,
#          '#친구': 3,
#          '#새벽': 1,
#          '#화장품': 1,
#          '#강남': 4,
#          '#삼겹살': 4,
#          '#소고기': 3,
#          '#알볼로': 1,
#          '#알볼로피자': 3,
#          '#피자알볼로': 2,
#          '#팔도자': 1,
#          '#먹상박상': 1,
#          '#인스타푸드': 6,
#          '#푸드스타그램': 14,
#          '#먹방스타그램': 13,
#          '#냠냠탱': 1,
#          '#binded': 1,
#          '#음식사진': 5,
#          '#공항맛집': 1,
#          '#뷔페': 1,
#          '#곱창집': 1,
#          '#제주돌담집': 1,
#          '#바나나': 1,
#          '#사탕수수': 1,
#          '#제주감귤': 1,
#          '#청춘당찹쌀꽈배기': 1,
#          '#키티아일랜드카페': 1,
#          '#스시망고': 1,
#          '#제주스타그램': 1,
#          '#홈파티': 6,
#          '#생일파티': 2,
#          '#진수성찬': 1,
#          '#케이크': 4,
#          '#고추바사삭': 1,
#          '#신전떡볶이': 2,
#          '#무뼈닭발': 1,
#          '#연어': 3,
#          '#염통꼬치': 1,
#          '#좋아요꾹': 1,
#          '#팔로우': 12,
#          '#팔로잉': 1,
#          '#직장인': 3,
#          '#follow': 5,
#          '#followforfollowback': 5,
#          '#likeforfollow': 1,
#          '#pic': 2,
#          '#울산': 3,
#          '#천상': 1,
#          '#인친해요': 1,
#          '#순살치킨': 2,
#          '#플랜피라구피자&포테이토': 1,
#          '#춘천맛집': 2,
#          '#애막골': 1,
#          '#피자는옳다': 1,
#          '#피자헛러버': 1,
#          '#협찬': 4,
#          '#연남동맛집': 5,
#          '#연남동': 4,
#          '#비건': 3,
#          '#비건맛집': 2,
#          '#비건식단': 1,
#          '#hongdae': 1,
#          '#yeonnamdong': 1,
#          '#vegankorea': 1,
#          '#seoulrestaurant': 31,
#          '#seoulrestaurants': 1,
#          '#veganpizza': 2,
#          '#veganseoul': 1,
#          '#외국인모델': 1,
#          '#외국인배우': 1,
#          '#배우': 1,
#          '#미국인': 1,
#          '#미국인모델': 1,
#          '#모델구함': 1,
#          '#인플루언서': 1,
#          '#인플루언서모집': 1,
#          '#モデル': 1,
#          '#외국인': 1,
#          '#模特': 1,
#          '#演员': 1,
#          '#피자만들기': 3,
#          '#homepizza': 1,
#          '#모임': 5,
#          '#주말요약': 1,
#          '#글램핑': 1,
#          '#하체운동': 1,
#          '#스퀏': 1,
#          '#호두과자': 1,
#          '#트레이더스': 4,
#          '#소맥': 2,
#          '#아가리어터': 1,
#          '#연댕이랑': 1,
#          '#짠짠🍻': 1,
#          '#로즈앤크라운': 1,
#          '#빽보이피자': 3,
#          '#맛집인가': 1,
#          '#모르겠다': 1,
#          '#일단': 2,
#          '#진행시켜': 1,
#          '#오늘': 3,
#          '#누메로뜨레스': 1,
#          '#브런치타임': 2,
#          '#브런치': 9,
#          '#브레라': 2,
#          '#버티고개역': 2,
#          '#버티고개맛집': 2,
#          '#빤나꼬따': 2,
#          '#에스프레소': 2,
#          '#이탈리안레스토랑': 34,
#          '#스프리츠': 2,
#          '#brera': 2,
#          '#이탈리안맛집': 2,
#          '#연말모임': 4,
#          '#italianpizza': 2,
#          '#이탈리안피자': 2,
#          '#까망베르': 1,
#          '#보꼬네': 1,
#          '#삼송맛집': 1,
#          '#화덕피자': 21,
#          '#나폴리피자': 5,
#          '#데이트맛집': 2,
#          '#은평구맛집': 1,
#          '#연신내맛집': 1,
#          '#맛있다그램': 11,
#          '#찐이야': 1,
#          '#여의도': 1,
#          '#더현대': 1,
#          '#이탈리': 1,
#          '#레스토랑': 37,
#          '#웨이팅': 2,
#          '#thehyundai': 1,
#          '#seoul': 5,
#          '#김해': 2,
#          '#미즈컨테이너': 1,
#          '#샐러드파스타': 1,
#          '#베이컨포테이토떠먹는피자': 1,
#          '#해이담': 1,
#          '#아메리카노': 3,
#          '#로데오거리': 1,
#          '#pizzahip': 2,
#          '#apgujeong': 1,
#          '#southkorea': 1,
#          '#키즈카페': 1,
#          '#퍼포먼스': 1,
#          '#솜사탕': 1,
#          '#에어바운스': 2,
#          '#여덟': 1,
#          '#플르서라구뜨': 1,
#          '#플르서라구뜨피자크리스마스라': 1,
#          '#myphoto': 1,
#          '#일상': 2,
#          '#사진': 1,
#          '#vscofilm': 1,
#          '#vscolove': 1,
#          '#vsco': 1,
#          '#vscocam': 1,
#          '#vscogood': 1,
#          '#日常': 1,
#          '#写真': 1,
#          '#vscofood': 1,
#          '#onthetable': 1,
#          '#온더테이블': 1,
#          '#체다콘치즈피자': 2,
#          '#대야동카페': 1,
#          '#시흥대형카페': 1,
#          '#소래산카페': 1,
#          '#시흥브런치': 1,
#          '#시흥브런치카페': 1,
#          '#브런치카페': 2,
#          '#몬테인': 1,
#          '#나폴리탄파스타': 1,
#          '#부라타': 1,
#          '#부라타피자': 1,
#          '#부라타화덕피자': 1,
#          '#무튼': 1,
#          '#아무튼': 1,
#          '#피자마루': 3,
#          '#포테이토피자우리집': 1,
#          '#먹깨비': 1,
#          '#먹거리': 4,
#          '#먹방그램': 4,
#          '#맛팔': 6,
#          '#蔬菜': 1,
#          '#菇類': 1,
#          '#植物肉家裡自己動手做客製化美食還是最最最能滿足自己的胃口家人都吃的開開心心💗💗주말은': 1,
#          '#저온숙성': 1,
#          '#피자도우': 3,
#          '#비건피자': 1,
#          '#토핑은': 1,
#          '#채소': 2,
#          '#버섯': 1,
#          '#비건고기': 1,
#          '#veganfood': 1,
#          '#homefood': 1,
#          '#披薩': 3,
#          '#매드포갈릭': 3,
#          '#푸드': 6,
#          '#감자피자': 1,
#          '#🍕몇달간': 1,
#          '#먹방투어': 4,
#          '#먹방여행': 2,
#          '#먹스타소통': 3,
#          '#냠스타그램': 1,
#          '#foodporn': 6,
#          '#집술안주🍺': 1,
#          '#에다마메': 1,
#          '#민찌넣은볶음김치': 1,
#          '#두부김치': 2,
#          '#막걸리': 3,
#          '#이밤의끝은어디인가🌙✨': 1,
#          '#iphone11': 1,
#          '#cocacola': 1,
#          '#코카콜라': 1,
#          '#청아한': 1,
#          '#춥다': 1,
#          '#먹스타스램': 2,
#          '#전포': 1,
#          '#전포동': 1,
#          '#전포끝자락': 1,
#          '#coke': 2,
#          '#스냅사진그램': 1,
#          '#스냅샷': 1,
#          '#사진계정': 3,
#          '#사진계정맞팔': 2,
#          '#소통🙆': 1,
#          '#스냅': 1,
#          '#사진그램': 1,
#          '#사진스타그램': 2,
#          '#사진보정': 1,
#          '#사진소통': 1,
#          '#사진맛집': 2,
#          '#towanoa': 1,
#          '#tawanico': 1,
#          '#タワニコ': 1,
#          '#トワノア': 1,
#          '#天満橋カフェ': 1,
#          '#谷町四丁目カフェ': 1,
#          '#いちごのタルト': 1,
#          '#カフェインスタグラマー': 1,
#          '#カフェスタグラム': 1,
#          '#カフェ巡り': 2,
#          '#スイーツ巡り': 1,
#          '#미식': 1,
#          '#밥스타그램': 2,
#          '#비밀피자': 1,
#          '#내추럴와인': 2,
#          '#꼬릿꼬릿': 1,
#          '#버터피자': 1,
#          '#비싼버터': 1,
#          '#버터': 1,
#          '#모르타델라': 1,
#          '#스트라치아텔라': 1,
#          '#부라타알맹': 1,
#          '#치즈플로': 1,
#          '#홈베이킹': 3,
#          '#mortadella': 1,
#          '#stracciatella': 1,
#          '#homebaked': 1,
#          '#방콕여행': 1,
#          '#방콕맛집': 2,
#          '#세계여행': 1,
#          '#d800': 1,
#          '#dslr': 1,
#          '#nikond800': 1,
#          '#bangkok': 2,
#          '#bangkoktour': 1,
#          '#bangkokfood': 1,
#          '#urbantravel': 1,
#          '#snapshot': 1,
#          '#DélicesdeCapoue': 1,
#          '#ekamai': 1,
#          '#초코볼': 1,
#          '#쿠키': 1,
#          '#드로잉쿠키': 1,
#          '#쿠방': 1,
#          '#곰돌이피자': 1,
#          '#수제피자': 5,
#          '#수제': 1,
#          '#내댜기랑': 1,
#          '#💖': 1,
#          '#먹그타그램': 1,
#          '#메드포갈릭에서': 1,
#          '#크리스마스외식🎄': 1,
#          '#까르보나라': 4,
#          '#봉골레': 2,
#          '#메뉴뿌시기👊': 1,
#          '#추천피자': 1,
#          '#추천맛집': 2,
#          '#배달의민족': 56,
#          '#먹보': 1,
#          '#좋아요반사': 2,
#          '#초등에서_중등이된_친구들': 1,
#          '#오랜만에_생사확인_동창회혼자만.다른학교': 1,
#          '#김밥': 6,
#          '#피자매너있게.아빠랑': 1,
#          '#그저신나는너희들😆': 1,
#          '#엄빠는그저고맙구나🤭너무': 1,
#          '#우리그거하자': 1,
#          '#산악회포즈': 1,
#          '#참센스있는녀석👍다음에': 1,
#          '#네네네네네네네네': 1,
#          '#😁😁😁😁😁😁😁뭐가되도.': 1,
#          '#될_놈들': 1,
#          '#또보자_계속보자': 1,
#          '#먹음_압구정로데오': 1,
#          '#먹음_클랩피자화려한': 1,
#          '#일요일': 6,
#          '#커피숍': 1,
#          '#고르곤졸라': 6,
#          '#대전카페': 2,
#          '#대전데이트': 3,
#          '#대전둔산동': 1,
#          '#대전둔산동카페': 1,
#          '#대전브런치카페': 1,
#          '#세이브존': 1,
#          '#썸데이로맨스': 1,
#          '#daejeon': 1,
#          '#임신20주': 2,
#          '#과일': 2,
#          '#눈': 1,
#          '#임신': 1,
#          '#임산부': 1,
#          '#예비맘': 1,
#          '#토끼띠': 2,
#          '#아들맘': 2,
#          '#축복이': 1,
#          '#축복아사랑해': 1,
#          '#감사': 3,
#          '#三重県': 1,
#          '#伊勢': 1,
#          '#三重ランチ': 1,
#          ...})

# %%
rank_text = Tag_count.most_common()
rank_text
# Out:
# [('#피자', 1840),
#  ('#일상', 382),
#  ('#소통', 290),
#  ('#댓글소통', 279),
#  ('#일상생활', 260),
#  ('#인스타일상', 253),
#  ('#선팔은맞팔', 239),
#  ('#일상스타그램', 224),
#  ('#맞팔좋아요', 213),
#  ('#맞팔은댓', 209),
#  ('#맛집', 190),
#  ('#파스타', 167),
#  ('#어린이집졸업', 161),
#  ('#맞팔그램', 160),
#  ('#맞팔해요', 160),
#  ('#맞팔선팔', 158),
#  ('#밥상일기', 158),
#  ('#좋반', 157),
#  ('#3차주문', 153),
#  ('#일상소통', 152),
#  ('#먹방시작', 151),
#  ('#소통하자', 151),
#  ('#좋아요반사', 151),
#  ('#같이먹자', 151),
#  ('#먹스타그램', 151),
#  ('#소통해요', 150),
#  ('#존맛탱', 150),
#  ('#좋튀', 148),
#  ('#입간판', 147),
#  ('#맞팔', 145),
#  ('#먹방찍고옴', 144),
#  ('#곱창국수', 144),
#  ('#스파게티', 143),
#  ('#맛있는음식', 143),
#  ('#빵', 143),
#  ('#맞팔댓', 141),
#  ('#프로먹방꾼', 139),
#  ('#배고프당', 138),
#  ('#미용', 138),
#  ('#대학로맛집추천', 138),
#  ('#음식', 137),
#  ('#먹팔맞팔', 137),
#  ('#음식그램', 136),
#  ('#소소한일상', 136),
#  ('#소통합시다', 136),
#  ('#먹팔해요', 135),
#  ('#instafood', 135),
#  ('#맞팔해용', 135),
#  ('#휴식시간', 134),
#  ('#생신꽃배달', 134),
#  ('#맞팔환영', 134),
#  ('#맞팔소통', 133),
#  ('#소통환영', 133),
#  ('#백일상꾸미기', 131),
#  ('#유치원입학', 131),
#  ('#시베리아횡단열차', 131),
#  ('#가을계절', 130),
#  ('#강릉여행중', 130),
#  ('#익선동비밀', 130),
#  ('#맞팔해', 130),
#  ('#첫줄반사', 130),
#  ('#데일리', 130),
#  ('#한국인의밥상', 129),
#  ('#맛집스타그램', 129),
#  ('#감칠맛가성비', 129),
#  ('#하동재첩국수', 129),
#  ('#집에안갈라함', 129),
#  ('#첫줄', 128),
#  ('#소통해요우리', 126),
#  ('#선팔은곧맞팔', 126),
#  ('#맛이가너무좋아요', 126),
#  ('#광주근교나들이', 125),
#  ('#맞팔해여', 125),
#  ('#음색깡패', 124),
#  ('#pizza', 123),
#  ('#소통그램', 123),
#  ('#일상기록', 123),
#  ('#음식이랑썸탐', 123),
#  ('#네일아트', 123),
#  ('#갈월이골목', 122),
#  ('#오늘먹방끝', 121),
#  ('#맛있어', 121),
#  ('#고냥이그램', 121),
#  ('#먹자그램', 121),
#  ('#대교', 120),
#  ('#너무맛있어', 120),
#  ('#선팔후맞팔', 120),
#  ('#소통좋아요', 119),
#  ('#에스컬레이터', 119),
#  ('#밴드로고', 119),
#  ('#구구전복삼계탕', 119),
#  ('#죠스', 119),
#  ('#먹는순간은행복', 119),
#  ('#두피문신', 119),
#  ('#맞팔은댓글', 119),
#  ('#아기옷스타그램', 118),
#  ('#맛이좋아요', 118),
#  ('#부천맛집추천', 118),
#  ('#팝핑댄스', 117),
#  ('#안압지야경', 117),
#  ('#고마운사람', 117),
#  ('#수유설빙', 117),
#  ('#리북집', 116),
#  ('#2만원대', 115),
#  ('#가족여행', 115),
#  ('#메시지', 115),
#  ('#옛것들', 115),
#  ('#난먹기만할거야', 115),
#  ('#맞팔가요', 115),
#  ('#맞팔해요우리', 115),
#  ('#오늘뭐먹지', 114),
#  ('#너기', 114),
#  ('#맞팔하자', 114),
#  ('#넘모맛있어', 114),
#  ('#제작하기', 114),
#  ('#긍정적인생각', 113),
#  ('#즐거운추억하나추가', 113),
#  ('#맞팔선팔환영', 113),
#  ('#소소한행복', 113),
#  ('#퇴사하고싶다', 113),
#  ('#멋글씨', 113),
#  ('#심심해', 112),
#  ('#맞좋튀', 112),
#  ('#먹어보자', 112),
#  ('#문어낚시', 112),
#  ('#먹는게좋아', 112),
#  ('#서우봉', 112),
#  ('#신월동네일', 111),
#  ('#애쉬브라운', 111),
#  ('#맞팔스타그램', 111),
#  ('#수유타투잘하는곳', 110),
#  ('#구조도', 110),
#  ('#선맞팔', 110),
#  ('#골프공', 110),
#  ('#여름마켓', 109),
#  ('#반사', 109),
#  ('#강원도에어비앤비', 109),
#  ('#분관', 109),
#  ('#과슈', 109),
#  ('#맞팔환영해요', 109),
#  ('#서귀포딱새우회', 109),
#  ('#선팔맞팔', 109),
#  ('#디디미니언쥬', 108),
#  ('#여자가을룩', 108),
#  ('#정신없다', 108),
#  ('#전시홀', 108),
#  ('#스테이크', 108),
#  ('#먹는순간기절', 107),
#  ('#가족들과함께', 107),
#  ('#돼지', 106),
#  ('#맞팔하면선팔', 106),
#  ('#조녜', 105),
#  ('#이태원칵테일', 105),
#  ('#선팔하면맞팔', 105),
#  ('#침나올라그램', 105),
#  ('#눈호강하고', 105),
#  ('#캐논800d', 103),
#  ('#네일샵', 103),
#  ('#맞팔로우', 103),
#  ('#금오동꽃집', 102),
#  ('#캐디', 102),
#  ('#일상사진', 102),
#  ('#시래기', 102),
#  ('#홍대편집샵', 101),
#  ('#요리그램', 101),
#  ('#전용잔', 101),
#  ('#소통스타그램', 99),
#  ('', 98),
#  ('#데일리그램', 98),
#  ('#인스타데일리', 97),
#  ('#영양공급', 96),
#  ('#웨딩부케', 96),
#  ('#맞팔100', 95),
#  ('#맛스타그램', 93),
#  ('#첫줄좋반', 93),
#  ('#특별한날특별한선물', 92),
#  ('#피자맛집', 83),
#  ('#아이교육은아이고고', 77),
#  ('#샐러드', 73),
#  ('#배달의민족', 56),
#  ('#맛집추천', 52),
#  ('#요기요', 51),
#  ('#스테이크맛집', 48),
#  ('#광주파스타맛집', 47),
#  ('#먹방', 46),
#  ('#전대후문맛집', 45),
#  ('#피가로', 45),
#  ('#광주핫플', 45),
#  ('#광주맛집', 45),
#  ('#전대맛집', 45),
#  ('#전대핫플', 45),
#  ('#화덕피자맛집', 45),
#  ('#텍사스등갈비가', 45),
#  ('#pasta', 44),
#  ('#foodstagram', 42),
#  ('#리조또', 41),
#  ('#전대파스타맛집Open', 39),
#  ('#치킨', 37),
#  ('#레스토랑', 37),
#  ('#먹팔', 34),
#  ('#이탈리안레스토랑', 34),
#  ('#restaurant', 33),
#  ('#seoulrestaurant', 31),
#  ('#steak', 31),
#  ('#좋아요', 30),
#  ('#누브티스', 30),
#  ('#nouveautes', 30),
#  ('#성북동맛집', 30),
#  ('#넥타이박물관', 30),
#  ('#italianrestaurant', 30),
#  ('#tiemuseum', 30),
#  ('#risotto', 30),
#  ('#foodpics', 30),
#  ('#dailylife', 30),
#  ('#fashionista', 30),
#  ('#fashion', 30),
#  ('#gallery', 30),
#  ('#smallwedding', 30),
#  ('#먹스타', 29),
#  ('#food', 28),
#  ('#성북동카페', 28),
#  ('#주말', 25),
#  ('#피맥', 24),
#  ('#데이트', 24),
#  ('#cookingclass', 24),
#  ('#ピザ', 22),
#  ('#카페', 22),
#  ('#daily', 21),
#  ('#맥주', 21),
#  ('#화덕피자', 21),
#  ('#페퍼로니피자', 20),
#  ('#저녁', 19),
#  ('#야식', 19),
#  ('#선팔', 19),
#  ('#먹스타맞팔', 18),
#  ('#피자스타그램', 18),
#  ('#맛있다', 17),
#  ('#피자추천', 17),
#  ('#와인', 16),
#  ('#조선육회', 16),
#  ('#술스타그램', 15),
#  ('#도미노피자', 15),
#  ('#파스타맛집', 14),
#  ('#점심', 14),
#  ('#치즈', 14),
#  ('#먹부림', 14),
#  ('#음식스타그램', 14),
#  ('#피자헛', 14),
#  ('#푸드스타그램', 14),
#  ('#셀카', 13),
#  ('#먹방스타그램', 13),
#  ('#떡볶이', 12),
#  ('#여행', 12),
#  ('#먹팔환영', 12),
#  ('#팔로우', 12),
#  ('#집밥', 11),
#  ('#홈쿡', 11),
#  ('#🍕', 11),
#  ('#안주', 11),
#  ('#맛집투어', 11),
#  ('#맛있다그램', 11),
#  ('#요리', 11),
#  ('#커피', 10),
#  ('#피자힙', 10),
#  ('#남양주맛집', 10),
#  ('#주말일상', 10),
#  ('#부산', 10),
#  ('#인친', 9),
#  ('#맛집탐방', 9),
#  ('#술', 9),
#  ('#브런치', 9),
#  ('#다이어트', 9),
#  ('#육회', 9),
#  ('#사진', 9),
#  ('#더블치즈크러스트', 9),
#  ('#모짜렐라치즈', 9),
#  ('#pizzatime', 8),
#  ('#cheese', 8),
#  ('#pizzaporn', 8),
#  ('#napoli', 8),
#  ('#서울', 8),
#  ('#치즈피자', 8),
#  ('#instagood', 8),
#  ('#먹스타그램', 8),
#  ('#간식', 8),
#  ('#통닭', 8),
#  ('#맛있겠다', 8),
#  ('#수퍼슈프림L', 8),
#  ('#수퍼슈프림', 8),
#  ('#엣지추가', 8),
#  ('#엣지', 8),
#  ('#수퍼슈프림엣지', 8),
#  ('#더블치즈크러스트L', 8),
#  ('#모짜렐라치즈추가', 8),
#  ('#더블치즈크러스트모짜렐라치즈', 8),
#  ('#육회듬뿍비빔밥', 8),
#  ('#특', 8),
#  ('#육회듬뿍비빔밥특', 8),
#  ('#비빔밥육회추가', 8),
#  ('#비빔밥육회', 8),
#  ('#소고기국밥https://youtu.be/Ui-D8tcsvKQhttps://youtube.com/@short_mouth_sun@cnstka486',
#   8),
#  ('#입짧은햇님@pizzahutkorea', 8),
#  ('#피자헛@korean.yukhoe', 8),
#  ('#출렁다리', 8),
#  ('#홍대맛집', 7),
#  ('#저녁메뉴', 7),
#  ('#pizzalover', 7),
#  ('#dinner', 7),
#  ('#피자', 7),
#  ('#감자튀김', 7),
#  ('#instadaily', 7),
#  ('#육아', 7),
#  ('#대구', 7),
#  ('#양식', 7),
#  ('#돈까스', 7),
#  ('#낮술', 7),
#  ('#대구맛집', 7),
#  ('#디트로이트피자', 7),
#  ('#배달맛집', 7),
#  ('#장인', 7),
#  ('#월요일', 7),
#  ('#커플링', 7),
#  ('#양가선물', 7),
#  ('#결혼기념일', 7),
#  ('#순금매입', 7),
#  ('#서양식', 7),
#  ('#일식집', 7),
#  ('#중국집', 7),
#  ('#토요일', 7),
#  ('#페퍼로니', 7),
#  ('#여행스타그램', 7),
#  ('#혼밥', 6),
#  ('#단체주문환영', 6),
#  ('#mozzarella', 6),
#  ('#pizzeria', 6),
#  ('#pizzaria', 6),
#  ('#margherita', 6),
#  ('#존맛', 6),
#  ('#바베큐', 6),
#  ('#foodie', 6),
#  ('#럽스타그램', 6),
#  ('#새해', 6),
#  ('#인스타푸드', 6),
#  ('#홈파티', 6),
#  ('#맛팔', 6),
#  ('#푸드', 6),
#  ('#foodporn', 6),
#  ('#김밥', 6),
#  ('#일요일', 6),
#  ('#고르곤졸라', 6),
#  ('#대전맛집', 6),
#  ('#전대파스타맛집', 6),
#  ('#요리스타그램', 6),
#  ('#만찢녀', 6),
#  ('#외식', 6),
#  ('#italianfood', 5),
#  ('#pizzas', 5),
#  ('#pizzaparty', 5),
#  ('#pizzaislife', 5),
#  ('#foodgasm', 5),
#  ('#pizzalove', 5),
#  ('#셀스타그램', 5),
#  ('#like', 5),
#  ('#부산여행', 5),
#  ('#고구마피자', 5),
#  ('#고르곤졸라피자', 5),
#  ('#운동', 5),
#  ('#힐링', 5),
#  ('#선팔', 5),
#  ('#맞팔', 5),
#  ('#맛스타그램', 5),
#  ('#소주', 5),
#  ('#음식사진', 5),
#  ('#follow', 5),
#  ('#followforfollowback', 5),
#  ('#연남동맛집', 5),
#  ('#모임', 5),
#  ('#나폴리피자', 5),
#  ('#seoul', 5),
#  ('#수제피자', 5),
#  ('#뇨끼', 5),
#  ('#likeforlikes', 5),
#  ('#피자스쿨', 5),
#  ('#분위기맛집', 5),
#  ('#불고기피자', 5),
#  ('#포테이토피자', 5),
#  ('#수타피자', 5),
#  ('#2023', 5),
#  ('#원주', 5),
#  ('#샐러드맛집', 5),
#  ('#맥주안주', 4),
#  ('#서울맛집', 4),
#  ('#집밥스타그램', 4),
#  ('#점심메뉴', 4),
#  ('#식사', 4),
#  ('#italian', 4),
#  ('#pizzalovers', 4),
#  ('#제주도', 4),
#  ('#bread', 4),
#  ('#jmt', 4),
#  ('#냠냠', 4),
#  ('#대전', 4),
#  ('#오늘의메뉴', 4),
#  ('#압구정로데오', 4),
#  ('#반올림피자샵', 4),
#  ('#맛스타', 4),
#  ('#카페스타그램', 4),
#  ('#운동하는여자', 4),
#  ('#다이어트식단', 4),
#  ('#좋반테러', 4),
#  ('#칵테일', 4),
#  ('#피자배달', 4),
#  ('#강남', 4),
#  ('#삼겹살', 4),
#  ('#케이크', 4),
#  ('#협찬', 4),
#  ('#연남동', 4),
#  ('#트레이더스', 4),
#  ('#연말모임', 4),
#  ('#먹거리', 4),
#  ('#먹방그램', 4),
#  ('#먹방투어', 4),
#  ('#까르보나라', 4),
#  ('#페페로니피자', 4),
#  ('#고구마', 4),
#  ('#라자냐', 4),
#  ('#배달', 4),
#  ('#배민', 4),
#  ('#생맥주', 4),
#  ('#beer', 4),
#  ('#수원', 4),
#  ('#막창', 4),
#  ('#햄버거', 4),
#  ('#korea', 4),
#  ('#관저동맛집', 4),
#  ('#比萨', 4),
#  ('#성수동맛집', 4),
#  ('#루꼴라피자', 4),
#  ('#전주', 4),
#  ('#피자네버슬립스', 4),
#  ('#디저트', 4),
#  ('#오오티디', 4),
#  ('#치즈오븐스파게티', 4),
#  ('#1인피자', 4),
#  ('#테라', 4),
#  ('#도시락', 4),
#  ('#쿠팡이츠', 4),
#  ('#콜라', 4),
#  ('#대전핫플', 4),
#  ('#태닝', 4),
#  ('#바디체크', 4),
#  ('#식단', 4),
#  ('#마르게리타', 4),
#  ('#배민원', 4),
#  ('#천안', 4),
#  ('#인스타', 4),
#  ('#Pizza', 4),
#  ('#초밥', 4),
#  ('#🍺', 4),
#  ('#포테이토', 4),
#  ('#부산맛집', 4),
#  ('#일상그램', 4),
#  ('#쁘띠졸리', 4),
#  ('#원주파스타', 4),
#  ('#원주맛집', 4),
#  ('#단계동', 4),
#  ('#봉화산', 4),
#  ('#봉화산맛집', 4),
#  ('#테라스', 4),
#  ('#전기차충전소', 4),
#  ('#주차장', 4),
#  ('#1인1메하면탄산음료도무료래', 4),
#  ('#화덕', 4),
#  ('#강원도맛집', 4),
#  ('#강원도여행', 4),
#  ('#마산샌드위치', 4),
#  ('#술안주', 3),
#  ('#동대문맛집', 3),
#  ('#제주시맛집', 3),
#  ('#아침', 3),
#  ('#피자덕후', 3),
#  ('#콤비네이션피자', 3),
#  ('#yummy', 3),
#  ('#감바스', 3),
#  ('#가로수길', 3),
#  ('#디너', 3),
#  ('#런치', 3),
#  ('#불토', 3),
#  ('#tasty', 3),
#  ('#instagram', 3),
#  ('#cooking', 3),
#  ('#피자워크샵잠실점', 3),
#  ('#잠실점', 3),
#  ('#방이동', 3),
#  ('#selfie', 3),
#  ('#instalike', 3),
#  ('#서면', 3),
#  ('#추천', 3),
#  ('#인친환영', 3),
#  ('#광주피자맛집', 3),
#  ('#저녁식사', 3),
#  ('#맛집', 3),
#  ('#푸드스타그램', 3),
#  ('#푸드', 3),
#  ('#먹스타맞팔', 3),
#  ('#먹팔', 3),
#  ('#맛스타', 3),
#  ('#먹스타', 3),
#  ('#fff', 3),
#  ('#피자포장', 3),
#  ('#쇼핑', 3),
#  ('#그림', 3),
#  ('#친구', 3),
#  ('#소고기', 3),
#  ('#알볼로피자', 3),
#  ('#연어', 3),
#  ('#직장인', 3),
#  ('#울산', 3),
#  ('#비건', 3),
#  ('#피자만들기', 3),
#  ('#빽보이피자', 3),
#  ('#오늘', 3),
#  ('#아메리카노', 3),
#  ('#피자마루', 3),
#  ('#피자도우', 3),
#  ('#披薩', 3),
#  ('#매드포갈릭', 3),
#  ('#먹스타소통', 3),
#  ('#막걸리', 3),
#  ('#사진계정', 3),
#  ('#홈베이킹', 3),
#  ('#대전데이트', 3),
#  ('#감사', 3),
#  ('#食べスタグラム', 3),
#  ('#바질', 3),
#  ('#꿀맛', 3),
#  ('#고양이', 3),
#  ('#사랑해', 3),
#  ('#가족', 3),
#  ('#잘먹겠습니다', 3),
#  ('#펍피맥', 3),
#  ('#라라코스트', 3),
#  ('#데이트코스', 3),
#  ('#제주', 3),
#  ('#선물', 3),
#  ('#삼산동', 3),
#  ('#홍대맛집추천', 3),
#  ('#김치볶음밥', 3),
#  ('#술집', 3),
#  ('#드라이브', 3),
#  ('#짬뽕', 3),
#  ('#치킨히어로', 3),
#  ('#부평시장역', 3),
#  ('#혜화', 3),
#  ('#대학로', 3),
#  ('#로제파스타', 3),
#  ('#크림파스타', 3),
#  ('#전주맛집', 3),
#  ('#압구정', 3),
#  ('#김해맛집', 3),
#  ('#목동맛집', 3),
#  ('#창원', 3),
#  ('#가산디지털단지맛집', 3),
#  ('#신혼스타그램', 3),
#  ('#대구화덕피자', 3),
#  ('#금요일', 3),
#  ('#생일', 3),
#  ('#부대찌개', 3),
#  ('#하남맛집', 3),
#  ('#산미구엘', 3),
#  ('#일산', 3),
#  ('#핸드메이드', 3),
#  ('#먹스타그램🐷', 3),
#  ('#족발', 3),
#  ('#가족외식', 3),
#  ('#주말스타그램', 3),
#  ('#마칸', 3),
#  ('#힙만들기', 3),
#  ('#필라테스그램', 3),
#  ('#운동소통', 3),
#  ('#오우난', 3),
#  ('#눈바디그램', 3),
#  ('#레깅스', 3),
#  ('#컨트롤s공구', 3),
#  ('#공구오픈', 3),
#  ('#몸매유지', 3),
#  ('#율', 3),
#  ('#신세경', 3),
#  ('#존예보스', 3),
#  ('#아이유', 3),
#  ('#콘서트', 3),
#  ('#본', 3),
#  ('#몸', 3),
#  ('#패션의완성', 3),
#  ('#분위기감', 3),
#  ('#안산PT', 3),
#  ('#선부동PT', 3),
#  ('#선부제2종합시장', 3),
#  ('#인스타그램', 3),
#  ('#완벽한인생대전관저점', 3),
#  ('#대전핫플추천', 3),
#  ('#대전서구맛집추천', 3),
#  ('#관저동맛집완벽한인생', 3),
#  ('#대전서구맛집', 3),
#  ('#대전서구핫플', 3),
#  ('#감성맛집', 3),
#  ('#감성술집', 3),
#  ('#치즈크러스트', 3),
#  ('#잠실', 3),
#  ('#해운대', 3),
#  ('#피제리아라르도', 3),
#  ('#미사강변맛집', 3),
#  ('#하남미사맛집', 3),
#  ('#먹팔소통', 3),
#  ('#캠핑', 3),
#  ('#메뉴', 3),
#  ('#불당동맛집', 3),
#  ('#스페인셰프', 3),
#  ('#제과', 3),
#  ('#제빵', 3),
#  ('#피자나라치킨공주', 3),
#  ('#🍝', 3),
#  ('#필라프', 3),
#  ('#건대맛집', 3),
#  ('#치팅데이', 3),
#  ('#피자먹다', 3),
#  ('#피자먹다보라매점', 3),
#  ('#보라매맛집', 3),
#  ('#보라매피자', 3),
#  ('#보라매공원맛집', 3),
#  ('#관악구맛집', 3),
#  ('#관악구피자', 3),
#  ('#동작구맛집', 3),
#  ('#동작구피자', 3),
#  ('#단체주문', 3),
#  ('#회사단체간식', 3),
#  ('#단체간식', 3),
#  ('#단체간식주문', 3),
#  ('#용인시청', 3),
#  ('#룸서비스', 3),
#  ('#광안리', 3),
#  ('#20230114', 3),
#  ('#샌드위치', 3),
#  ('#새우', 3),
#  ('#백스트리트피자', 2),
#  ('#홍대술집', 2),
#  ('#명동피자', 2),
#  ('#피자덕후피자힙', 2),
#  ('#압구정맛집', 2),
#  ('#압구정로데오맛집', 2),
#  ('#홈메이드', 2),
#  ('#가정식', 2),
#  ('#한식', 2),
#  ('#냉동피자', 2),
#  ('#피자마루증산점', 2),
#  ('#피자마루웅상점', 2),
#  ('#피자마루덕계점', 2),
#  ('#피자치즈', 2),
#  ('#토핑', 2),
#  ('#제주도카페', 2),
#  ('#야식타임', 2),
#  ('#피자피자', 2),
#  ('#피자집', 2),
#  ('#honey', 2),
#  ('#꿀', 2),
#  ('#빵순이', 2),
#  ('#버거', 2),
#  ('#남해맛집', 2),
#  ('#독일마을맛집', 2),
#  ('#남해맛집완벽한인생', 2),
#  ('#경남맛집', 2),
#  ('#남해맛집추천', 2),
#  ('#슈니첼', 2),
#  ('#떡국', 2),
#  ('#둔산동', 2),
#  ('#패션', 2),
#  ('#f4f', 2),
#  ('#음식추천', 2),
#  ('#ピザ', 2),
#  ('#tastyfood', 2),
#  ('#foodlover', 2),
#  ('#foodblogger', 2),
#  ('#닭발', 2),
#  ('#파파존스', 2),
#  ('#❤️', 2),
#  ('#😍', 2),
#  ('#풍경사진', 2),
#  ('#안산', 2),
#  ('#커플스타그램', 2),
#  ('#2023년', 2),
#  ('#likesforlike', 2),
#  ('#네가지맛피자', 2),
#  ('#알콜스타그램', 2),
#  ('#스폰티니', 2),
#  ('#상무지구맥스', 2),
#  ('#필라테스', 2),
#  ('#좋반', 2),
#  ('#시흥', 2),
#  ('#시흥카페', 2),
#  ('#한남동', 2),
#  ('#야식추천', 2),
#  ('#맛나요', 2),
#  ('#건강식단', 2),
#  ('#좋아요반사❤️', 2),
#  ('#좋반환영', 2),
#  ('#집쿡', 2),
#  ('#붕어빵', 2),
#  ('#프리미엄피자', 2),
#  ('#축구', 2),
#  ('#등산', 2),
#  ('#쇼핑몰', 2),
#  ('#영화', 2),
#  ('#피자알볼로', 2),
#  ('#생일파티', 2),
#  ('#신전떡볶이', 2),
#  ('#pic', 2),
#  ('#순살치킨', 2),
#  ('#춘천맛집', 2),
#  ('#비건맛집', 2),
#  ('#veganpizza', 2),
#  ('#소맥', 2),
#  ('#일단', 2),
#  ('#브런치타임', 2),
#  ('#브레라', 2),
#  ('#버티고개역', 2),
#  ('#버티고개맛집', 2),
#  ('#빤나꼬따', 2),
#  ('#에스프레소', 2),
#  ('#스프리츠', 2),
#  ('#brera', 2),
#  ('#이탈리안맛집', 2),
#  ('#italianpizza', 2),
#  ('#이탈리안피자', 2),
#  ('#데이트맛집', 2),
#  ('#웨이팅', 2),
#  ('#김해', 2),
#  ('#pizzahip', 2),
#  ('#에어바운스', 2),
#  ('#일상', 2),
#  ('#체다콘치즈피자', 2),
#  ('#브런치카페', 2),
#  ('#채소', 2),
#  ('#먹방여행', 2),
#  ('#두부김치', 2),
#  ('#먹스타스램', 2),
#  ('#coke', 2),
#  ('#사진계정맞팔', 2),
#  ('#사진스타그램', 2),
#  ('#사진맛집', 2),
#  ('#カフェ巡り', 2),
#  ('#밥스타그램', 2),
#  ('#내추럴와인', 2),
#  ('#방콕맛집', 2),
#  ('#bangkok', 2),
#  ('#봉골레', 2),
#  ('#추천맛집', 2),
#  ('#좋아요반사', 2),
#  ('#대전카페', 2),
#  ('#임신20주', 2),
#  ('#과일', 2),
#  ('#토끼띠', 2),
#  ('#아들맘', 2),
#  ('#イタリアン', 2),
#  ('#マルゲリータ', 2),
#  ('#美味しい', 2),
#  ('#lunch', 2),
#  ('#피자는치즈빨', 2),
#  ('#한잔', 2),
#  ('#푸라닭', 2),
#  ('#2차', 2),
#  ('#망원동맛집', 2),
#  ('#망원맛집', 2),
#  ('#망원역맛집', 2),
#  ('#망리단길맛집', 2),
#  ('#합정맛집', 2),
#  ('#먹스타그램맞팔', 2),
#  ('#주말먹방', 2),
#  ('#시카고피자', 2),
#  ('#두부', 2),
#  ('#제주도여행', 2),
#  ('#남매맘', 2),
#  ('#유머', 2),
#  ('#유머스타그램', 2),
#  ('#공감', 2),
#  ('#가성비갑', 2),
#  ('#물고기자리', 2),
#  ('#볶음밥', 2),
#  ('#청년피자', 2),
#  ('#분위기좋은술집', 2),
#  ('#pizzaandbeer', 2),
#  ('#foodart', 2),
#  ('#illustration', 2),
#  ('#digitalart', 2),
#  ('#foodillustration', 2),
#  ('#사진취미', 2),
#  ('#photo', 2),
#  ('#반올림피자', 2),
#  ('#제주도민', 2),
#  ('#마라탕', 2),
#  ('#l4l', 2),
#  ('#갈릭', 2),
#  ('#겨울', 2),
#  ('#나들이', 2),
#  ('#대존맛', 2),
#  ('#냥팔맞팔', 2),
#  ('#기특해', 2),
#  ('#건행', 2),
#  ('#전', 2),
#  ('#골프중독', 2),
#  ('#카시트', 2),
#  ('#횟집', 2),
#  ('#제주여행코스', 2),
#  ('#셀카고자', 2),
#  ('#마드리드', 2),
#  ('#셀프웨딩촬영', 2),
#  ('#추석선물', 2),
#  ('#남편이랑💨', 2),
#  ('#가구스타그램🦘', 2),
#  ('#업텐션💂', 2),
#  ('#피자😵', 2),
#  ('#떠나요👳\\u200d♀️', 2),
#  ('#교회', 2),
#  ('#눈오는날', 2),
#  ('#다시시작', 2),
#  ('#두판', 2),
#  ('#김치전', 2),
#  ('#한라비발디', 2),
#  ('#마르게리따', 2),
#  ('#성수동카페', 2),
#  ('#friends', 2),
#  ('#마르게리따피자', 2),
#  ('#레드와인', 2),
#  ('#日曜日', 2),
#  ('#wine', 2),
#  ('#sunday', 2),
#  ('#주말저녁', 2),
#  ('#객리단길', 2),
#  ('#성북동', 2),
#  ('#김해핫플', 2),
#  ('#김해피자', 2),
#  ('#김해파스타', 2),
#  ('#오목교', 2),
#  ('#오목교맛집', 2),
#  ('#목동', 2),
#  ('#애견동반', 2),
#  ('#피자맛집추천', 2),
#  ('#반반피자', 2),
#  ('#catstagram', 2),
#  ('#illustrationgram', 2),
#  ('#카레', 2),
#  ('#금천구맛집', 2),
#  ('#가산맛집', 2),
#  ('#서울파스타맛집', 2),
#  ('#가디맛집', 2),
#  ('#가디맛집델리커리', 2),
#  ('#독산역맛집', 2),
#  ('#가산동맛집', 2),
#  ('#독산역카레', 2),
#  ('#저녁뭐먹지', 2),
#  ('#냉면', 2),
#  ('#비아나폴리', 2),
#  ('#반월당맛집', 2),
#  ('#대구피자', 2),
#  ('#김치찌개', 2),
#  ('#누룽지', 2),
#  ('#딸스타그램', 2),
#  ('#딸랑구', 2),
#  ('#다둥이네', 2),
#  ('#짜파게티', 2),
#  ('#안주스타그램', 2),
#  ('#마산', 2),
#  ('#창원맛집', 2),
#  ('#참이슬', 2),
#  ('#환영', 2),
#  ('#교촌치킨', 2),
#  ('#코지하우스', 2),
#  ('#봉골레파스타', 2),
#  ('#취미', 2),
#  ('#분위기', 2),
#  ('#97년생', 2),
#  ('#이태원맛집', 2),
#  ('#한국', 2),
#  ('#피앤타', 2),
#  ('#스탭밀', 2),
#  ('#직원식', 2),
#  ('#피앤타1201', 2),
#  ('#피자앤파스타', 2),
#  ('#하남2지구맛집', 2),
#  ('#수완지구맛집', 2),
#  ('#산정동맛집', 2),
#  ('#흑석동맛집', 2),
#  ('#월곡동맛집', 2),
#  ('#광산구맛집', 2),
#  ('#피크닉몰맛집', 2),
#  ('#피크닉몰', 2),
#  ('#associazionepizzaiuolinapoletani', 2),
#  ('#한국나폴리피자장인협회', 2),
#  ('#pizzavillage', 2),
#  ('#pizzanight', 2),
#  ('#yum', 2),
#  ('#토요일밤', 2),
#  ('#파이프라인피자', 2),
#  ('#대만망고맥주', 2),
#  ('#NOMOREBLUES', 2),
#  ('#겨울방학', 2),
#  ('#치즈볼', 2),
#  ('#고기', 2),
#  ('#내돈내산', 2),
#  ('#추천', 2),
#  ('#좋아요', 2),
#  ('#팔로우', 2),
#  ('#운정맛집', 2),
#  ('#salad', 2),
#  ('#パスタ', 2),
#  ('#이대맛집', 2),
#  ('#이대', 2),
#  ('#이대역맛집', 2),
#  ('#이대핫플레이스', 2),
#  ('#서대문구맛집', 2),
#  ('#뉴욕스타일', 2),
#  ('#조각피자', 2),
#  ('#홈메이드피자', 2),
#  ('#나우어스', 2),
#  ('#나우어스피자', 2),
#  ('#수원피자', 2),
#  ('#수원피자맛집', 2),
#  ('#우만동', 2),
#  ('#우만동맛집', 2),
#  ('#우만동피자맛집', 2),
#  ('#우만동펍', 2),
#  ('#우만동데이트', 2),
#  ('#아주대맛집', 2),
#  ('#아주대피자', 2),
#  ('#아주대피자맛집', 2),
#  ('#아주대펍', 2),
#  ('#아주대데이트', 2),
#  ('#오픈예정', 2),
#  ('#기대기대', 2),
#  ('#빠네', 2),
#  ('#하와이안피자', 2),
#  ('#주말메뉴', 2),
#  ('#도미노', 2),
#  ('#임실치즈', 2),
#  ('#첫끼', 2),
#  ('#집들이', 2),
#  ('#스트레스해소', 2),
#  ('#코지하우스진영점', 2),
#  ('#가성비맛집', 2),
#  ('#제주해녀밥상', 2),
#  ('#개정', 2),
#  ('#아침식사', 2),
#  ('#골프', 2),
#  ('#골프스타그램', 2),
#  ('#혼술', 2),
#  ('#디저트그램', 2),
#  ('#신혼밥상', 2),
#  ('#배달음식', 2),
#  ('#커플', 2),
#  ('#맛점', 2),
#  ('#발렌타인피자', 2),
#  ('#어제', 2),
#  ('#주말외식', 2),
#  ('#날치알', 2),
#  ('#간식스타그램', 2),
#  ('#군산', 2),
#  ('#집스타그램', 2),
#  ('#포항', 2),
#  ('#레시피', 2),
#  ('#뽁식당', 2),
#  ('#쌈싸먹는피자', 2),
#  ('#리코타치즈샐러드', 2),
#  ('#잠실맛집', 2),
#  ('#ピッツァ', 2),
#  ('#ピザ好きな人と繋がりたい', 2),
#  ('#チーズ', 2),
#  ('#followme', 2),
#  ('#명절선물', 2),
#  ('#콰트로포르마지', 2),
#  ('#달랏', 2),
#  ('#디어밸리', 2),
#  ('#트리팜', 2),
#  ('#헤이마', 2),
#  ('#팔공산데이트', 2),
#  ('#팔공산데이트코스', 2),
#  ('#팔공산피자', 2),
#  ('#팔공산화덕피자', 2),
#  ('#피자잘하는집', 2),
#  ('#팔공산피제리아라르도', 2),
#  ('#대구맛집추천', 2),
#  ('#팔공산맛집', 2),
#  ('#팔공산카페', 2),
#  ('#팔공산맛집추천', 2),
#  ('#미사양식당', 2),
#  ('#미사강변도시맛집', 2),
#  ('#미사역맛집', 2),
#  ('#미사파스타', 2),
#  ('#미사수변공원파스타', 2),
#  ('#미사수변공원맛집', 2),
#  ('#미사강변파스타', 2),
#  ('#미사역파스타맛집', 2),
#  ...]

# %%
rank_text = np.array(rank_text)
rank_text = rank_text[0:,0]

# %%
rt = rank_text[0:10]
rt
# Out:
# array(['#피자', '#일상', '#소통', '#댓글소통', '#일상생활', '#인스타일상', '#선팔은맞팔',
#        '#일상스타그램', '#맞팔좋아요', '#맞팔은댓'], dtype='<U138')

# %%
rank = []
for i in rt:
    ex = i[:].split(", ")
    for j in ex:
        rank.append(j)
rank
# Out:
# ['#피자',
#  '#일상',
#  '#소통',
#  '#댓글소통',
#  '#일상생활',
#  '#인스타일상',
#  '#선팔은맞팔',
#  '#일상스타그램',
#  '#맞팔좋아요',
#  '#맞팔은댓']

# %%
result["RT"] = rank_text[1:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [243], in <cell line: 1>()
# ----> 1 result["RT"] = rank_text[1:10]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (9) does not match length of index (2000)

# %%
result = result.astype({ "Tags" : "string" })

# %%
result["Tags"] = result["Tags"].str.replace(pat=r'^[#]', repl=r' ', regex=True)
result
# Out:
#                                                Contents  Like  \
# 0     피자 좋아하는 대식가들 여기 당장가야되요 사장님 걱정될 정도로 미친듯이 토핑이 부어...  1051
# 1     우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1496
# 2                                      피자힙 도우는 신세계라던데      60
# 3     피자의 한 획을 그은 그 피자집이에요토핑으로 빽빽하게 채운 디트로이트 피자로 다양한...   494
# 4       제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   972
# ...                                                 ...   ...
# 1995   영양공급 긍정적인생각 고마운사람 조녜 한국인의밥상 일상생활 먹팔해요 맞팔가요 유치...     2
# 1996   일상스타그램 팝핑댄스 가을계절 너무맛있어 맞팔그램 먹는순간기절 먹팔해요 강릉여행중...     2
# 1997   대교 맞팔100 여자가을룩 첫줄반사 맞팔그램 먹는순간기절 이태원칵테일 감칠맛가성비...     0
# 1998  오늘의 비건 식단  브로콜리 피자랑 미트프리 치킨 피자   세일해서 3유로씩 했다 ...     6
# 1999   과슈 맞팔100 돼지 구구전복삼계탕 한국인의밥상 일상생활 음식이랑썸탐 맛이좋아요 ...     0
#
#                        ID                                               Tags
# 0              _yamiyomi_  ['#홍대', '#백스트리트피자', '#피자', '#피자맛집', '#대왕피자', '...
# 1          st_foodfighter  ['#명동피자', '#명동피자동대문점', '#피자맛집', '#파스타맛집', '#동대...
# 2            ahfflqmepsja                                                 []
# 3            mari_mukkkkk  ['#피자덕후피자힙', '#압구정맛집', '#압구정로데오맛집', '#신사맛집', '...
# 4             gyeongboki_  ['#리보스코피자제주도', '#리보스코피자', '#맛집경보_제주', '#제주여행',...
# ...                   ...                                                ...
# 1995    bellawilkins812mz  ['#영양공급', '#긍정적인생각', '#고마운사람', '#조녜', '#한국인의밥상...
# 1996  gabriellenash718ikk  ['#일상스타그램', '#팝핑댄스', '#가을계절', '#너무맛있어', '#맞팔그램...
# 1997            yomnyong1  ['#대교', '#맞팔100', '#여자가을룩', '#첫줄반사', '#맞팔그램', ...
# 1998          emily_vivid  ['#유럽', '#유럽일상', '#식단', '#비건', '#vegan', '#piz...
# 1999       emilymay3105jf  ['#과슈', '#맞팔100', '#돼지', '#구구전복삼계탕', '#한국인의밥상'...
#
# [2000 rows x 4 columns]

# %%
result["Tags"] = str(result["Tags"]).replace("[|]", "")

# %%
result
# Out:
#                                                Contents  Like  \
# 0     피자 좋아하는 대식가들 여기 당장가야되요 사장님 걱정될 정도로 미친듯이 토핑이 부어...  1051
# 1     우리는 지금 월드클래스 명동피자의 시대에 살고있습니다  카타르 월드컵보다 더욱 핫한...  1496
# 2                                      피자힙 도우는 신세계라던데      60
# 3     피자의 한 획을 그은 그 피자집이에요토핑으로 빽빽하게 채운 디트로이트 피자로 다양한...   494
# 4       제주돌담 몸통으로 박살내고 가야하는 피자집맛집경보             9 10...   972
# ...                                                 ...   ...
# 1995   영양공급 긍정적인생각 고마운사람 조녜 한국인의밥상 일상생활 먹팔해요 맞팔가요 유치...     2
# 1996   일상스타그램 팝핑댄스 가을계절 너무맛있어 맞팔그램 먹는순간기절 먹팔해요 강릉여행중...     2
# 1997   대교 맞팔100 여자가을룩 첫줄반사 맞팔그램 먹는순간기절 이태원칵테일 감칠맛가성비...     0
# 1998  오늘의 비건 식단  브로콜리 피자랑 미트프리 치킨 피자   세일해서 3유로씩 했다 ...     6
# 1999   과슈 맞팔100 돼지 구구전복삼계탕 한국인의밥상 일상생활 음식이랑썸탐 맛이좋아요 ...     0
#
#                        ID                                               Tags
# 0              _yamiyomi_  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 1          st_foodfighter  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 2            ahfflqmepsja  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 3            mari_mukkkkk  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 4             gyeongboki_  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# ...                   ...                                                ...
# 1995    bellawilkins812mz  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 1996  gabriellenash718ikk  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 1997            yomnyong1  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 1998          emily_vivid  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
# 1999       emilymay3105jf  0       0       ['#홍대', '#백스트리트피자', '#피자', '#피...
#
# [2000 rows x 4 columns]

# %%
Content = []
for i in result["Contents"]:
    ex = i[2:-2].split(" ")
    for j in ex:
        Content.append(j)
Content
# Out:
# ['해',
#  '대신',
#  '올해는',
#  '',
#  '동근',
#  '해가',
#  '떴습니다',
#  '',
#  '우동사리에',
#  '치밥까지',
#  '치킨으로',
#  '풀코스',
#  '즐기는',
#  '법',
#  'JPG바베큐치킨',
#  '먹을',
#  '때',
#  '됐으면',
#  '',
#  '',
#  '',
#  '',
#  '동근이숯불두마리치킨',
#  '입안가득',
#  '숯불구이향',
#  '',
#  '',
#  '야들촉촉',
#  '식감으로',
#  '꽉찼어요',
#  '',
#  '동근이표',
#  '독보적인',
#  '양념엔',
#  '우동사리',
#  '치밥은',
#  '무조건임',
#  '',
#  '소금구이는',
#  '담백하니',
#  '살',
#  '안찌는거',
#  '아시죠',
#  '',
#  '꽤나',
#  '뻔뻔',
#  '꼬',
#  '소한',
#  '치즈스틱과',
#  '치즈볼은',
#  '정신차리고보니',
#  '추가함',
#  '동상이몽',
#  '요리대첩에',
#  '나온',
#  '그',
#  '치킨',
#  '드디어',
#  '먹어봤어요한마리는',
#  '살짝',
#  '서운한데',
#  '가성비',
#  '두마리치킨이라',
#  '좋고',
#  '바베큐만',
#  '아니라',
#  '튀긴치킨도',
#  '있어서',
#  '싸울일은',
#  '없어요요즘',
#  '세상에',
#  '배달비',
#  '없는곳이',
#  '있다구요',
#  '',
#  '',
#  '',
#  '청주복대점배달구역',
#  '전부무료',
#  '',
#  '',
#  '가경',
#  '강서',
#  '개신',
#  '죽림',
#  '산남',
#  '수곡',
#  '',
#  '',
#  '',
#  '동근이숯불두마리치킨',
#  '청주복대점',
#  '',
#  '',
#  'donggeun2_official',
#  '',
#  '숯불양념',
#  '소금세트',
#  '26',
#  '900',
#  '',
#  '치즈볼',
#  '3',
#  '000',
#  '',
#  '치즈스틱',
#  '3',
#  '000',
#  '',
#  '',
#  '치킨',
#  '',
#  '치킨맛집',
#  '',
#  '배달치킨',
#  '',
#  '배달맛집',
#  '',
#  '숯불바베큐',
#  '치킨추천',
#  '',
#  '복대동맛집',
#  '',
#  '청주맛집',
#  '',
#  '청주배달',
#  '찬',
#  '',
#  '떡볶이에',
#  '타피오카',
#  '펄',
#  '쏟은',
#  '줄',
#  '알았다',
#  '',
#  '버블티같은',
#  '떡볶이다',
#  '',
#  '맥주를',
#  '부르는',
#  '맛이다',
#  '',
#  '',
#  '',
#  '치킨매니아',
#  '',
#  '한국식',
#  '버블티다',
#  '',
#  '치킨이랑',
#  '떡볶이의',
#  '조합이',
#  '이렇게',
#  '좋은',
#  '줄',
#  '처음',
#  '알았다',
#  '',
#  '동글동글한',
#  '구슬떡볶이라',
#  '숟가락으로',
#  '퍼먹기',
#  '딱',
#  '좋다',
#  '',
#  '소스도',
#  '진짜',
#  '꾸덕하고',
#  '진하다',
#  '',
#  '왕새우치킨은',
#  '이름값',
#  '제대로',
#  '한다',
#  '',
#  '블랙타이거만한',
#  '새우가',
#  '바삭하게',
#  '튀겨졌다',
#  '',
#  '치킨도',
#  '먹고',
#  '새우튀김도',
#  '먹고',
#  '일석이조다',
#  '',
#  '푸드갱_배달',
#  '',
#  '배달맛집',
#  '',
#  '치킨맛집',
#  '',
#  '떡볶이맛집',
#  '',
#  '배달음식추천',
#  '',
#  '야식추천',
#  '',
#  '치맥',
#  '',
#  '치킨',
#  '',
#  '사료',
#  '일지',
#  '',
#  '',
#  '506',
#  '',
#  '지코바',
#  '성정점뿡빵쓰가',
#  '스트레스',
#  '받으면',
#  '주기적',
#  '수혈하는',
#  '3대장',
#  '1',
#  '',
#  '신라면생라면',
#  '',
#  '',
#  '맥주',
#  '',
#  '',
#  '2',
#  '',
#  '엽떡',
#  '',
#  '',
#  '그리고',
#  '3',
#  '',
#  '지코바',
#  '',
#  '양념순살',
#  '매운맛',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '저도',
#  '모르게',
#  '이',
#  '메뉴들을',
#  '찾고',
#  '있으면',
#  '스트레스',
#  '받거나',
#  '힐링하고',
#  '싶을때',
#  '더라구요',
#  '',
#  '매운맛',
#  '음식',
#  '후후하하',
#  '먹어주다보면',
#  '자연스럽게',
#  '행복감으로',
#  '바뀌니깐',
#  '간단하게',
#  '기분',
#  '좋아지고',
#  '싶을때는',
#  '꼬옥',
#  '찾게',
#  '되네요',
#  '',
#  '지코바는',
#  '무조건',
#  '떡사리',
#  '추가해서',
#  '드시고',
#  '',
#  '',
#  '순살',
#  '',
#  '',
#  '닭다리살로만',
#  '되어있어서',
#  '진짜',
#  '핵',
#  '맛',
#  '',
#  '',
#  '로',
#  '시키셔야하고',
#  '',
#  '스트레스',
#  '확',
#  '풀리게',
#  '혹은',
#  '술안주로',
#  '드시고싶다',
#  '',
#  '그럼',
#  '매운맛',
#  '고고',
#  '하세요',
#  '',
#  '후회',
#  '안하실껍니다',
#  '진쟈루',
#  '',
#  '저희',
#  '어머니가',
#  '주먹밥',
#  '장인이신데',
#  '',
#  '참기름이랑',
#  '김',
#  '낭낭하게',
#  '뿌셔서',
#  '만든',
#  '주먹밥에',
#  '소스',
#  '푸욱',
#  '찍어서',
#  '먹으면',
#  '이맛은',
#  '진짜',
#  '찐행복이예요',
#  '오늘도',
#  '월요팅',
#  '잘',
#  '하셨나요',
#  '',
#  '날이',
#  '또',
#  '갑자기',
#  '추워졌네요',
#  '',
#  '저는',
#  '감기가',
#  '올라고',
#  '하는데',
#  '',
#  '여러분들은',
#  '감기',
#  '조심하세요',
#  '',
#  '',
#  '',
#  '지코바',
#  '양념',
#  '순살',
#  '매운맛',
#  '',
#  '',
#  '20000원',
#  '',
#  '',
#  '떡사리',
#  '서',
#  '나',
#  '맛있었으면',
#  '포장까지ㄷㄷㄷ',
#  '',
#  '',
#  '',
#  '범맥주',
#  '노랑통닭ㆍㆍㆍ',
#  '대구맛집',
#  '',
#  '먹방',
#  '',
#  'instafood',
#  '',
#  '요리스타그램',
#  '',
#  '요리',
#  '',
#  '맛스타그램',
#  '',
#  '먹스타그램',
#  '',
#  '선팔',
#  '',
#  '맞팔',
#  '',
#  '선팔하면맞팔',
#  '',
#  '선팔해요',
#  '',
#  'followforfollow',
#  '',
#  '맞팔해요',
#  '',
#  '팔로우',
#  '',
#  '팔로잉',
#  '',
#  '팔로미',
#  '',
#  '팔로워',
#  '',
#  '데일리',
#  '',
#  '팔로우미',
#  '',
#  '소통',
#  '',
#  '소통해요',
#  '',
#  '셀피',
#  '',
#  '카페스타그램',
#  '',
#  '댓글',
#  '',
#  'follow4like',
#  '',
#  '좋아요반사',
#  '',
#  '좋아요',
#  '',
#  'like4li',
#  '',
#  '협찬',
#  '',
#  '소떡소떡',
#  '밀어내고',
#  '이제는',
#  '치떡',
#  '시대야식',
#  '하면',
#  '가장',
#  '먼저',
#  '생각나는',
#  '치킨과',
#  '떡볶이가만났다구요',
#  '',
#  '이건',
#  '도대체',
#  '안먹을수가',
#  '없는',
#  '조합이에여',
#  '_',
#  '부산시장',
#  '스타일의',
#  '꾸덕하고',
#  '감칠맛',
#  '가득한',
#  '소스에동글동글한',
#  '구슬떡',
#  '',
#  '',
#  '치킨을',
#  '소스에',
#  '찍어먹어도',
#  '맛있고',
#  '그냥',
#  '숟가락으로',
#  '떡만',
#  '퍼먹어도',
#  '세상',
#  '행복',
#  '왕새우치킨은',
#  '바삭바삭한',
#  '튀김옷',
#  '안에',
#  '탱글한',
#  '새우가',
#  '있어서',
#  '누가',
#  '먹어도',
#  '좋아할',
#  '맛과',
#  '식감이에여',
#  '',
#  '',
#  '',
#  '치킨매니아',
#  '',
#  '',
#  '치킨맛집',
#  '',
#  '떡볶이맛집',
#  '',
#  '치킨추천',
#  '',
#  '떡볶이추천',
#  '',
#  '배달',
#  '치킨',
#  '신상',
#  '국물게티X레드마블',
#  '네네치킨에서',
#  '신메뉴를',
#  '선보입니다',
#  '',
#  '넉넉한',
#  '국물에',
#  '떡볶이',
#  '양념이',
#  '잔뜩',
#  '밴',
#  '',
#  '국물게티',
#  '와',
#  '매콤달콤한',
#  '',
#  '레드마블치킨',
#  '이',
#  '그',
#  '주인공입니다',
#  '국물게티는',
#  '로제맛',
#  '',
#  '매콤맛',
#  '두',
#  '가지로',
#  '취향에',
#  '맞게',
#  '즐길',
#  '수',
#  '있는데요',
#  '',
#  '깊고',
#  '진한맛의',
#  '특제',
#  '떡볶이',
#  '소스가',
#  '스파게티면에',
#  '잔뜩',
#  '들러',
#  '붙어',
#  '입안에',
#  '풍미가',
#  '가득한데',
#  '',
#  '바삭한',
#  '치킨과',
#  '함께',
#  '즐기기',
#  '좋아요',
#  '이번',
#  '네네치킨',
#  '신상',
#  '',
#  '국물게티',
#  '와',
#  '',
#  '레드마블치킨',
#  '',
#  '세트를',
#  '쿠캣',
#  '신상마켓에서',
#  '40',
#  '',
#  '할인된',
#  '가격으로',
#  '먼저',
#  '만나보세요',
#  '',
#  '',
#  '쿠캣',
#  '신상마켓',
#  '보러가기',
#  'cookat',
#  'magazine',
#  '프로필링크',
#  '',
#  '',
#  '네네치킨',
#  '',
#  '네네치킨신상',
#  '',
#  '신상마켓',
#  '',
#  '쿠캣신상마켓',
#  '',
#  '국물게티',
#  '',
#  '로제게티',
#  '',
#  '매콤게티',
#  '',
#  '레드마블치킨',
#  '',
#  '레드마블',
#  '',
#  '치킨',
#  '',
#  '치킨추천',
#  '',
#  '스파게티',
#  '',
#  '파스타',
#  '',
#  '홈술',
#  '',
#  '분식',
#  '',
#  '야식',
#  '',
#  '저메추',
#  '',
#  '쿠캣',
#  '',
#  '쿠캣마켓',
#  '',
#  '신상리뷰',
#  '',
#  '쿠캣매거진',
#  '',
#  '쿠캣디',
#  '',
#  'pasta',
#  '',
#  'spaghetti',
#  '',
#  'chick',
#  '이도',
#  '폭풍흡입하는',
#  '',
#  '',
#  '고추바사삭',
#  '',
#  '',
#  '볼케이노',
#  '',
#  '',
#  '오늘은',
#  '굽네치킨입니다',
#  '',
#  '',
#  '',
#  '배달',
#  '',
#  '굽네치킨제',
#  '최애치킨인',
#  '굽네치킨',
#  '고추바사삭은',
#  '왜',
#  '매일',
#  '땡기는거죠',
#  '더',
#  '매운게',
#  '땡길땐',
#  '볼케이노와',
#  '함께',
#  '행복한',
#  '고민에',
#  '빠집니다',
#  '',
#  '그렇다고',
#  '반반시키기엔',
#  '튀김옷이',
#  '없는',
#  '굽네',
#  '특성상',
#  '양이',
#  '적다',
#  '',
#  '괜찮아요',
#  '한마리',
#  '',
#  '',
#  '한마리',
#  '세트가',
#  '있으니까요총',
#  '두마리가',
#  '오는',
#  '세트',
#  '구성이라니요',
#  '이',
#  '구성',
#  '매우',
#  '칭찬합니다',
#  '',
#  '볼케이노는',
#  '치밥으로',
#  '유명하죠',
#  '',
#  '볼케이노',
#  '시키면',
#  '마그마소스는',
#  '항상',
#  '따로',
#  '주는데',
#  '이거',
#  '진짜',
#  '맘에',
#  '들더라구요너무',
#  '맵지도',
#  '않고',
#  '맵찔이들도',
#  '충분히',
#  '맛있게',
#  '먹을',
#  '수',
#  '있어요',
#  '',
#  '고추바사삭은',
#  '고블링',
#  '마블링',
#  '소스가',
#  '진짜',
#  '존맛탱',
#  '',
#  'ㅠㅠㅠㅠㅠ오늘',
#  '저녁',
#  '치맥은',
#  '굽네치킨으로',
#  '해야겠어요',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '굽네치킨',
#  '치',
#  '치',
#  '세트',
#  '',
#  '32',
#  '000',
#  '',
#  '우뉴_배달',
#  '배달음식',
#  '',
#  '배달맛집',
#  '',
#  '고추바사삭',
#  '',
#  '볼케이노',
#  '',
#  '굽네치킨',
#  '치킨은',
#  '절대',
#  '못참지',
#  '',
#  '',
#  '치즈소스도',
#  '못참지',
#  '',
#  '',
#  '',
#  '',
#  '훌랄라치킨',
#  '',
#  '훌랄라참숯바베큐치킨',
#  '',
#  '광고',
#  '제가',
#  '참숯치킨',
#  '참',
#  '좋아하는데요',
#  '',
#  '',
#  '치킨은',
#  '역시',
#  '훌랄라',
#  '훌랄라는',
#  '참숯향이',
#  '아주',
#  '일품인',
#  '촉촉한',
#  '치킨이에요',
#  '오븐에',
#  '촉촉하게',
#  '구워내어',
#  '참숯에서',
#  '한번',
#  '더',
#  '구워주시는',
#  '',
#  '맛있는',
#  '양념옷을',
#  '입고',
#  '탄생하는',
#  '존맛',
#  '치킨',
#  '양념된',
#  '치킨구이에',
#  '치즈소스가',
#  '뿌려진다면',
#  '',
#  '',
#  '이건',
#  '완전',
#  '꿀조합이라',
#  '안먹어봐도',
#  '맛있쥬',
#  '',
#  '약간',
#  '매콤한',
#  '양념에',
#  '치즈가',
#  '더해져',
#  '짝을',
#  '제대로',
#  '만났어용',
#  '치즈볼과',
#  '라면사리까지',
#  '추가해주시면',
#  '탄단지',
#  '제대로ㅋㅋㅋ라면사리',
#  '추가하면',
#  '소스에',
#  '같이',
#  '비벼져',
#  '나오는데',
#  '엄지척',
#  '',
#  '치킨이랑',
#  '같이',
#  '먹으면',
#  '그렇게',
#  '맛있을수가',
#  '없네요ㅠㅠ앞으로',
#  '치킨은',
#  '여기로',
#  '정착합니닷',
#  '',
#  '',
#  '',
#  '',
#  '1월',
#  '배달의',
#  '민족',
#  '매주',
#  '수요일',
#  '3',
#  '000원',
#  '할인',
#  '',
#  '배달의',
#  '민족',
#  '1월',
#  '23',
#  '29일',
#  '포장',
#  '기획전',
#  '3',
#  '500원',
#  '할인',
#  '',
#  '요기요',
#  '1월',
#  '매일',
#  '신메뉴',
#  '3종',
#  '3',
#  '000원',
#  '할인중',
#  '훌랄라치킨',
#  '',
#  '안산맛집',
#  '인천맛집',
#  '치킨맛집',
#  '숯불치킨',
#  '숯불바베큐',
#  '서산맛집',
#  '',
#  '대전맛집',
#  '',
#  '동탄맛집',
#  '',
#  '대구맛집',
#  '',
#  '파주맛집',
#  '',
#  '서울맛집',
#  '',
#  '경기도맛집',
#  '',
#  '치킨',
#  '',
#  '양념치킨',
#  '',
#  'foodporn',
#  '',
#  'foodpi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '하하호호오늘',
#  '넘',
#  '많이',
#  '웃었다',
#  '대화가',
#  '되는',
#  '나이가',
#  '됐군',
#  '',
#  '',
#  '좀',
#  '천천히',
#  '커주라',
#  '',
#  '',
#  '',
#  '햄버거셔틀',
#  '',
#  '',
#  '상전아들',
#  '바쁜',
#  '남편대신',
#  '예약했더니호텔인줄',
#  '알고',
#  '왔는데콘도였어',
#  '',
#  '',
#  '하',
#  '',
#  '',
#  '어쩔수',
#  '없지하고',
#  '들어왔는데생각보다',
#  '뷰도',
#  '좋고',
#  '넓직하고리모델링해서',
#  '깔끔하다',
#  '',
#  '',
#  '싄나싄나',
#  '',
#  '',
#  '춤추고난리',
#  'ㅎㅎㅎㅎ',
#  '야식',
#  '',
#  '치킨',
#  '모시러갔다',
#  '맨발의청춘',
#  '',
#  '영하14도',
#  '',
#  '뛰고뛰고또뛰고',
#  '',
#  '추워도좋아',
#  '',
#  '눈이좋아',
#  '감사',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '휘닉스',
#  '그램',
#  '',
#  '',
#  '',
#  'dangchiddaeng',
#  'official',
#  'by',
#  '',
#  'get_regrammer',
#  'EVENT',
#  '당치땡',
#  '행운의부적',
#  '인증샷',
#  '이벤트',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '당치땡이',
#  '준비한',
#  '행운의',
#  '부적과',
#  '함께하는여러분의',
#  '일상을',
#  '공유해주세요',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '추첨을',
#  '통해',
#  ...]

# %%
Content_count = Counter(Content)
Content_count
# Out:
# Counter({'해': 16,
#          '대신': 14,
#          '올해는': 7,
#          '': 38969,
#          '동근': 1,
#          '해가': 1,
#          '떴습니다': 1,
#          '우동사리에': 1,
#          '치밥까지': 1,
#          '치킨으로': 13,
#          '풀코스': 1,
#          '즐기는': 7,
#          '법': 6,
#          'JPG바베큐치킨': 1,
#          '먹을': 62,
#          '때': 17,
#          '됐으면': 1,
#          '동근이숯불두마리치킨': 4,
#          '입안가득': 2,
#          '숯불구이향': 1,
#          '야들촉촉': 1,
#          '식감으로': 1,
#          '꽉찼어요': 1,
#          '동근이표': 1,
#          '독보적인': 1,
#          '양념엔': 1,
#          '우동사리': 6,
#          '치밥은': 2,
#          '무조건임': 1,
#          '소금구이는': 2,
#          '담백하니': 2,
#          '살': 14,
#          '안찌는거': 1,
#          '아시죠': 7,
#          '꽤나': 5,
#          '뻔뻔': 1,
#          '꼬': 1,
#          '소한': 1,
#          '치즈스틱과': 2,
#          '치즈볼은': 5,
#          '정신차리고보니': 1,
#          '추가함': 1,
#          '동상이몽': 2,
#          '요리대첩에': 2,
#          '나온': 8,
#          '그': 49,
#          '치킨': 1885,
#          '드디어': 14,
#          '먹어봤어요한마리는': 1,
#          '살짝': 22,
#          '서운한데': 1,
#          '가성비': 11,
#          '두마리치킨이라': 1,
#          '좋고': 9,
#          '바베큐만': 1,
#          '아니라': 9,
#          '튀긴치킨도': 1,
#          '있어서': 41,
#          '싸울일은': 1,
#          '없어요요즘': 1,
#          '세상에': 6,
#          '배달비': 3,
#          '없는곳이': 1,
#          '있다구요': 2,
#          '청주복대점배달구역': 1,
#          '전부무료': 2,
#          '가경': 2,
#          '강서': 2,
#          '개신': 2,
#          '죽림': 2,
#          '산남': 2,
#          '수곡': 2,
#          '청주복대점': 4,
#          'donggeun2_official': 2,
#          '숯불양념': 2,
#          '소금세트': 1,
#          '26': 6,
#          '900': 8,
#          '치즈볼': 21,
#          '3': 84,
#          '000': 19,
#          '치즈스틱': 5,
#          '치킨맛집': 266,
#          '배달치킨': 8,
#          '배달맛집': 59,
#          '숯불바베큐': 11,
#          '치킨추천': 137,
#          '복대동맛집': 3,
#          '청주맛집': 8,
#          '청주배달': 1,
#          '찬': 14,
#          '떡볶이에': 5,
#          '타피오카': 3,
#          '펄': 2,
#          '쏟은': 1,
#          '줄': 24,
#          '알았다': 3,
#          '버블티같은': 1,
#          '떡볶이다': 1,
#          '맥주를': 9,
#          '부르는': 1,
#          '맛이다': 6,
#          '치킨매니아': 9,
#          '한국식': 1,
#          '버블티다': 1,
#          '치킨이랑': 9,
#          '떡볶이의': 2,
#          '조합이': 6,
#          '이렇게': 29,
#          '좋은': 48,
#          '처음': 19,
#          '동글동글한': 1,
#          '구슬떡볶이라': 1,
#          '숟가락으로': 4,
#          '퍼먹기': 1,
#          '딱': 47,
#          '좋다': 12,
#          '소스도': 6,
#          '진짜': 92,
#          '꾸덕하고': 3,
#          '진하다': 1,
#          '왕새우치킨은': 3,
#          '이름값': 2,
#          '제대로': 14,
#          '한다': 14,
#          '블랙타이거만한': 1,
#          '새우가': 3,
#          '바삭하게': 3,
#          '튀겨졌다': 1,
#          '치킨도': 17,
#          '먹고': 93,
#          '새우튀김도': 1,
#          '일석이조다': 1,
#          '푸드갱_배달': 1,
#          '떡볶이맛집': 13,
#          '배달음식추천': 8,
#          '야식추천': 31,
#          '치맥': 251,
#          '사료': 2,
#          '일지': 1,
#          '506': 1,
#          '지코바': 17,
#          '성정점뿡빵쓰가': 1,
#          '스트레스': 12,
#          '받으면': 1,
#          '주기적': 1,
#          '수혈하는': 1,
#          '3대장': 1,
#          '1': 173,
#          '신라면생라면': 1,
#          '맥주': 164,
#          '2': 101,
#          '엽떡': 11,
#          '그리고': 48,
#          '양념순살': 2,
#          '매운맛': 13,
#          '저도': 12,
#          '모르게': 1,
#          '이': 84,
#          '메뉴들을': 1,
#          '찾고': 14,
#          '있으면': 6,
#          '받거나': 1,
#          '힐링하고': 1,
#          '싶을때': 2,
#          '더라구요': 1,
#          '음식': 83,
#          '후후하하': 1,
#          '먹어주다보면': 1,
#          '자연스럽게': 3,
#          '행복감으로': 1,
#          '바뀌니깐': 1,
#          '간단하게': 5,
#          '기분': 8,
#          '좋아지고': 1,
#          '싶을때는': 1,
#          '꼬옥': 2,
#          '찾게': 1,
#          '되네요': 2,
#          '지코바는': 3,
#          '무조건': 17,
#          '떡사리': 4,
#          '추가해서': 6,
#          '드시고': 8,
#          '순살': 25,
#          '닭다리살로만': 3,
#          '되어있어서': 1,
#          '핵': 1,
#          '맛': 70,
#          '로': 20,
#          '시키셔야하고': 1,
#          '확': 3,
#          '풀리게': 1,
#          '혹은': 3,
#          '술안주로': 2,
#          '드시고싶다': 1,
#          '그럼': 10,
#          '고고': 3,
#          '하세요': 14,
#          '후회': 14,
#          '안하실껍니다': 1,
#          '진쟈루': 1,
#          '저희': 20,
#          '어머니가': 2,
#          '주먹밥': 5,
#          '장인이신데': 1,
#          '참기름이랑': 1,
#          '김': 6,
#          '낭낭하게': 2,
#          '뿌셔서': 1,
#          '만든': 18,
#          '주먹밥에': 1,
#          '소스': 30,
#          '푸욱': 4,
#          '찍어서': 2,
#          '먹으면': 41,
#          '이맛은': 1,
#          '찐행복이예요': 1,
#          '오늘도': 35,
#          '월요팅': 4,
#          '잘': 104,
#          '하셨나요': 2,
#          '날이': 12,
#          '또': 72,
#          '갑자기': 9,
#          '추워졌네요': 1,
#          '저는': 29,
#          '감기가': 1,
#          '올라고': 1,
#          '하는데': 9,
#          '여러분들은': 2,
#          '감기': 7,
#          '조심하세요': 4,
#          '양념': 41,
#          '20000원': 1,
#          '서': 6,
#          '나': 25,
#          '맛있었으면': 1,
#          '포장까지ㄷㄷㄷ': 1,
#          '범맥주': 3,
#          '노랑통닭ㆍㆍㆍ': 1,
#          '대구맛집': 22,
#          '먹방': 224,
#          'instafood': 30,
#          '요리스타그램': 28,
#          '요리': 47,
#          '맛스타그램': 292,
#          '먹스타그램': 378,
#          '선팔': 74,
#          '맞팔': 178,
#          '선팔하면맞팔': 64,
#          '선팔해요': 1,
#          'followforfollow': 1,
#          '맞팔해요': 22,
#          '팔로우': 112,
#          '팔로잉': 4,
#          '팔로미': 4,
#          '팔로워': 19,
#          '데일리': 95,
#          '팔로우미': 5,
#          '소통': 126,
#          '소통해요': 14,
#          '셀피': 13,
#          '카페스타그램': 3,
#          '댓글': 19,
#          'follow4like': 1,
#          '좋아요반사': 90,
#          '좋아요': 259,
#          'like4li': 1,
#          '협찬': 7,
#          '소떡소떡': 6,
#          '밀어내고': 1,
#          '이제는': 2,
#          '치떡': 5,
#          '시대야식': 1,
#          '하면': 30,
#          '가장': 29,
#          '먼저': 11,
#          '생각나는': 12,
#          '치킨과': 42,
#          '떡볶이가만났다구요': 1,
#          '이건': 5,
#          '도대체': 2,
#          '안먹을수가': 1,
#          '없는': 37,
#          '조합이에여': 1,
#          '_': 17,
#          '부산시장': 2,
#          '스타일의': 2,
#          '감칠맛': 2,
#          '가득한': 13,
#          '소스에동글동글한': 1,
#          '구슬떡': 2,
#          '치킨을': 48,
#          '소스에': 21,
#          '찍어먹어도': 1,
#          '맛있고': 16,
#          '그냥': 33,
#          '떡만': 1,
#          '퍼먹어도': 1,
#          '세상': 9,
#          '행복': 11,
#          '바삭바삭한': 2,
#          '튀김옷': 4,
#          '안에': 6,
#          '탱글한': 1,
#          '누가': 3,
#          '먹어도': 24,
#          '좋아할': 4,
#          '맛과': 9,
#          '식감이에여': 1,
#          '떡볶이추천': 4,
#          '배달': 58,
#          '신상': 8,
#          '국물게티X레드마블': 1,
#          '네네치킨에서': 3,
#          '신메뉴를': 1,
#          '선보입니다': 1,
#          '넉넉한': 3,
#          '국물에': 2,
#          '떡볶이': 93,
#          '양념이': 7,
#          '잔뜩': 8,
#          '밴': 2,
#          '국물게티': 9,
#          '와': 30,
#          '매콤달콤한': 5,
#          '레드마블치킨': 5,
#          '주인공입니다': 1,
#          '국물게티는': 1,
#          '로제맛': 1,
#          '매콤맛': 1,
#          '두': 6,
#          '가지로': 1,
#          '취향에': 2,
#          '맞게': 3,
#          '즐길': 16,
#          '수': 273,
#          '있는데요': 4,
#          '깊고': 1,
#          '진한맛의': 1,
#          '특제': 6,
#          '소스가': 11,
#          '스파게티면에': 1,
#          '들러': 3,
#          '붙어': 2,
#          '입안에': 3,
#          '풍미가': 2,
#          '가득한데': 1,
#          '바삭한': 17,
#          '함께': 152,
#          '즐기기': 2,
#          '이번': 10,
#          '네네치킨': 35,
#          '세트를': 1,
#          '쿠캣': 4,
#          '신상마켓에서': 1,
#          '40': 4,
#          '할인된': 1,
#          '가격으로': 5,
#          '만나보세요': 7,
#          '신상마켓': 2,
#          '보러가기': 7,
#          'cookat': 1,
#          'magazine': 1,
#          '프로필링크': 9,
#          '네네치킨신상': 2,
#          '쿠캣신상마켓': 1,
#          '로제게티': 14,
#          '매콤게티': 5,
#          '레드마블': 5,
#          '스파게티': 8,
#          '파스타': 40,
#          '홈술': 9,
#          '분식': 14,
#          '야식': 126,
#          '저메추': 8,
#          '쿠캣마켓': 1,
#          '신상리뷰': 2,
#          '쿠캣매거진': 1,
#          '쿠캣디': 1,
#          'pasta': 2,
#          'spaghetti': 1,
#          'chick': 14,
#          '이도': 1,
#          '폭풍흡입하는': 1,
#          '고추바사삭': 12,
#          '볼케이노': 6,
#          '오늘은': 37,
#          '굽네치킨입니다': 1,
#          '굽네치킨제': 1,
#          '최애치킨인': 1,
#          '굽네치킨': 21,
#          '고추바사삭은': 2,
#          '왜': 27,
#          '매일': 26,
#          '땡기는거죠': 1,
#          '더': 131,
#          '매운게': 1,
#          '땡길땐': 2,
#          '볼케이노와': 1,
#          '행복한': 20,
#          '고민에': 1,
#          '빠집니다': 1,
#          '그렇다고': 3,
#          '반반시키기엔': 1,
#          '튀김옷이': 6,
#          '굽네': 9,
#          '특성상': 1,
#          '양이': 16,
#          '적다': 2,
#          '괜찮아요': 1,
#          '한마리': 18,
#          '세트가': 2,
#          '있으니까요총': 1,
#          '두마리가': 1,
#          '오는': 11,
#          '세트': 22,
#          '구성이라니요': 1,
#          '구성': 1,
#          '매우': 10,
#          '칭찬합니다': 1,
#          '볼케이노는': 1,
#          '치밥으로': 6,
#          '유명하죠': 2,
#          '시키면': 4,
#          '마그마소스는': 1,
#          '항상': 28,
#          '따로': 6,
#          '주는데': 2,
#          '이거': 11,
#          '맘에': 3,
#          '들더라구요너무': 1,
#          '맵지도': 3,
#          '않고': 19,
#          '맵찔이들도': 1,
#          '충분히': 2,
#          '맛있게': 48,
#          '있어요': 32,
#          '고블링': 1,
#          '마블링': 1,
#          '존맛탱': 52,
#          'ㅠㅠㅠㅠㅠ오늘': 1,
#          '저녁': 97,
#          '치맥은': 2,
#          '굽네치킨으로': 1,
#          '해야겠어요': 2,
#          '치': 19,
#          '32': 1,
#          '우뉴_배달': 1,
#          '배달음식': 42,
#          '치킨은': 49,
#          '절대': 21,
#          '못참지': 7,
#          '치즈소스도': 1,
#          '훌랄라치킨': 4,
#          '훌랄라참숯바베큐치킨': 2,
#          '광고': 5,
#          '제가': 18,
#          '참숯치킨': 1,
#          '참': 13,
#          '좋아하는데요': 1,
#          '역시': 53,
#          '훌랄라': 3,
#          '훌랄라는': 1,
#          '참숯향이': 1,
#          '아주': 29,
#          '일품인': 1,
#          '촉촉한': 14,
#          '치킨이에요': 6,
#          '오븐에': 20,
#          '촉촉하게': 7,
#          '구워내어': 1,
#          '참숯에서': 1,
#          '한번': 31,
#          '구워주시는': 1,
#          '맛있는': 102,
#          '양념옷을': 1,
#          '입고': 2,
#          '탄생하는': 1,
#          '존맛': 35,
#          '양념된': 1,
#          '치킨구이에': 1,
#          '치즈소스가': 1,
#          '뿌려진다면': 1,
#          '완전': 50,
#          '꿀조합이라': 1,
#          '안먹어봐도': 1,
#          '맛있쥬': 1,
#          '약간': 10,
#          '매콤한': 28,
#          '양념에': 4,
#          '치즈가': 6,
#          '더해져': 4,
#          '짝을': 1,
#          '만났어용': 1,
#          '치즈볼과': 1,
#          '라면사리까지': 2,
#          '추가해주시면': 1,
#          '탄단지': 1,
#          '제대로ㅋㅋㅋ라면사리': 1,
#          '추가하면': 2,
#          '같이': 75,
#          '비벼져': 1,
#          '나오는데': 4,
#          '엄지척': 2,
#          '그렇게': 16,
#          '맛있을수가': 1,
#          '없네요ㅠㅠ앞으로': 1,
#          '여기로': 3,
#          '정착합니닷': 1,
#          '1월': 100,
#          '배달의': 15,
#          '민족': 8,
#          '매주': 16,
#          '수요일': 14,
#          '000원': 46,
#          '할인': 51,
#          '23': 56,
#          '29일': 2,
#          '포장': 27,
#          '기획전': 3,
#          '500원': 9,
#          '요기요': 26,
#          '신메뉴': 35,
#          '3종': 13,
#          '할인중': 4,
#          '안산맛집': 4,
#          '인천맛집': 7,
#          '숯불치킨': 26,
#          '서산맛집': 3,
#          '대전맛집': 5,
#          '동탄맛집': 3,
#          '파주맛집': 2,
#          '서울맛집': 37,
#          '경기도맛집': 2,
#          '양념치킨': 67,
#          'foodporn': 25,
#          'foodpi': 3,
#          '하하호호오늘': 1,
#          '넘': 39,
#          '많이': 80,
#          '웃었다': 1,
#          '대화가': 1,
#          '되는': 12,
#          '나이가': 2,
#          '됐군': 1,
#          '좀': 41,
#          '천천히': 1,
#          '커주라': 1,
#          '햄버거셔틀': 1,
#          '상전아들': 1,
#          '바쁜': 5,
#          '남편대신': 1,
#          '예약했더니호텔인줄': 1,
#          '알고': 9,
#          '왔는데콘도였어': 1,
#          '하': 4,
#          '어쩔수': 3,
#          '없지하고': 1,
#          '들어왔는데생각보다': 1,
#          '뷰도': 2,
#          '넓직하고리모델링해서': 1,
#          '깔끔하다': 1,
#          '싄나싄나': 1,
#          '춤추고난리': 1,
#          'ㅎㅎㅎㅎ': 3,
#          '모시러갔다': 1,
#          '맨발의청춘': 1,
#          '영하14도': 1,
#          '뛰고뛰고또뛰고': 1,
#          '추워도좋아': 1,
#          '눈이좋아': 1,
#          '감사': 8,
#          '휘닉스': 1,
#          '그램': 15,
#          'dangchiddaeng': 3,
#          'official': 32,
#          'by': 19,
#          'get_regrammer': 11,
#          'EVENT': 35,
#          '당치땡': 25,
#          '행운의부적': 2,
#          '인증샷': 4,
#          '이벤트': 169,
#          '당치땡이': 1,
#          '준비한': 2,
#          '행운의': 8,
#          '부적과': 2,
#          '함께하는여러분의': 1,
#          '일상을': 1,
#          '공유해주세요': 2,
#          '추첨을': 12,
#          '통해': 30,
#          '교환권을': 1,
#          '드립니다': 32,
#          '참여': 41,
#          '방법①': 4,
#          '당치땡을': 1,
#          '주문하고': 7,
#          '부적': 2,
#          '을': 32,
#          '받는다②': 1,
#          '찍은': 2,
#          '사진을': 3,
#          '인스타그램': 39,
#          '피드': 9,
#          '또는': 11,
#          '스토리에': 2,
#          '올린다': 1,
#          '필수': 33,
#          '계정태그': 1,
#          '해시태그': 3,
#          '부적인증샷': 1,
#          '당치땡부적': 2,
#          'TIP': 1,
#          '게시물': 18,
#          '시': 32,
#          '당첨': 50,
#          '확률': 26,
#          'UP': 36,
#          '응모': 7,
#          '기간2023': 3,
#          '01': 60,
#          '05': 1,
#          '31': 3,
#          '화': 22,
#          '당첨자': 39,
#          '발표2023': 2,
#          '02': 16,
#          '06': 7,
#          '월': 37,
#          '경품당치땡': 1,
#          '2만원권': 1,
#          '10명': 7,
#          '주의사항': 1,
#          '공식': 8,
#          '계정을': 2,
#          '꼭': 58,
#          '태그해주세요': 4,
#          '주문': 22,
#          '랜덤': 4,
#          '제공': 1,
#          '여부': 1,
#          '및': 105,
#          '수령': 6,
#          '조건을': 1,
#          '확인해주세요': 3,
#          '부적은': 1,
#          '지점별': 1,
#          '선착순': 6,
#          '제공되어': 1,
#          '조기': 3,
#          '소진될': 1,
#          '있습니다': 62,
#          '비공개': 4,
#          '계정일': 1,
#          '경우': 2,
#          '확인이': 3,
#          '어려워': 1,
#          '대상에서': 1,
#          '제외될': 1,
#          '당신은지금치킨이땡긴다': 5,
#          '신년부적': 1,
#          '새해부적': 1,
#          '인증샷이': 1,
#          'de': 9,
#          'Fried': 8,
#          'Chicken': 29,
#          'rice': 7,
#          'again': 1,
#          'after': 2,
#          'almost': 1,
#          'years': 1,
#          'This': 6,
#          'time': 2,
#          'I': 15,
#          'used': 1,
#          'Korean': 15,
#          'the': 36,
#          'real': 1,
#          'KFC': 8,
#          'Also': 2,
#          'had': 5,
#          'some': 1,
#          'kimchi': 8,
#          'and': 32,
#          'miso': 1,
#          'soup': 1,
#          'with': 21,
#          'clams': 1,
#          'mushrooms': 2,
#          'on': 7,
#          'side': 2,
#          'koreanfriedchicken': 9,
#          'friedchicken': 23,
#          'chikin': 2,
#          'huraideuchikin': 1,
#          '후라이드치킨': 58,
#          'chickenrice': 1,
#          'riceislife': 1,
#          'misosoup': 1,
#          'sunday': 2,
#          'lunch': 12,
#          'weekend': 5,
#          'foodstagr': 7,
#          '22': 39,
#          '10': 16,
#          '16저녁': 1,
#          'Noodles': 1,
#          'Fishballs': 1,
#          'Meatballs': 1,
#          'in': 16,
#          'Soup': 4,
#          '梁家家常菜________________________': 2,
#          'dinner': 16,
#          'dadscooking': 2,
#          'noodles': 1,
#          'fishball': 1,
#          'meatballs': 1,
#          'chickenwings': 6,
#          'chicken': 125,
#          'homemade': 4,
#          'jmt': 54,
#          'yummy': 20,
#          'lifestyle': 2,
#          'daily': 82,
#          '집밥': 66,
#          '국수': 5,
#          '미트볼': 3,
#          '고기': 18,
#          '홈메이드': 7,
#          '홈쿡': 33,
#          '냠냠': 45,
#          '맛있다': 81,
#          '라이프스타일': 2,
#          '일상': 231,
#          '데': 4,
#          '킨': 40,
#          '아이들': 8,
#          '방학집에서': 1,
#          '만들어서': 9,
#          '먹으니': 6,
#          '아들이': 3,
#          '맛있다고': 4,
#          '하네요': 1,
#          '터치': 4,
#          '맛있당': 6,
#          '맘스터치치킨': 4,
#          '맘스터치': 14,
#          '간장마늘치킨': 1,
#          '블로거': 1,
#          '20대남자': 1,
#          '데이': 3,
#          '크': 2,
#          '맛집': 345,
#          '신혼부부': 8,
#          '신혼': 1,
#          '부부': 7,
#          '부부스타그램': 6,
#          '신혼부부밥상': 2,
#          '신혼부부그램': 1,
#          '크크크치킨': 9,
#          '60계치킨': 18,
#          '갓집양념치킨': 1,
#          '라면': 19,
#          '유부초밥': 2,
#          '초밥': 20,
#          'sushi': 1,
#          '물회': 1,
#          '회덮밥': 1,
#          '딸기': 11,
#          '치즈돈가스': 1,
#          '디저트': 22,
#          '카페': 48,
#          'cafe': 1,
#          'food': 115,
#          'foodie': 34,
#          'koreanfood': 44,
#          '북런던': 1,
#          '더비': 1,
#          '완승': 1,
#          '런던은': 1,
#          '레드랍니다': 1,
#          '너무': 150,
#          '편해서': 1,
#          '우리홈인줄': 1,
#          '알았지': 2,
#          '모야': 2,
#          '북런던더비': 1,
#          '아스날': 1,
#          '토트넘': 1,
#          'coyg': 1,
#          'comeonyougunners': 1,
#          'northlondonisr': 1,
#          '식사진들': 1,
#          '광어우럭회': 1,
#          '낙곱새': 2,
#          '바스크치즈케이크': 1,
#          '타코타치즈샐러드': 1,
#          '성공적인': 10,
#          '사업의': 10,
#          '서포터가': 10,
#          '되어': 11,
#          '소규모': 10,
#          '외식업': 20,
#          '창업': 27,
#          '아이템': 10,
#          '선정': 10,
#          '기획': 20,
#          '점포개발': 10,
#          '메뉴개발': 30,
#          '교육': 30,
#          '운영': 21,
#          '등': 32,
#          '신규': 31,
#          '브랜드': 43,
#          '론칭': 20,
#          '외식': 17,
#          '전분야': 10,
#          '사업': 13,
#          '타당성': 10,
#          '분석': 11,
#          '컨셉': 10,
#          '본사': 12,
#          '수익률': 10,
#          '디자인': 10,
#          '인테리어': 16,
#          '컵셉': 10,
#          '개발': 51,
#          '매뉴얼': 20,
#          '상권분석': 10,
#          '가맹사업': 10,
#          '진행': 27,
#          '사후관리': 20,
#          '메뉴': 95,
#          '개인': 13,
#          '기업': 10,
#          '매뉴': 20,
#          '리뉴얼': 14,
#          '4': 24,
#          '각종': 40,
#          '인허가': 10,
#          'HACCP': 10,
#          '식품': 10,
#          '제조': 10,
#          '허가': 10,
#          '문의': 27,
#          '인스타': 33,
#          'DM': 22,
#          '이메일': 11,
#          'yeol1221': 10,
#          'nate': 10,
#          'com': 24,
#          '카카오톡': 12,
#          'baristasoo10': 10,
#          '소규모창업': 10,
#          '커피': 29,
#          '베이커리': 11,
#          '샌드위치': 24,
#          '브런치': 19,
#          '햅썹인증': 10,
#          '식품제조허가': 10,
#          '신규브랜드': 10,
#          '사업타당성': 10,
#          '메뉴엔지니어링': 10,
#          '메뉴원가': 10,
#          '손익시물레이션': 3,
#          '샐러드': 49,
#          '밀키트': 14,
#          'HMR': 10,
#          '상권조사개발': 10,
#          '개인매장': 10,
#          '아이템개발': 10,
#          '2023년': 47,
#          '손익시물레이셤': 7,
#          '잇식단': 1,
#          '제품제공': 2,
#          '열어분': 1,
#          '불금에만': 1,
#          '먹는다는': 2,
#          '그런': 4,
#          '고정관념을': 1,
#          '버리세요': 1,
#          'ㅎr': 1,
#          '월요병': 6,
#          '치유에': 1,
#          '탁월한': 1,
#          '선택': 5,
#          '그것은': 1,
#          '바로': 55,
#          'godchicken': 1,
#          'market': 1,
#          '갓치킨': 1,
#          '의': 31,
#          '골든치킨윙': 1,
#          '되시겠습니다': 1,
#          '얼마전에': 1,
#          '당첨으로': 1,
#          '받았는데': 2,
#          'ㅋㅋㅋ먹으려고': 1,
#          '벼르고': 1,
#          '있었거든요': 1,
#          '냉동실': 1,
#          '문': 5,
#          '열': 3,
#          '때마다': 3,
#          '마주쳐서': 1,
#          '월요일이라': 2,
#          '킹받는': 1,
#          '맴': 1,
#          '달래는거': 1,
#          '참으로': 2,
#          '나쁘지': 4,
#          '않구여': 1,
#          '1단도': 1,
#          '아니고': 10,
#          '2단으로': 1,
#          '쫘악': 1,
#          '쌓아': 1,
#          '올려서': 3,
#          '알차게': 10,
#          '먹었어요': 12,
#          '에프굽': 1,
#          '15분': 1,
#          '후': 45,
#          '천국문이': 1,
#          '열릴지니': 1,
#          '무교임': 1,
#          '흡': 1,
#          'ㅠ': 7,
#          'ㅠ뽀얀': 1,
#          '속살을': 1,
#          '흡입하며': 1,
#          '뼈': 10,
#          '발골쇼': 1,
#          '했어욬ㅋㅋㅋㅋㅋㅋ증맬증맬루': 1,
#          '행복했댜': 1,
#          '양심상': 1,
#          '샐러드도': 1,
#          '먹었으니까': 1,
#          '0칼로리': 2,
#          '이제': 23,
#          '안시켜먹어도': 1,
#          '되겠다눙': 1,
#          '갓치킨의': 1,
#          '갓': 6,
#          '은': 54,
#          '닭고기계의': 1,
#          '갓이라서': 1,
#          '갓인건가요': 1,
#          '암튼': 4,
#          '드셔봐여': 1,
#          'ㅠㅠ': 25,
#          '행복해지니까': 1,
#          '린기남은': 1,
#          '다': 76,
#          '버렸는데이제': 1,
#          '안': 30,
#          '버려도': 1,
#          '되겠다치킨': 1,
#          '별로': 6,
#          '안좋아하는데': 1,
#          '이거땜': 1,
#          '자주': 15,
#          '시켜야할듯': 1,
#          '남은치킨요리': 1,
#          '10분컷요리': 1,
#          '집밥챌린지': 2,
#          '식단기록': 4,
#          '술안주': 38,
#          '오늘뭐먹지': 41,
#          '2인밥상': 1,
#          '먹': 15,
#          '일': 31,
#          '판매량': 2,
#          '중간정산': 1,
#          '비': 10,
#          '온': 8,
#          '뒤': 3,
#          '날씨가': 5,
#          '매섭게': 1,
#          '추워졌습니다': 1,
#          '건강이': 2,
#          '최고인거': 1,
#          '감기걸리지않게': 1,
#          '꼭꼭': 1,
#          '자연닭': 1,
#          '든든': 1,
#          '일주일': 3,
#          '판매': 16,
#          '총': 11,
#          '75': 2,
#          '5마리': 2,
#          '가': 26,
#          '팔렸습니다': 1,
#          '기부금액': 1,
#          '적립': 6,
#          '완료': 15,
#          '설연휴가': 1,
#          ...})

# %%
rank_text = Content_count.most_common()
rank_text
# Out:
# [('', 38969),
#  ('치킨', 1885),
#  ('먹스타그램', 378),
#  ('맛집', 345),
#  ('맛스타그램', 292),
#  ('수', 273),
#  ('치킨맛집', 266),
#  ('좋아요', 259),
#  ('치맥', 251),
#  ('일상', 231),
#  ('먹방', 224),
#  ('먹스타', 187),
#  ('맞팔', 178),
#  ('1', 173),
#  ('이벤트', 169),
#  ('맥주', 164),
#  ('함께', 152),
#  ('너무', 150),
#  ('있는', 143),
#  ('치킨스타그램', 138),
#  ('술스타그램', 138),
#  ('치킨추천', 137),
#  ('더', 131),
#  ('소통', 126),
#  ('야식', 126),
#  ('chicken', 125),
#  ('먹팔', 125),
#  ('food', 115),
#  ('주말', 113),
#  ('팔로우', 112),
#  ('및', 105),
#  ('쌈닭', 105),
#  ('잘', 104),
#  ('누구나홀딱반한닭', 104),
#  ('맛있는', 102),
#  ('불금', 102),
#  ('2', 101),
#  ('1월', 100),
#  ('저녁', 97),
#  ('데일리', 95),
#  ('메뉴', 95),
#  ('먹고', 93),
#  ('떡볶이', 93),
#  ('일상스타그램', 93),
#  ('진짜', 92),
#  ('좋아요반사', 90),
#  ('술', 90),
#  ('한', 88),
#  ('통닭', 88),
#  ('후라이드', 87),
#  ('치킨먹방', 85),
#  ('3', 84),
#  ('이', 84),
#  ('음식', 83),
#  ('daily', 82),
#  ('피자', 82),
#  ('데이트', 82),
#  ('맛있다', 81),
#  ('많이', 80),
#  ('부산', 80),
#  ('소주', 80),
#  ('신년회모임', 77),
#  ('다', 76),
#  ('같이', 75),
#  ('선팔', 74),
#  ('서울', 74),
#  ('또', 72),
#  ('맛', 70),
#  ('먹스타맞팔', 70),
#  ('좋반', 69),
#  ('새해', 68),
#  ('치느님', 68),
#  ('양념치킨', 67),
#  ('집밥', 66),
#  ('선팔하면맞팔', 64),
#  ('맛집추천', 64),
#  ('먹을', 62),
#  ('있습니다', 62),
#  ('삼겹살', 62),
#  ('교촌치킨', 62),
#  ('치킨먹는날', 62),
#  ('01', 60),
#  ('치킨맥주', 60),
#  ('배달맛집', 59),
#  ('배달', 58),
#  ('꼭', 58),
#  ('후라이드치킨', 58),
#  ('럽스타그램', 57),
#  ('23', 56),
#  ('금', 56),
#  ('치킨그램', 56),
#  ('바로', 55),
#  ('f4f', 55),
#  ('jmt', 54),
#  ('은', 54),
#  ('먹방스타그램', 54),
#  ('맛이', 54),
#  ('00', 54),
#  ('역시', 53),
#  ('닭', 53),
#  ('2023', 53),
#  ('존맛탱', 52),
#  ('맛집스타그램', 52),
#  ('맛스타', 52),
#  ('야식치킨', 52),
#  ('맥주전문점', 52),
#  ('치킨한마리', 52),
#  ('할인', 51),
#  ('개발', 51),
#  ('완전', 50),
#  ('당첨', 50),
#  ('신년파티', 50),
#  ('그', 49),
#  ('치킨은', 49),
#  ('샐러드', 49),
#  ('안주', 49),
#  ('좋은', 48),
#  ('그리고', 48),
#  ('치킨을', 48),
#  ('맛있게', 48),
#  ('카페', 48),
#  ('정말', 48),
#  ('신년회', 48),
#  ('딱', 47),
#  ('요리', 47),
#  ('2023년', 47),
#  ('다들', 47),
#  ('오랜만에', 47),
#  ('000원', 46),
#  ('다이어트', 46),
#  ('오늘', 46),
#  ('많은', 46),
#  ('소맥', 46),
#  ('냠냠', 45),
#  ('후', 45),
#  ('foodstagram', 45),
#  ('에', 45),
#  ('배달의민족', 45),
#  ('koreanfood', 44),
#  ('먹부림', 44),
#  ('맥주안주', 44),
#  ('브랜드', 43),
#  ('내', 43),
#  ('곱창', 43),
#  ('치킨치킨', 43),
#  ('치킨과', 42),
#  ('배달음식', 42),
#  ('팔', 42),
#  ('치킨이닭', 42),
#  ('중', 42),
#  ('치킨집', 42),
#  ('치킨파티', 42),
#  ('있어서', 41),
#  ('먹으면', 41),
#  ('양념', 41),
#  ('좀', 41),
#  ('참여', 41),
#  ('오늘뭐먹지', 41),
#  ('먹는', 41),
#  ('점심', 41),
#  ('bhc', 41),
#  ('파스타', 40),
#  ('킨', 40),
#  ('각종', 40),
#  ('것', 40),
#  ('전', 40),
#  ('넘', 39),
#  ('인스타그램', 39),
#  ('당첨자', 39),
#  ('22', 39),
#  ('치킨이', 39),
#  ('금요일', 39),
#  ('술안주', 38),
#  ('밥', 38),
#  ('없는', 37),
#  ('오늘은', 37),
#  ('서울맛집', 37),
#  ('월', 37),
#  ('좋아하는', 37),
#  ('푸드스타그램', 37),
#  ('생맥주', 37),
#  ('다양한', 37),
#  ('UP', 36),
#  ('the', 36),
#  ('하고', 36),
#  ('맛집탐방', 36),
#  ('BBQ', 36),
#  ('오늘도', 35),
#  ('네네치킨', 35),
#  ('존맛', 35),
#  ('신메뉴', 35),
#  ('EVENT', 35),
#  ('뿌링클', 35),
#  ('나는', 35),
#  ('cccv', 35),
#  ('바베큐', 35),
#  ('foodie', 34),
#  ('먹팔맞팔', 34),
#  ('0', 34),
#  ('오븐치킨', 34),
#  ('발표', 34),
#  ('상품', 34),
#  ('그냥', 33),
#  ('필수', 33),
#  ('홈쿡', 33),
#  ('인스타', 33),
#  ('남겨주세요', 33),
#  ('추천', 33),
#  ('시간', 33),
#  ('경품', 33),
#  ('있어요', 32),
#  ('official', 32),
#  ('드립니다', 32),
#  ('을', 32),
#  ('시', 32),
#  ('and', 32),
#  ('등', 32),
#  ('셀카', 32),
#  ('순살치킨', 32),
#  ('음식스타그램', 32),
#  ('치킨은사랑입니다', 32),
#  ('저녁메뉴', 32),
#  ('13', 32),
#  ('치킨메뉴추천', 32),
#  ('계묘년', 32),
#  ('그래서', 32),
#  ('야식추천', 31),
#  ('한번', 31),
#  ('신규', 31),
#  ('의', 31),
#  ('일', 31),
#  ('입니다', 31),
#  ('먹은', 31),
#  ('맛있다그램', 31),
#  ('부산맛집', 31),
#  ('모임', 31),
#  ('오븐치킨구이', 31),
#  ('기간', 31),
#  ('소스', 30),
#  ('instafood', 30),
#  ('하면', 30),
#  ('와', 30),
#  ('통해', 30),
#  ('메뉴개발', 30),
#  ('교육', 30),
#  ('안', 30),
#  ('먹팔해요', 30),
#  ('먹기', 30),
#  ('를', 30),
#  ('인친', 30),
#  ('5', 30),
#  ('예약', 30),
#  ('시그니처', 30),
#  ('신년회식', 30),
#  ('토요일', 30),
#  ('맛있는치킨', 30),
#  ('이렇게', 29),
#  ('저는', 29),
#  ('가장', 29),
#  ('아주', 29),
#  ('Chicken', 29),
#  ('커피', 29),
#  ('맛집투어', 29),
#  ('15', 29),
#  ('존맛탱구리', 29),
#  ('치쏘', 29),
#  ('간식', 29),
#  ('다이어트치킨', 29),
#  ('감자튀김', 29),
#  ('https', 29),
#  ('오븐구이', 29),
#  ('야식메뉴', 29),
#  ('요리스타그램', 28),
#  ('항상', 28),
#  ('매콤한', 28),
#  ('닭강정', 28),
#  ('조합', 28),
#  ('사진', 28),
#  ('チキン', 28),
#  ('하루', 28),
#  ('왜', 27),
#  ('포장', 27),
#  ('창업', 27),
#  ('진행', 27),
#  ('문의', 27),
#  ('요즘', 27),
#  ('엄청', 27),
#  ('댓글에', 27),
#  ('집에서', 27),
#  ('집', 27),
#  ('치킨은사랑', 27),
#  ('20', 27),
#  ('매일', 26),
#  ('요기요', 26),
#  ('숯불치킨', 26),
#  ('확률', 26),
#  ('가', 26),
#  ('맞팔환영', 26),
#  ('내가', 26),
#  ('ㅎㅎ', 26),
#  ('17', 26),
#  ('매장', 26),
#  ('ㅋㅋ', 26),
#  ('순살', 25),
#  ('나', 25),
#  ('foodporn', 25),
#  ('당치땡', 25),
#  ('ㅠㅠ', 25),
#  ('설날', 25),
#  ('과', 25),
#  ('20일', 25),
#  ('5명', 25),
#  ('bbq', 25),
#  ('위해', 25),
#  ('12', 25),
#  ('회식', 25),
#  ('도', 25),
#  ('간장치킨', 25),
#  ('튀김', 25),
#  ('일요일', 25),
#  ('줄', 24),
#  ('먹어도', 24),
#  ('4', 24),
#  ('com', 24),
#  ('샌드위치', 24),
#  ('BHC', 24),
#  ('댓글로', 24),
#  ('야식스타그램', 24),
#  ('그래도', 24),
#  ('혼술', 24),
#  ('날', 24),
#  ('bhc치킨', 24),
#  ('노랑통닭', 24),
#  ('친구', 24),
#  ('광주', 24),
#  ('friedchicken', 23),
#  ('이제', 23),
#  ('제일', 23),
#  ('같은', 23),
#  ('게시글', 23),
#  ('조금', 23),
#  ('교촌', 23),
#  ('최고', 23),
#  ('운동', 23),
#  ('다시', 23),
#  ('맛을', 23),
#  ('후레쉬쌈닭', 23),
#  ('닭다리', 23),
#  ('혼밥', 23),
#  ('와인', 23),
#  ('살짝', 22),
#  ('대구맛집', 22),
#  ('맞팔해요', 22),
#  ('세트', 22),
#  ('화', 22),
#  ('주문', 22),
#  ('디저트', 22),
#  ('DM', 22),
#  ('집밥스타그램', 22),
#  ('정답을', 22),
#  ('황금올리브', 22),
#  ('간장', 22),
#  ('가능합니다', 22),
#  ('여기', 22),
#  ('맛팔', 22),
#  ('a', 22),
#  ('에서', 22),
#  ('치즈볼', 21),
#  ('소스에', 21),
#  ('굽네치킨', 21),
#  ('절대', 21),
#  ('with', 21),
#  ('운영', 21),
#  ('근데', 21),
#  ('오운완', 21),
#  ('맛있어', 21),
#  ('옛날통닭', 21),
#  ('는', 21),
#  ('호식이두마리치킨', 21),
#  ('was', 21),
#  ('로', 20),
#  ('저희', 20),
#  ('행복한', 20),
#  ('오븐에', 20),
#  ('yummy', 20),
#  ('초밥', 20),
#  ('외식업', 20),
#  ('기획', 20),
#  ('론칭', 20),
#  ('매뉴얼', 20),
#  ('사후관리', 20),
#  ('매뉴', 20),
#  ('저녁은', 20),
#  ('열심히', 20),
#  ('월요일', 20),
#  ('치킨에', 20),
#  ('가지고', 20),
#  ('오후', 20),
#  ('11', 20),
#  ('우리', 20),
#  ('생일', 20),
#  ('7', 20),
#  ('주', 20),
#  ('30', 20),
#  ('해서', 20),
#  ('바삭', 20),
#  ('버거', 20),
#  ('있어', 20),
#  ('회식장소', 20),
#  ('맛있어요', 20),
#  ('무료', 20),
#  ('다른', 20),
#  ('여행', 20),
#  ('먹거리', 20),
#  ('000', 19),
#  ('처음', 19),
#  ('팔로워', 19),
#  ('댓글', 19),
#  ('않고', 19),
#  ('치', 19),
#  ('by', 19),
#  ('라면', 19),
#  ('브런치', 19),
#  ('어제', 19),
#  ('위에', 19),
#  ('계정', 19),
#  ('링크', 19),
#  ('16일', 19),
#  ('follow', 19),
#  ('16', 19),
#  ('전화', 19),
#  ('감사합니다', 19),
#  ('사실', 19),
#  ('먹었는데', 19),
#  ('양', 19),
#  ('사장님', 19),
#  ('술집', 19),
#  ('복', 19),
#  ('바삭하고', 19),
#  ('구운치킨', 19),
#  ('담백한', 19),
#  ('바베큐쌈닭', 19),
#  ('끝', 19),
#  ('쿠폰', 19),
#  ('부탁드립니다', 19),
#  ('배달맛집추천', 19),
#  ('강남', 19),
#  ('콜라', 19),
#  ('오사카', 19),
#  ('치킨은언제나옳다', 19),
#  ('만든', 18),
#  ('한마리', 18),
#  ('제가', 18),
#  ('게시물', 18),
#  ('고기', 18),
#  ('60계치킨', 18),
#  ('할', 18),
#  ('CCCV', 18),
#  ('복주머니를', 18),
#  ('팔로우이벤트', 18),
#  ('먹스타소통', 18),
#  ('직장인', 18),
#  ('허니콤보', 18),
#  ('로제', 18),
#  ('푸라닭', 18),
#  ('까지', 18),
#  ('18', 18),
#  ('햄버거', 18),
#  ('만에', 18),
#  ('하나', 18),
#  ('무한리필', 18),
#  ('족발', 18),
#  ('delicious', 18),
#  ('건강', 18),
#  ('누구나홀딱반한닭에서', 18),
#  ('본', 18),
#  ('010', 18),
#  ('한식뷔페', 18),
#  ('테라타워2', 18),
#  ('맛은', 18),
#  ('먹팔환영', 18),
#  ('다이어트메뉴', 18),
#  ('모든', 18),
#  ('때', 17),
#  ('치킨도', 17),
#  ('지코바', 17),
#  ('무조건', 17),
#  ('_', 17),
#  ('바삭한', 17),
#  ('외식', 17),
#  ('대구', 17),
#  ('치즈', 17),
#  ('ㅋㅋㅋ', 17),
#  ('힐링', 17),
#  ('혼자', 17),
#  ('해당', 17),
#  ('하는', 17),
#  ('닭을', 17),
#  ('푸드', 17),
#  ('에어프라이어', 17),
#  ('계속', 17),
#  ('최고의', 17),
#  ('위한', 17),
#  ('모두', 17),
#  ('프로필', 17),
#  ('김밥', 17),
#  ('식당', 17),
#  ('없이', 17),
#  ('하이볼', 17),
#  ('韓国料理', 17),
#  ('최애', 17),
#  ('ㅋ', 17),
#  ('매콤', 17),
#  ('배민', 17),
#  ('참여방법', 17),
#  ('fried', 17),
#  ('24', 17),
#  ('제품', 17),
#  ('해', 16),
#  ('맛있고', 16),
#  ('즐길', 16),
#  ('양이', 16),
#  ('그렇게', 16),
#  ('매주', 16),
#  ('02', 16),
#  ('10', 16),
#  ('in', 16),
#  ('dinner', 16),
#  ('인테리어', 16),
#  ('판매', 16),
#  ('맛있어서', 16),
#  ('꿀맛', 16),
#  ('있도록', 16),
#  ('확인', 16),
#  ('늘', 16),
#  ('韓国チキン', 16),
#  ('안주스타그램', 16),
#  ('없어서', 16),
#  ('사이드', 16),
#  ('한잔', 16),
#  ('반반', 16),
#  ('건강한', 16),
#  ('야식메뉴추천', 16),
#  ('쌈닭화히타', 16),
#  ('누구나홀딱반한닭으로', 16),
#  ('마무리', 16),
#  ('가득', 16),
#  ('보쌈', 16),
#  ('먹방투어', 16),
#  ('배달의', 15),
#  ('그램', 15),
#  ('I', 15),
#  ('Korean', 15),
#  ('자주', 15),
#  ('먹', 15),
#  ('완료', 15),
#  ('홍대', 15),
#  ('만들어', 15),
#  ('국물떡볶이', 15),
#  ('찾아', 15),
#  ('깨끗한', 15),
#  ('싶은', 15),
#  ('식사', 15),
#  ('서비스', 15),
#  ('겨울', 15),
#  ('때문에', 15),
#  ('볼', 15),
#  ('선물', 15),
#  ('넣고', 15),
#  ('거', 15),
#  ('is', 15),
#  ('koreanchicken', 15),
#  ('위치한', 15),
#  ('인기', 15),
#  ('부드러운', 15),
#  ('구운', 15),
#  ('naver', 15),
#  ('셀스타그램', 15),
#  ('목', 15),
#  ('첫', 15),
#  ('일루입니다', 15),
#  ('휴일', 15),
#  ('ㅎ', 15),
#  ('스테이크', 15),
#  ('먹방그램', 15),
#  ('데이트맛집', 15),
#  ('포차', 15),
#  ('있고', 15),
#  ('가게', 15),
#  ('치킨에맥주', 15),
#  ('난', 15),
#  ('대신', 14),
#  ('살', 14),
#  ('드디어', 14),
#  ('찬', 14),
#  ('제대로', 14),
#  ('한다', 14),
#  ('찾고', 14),
#  ('하세요', 14),
#  ('후회', 14),
#  ('소통해요', 14),
#  ('로제게티', 14),
#  ('분식', 14),
#  ('chick', 14),
#  ('촉촉한', 14),
#  ('수요일', 14),
#  ('맘스터치', 14),
#  ('리뉴얼', 14),
#  ('밀키트', 14),
#  ('기념', 14),
#  ('메뉴는', 14),
#  ('미리', 14),
#  ('언제나', 14),
#  ('아직', 14),
#  ('살이', 14),
#  ('돈까스', 14),
#  ('합니다', 14),
#  ('받으세요', 14),
#  ('퇴근', 14),
#  ('떡', 14),
#  ('오픈', 14),
#  ('있는데', 14),
#  ('내돈내산', 14),
#  ('of', 14),
#  ('가서', 14),
#  ('모임장소추천', 14),
#  ('않는', 14),
#  ('싸먹는', 14),
#  ('사이드메뉴', 14),
#  ('아', 14),
#  ('instagood', 14),
#  ('21', 14),
#  ('기프티콘', 14),
#  ('가족', 14),
#  ('The', 14),
#  ('소스를', 14),
#  ('구매', 14),
#  ('같아요', 14),
#  ('집에', 14),
#  ('구도로통닭', 14),
#  ('푸드렐라', 14),
#  ('닭발', 14),
#  ('비비큐', 14),
#  ('익선동맛집', 14),
#  ('블랙시크릿', 14),
#  ('리그램', 14),
#  ('청주', 14),
#  ('노래방', 14),
#  ('바른치킨', 14),
#  ('치킨으로', 13),
#  ('떡볶이맛집', 13),
#  ('매운맛', 13),
#  ('셀피', 13),
#  ('가득한', 13),
#  ('참', 13),
#  ('3종', 13),
#  ('사업', 13),
#  ('개인', 13),
#  ('더욱', 13),
#  ('남은', 13),
#  ('밥스타그램', 13),
#  ('퀴즈', 13),
#  ('토끼', 13),
#  ('사랑', 13),
#  ('치밥', 13),
#  ('이런', 13),
#  ('우리집', 13),
#  ('겉바속촉', 13),
#  ('말', 13),
#  ('korea', 13),
#  ('한끼', 13),
#  ('덕분에', 13),
#  ('거기에', 13),
#  ('지금', 13),
#  ('퇴근후', 13),
#  ('찐', 13),
#  ('꽤', 13),
#  ('의정부맛집', 13),
#  ('야식배달', 13),
#  ('로제쫄볶이', 13),
#  ('직접', 13),
#  ('14', 13),
#  ('시켰는데', 13),
#  ('회', 13),
#  ('얼스타그램', 13),
#  ('못', 13),
#  ('한식', 13),
#  ('SNS', 13),
#  ('일루', 13),
#  ('자담치킨', 13),
#  ('장소', 13),
#  ('블로그', 13),
#  ('가능', 13),
#  ('100', 13),
#  ('비비큐치킨', 13),
#  ('있다', 13),
#  ('신년회하자', 13),
#  ('모임맛집', 13),
#  ('신년이니까', 13),
#  ('치킨또띠아', 13),
#  ('팔로', 13),
#  ('좋다', 12),
#  ('스트레스', 12),
#  ('저도', 12),
#  ('날이', 12),
#  ('생각나는', 12),
#  ('고추바사삭', 12),
#  ('되는', 12),
#  ('추첨을', 12),
#  ('lunch', 12),
#  ('본사', 12),
#  ('카카오톡', 12),
#  ('먹었어요', 12),
#  ('화이팅', 12),
#  ('바삭바삭', 12),
#  ('생맥', 12),
#  ('식단', 12),
#  ('마음으로', 12),
#  ('안내', 12),
#  ('스토리', 12),
#  ('선팔맞팔', 12),
#  ('강서구맛집', 12),
#  ('양천구맛집', 12),
#  ('없습니다', 12),
#  ('음식입니다', 12),
#  ('해주시면', 12),
#  ('맞팔하면선팔', 12),
#  ('덕천맛집', 12),
#  ('헬스', 12),
#  ('캠핑', 12),
#  ('9', 12),
#  ('저', 12),
#  ('맛으로', 12),
#  ('추가', 12),
#  ('설', 12),
#  ('으로', 12),
#  ('닭고기', 12),
#  ('1인', 12),
#  ('짬뽕', 12),
#  ('있으니', 12),
#  ('온더테이블', 12),
#  ('사랑하는', 12),
#  ('부드럽고', 12),
#  ('젤', 12),
#  ('땅땅치킨', 12),
#  ('맛집리뷰', 12),
#  ('누구나홀딱반한닭의', 12),
#  ('분위기', 12),
#  ('쌈', 12),
#  ('추천드립니다', 12),
#  ('했는데', 12),
#  ('메뉴가', 12),
#  ('하지만', 12),
#  ('기본', 12),
#  ('치킨의', 12),
#  ('느낌', 12),
#  ('8', 12),
#  ('fff', 12),
#  ('먹음', 12),
#  ('닭꼬치', 12),
#  ('반반치킨', 12),
#  ('나오는', 12),
#  ('새로운', 12),
#  ('01월', 12),
#  ('여기는', 12),
#  ('골뱅이무침', 12),
#  ('보내세요', 12),
#  ('to', 12),
#  ('상품권', 12),
#  ('스타벅스', 12),
#  ('닭가슴살', 12),
#  ('가격', 12),
#  ('어떤', 12),
#  ('성신여대맛집', 12),
#  ('고대맛집', 12),
#  ('먹방여행', 12),
#  ('있음', 12),
#  ('감튀', 12),
#  ('13일', 12),
#  ('저녁식사', 12),
#  ('청대', 12),
#  ('동안', 12),
#  ('사람은', 12),
#  ('가성비', 11),
#  ('숯불바베큐', 11),
#  ('엽떡', 11),
#  ('먼저', 11),
#  ('행복', 11),
#  ('소스가', 11),
#  ('오는', 11),
#  ('이거', 11),
#  ('get_regrammer', 11),
#  ('또는', 11),
#  ('딸기', 11),
#  ('되어', 11),
#  ('분석', 11),
#  ('이메일', 11),
#  ('베이커리', 11),
#  ('총', 11),
#  ('좋반테러', 11),
#  ('사랑해', 11),
#  ('맛있음', 11),
#  ('건', 11),
#  ('먹자', 11),
#  ('마지막', 11),
#  ('생각보다', 11),
#  ('아닌', 11),
#  ('담아', 11),
#  ('상단', 11),
#  ('정답', 11),
#  ('방문', 11),
#  ('옛날', 11),
#  ('속은', 11),
#  ('소고기', 11),
#  ('육회', 11),
#  ('과일', 11),
#  ('앞으로', 11),
#  ('맛있네', 11),
#  ('북구에서', 11),
#  ('치킨하면은', 11),
#  ('인스타보고왔다고', 11),
#  ('몰래서비스', 11),
#  ('먹어보시면', 11),
#  ('안하십니다', 11),
#  ('ㆍㆍㆍㆍㆍㆍㆍㆍㆍ', 11),
#  ('화명동', 11),
#  ('구포동', 11),
#  ('만덕맛집', 11),
#  ('덕천카페', 11),
#  ('덕천', 11),
#  ('화명동맛집', 11),
#  ('구포', 11),
#  ('만덕', 11),
#  ('숯양두마리', 11),
#  ('주세요', 11),
#  ('나도', 11),
#  ('공유', 11),
#  ('클릭', 11),
#  ('콘소메이징', 11),
#  ('튀긴', 11),
#  ('19', 11),
#  ('맛도', 11),
#  ('기록', 11),
#  ('겉은', 11),
#  ('울산', 11),
#  ('뭐', 11),
#  ('페리카나', 11),
#  ('특히', 11),
#  ('일단', 11),
#  ('맛있었어요', 11),
#  ('완벽한인생', 11),
#  ('시원한', 11),
#  ('음식사진', 11),
#  ('않아', 11),
#  ('있다는', 11),
#  ('3명', 11),
#  ('개별', 11),
#  ('먹어서', 11),
#  ('듯', 11),
#  ('레드킹폭립', 11),
#  ('게', 11),
#  ('韓国', 11),
#  ('전기구이', 11),
#  ('생생정보', 11),
#  ('2차', 11),
#  ('향이', 11),
#  ('되겠습니다', 11),
#  ('당일', 11),
#  ('파닭', 11),
#  ('핫플', 11),
#  ('신나게', 11),
#  ('로제떡볶이', 11),
#  ('돈암동맛집', 11),
#  ('성신여대데이트', 11),
#  ('성신여대맛집닭만리', 11),
#  ('종로3가맛집', 11),
#  ('안암', 11),
#  ('뭔가', 11),
#  ('보고', 11),
#  ('받은', 11),
#  ('1명', 11),
#  ('언제', 11),
#  ('됩니다', 11),
#  ('후기', 11),
#  ('전부', 11),
#  ('여의도', 11),
#  ('치맥타임', 11),
#  ('빠진', 11),
#  ('フライドチキン', 11),
#  ('많아서', 11),
#  ('유튜브', 11),
#  ('광주맛집', 11),
#  ('치맥은진리', 11),
#  ('고양이', 11),
#  ('그럼', 10),
#  ('이번', 10),
#  ('매우', 10),
#  ('약간', 10),
#  ('성공적인', 10),
#  ('사업의', 10),
#  ('서포터가', 10),
#  ('소규모', 10),
#  ('아이템', 10),
#  ('선정', 10),
#  ('점포개발', 10),
#  ('전분야', 10),
#  ('타당성', 10),
#  ('컨셉', 10),
#  ('수익률', 10),
#  ('디자인', 10),
#  ('컵셉', 10),
#  ('상권분석', 10),
#  ('가맹사업', 10),
#  ('기업', 10),
#  ('인허가', 10),
#  ('HACCP', 10),
#  ('식품', 10),
#  ('제조', 10),
#  ('허가', 10),
#  ('yeol1221', 10),
#  ('nate', 10),
#  ('baristasoo10', 10),
#  ('소규모창업', 10),
#  ('햅썹인증', 10),
#  ('식품제조허가', 10),
#  ('신규브랜드', 10),
#  ('사업타당성', 10),
#  ('메뉴엔지니어링', 10),
#  ('메뉴원가', 10),
#  ('HMR', 10),
#  ('상권조사개발', 10),
#  ('개인매장', 10),
#  ('아이템개발', 10),
#  ('아니고', 10),
#  ('알차게', 10),
#  ('뼈', 10),
#  ('비', 10),
#  ('부천맛집', 10),
#  ('메뉴추천', 10),
#  ('아니', 10),
#  ('엄마가', 10),
#  ('쿡스타그램', 10),
#  ('얼마나', 10),
#  ('리뷰이벤트', 10),
#  ('여러분', 10),
#  ('방법1', 10),
#  ('친구를', 10),
#  ('이벤트그램', 10),
#  ('좋아요테러', 10),
#  ('맛의', 10),
#  ('좋아요그램', 10),
#  ('팔로우반사', 10),
#  ('좋아서', 10),
#  ('닭갈비', 10),
#  ('먹어본', 10),
#  ('거의', 10),
#  ('운동하는여자', 10),
#  ('김치', 10),
#  ('30분', 10),
#  ('느낄', 10),
#  ('1층', 10),
#  ('오뎅탕', 10),
#  ('볶음밥', 10),
#  ('새우', 10),
#  ('레시피', 10),
#  ('주는', 10),
#  ('선팔환영', 10),
#  ('instadaily', 10),
#  ('이벤트는', 10),
#  ('오리지널', 10),
#  ('누구나', 10),
#  ('양주맛집', 10),
#  ('감성', 10),
#  ('고소한', 10),
#  ('천안', 10),
#  ('치킨은옳다', 10),
#  ('맛있는치킨추천', 10),
#  ('신년회파티', 10),
#  ('저녁메뉴추천', 10),
#  ('음식도', 10),
#  ('강추', 10),
#  ('벌써', 10),
#  ('완성', 10),
#  ('시켜', 10),
#  ('파티', 10),
#  ('육아', 10),
#  ('소금', 10),
#  ('맛난', 10),
#  ('채널J', 10),
#  ('25L', 10),
#  ('콘서트', 10),
#  ('바이브맛봉', 10),
#  ('남양주맛집', 10),
#  ('송파맛집', 10),
#  ('문정동맛집', 10),
#  ('무제한', 10),
#  ('문정동', 10),
#  ('새벽6시까지', 10),
#  ('된', 10),
#  ('윙', 10),
#  ...]

# %%
rank_text = np.array(rank_text)
rank_text = rank_text[0:,0]

# %%
rank_text[1:11]
# Out:
# array(['치킨', '먹스타그램', '맛집', '맛스타그램', '수', '치킨맛집', '좋아요', '치맥', '일상', '먹방'],
#       dtype='<U133')
