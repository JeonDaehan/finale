# %% [markdown]
# - 모델 (은닉층 2개만)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Flatten, Dense, Input, concatenate, Dropout
from tensorflow.keras.layers import Conv2D, MaxPool2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical #원 핫 인코딩

from tensorflow.keras.applications import Xception, ResNet50, InceptionV3, MobileNet
from tensorflow.keras.callbacks import EarlyStopping

import shutil
import os
import cv2
import glob

from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
dataset_path = '/content/gdrive/MyDrive/Colab Notebooks/data'
shutil.copy(os.path.join(dataset_path, '0118food.zip'), '/content')
# Out:
# '/content/0118food.zip'

# %% [markdown]
# - food
#   - train
#     - burger
#     - chicken
#     - pasta
#     - pizza
#     - porkcutlet
#     - sushi
#     - tteokbokki
#   - test
#     - ..

# %%
# 꼭대기 폴더 'food' 안에 각 폴더+정답이름이미지폴더 만들어서 진행할 것

DATA_ROOT_DIR = os.path.join('/content', 'food') #꼭대기 폴더 지정
TRAIN_DATA_ROOT_DIR = os.path.join(DATA_ROOT_DIR, 'train')
TEST_DATA_ROOT_DIR = os.path.join(DATA_ROOT_DIR, 'test')

# %%
### food.zip 압축풀기
import zipfile
with zipfile.ZipFile(os.path.join('/content', '0118food.zip'), 'r') as target_file:
    target_file.extractall(TRAIN_DATA_ROOT_DIR)

# %%
# test폴더 - Pasta,Burger, ... 폴더 생성
os.mkdir(TEST_DATA_ROOT_DIR)
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'pasta'))
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'burger'))
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'chicken'))
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'sushi'))
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'pizza'))
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'porkcutlet'))
os.mkdir(os.path.join(TEST_DATA_ROOT_DIR, 'tteokbokki'))

# %%
import glob
ratio = 0.2

src_root_dir = "/content/food/train/"
dst_root_dir = "/content/food/test/"

label_name_list = os.listdir(TRAIN_DATA_ROOT_DIR)
for label_name in label_name_list:
    train_image_file_list = glob.glob(src_root_dir + label_name + "/*.*")
    print("==========================================================")
    
    print("total [%s] image file nums => [%s]"%(label_name, len(train_image_file_list)))
    
    split_num = int(ratio * len(train_image_file_list))
    print("분리할 갯수 : ", split_num)
    
    test_image_file_list = train_image_file_list[0:split_num]
    
    # move
    move_nums = 0
    for image_file in test_image_file_list:
        shutil.move(image_file, dst_root_dir + label_name)
        move_nums = move_nums + 1
        
    print("total move nums => ", move_nums)
    print("===========================================================")
# Out:
# ==========================================================
# total [sushi] image file nums => [3650]
# 분리할 갯수 :  730
# total move nums =>  730
# ===========================================================
# ==========================================================
# total [pasta] image file nums => [3562]
# 분리할 갯수 :  712
# total move nums =>  712
# ===========================================================
# ==========================================================
# total [chicken] image file nums => [3580]
# 분리할 갯수 :  716
# total move nums =>  716
# ===========================================================
# ==========================================================
# total [burger] image file nums => [4024]
# 분리할 갯수 :  804
# total move nums =>  804
# ===========================================================
# ==========================================================
# total [porkcutlet] image file nums => [4756]
# 분리할 갯수 :  951
# total move nums =>  951
# ===========================================================
# ==========================================================
# total [tteokbokki] image file nums => [3695]
# 분리할 갯수 :  739
# total move nums =>  739
# ===========================================================
# ==========================================================
# total [pizza] image file nums => [4814]
# 분리할 갯수 :  962
# total move nums =>  962
# ===========================================================

# %%
label_name_list
# Out:
# ['sushi', 'pasta', 'chicken', 'burger', 'porkcutlet', 'tteokbokki', 'pizza']

# %% [markdown]
# ## 훈련용 데이터

# %%
import cv2

train_data_list = []
train_label_list = [] #정답

class_dict = {'burger':0, 'chicken':1, 'pasta':2, 'pizza':3, 'porkcutlet':4, 'sushi':5, 'tteokbokki':6}

start_time = datetime.now()
for label_name in label_name_list:
  file_path = os.path.join(TRAIN_DATA_ROOT_DIR, label_name)
  img_file_list = glob.glob(file_path + '/*.*') #여기서 읽어온 것 아니고 읽어올 리스트만 가져온 것

  for img in img_file_list:
    src_img = cv2.imread(img, cv2.IMREAD_COLOR)
    src_img = cv2.resize(src_img, dsize=(128, 128)) #사진크기
    src_img = cv2.cvtColor(src_img, cv2.COLOR_BGR2RGB)

    train_data_list.append(src_img)
    train_label_list.append(class_dict[label_name]) #정답(문자-> 0, 1로 바꿔주기; dict[key값]으로 0, 1 가져오기. 간단하게 이렇게 할수도)
end_time = datetime.now()
print('Elapsed Time : ', end_time-start_time)
# Out:
# Elapsed Time :  0:00:41.420768

# %%
X_train = np.array(train_data_list).astype('float32')
y_train = np.array(train_label_list).astype('float32')

print(X_train.shape, y_train.shape)
# Out:
# (22467, 128, 128, 3) (22467,)

# %% [markdown]
# ## 테스트용 데이터

# %%
test_data_list = []
test_label_list = [] #정답

for label_name in label_name_list:
  file_path = os.path.join(TEST_DATA_ROOT_DIR, label_name)
  img_file_list = glob.glob(file_path + '/*.*') #여기서 읽어온 것 아니고 읽어올 리스트만 가져온 것

  for img in img_file_list:
    src_img = cv2.imread(img, cv2.IMREAD_COLOR)
    src_img = cv2.resize(src_img, dsize=(128, 128)) 
    src_img = cv2.cvtColor(src_img, cv2.COLOR_BGR2RGB)

    test_data_list.append(src_img)
    test_label_list.append(class_dict[label_name])

# %%
X_test = np.array(test_data_list).astype('float32')
y_test = np.array(test_label_list).astype('float32')

print(X_test.shape, y_test.shape)
# Out:
# (5614, 128, 128, 3) (5614,)

# %%
len(os.listdir(TRAIN_DATA_ROOT_DIR))
# Out:
# 7

# %%
# 정규화
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## 전이학습

# %%
# 모바일넷
IMAGE_WIDTH = 128
IMAGE_HEIGHT = 128

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_128_tf_no_top.h5
# 17225924/17225924 [==============================] - 1s 0us/step
# Model: "mobilenet_1.00_128"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv1 (Conv2D)              (None, 64, 64, 32)        864
#
#  conv1_bn (BatchNormalizatio  (None, 64, 64, 32)       128
#  n)
#
#  conv1_relu (ReLU)           (None, 64, 64, 32)        0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 64, 64, 32)       288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 64, 64, 32)       128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 64, 64, 32)        0
#
#  conv_pw_1 (Conv2D)          (None, 64, 64, 64)        2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 64, 64, 64)       256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 64, 64, 64)        0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 65, 65, 64)        0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 32, 32, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 32, 32, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 32, 32, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 32, 32, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 32, 32, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 32, 32, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 32, 32, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 33, 33, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 16, 16, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 16, 16, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 16, 16, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 16, 16, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 16, 16, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 16, 16, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 16, 16, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 16, 16, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 16, 16, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 16, 16, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 16, 16, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 16, 16, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 17, 17, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 8, 8, 256)        2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 8, 8, 256)        1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 8, 8, 256)         0
#
#  conv_pw_6 (Conv2D)          (None, 8, 8, 512)         131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 8, 8, 512)        4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_pw_7 (Conv2D)          (None, 8, 8, 512)         262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 8, 8, 512)        4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_pw_8 (Conv2D)          (None, 8, 8, 512)         262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 8, 8, 512)        4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_pw_9 (Conv2D)          (None, 8, 8, 512)         262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 8, 8, 512)        2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 8, 8, 512)         0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 8, 8, 512)        4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 8, 8, 512)        2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 8, 8, 512)         0
#
#  conv_pw_10 (Conv2D)         (None, 8, 8, 512)         262144
#
#  conv_pw_10_bn (BatchNormali  (None, 8, 8, 512)        2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 8, 8, 512)         0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 8, 8, 512)        4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 8, 8, 512)        2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 8, 8, 512)         0
#
#  conv_pw_11 (Conv2D)         (None, 8, 8, 512)         262144
#
#  conv_pw_11_bn (BatchNormali  (None, 8, 8, 512)        2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 8, 8, 512)         0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 9, 9, 512)        0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 4, 4, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 4, 4, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 4, 4, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 4, 4, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 4, 4, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 4, 4, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 4, 4, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 4, 4, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 4, 4, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 4, 4, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 4, 4, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 4, 4, 1024)        0
#
# =================================================================
# Total params: 3,228,864
# Trainable params: 3,206,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
class_nums = len(os.listdir(TRAIN_DATA_ROOT_DIR)) #정답 개수
print(class_nums)
# Out:
# 7

# %%
model = Sequential()

model.add(base_model)
model.add(GlobalAveragePooling2D())


model.add(Dense(64, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.25))

model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.25))



model.add(Dense(class_nums, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_128 (Functio  (None, 4, 4, 1024)       3228864
#  nal)
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                65600
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 3,303,687
# Trainable params: 3,281,799
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
from datetime import datetime
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


# earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss) 
#                               patience=5,          # 5회 Epoch동안 개선되지 않는다면 종료
#                              )


start_time = datetime.now()

hist = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=128) #callbacks=[earlystopping]

end_time = datetime.now()
print('elapsed time = ', end_time-start_time)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 53s 238ms/step - loss: 1.3462 - accuracy: 0.5140 - val_loss: 5.1940 - val_accuracy: 0.1664
# Epoch 2/50
# 176/176 [==============================] - 40s 226ms/step - loss: 0.8047 - accuracy: 0.7317 - val_loss: 2.1720 - val_accuracy: 0.4727
# Epoch 3/50
# 176/176 [==============================] - 40s 226ms/step - loss: 0.6467 - accuracy: 0.8053 - val_loss: 1.4939 - val_accuracy: 0.6128
# Epoch 4/50
# 176/176 [==============================] - 40s 230ms/step - loss: 0.5422 - accuracy: 0.8395 - val_loss: 1.7726 - val_accuracy: 0.3814
# Epoch 5/50
# 176/176 [==============================] - 40s 230ms/step - loss: 0.4880 - accuracy: 0.8549 - val_loss: 0.9672 - val_accuracy: 0.6840
# Epoch 6/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.4423 - accuracy: 0.8734 - val_loss: 1.0562 - val_accuracy: 0.6995
# Epoch 7/50
# 176/176 [==============================] - 41s 232ms/step - loss: 0.4096 - accuracy: 0.8842 - val_loss: 1.2022 - val_accuracy: 0.6432
# Epoch 8/50
# 176/176 [==============================] - 41s 232ms/step - loss: 0.3688 - accuracy: 0.8965 - val_loss: 1.0129 - val_accuracy: 0.7262
# Epoch 9/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.3206 - accuracy: 0.9114 - val_loss: 0.8967 - val_accuracy: 0.7485
# Epoch 10/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.2951 - accuracy: 0.9163 - val_loss: 1.0643 - val_accuracy: 0.6790
# Epoch 11/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.2610 - accuracy: 0.9283 - val_loss: 0.7153 - val_accuracy: 0.7629
# Epoch 12/50
# 176/176 [==============================] - 40s 230ms/step - loss: 0.2753 - accuracy: 0.9238 - val_loss: 0.8298 - val_accuracy: 0.7846
# Epoch 13/50
# 176/176 [==============================] - 41s 232ms/step - loss: 0.2256 - accuracy: 0.9383 - val_loss: 1.9883 - val_accuracy: 0.5278
# Epoch 14/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.2473 - accuracy: 0.9290 - val_loss: 0.6644 - val_accuracy: 0.8203
# Epoch 15/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.2214 - accuracy: 0.9398 - val_loss: 0.9924 - val_accuracy: 0.7722
# Epoch 16/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.2138 - accuracy: 0.9427 - val_loss: 0.5762 - val_accuracy: 0.8171
# Epoch 17/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.2147 - accuracy: 0.9427 - val_loss: 0.6296 - val_accuracy: 0.7923
# Epoch 18/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.2014 - accuracy: 0.9480 - val_loss: 0.8124 - val_accuracy: 0.7998
# Epoch 19/50
# 176/176 [==============================] - 41s 236ms/step - loss: 0.2000 - accuracy: 0.9454 - val_loss: 1.3994 - val_accuracy: 0.7121
# Epoch 20/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1808 - accuracy: 0.9509 - val_loss: 1.4432 - val_accuracy: 0.7173
# Epoch 21/50
# 176/176 [==============================] - 41s 236ms/step - loss: 0.1531 - accuracy: 0.9599 - val_loss: 1.0741 - val_accuracy: 0.7433
# Epoch 22/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1547 - accuracy: 0.9582 - val_loss: 0.8619 - val_accuracy: 0.7734
# Epoch 23/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.1802 - accuracy: 0.9517 - val_loss: 3.7623 - val_accuracy: 0.4874
# Epoch 24/50
# 176/176 [==============================] - 41s 232ms/step - loss: 0.1633 - accuracy: 0.9573 - val_loss: 1.0777 - val_accuracy: 0.7713
# Epoch 25/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.1405 - accuracy: 0.9615 - val_loss: 2.1475 - val_accuracy: 0.5926
# Epoch 26/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1328 - accuracy: 0.9649 - val_loss: 0.7003 - val_accuracy: 0.8274
# Epoch 27/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1582 - accuracy: 0.9588 - val_loss: 0.4344 - val_accuracy: 0.8929
# Epoch 28/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.1298 - accuracy: 0.9675 - val_loss: 0.6264 - val_accuracy: 0.8546
# Epoch 29/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.1263 - accuracy: 0.9662 - val_loss: 0.8615 - val_accuracy: 0.7683
# Epoch 30/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.1165 - accuracy: 0.9701 - val_loss: 0.4984 - val_accuracy: 0.8614
# Epoch 31/50
# 176/176 [==============================] - 41s 232ms/step - loss: 0.1495 - accuracy: 0.9607 - val_loss: 0.6861 - val_accuracy: 0.8400
# Epoch 32/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1230 - accuracy: 0.9672 - val_loss: 0.7108 - val_accuracy: 0.8067
# Epoch 33/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1118 - accuracy: 0.9713 - val_loss: 0.6523 - val_accuracy: 0.8295
# Epoch 34/50
# 176/176 [==============================] - 41s 233ms/step - loss: 0.0998 - accuracy: 0.9735 - val_loss: 1.0652 - val_accuracy: 0.7834
# Epoch 35/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1212 - accuracy: 0.9686 - val_loss: 1.2464 - val_accuracy: 0.7877
# Epoch 36/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1030 - accuracy: 0.9728 - val_loss: 1.3725 - val_accuracy: 0.8033
# Epoch 37/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1170 - accuracy: 0.9698 - val_loss: 0.5087 - val_accuracy: 0.8507
# Epoch 38/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.0951 - accuracy: 0.9752 - val_loss: 0.6309 - val_accuracy: 0.8420
# Epoch 39/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1027 - accuracy: 0.9746 - val_loss: 0.6204 - val_accuracy: 0.8438
# Epoch 40/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.0870 - accuracy: 0.9772 - val_loss: 1.6103 - val_accuracy: 0.6988
# Epoch 41/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1131 - accuracy: 0.9716 - val_loss: 0.8912 - val_accuracy: 0.8030
# Epoch 42/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1203 - accuracy: 0.9688 - val_loss: 0.4910 - val_accuracy: 0.8787
# Epoch 43/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1006 - accuracy: 0.9757 - val_loss: 1.0149 - val_accuracy: 0.8103
# Epoch 44/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.1026 - accuracy: 0.9744 - val_loss: 0.8182 - val_accuracy: 0.8342
# Epoch 45/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.0936 - accuracy: 0.9764 - val_loss: 0.7519 - val_accuracy: 0.8261
# Epoch 46/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.0774 - accuracy: 0.9802 - val_loss: 0.8080 - val_accuracy: 0.7994
# Epoch 47/50
# 176/176 [==============================] - 41s 235ms/step - loss: 0.0776 - accuracy: 0.9811 - val_loss: 0.7494 - val_accuracy: 0.8123
# Epoch 48/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.0685 - accuracy: 0.9821 - val_loss: 0.5215 - val_accuracy: 0.8799
# Epoch 49/50
# 176/176 [==============================] - 41s 232ms/step - loss: 0.0905 - accuracy: 0.9764 - val_loss: 1.0549 - val_accuracy: 0.8073
# Epoch 50/50
# 176/176 [==============================] - 41s 234ms/step - loss: 0.1302 - accuracy: 0.9666 - val_loss: 0.7881 - val_accuracy: 0.8107
# elapsed time =  0:34:26.355498

# %%
# 0.9881 / 0.9478 :  (food.zip/yespizz.h5) epochs=50, batch_size=128, learning_rate=0.00001
# 0.9927  0.9526 :  (0118food.zip) 은닉층 2개(64, 128) epochs=50, batch_size=128, learning_rate=0.00001
# 0.9666  0.8107 :  (0118food.zip) 은닉층 2개(64, 128) epochs=50, batch_size=128, learning_rate=0.01

# %%
model.save('finalfood_hidden2_lr001.h5')

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 2, 1)
plt.title("LOSS TREND")
plt.xlabel("epochs")
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label='train_loss')
plt.plot(hist.history['val_loss'], label='validation_loss')
plt.legend(loc='best')

plt.subplot(1, 2, 2)
plt.title("ACCURACY TREND")
plt.xlabel("epochs")
plt.ylabel('accuracy')
plt.grid()

plt.plot(hist.history['accuracy'], label='train_accuracy')
plt.plot(hist.history['val_accuracy'], label='validation_accuracy')
plt.legend(loc='best')

# %% [markdown]
# ## predict1 - 진행X

# %%
# 이미지 불러오기, 색상변환, 크기조정, 정규화
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
pred_img_list = []
pred_img_name_list = glob.glob('./predict/*.*')
for i in range(len(pred_img_name_list)):
    src_img = cv2.imread(pred_img_name_list[i], cv2.IMREAD_COLOR)
    src_img = cv2.resize(src_img, dsize=(IMAGE_HEIGHT, IMAGE_WIDTH))
    src_img = cv2.cvtColor(src_img, cv2.COLOR_BGR2RGB)
    src_img = src_img / 255.0
    pred_img_list.append(src_img)
len(pred_img_list)
# Out:
# 36

# %%
pred_img_array = np.array(pred_img_list) #3차원 한번더 묶어서 4차원으로 차원 맞추기
pred_img_array.shape
# Out:
# (36, 128, 128, 3)

# %%
pred = model.predict(pred_img_array)
# Out:
# 2/2 [==============================] - 1s 182ms/step

# %%
# {'burger':0, 'chicken':1, 'pasta':2, 'pizza':3, 'porkcutlet':4, 'sushi':5, 'tteokbokki':6}

class_name = ['burger', 'chicken', 'pasta', 'pizza', 'porkcutlet', 'sushi', 'tteokbokki']
for i in range(len(pred)):
    class_index = np.argmax(pred[i])
    print(str(i+1) + '번째 : ' + class_name[class_index], pred[i].max())
# Out:
# 1번째 : pizza 0.99999774
# 2번째 : tteokbokki 0.9999987
# 3번째 : porkcutlet 0.99996257
# 4번째 : pizza 0.99992836
# 5번째 : pasta 0.99999857
# 6번째 : tteokbokki 1.0
# 7번째 : pizza 0.99549687
# 8번째 : sushi 1.0
# 9번째 : tteokbokki 0.9345794
# 10번째 : pasta 0.9999999
# 11번째 : sushi 0.99999964
# 12번째 : tteokbokki 0.9999999
# 13번째 : chicken 0.999874
# 14번째 : pasta 0.9999871
# 15번째 : sushi 0.99949956
# 16번째 : pizza 0.9997292
# 17번째 : pizza 0.9999932
# 18번째 : porkcutlet 0.99967146
# 19번째 : pasta 0.99999964
# 20번째 : pasta 0.9994691
# 21번째 : pasta 1.0
# 22번째 : tteokbokki 1.0
# 23번째 : pizza 0.9547805
# 24번째 : pasta 0.9999993
# 25번째 : pizza 0.92842174
# 26번째 : porkcutlet 0.9973139
# 27번째 : pasta 0.8573204
# 28번째 : tteokbokki 0.99998474
# 29번째 : sushi 1.0
# 30번째 : chicken 0.999998
# 31번째 : pizza 0.9966882
# 32번째 : pasta 0.9999981
# 33번째 : burger 0.5884311
# 34번째 : sushi 0.9999999
# 35번째 : burger 0.7181613
# 36번째 : pasta 0.7248162

# %%
# 상위 3개 예측값
top3 = 3
for i in range(len(pred)):
    sorted_index = pred[i].argsort()
    sorted_index = sorted_index[::-1]
    print("===================================")
    print(str(i+1) + '번째')
    print(sorted_index)
    for j in range(top3):
        pred_val = pred[i, sorted_index[j]]
        class_index = sorted_index[j]
        print("예측값 : ", class_name[class_index], pred_val)
# Out:
# ===================================
# 1번째
# [3 2 6 4 0 5 1]
# 예측값 :  pizza 0.99999774
# 예측값 :  pasta 8.295222e-07
# 예측값 :  tteokbokki 6.620841e-07
# ===================================
# 2번째
# [6 2 1 0 4 3 5]
# 예측값 :  tteokbokki 0.9999987
# 예측값 :  pasta 1.0506533e-06
# 예측값 :  chicken 1.3242516e-07
# ===================================
# 3번째
# [4 6 0 3 5 1 2]
# 예측값 :  porkcutlet 0.99996257
# 예측값 :  tteokbokki 1.5714815e-05
# 예측값 :  burger 1.3444157e-05
# ===================================
# 4번째
# [3 1 2 0 6 4 5]
# 예측값 :  pizza 0.99992836
# 예측값 :  chicken 5.5623084e-05
# 예측값 :  pasta 1.4224393e-05
# ===================================
# 5번째
# [2 6 3 0 5 4 1]
# 예측값 :  pasta 0.99999857
# 예측값 :  tteokbokki 9.206568e-07
# 예측값 :  pizza 3.3883381e-07
# ===================================
# 6번째
# [6 2 4 1 3 0 5]
# 예측값 :  tteokbokki 1.0
# 예측값 :  pasta 3.1246195e-08
# 예측값 :  porkcutlet 7.718384e-09
# ===================================
# 7번째
# [3 2 0 6 4 1 5]
# 예측값 :  pizza 0.99549687
# 예측값 :  pasta 0.004167356
# 예측값 :  burger 0.00012208708
# ===================================
# 8번째
# [5 0 2 4 6 1 3]
# 예측값 :  sushi 1.0
# 예측값 :  burger 7.872229e-11
# 예측값 :  pasta 4.3361287e-11
# ===================================
# 9번째
# [6 2 1 3 0 5 4]
# 예측값 :  tteokbokki 0.9345794
# 예측값 :  pasta 0.04854603
# 예측값 :  chicken 0.010740777
# ===================================
# 10번째
# [2 6 4 3 5 1 0]
# 예측값 :  pasta 0.9999999
# 예측값 :  tteokbokki 4.4139227e-08
# 예측값 :  porkcutlet 2.5903805e-08
# ===================================
# 11번째
# [5 4 2 6 0 3 1]
# 예측값 :  sushi 0.99999964
# 예측값 :  porkcutlet 1.8442661e-07
# 예측값 :  pasta 5.563057e-08
# ===================================
# 12번째
# [6 2 0 4 1 3 5]
# 예측값 :  tteokbokki 0.9999999
# 예측값 :  pasta 1.0729582e-07
# 예측값 :  burger 2.6111055e-08
# ===================================
# 13번째
# [1 6 2 5 0 4 3]
# 예측값 :  chicken 0.999874
# 예측값 :  tteokbokki 6.50814e-05
# 예측값 :  pasta 3.8650724e-05
# ===================================
# 14번째
# [2 6 1 5 4 3 0]
# 예측값 :  pasta 0.9999871
# 예측값 :  tteokbokki 1.2433158e-05
# 예측값 :  chicken 1.9736181e-07
# ===================================
# 15번째
# [5 4 0 6 2 3 1]
# 예측값 :  sushi 0.99949956
# 예측값 :  porkcutlet 0.0004705737
# 예측값 :  burger 1.5842046e-05
# ===================================
# 16번째
# [3 2 4 5 0 6 1]
# 예측값 :  pizza 0.9997292
# 예측값 :  pasta 0.00013819979
# 예측값 :  porkcutlet 6.655682e-05
# ===================================
# 17번째
# [3 2 0 4 5 6 1]
# 예측값 :  pizza 0.9999932
# 예측값 :  pasta 5.398559e-06
# 예측값 :  burger 7.1727925e-07
# ===================================
# 18번째
# [4 0 6 2 3 5 1]
# 예측값 :  porkcutlet 0.99967146
# 예측값 :  burger 0.00024790826
# 예측값 :  tteokbokki 4.2014926e-05
# ===================================
# 19번째
# [2 3 4 5 6 0 1]
# 예측값 :  pasta 0.99999964
# 예측값 :  pizza 1.5027919e-07
# 예측값 :  porkcutlet 1.2345924e-07
# ===================================
# 20번째
# [2 4 0 5 6 3 1]
# 예측값 :  pasta 0.9994691
# 예측값 :  porkcutlet 0.00038483017
# 예측값 :  burger 6.0882503e-05
# ===================================
# 21번째
# [2 5 3 4 6 1 0]
# 예측값 :  pasta 1.0
# 예측값 :  sushi 4.064447e-10
# 예측값 :  pizza 1.8563938e-10
# ===================================
# 22번째
# [6 2 1 3 0 4 5]
# 예측값 :  tteokbokki 1.0
# 예측값 :  pasta 3.3610033e-09
# 예측값 :  chicken 1.5146129e-10
# ===================================
# 23번째
# [3 2 6 0 1 4 5]
# 예측값 :  pizza 0.9547805
# 예측값 :  pasta 0.044511076
# 예측값 :  tteokbokki 0.0006006362
# ===================================
# 24번째
# [2 6 5 0 3 4 1]
# 예측값 :  pasta 0.9999993
# 예측값 :  tteokbokki 3.740603e-07
# 예측값 :  sushi 2.1597292e-07
# ===================================
# 25번째
# [3 2 6 4 5 0 1]
# 예측값 :  pizza 0.92842174
# 예측값 :  pasta 0.071421266
# 예측값 :  tteokbokki 8.4862986e-05
# ===================================
# 26번째
# [4 5 0 6 3 1 2]
# 예측값 :  porkcutlet 0.9973139
# 예측값 :  sushi 0.001157365
# 예측값 :  burger 0.0011084662
# ===================================
# 27번째
# [2 3 0 4 5 6 1]
# 예측값 :  pasta 0.8573204
# 예측값 :  pizza 0.14004424
# 예측값 :  burger 0.0012358949
# ===================================
# 28번째
# [6 2 1 0 5 3 4]
# 예측값 :  tteokbokki 0.99998474
# 예측값 :  pasta 7.6092556e-06
# 예측값 :  chicken 5.8164746e-06
# ===================================
# 29번째
# [5 6 0 4 2 1 3]
# 예측값 :  sushi 1.0
# 예측값 :  tteokbokki 7.815535e-09
# 예측값 :  burger 7.4994295e-09
# ===================================
# 30번째
# [1 6 5 0 2 4 3]
# 예측값 :  chicken 0.999998
# 예측값 :  tteokbokki 1.2660496e-06
# 예측값 :  sushi 3.362189e-07
# ===================================
# 31번째
# [3 2 4 0 6 5 1]
# 예측값 :  pizza 0.9966882
# 예측값 :  pasta 0.0030040236
# 예측값 :  porkcutlet 0.00021698471
# ===================================
# 32번째
# [2 4 3 6 0 5 1]
# 예측값 :  pasta 0.9999981
# 예측값 :  porkcutlet 6.6125904e-07
# 예측값 :  pizza 5.327364e-07
# ===================================
# 33번째
# [0 4 1 6 3 5 2]
# 예측값 :  burger 0.5884311
# 예측값 :  porkcutlet 0.2337453
# 예측값 :  chicken 0.14728259
# ===================================
# 34번째
# [5 0 4 6 2 1 3]
# 예측값 :  sushi 0.9999999
# 예측값 :  burger 1.2438083e-07
# 예측값 :  porkcutlet 4.4774495e-08
# ===================================
# 35번째
# [0 1 5 6 2 3 4]
# 예측값 :  burger 0.7181613
# 예측값 :  chicken 0.13514754
# 예측값 :  sushi 0.054891545
# ===================================
# 36번째
# [2 3 4 5 0 6 1]
# 예측값 :  pasta 0.7248162
# 예측값 :  pizza 0.25909787
# 예측값 :  porkcutlet 0.015758296

# %%
plt.figure(figsize=(13,13))

for i in range(len(pred)):
    plt.subplot(round(len(pred)/6), 6, i+1)
    class_index = np.argmax(pred[i])
    strTitle = str('{0:0.2f}'.format(100*max(pred[i]))) + '%'
    plt.title(str(i+1) + ') ' + class_name[class_index] + ' ' + strTitle) 
    plt.imshow(pred_img_list[i])
    plt.axis('off')
plt.tight_layout()

# %%
model = load_model('finalfood_hidden2.h5')

# %% [markdown]
# ## predict2

# %%
# 이미지 불러오기, 색상변환, 크기조정, 정규화
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
pred_img_list = []
pred_img_name_list = glob.glob('./predict2/*.*')
for i in range(len(pred_img_name_list)):
    src_img = cv2.imread(pred_img_name_list[i], cv2.IMREAD_COLOR)
    src_img = cv2.resize(src_img, dsize=(IMAGE_HEIGHT, IMAGE_WIDTH))
    src_img = cv2.cvtColor(src_img, cv2.COLOR_BGR2RGB)
    src_img = src_img / 255.0
    pred_img_list.append(src_img)
len(pred_img_list)
# Out:
# 36

# %%
pred_img_array = np.array(pred_img_list) #3차원 한번더 묶어서 4차원으로 차원 맞추기
pred_img_array.shape
# Out:
# (36, 128, 128, 3)

# %%
pred = model.predict(pred_img_array)
# Out:
# 2/2 [==============================] - 1s 190ms/step

# %%
# {'burger':0, 'chicken':1, 'pasta':2, 'pizza':3, 'porkcutlet':4, 'sushi':5, 'tteokbokki':6}

class_name = ['burger', 'chicken', 'pasta', 'pizza', 'porkcutlet', 'sushi', 'tteokbokki']
for i in range(len(pred)):
    class_index = np.argmax(pred[i])
    print(str(i+1) + '번째 : ' + class_name[class_index], pred[i].max())
# Out:
# 1번째 : pizza 0.99002457
# 2번째 : chicken 0.82368916
# 3번째 : porkcutlet 0.9957054
# 4번째 : tteokbokki 0.47746703
# 5번째 : tteokbokki 1.0
# 6번째 : pizza 0.99002457
# 7번째 : sushi 0.99998057
# 8번째 : chicken 0.83491325
# 9번째 : tteokbokki 0.90787375
# 10번째 : pizza 0.64711803
# 11번째 : tteokbokki 1.0
# 12번째 : chicken 0.94620353
# 13번째 : tteokbokki 0.9991641
# 14번째 : sushi 0.6944591
# 15번째 : pizza 0.6073187
# 16번째 : chicken 0.97547513
# 17번째 : porkcutlet 0.9776012
# 18번째 : tteokbokki 0.9999999
# 19번째 : pasta 0.75512683
# 20번째 : porkcutlet 0.6224987
# 21번째 : pasta 0.71278566
# 22번째 : tteokbokki 1.0
# 23번째 : chicken 0.7960022
# 24번째 : tteokbokki 0.9197923
# 25번째 : pizza 0.9908971
# 26번째 : porkcutlet 0.9900919
# 27번째 : pizza 0.38443506
# 28번째 : sushi 0.9367233
# 29번째 : chicken 0.93689865
# 30번째 : pizza 0.99072087
# 31번째 : porkcutlet 0.70616466
# 32번째 : porkcutlet 0.8172406
# 33번째 : porkcutlet 0.636372
# 34번째 : pizza 0.49780703
# 35번째 : chicken 0.9767785
# 36번째 : pizza 0.9907811

# %%
# 상위 3개 예측값
top3 = 3
for i in range(len(pred)):
    sorted_index = pred[i].argsort()
    sorted_index = sorted_index[::-1]
    print("===================================")
    print(str(i+1) + '번째')
    print(sorted_index)
    for j in range(top3):
        pred_val = pred[i, sorted_index[j]]
        class_index = sorted_index[j]
        print("예측값 : ", class_name[class_index], pred_val)
# Out:
# ===================================
# 1번째
# [3 2 5 1 6 4 0]
# 예측값 :  pizza 0.99002457
# 예측값 :  pasta 0.0064926124
# 예측값 :  sushi 0.0012735118
# ===================================
# 2번째
# [1 6 4 2 0 3 5]
# 예측값 :  chicken 0.82368916
# 예측값 :  tteokbokki 0.15842699
# 예측값 :  porkcutlet 0.010098351
# ===================================
# 3번째
# [4 3 1 6 2 5 0]
# 예측값 :  porkcutlet 0.9957054
# 예측값 :  pizza 0.0018105796
# 예측값 :  chicken 0.0017004921
# ===================================
# 4번째
# [6 2 1 3 4 0 5]
# 예측값 :  tteokbokki 0.47746703
# 예측값 :  pasta 0.42340064
# 예측값 :  chicken 0.05795606
# ===================================
# 5번째
# [6 2 5 4 3 1 0]
# 예측값 :  tteokbokki 1.0
# 예측값 :  pasta 3.184651e-33
# 예측값 :  sushi 0.0
# ===================================
# 6번째
# [3 2 5 1 6 4 0]
# 예측값 :  pizza 0.99002457
# 예측값 :  pasta 0.0064926124
# 예측값 :  sushi 0.0012735118
# ===================================
# 7번째
# [5 3 4 1 0 2 6]
# 예측값 :  sushi 0.99998057
# 예측값 :  pizza 6.0250777e-06
# 예측값 :  porkcutlet 4.8421857e-06
# ===================================
# 8번째
# [1 6 2 4 3 0 5]
# 예측값 :  chicken 0.83491325
# 예측값 :  tteokbokki 0.107079655
# 예측값 :  pasta 0.030934284
# ===================================
# 9번째
# [6 2 1 0 3 4 5]
# 예측값 :  tteokbokki 0.90787375
# 예측값 :  pasta 0.07687282
# 예측값 :  chicken 0.008611899
# ===================================
# 10번째
# [3 2 6 1 4 5 0]
# 예측값 :  pizza 0.64711803
# 예측값 :  pasta 0.17434482
# 예측값 :  tteokbokki 0.085783504
# ===================================
# 11번째
# [6 2 1 5 4 3 0]
# 예측값 :  tteokbokki 1.0
# 예측값 :  pasta 3.7244995e-25
# 예측값 :  chicken 3.172495e-37
# ===================================
# 12번째
# [1 6 2 4 0 3 5]
# 예측값 :  chicken 0.94620353
# 예측값 :  tteokbokki 0.039917618
# 예측값 :  pasta 0.0072544403
# ===================================
# 13번째
# [6 2 1 4 3 0 5]
# 예측값 :  tteokbokki 0.9991641
# 예측값 :  pasta 0.0007692681
# 예측값 :  chicken 6.631196e-05
# ===================================
# 14번째
# [5 0 2 3 1 6 4]
# 예측값 :  sushi 0.6944591
# 예측값 :  burger 0.081977814
# 예측값 :  pasta 0.061581366
# ===================================
# 15번째
# [3 2 4 6 1 5 0]
# 예측값 :  pizza 0.6073187
# 예측값 :  pasta 0.19621512
# 예측값 :  porkcutlet 0.07761419
# ===================================
# 16번째
# [1 6 2 4 0 3 5]
# 예측값 :  chicken 0.97547513
# 예측값 :  tteokbokki 0.017719798
# 예측값 :  pasta 0.003940591
# ===================================
# 17번째
# [4 1 0 3 6 2 5]
# 예측값 :  porkcutlet 0.9776012
# 예측값 :  chicken 0.014650312
# 예측값 :  burger 0.007177151
# ===================================
# 18번째
# [6 2 1 4 3 0 5]
# 예측값 :  tteokbokki 0.9999999
# 예측값 :  pasta 1.3061131e-07
# 예측값 :  chicken 3.3846687e-10
# ===================================
# 19번째
# [2 6 1 3 4 0 5]
# 예측값 :  pasta 0.75512683
# 예측값 :  tteokbokki 0.19978042
# 예측값 :  chicken 0.025713123
# ===================================
# 20번째
# [4 2 6 3 1 0 5]
# 예측값 :  porkcutlet 0.6224987
# 예측값 :  pasta 0.15654635
# 예측값 :  tteokbokki 0.09279185
# ===================================
# 21번째
# [2 6 1 3 4 0 5]
# 예측값 :  pasta 0.71278566
# 예측값 :  tteokbokki 0.21299098
# 예측값 :  chicken 0.037781164
# ===================================
# 22번째
# [6 2 5 4 3 1 0]
# 예측값 :  tteokbokki 1.0
# 예측값 :  pasta 3.619112e-29
# 예측값 :  sushi 0.0
# ===================================
# 23번째
# [1 6 4 2 0 3 5]
# 예측값 :  chicken 0.7960022
# 예측값 :  tteokbokki 0.085096
# 예측값 :  porkcutlet 0.052976575
# ===================================
# 24번째
# [6 2 1 3 4 0 5]
# 예측값 :  tteokbokki 0.9197923
# 예측값 :  pasta 0.07086217
# 예측값 :  chicken 0.0067428667
# ===================================
# 25번째
# [3 2 1 5 4 6 0]
# 예측값 :  pizza 0.9908971
# 예측값 :  pasta 0.005753325
# 예측값 :  chicken 0.0009430702
# ===================================
# 26번째
# [4 3 1 6 2 5 0]
# 예측값 :  porkcutlet 0.9900919
# 예측값 :  pizza 0.0046368726
# 예측값 :  chicken 0.0030547287
# ===================================
# 27번째
# [3 6 2 1 4 5 0]
# 예측값 :  pizza 0.38443506
# 예측값 :  tteokbokki 0.24977922
# 예측값 :  pasta 0.23845892
# ===================================
# 28번째
# [5 3 1 2 0 4 6]
# 예측값 :  sushi 0.9367233
# 예측값 :  pizza 0.017946335
# 예측값 :  chicken 0.01272754
# ===================================
# 29번째
# [1 6 4 2 0 3 5]
# 예측값 :  chicken 0.93689865
# 예측값 :  tteokbokki 0.044262815
# 예측값 :  porkcutlet 0.008341714
# ===================================
# 30번째
# [3 2 1 5 4 6 0]
# 예측값 :  pizza 0.99072087
# 예측값 :  pasta 0.0055221096
# 예측값 :  chicken 0.0011910727
# ===================================
# 31번째
# [4 2 1 3 6 5 0]
# 예측값 :  porkcutlet 0.70616466
# 예측값 :  pasta 0.08067882
# 예측값 :  chicken 0.080146365
# ===================================
# 32번째
# [4 1 3 2 6 0 5]
# 예측값 :  porkcutlet 0.8172406
# 예측값 :  chicken 0.1229374
# 예측값 :  pizza 0.026709171
# ===================================
# 33번째
# [4 1 3 2 6 0 5]
# 예측값 :  porkcutlet 0.636372
# 예측값 :  chicken 0.22748016
# 예측값 :  pizza 0.04707373
# ===================================
# 34번째
# [3 6 2 1 4 5 0]
# 예측값 :  pizza 0.49780703
# 예측값 :  tteokbokki 0.19981098
# 예측값 :  pasta 0.15672973
# ===================================
# 35번째
# [1 6 4 2 0 3 5]
# 예측값 :  chicken 0.9767785
# 예측값 :  tteokbokki 0.012065073
# 예측값 :  porkcutlet 0.00509138
# ===================================
# 36번째
# [3 2 1 5 4 6 0]
# 예측값 :  pizza 0.9907811
# 예측값 :  pasta 0.0057821022
# 예측값 :  chicken 0.0010170358

# %%
plt.figure(figsize=(13,13))

for i in range(len(pred)):
    plt.subplot(round(len(pred)/6), 6, i+1)
    class_index = np.argmax(pred[i])
    strTitle = str('{0:0.2f}'.format(100*max(pred[i]))) + '%'
    plt.title(str(i+1) + ') ' + class_name[class_index] + ' ' + strTitle) 
    plt.imshow(pred_img_list[i])
    plt.axis('off')
plt.tight_layout()

# %% [markdown]
# ## 오답리스트

# %%
X_test.shape
# Out:
# (5614, 128, 128, 3)

# %%
predicted_val
# Out:
# array([5, 5, 5, ..., 6, 3, 3])

# %%
##### 오답 리스트

ret_val = model.predict(X_test)
print('type(ret_val) = ', type(ret_val), ', ret_val.shape = ', ret_val.shape)


predicted_val = np.argmax(ret_val, axis=1)  
prediction_label_comp_val = np.equal(predicted_val, y_test) #맞은거?


index_label_prediction_list = [ [index, y_test[index], predicted_val[index] ]  
    for index, result in enumerate(prediction_label_comp_val)  if result == False ]

print(len(index_label_prediction_list)) #틀린거?

print(index_label_prediction_list)

false_data_index = np.random.randint(len(index_label_prediction_list))

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + \
' , prediction = ' + str(prediction)

img = X_test[mnist_index]

plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# 176/176 [==============================] - 2s 13ms/step
# type(ret_val) =  <class 'numpy.ndarray'> , ret_val.shape =  (5614, 7)
# 1063
# [[23, 5.0, 1], [36, 5.0, 6], [51, 5.0, 2], [63, 5.0, 0], [72, 5.0, 3], [77, 5.0, 6], [90, 5.0, 6], [108, 5.0, 0], [116, 5.0, 3], [161, 5.0, 0], [165, 5.0, 0], [195, 5.0, 0], [214, 5.0, 2], [218, 5.0, 6], [219, 5.0, 0], [229, 5.0, 3], [238, 5.0, 2], [242, 5.0, 3], [256, 5.0, 3], [315, 5.0, 0], [330, 5.0, 0], [343, 5.0, 6], [352, 5.0, 0], [354, 5.0, 6], [355, 5.0, 1], [376, 5.0, 0], [377, 5.0, 0], [410, 5.0, 0], [438, 5.0, 0], [442, 5.0, 0], [444, 5.0, 0], [455, 5.0, 2], [489, 5.0, 6], [495, 5.0, 0], [507, 5.0, 0], [534, 5.0, 2], [552, 5.0, 1], [558, 5.0, 0], [562, 5.0, 3], [572, 5.0, 0], [575, 5.0, 0], [577, 5.0, 3], [592, 5.0, 3], [595, 5.0, 0], [603, 5.0, 0], [613, 5.0, 6], [632, 5.0, 0], [634, 5.0, 1], [646, 5.0, 6], [647, 5.0, 6], [655, 5.0, 3], [673, 5.0, 0], [685, 5.0, 6], [703, 5.0, 3], [709, 5.0, 0], [725, 5.0, 2], [730, 2.0, 6], [732, 2.0, 4], [733, 2.0, 6], [734, 2.0, 6], [736, 2.0, 6], [737, 2.0, 6], [738, 2.0, 1], [739, 2.0, 6], [740, 2.0, 6], [741, 2.0, 4], [743, 2.0, 6], [745, 2.0, 6], [746, 2.0, 1], [747, 2.0, 6], [749, 2.0, 0], [751, 2.0, 1], [752, 2.0, 6], [755, 2.0, 6], [756, 2.0, 6], [757, 2.0, 6], [758, 2.0, 1], [759, 2.0, 1], [760, 2.0, 3], [761, 2.0, 6], [762, 2.0, 6], [764, 2.0, 6], [765, 2.0, 1], [766, 2.0, 6], [767, 2.0, 0], [768, 2.0, 6], [769, 2.0, 6], [771, 2.0, 6], [772, 2.0, 6], [773, 2.0, 3], [774, 2.0, 6], [775, 2.0, 1], [776, 2.0, 6], [777, 2.0, 6], [778, 2.0, 0], [779, 2.0, 1], [780, 2.0, 6], [781, 2.0, 1], [783, 2.0, 6], [785, 2.0, 6], [786, 2.0, 6], [787, 2.0, 3], [788, 2.0, 6], [789, 2.0, 1], [793, 2.0, 6], [794, 2.0, 6], [795, 2.0, 6], [796, 2.0, 3], [797, 2.0, 6], [798, 2.0, 6], [799, 2.0, 6], [802, 2.0, 1], [803, 2.0, 1], [804, 2.0, 3], [805, 2.0, 0], [806, 2.0, 1], [808, 2.0, 6], [809, 2.0, 1], [811, 2.0, 1], [812, 2.0, 1], [813, 2.0, 6], [814, 2.0, 3], [815, 2.0, 6], [816, 2.0, 1], [817, 2.0, 0], [818, 2.0, 6], [819, 2.0, 6], [820, 2.0, 1], [821, 2.0, 6], [822, 2.0, 6], [823, 2.0, 6], [824, 2.0, 3], [825, 2.0, 6], [826, 2.0, 6], [827, 2.0, 6], [829, 2.0, 1], [832, 2.0, 6], [833, 2.0, 6], [834, 2.0, 6], [835, 2.0, 1], [836, 2.0, 6], [837, 2.0, 1], [838, 2.0, 6], [840, 2.0, 6], [841, 2.0, 6], [842, 2.0, 4], [843, 2.0, 1], [844, 2.0, 6], [847, 2.0, 6], [848, 2.0, 6], [849, 2.0, 6], [853, 2.0, 1], [854, 2.0, 1], [855, 2.0, 0], [856, 2.0, 3], [857, 2.0, 3], [859, 2.0, 6], [860, 2.0, 6], [861, 2.0, 1], [862, 2.0, 3], [863, 2.0, 3], [864, 2.0, 6], [865, 2.0, 6], [867, 2.0, 6], [868, 2.0, 6], [870, 2.0, 1], [871, 2.0, 1], [872, 2.0, 6], [873, 2.0, 6], [874, 2.0, 3], [875, 2.0, 6], [877, 2.0, 0], [878, 2.0, 3], [879, 2.0, 6], [880, 2.0, 6], [881, 2.0, 6], [885, 2.0, 1], [886, 2.0, 6], [887, 2.0, 6], [889, 2.0, 1], [890, 2.0, 6], [891, 2.0, 4], [893, 2.0, 6], [894, 2.0, 1], [895, 2.0, 6], [896, 2.0, 1], [898, 2.0, 6], [899, 2.0, 3], [900, 2.0, 3], [901, 2.0, 6], [902, 2.0, 6], [904, 2.0, 6], [906, 2.0, 3], [907, 2.0, 6], [910, 2.0, 3], [911, 2.0, 6], [912, 2.0, 6], [913, 2.0, 6], [915, 2.0, 6], [917, 2.0, 6], [919, 2.0, 6], [921, 2.0, 6], [922, 2.0, 6], [923, 2.0, 3], [924, 2.0, 6], [925, 2.0, 4], [926, 2.0, 6], [928, 2.0, 1], [929, 2.0, 6], [930, 2.0, 1], [931, 2.0, 6], [932, 2.0, 1], [935, 2.0, 1], [938, 2.0, 3], [939, 2.0, 6], [941, 2.0, 5], [942, 2.0, 6], [943, 2.0, 6], [944, 2.0, 6], [946, 2.0, 1], [947, 2.0, 6], [948, 2.0, 0], [949, 2.0, 6], [951, 2.0, 1], [952, 2.0, 6], [953, 2.0, 6], [954, 2.0, 1], [955, 2.0, 6], [956, 2.0, 6], [957, 2.0, 6], [958, 2.0, 6], [959, 2.0, 6], [960, 2.0, 3], [961, 2.0, 6], [962, 2.0, 3], [964, 2.0, 6], [965, 2.0, 6], [966, 2.0, 6], [967, 2.0, 1], [968, 2.0, 6], [969, 2.0, 6], [971, 2.0, 6], [972, 2.0, 1], [973, 2.0, 6], [974, 2.0, 6], [975, 2.0, 0], [976, 2.0, 6], [977, 2.0, 3], [978, 2.0, 1], [979, 2.0, 4], [980, 2.0, 6], [982, 2.0, 3], [984, 2.0, 6], [985, 2.0, 6], [986, 2.0, 6], [989, 2.0, 6], [990, 2.0, 4], [992, 2.0, 1], [993, 2.0, 6], [995, 2.0, 6], [996, 2.0, 1], [997, 2.0, 1], [998, 2.0, 1], [999, 2.0, 6], [1000, 2.0, 0], [1004, 2.0, 6], [1005, 2.0, 6] ...
